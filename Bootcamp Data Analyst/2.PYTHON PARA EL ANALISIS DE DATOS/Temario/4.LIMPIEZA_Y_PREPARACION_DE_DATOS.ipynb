# %% [markdown]
# | **Inicio** | **atrás 3** |
# |----------- |-------------- |
# | [🏠](../../../README.md) | [⏪](./3.VISUALIZACION_EN_PYTHON_(MATPLOTLIB).ipynb)|

# %% [markdown]
# # **4. LIMPIEZA Y PREPARACIÓN DE DATOS**

# %% [markdown]
# ## **Analítica descriptiva vs predictiva**

# %% [markdown]
# La analítica descriptiva y la analítica predictiva son dos enfoques diferentes en el análisis de datos. A continuación, se explica cada uno de estos conceptos:
#
# 1. **Analítica descriptiva:**
#
# La analítica descriptiva se centra en comprender y describir los datos existentes. Su objetivo principal es resumir, organizar y visualizar los datos de manera significativa para obtener información sobre patrones, tendencias y características clave de los datos. Esta técnica se utiliza para responder preguntas como "¿Qué ha sucedido en el pasado?" y "¿Cuál es el estado actual de los datos?". Algunas técnicas comunes utilizadas en la analítica descriptiva son:
#
# * **Estadísticas descriptivas:** cálculo de medidas como la media, la mediana, la desviación estándar, entre otros, para resumir los datos.
# * **Gráficos y visualizaciones:** representación visual de los datos utilizando gráficos como histogramas, diagramas de dispersión, gráficos de barras, entre otros.
# * **Tablas de frecuencia:** recuento de la frecuencia de valores únicos en una variable categórica.
#
# **Ejemplo:** Supongamos que tenemos un conjunto de datos que contiene información sobre ventas mensuales de una tienda. Utilizando técnicas de analítica descriptiva, podemos calcular la media, la mediana y la desviación estándar de las ventas para tener una idea de las ventas promedio y su variabilidad. También podemos crear gráficos de líneas para visualizar la tendencia de las ventas a lo largo del tiempo.
#
# 2. **Analítica predictiva:**
#
# La analítica predictiva se centra en predecir eventos futuros o resultados desconocidos basados en los datos históricos. Utiliza técnicas y modelos estadísticos, de aprendizaje automático y minería de datos para realizar estas predicciones. Este enfoque se utiliza para responder preguntas como "¿Qué sucederá en el futuro?" y "¿Cuál es la probabilidad de que ocurra un evento específico?". Algunas técnicas comunes utilizadas en la analítica predictiva son:
#
# * **Regresión:** construcción de modelos matemáticos para predecir valores numéricos continuos.
# * **Clasificación:** construcción de modelos para predecir la pertenencia a una clase o categoría específica.
# * **Series de tiempo:** análisis de patrones y tendencias en datos secuenciales para hacer predicciones futuras.
#
# **Ejemplo:** Supongamos que tenemos datos históricos de ventas mensuales de una tienda durante varios años. Utilizando técnicas de analítica predictiva, podemos construir un modelo de regresión para predecir las ventas futuras en función de factores como el mes del año, el gasto en publicidad y el precio de los productos. Este modelo nos permitirá hacer pronósticos y tomar decisiones comerciales basadas en esas predicciones.
#
# En resumen, la analítica descriptiva se enfoca en comprender los datos existentes y resumirlos, mientras que la analítica predictiva se centra en predecir eventos futuros utilizando técnicas y modelos estadísticos. Ambos enfoques son importantes en el análisis de datos y se complementan entre sí para obtener información valiosa y respuestas a preguntas específicas.

# %% [markdown]
# ![Analítica descriptiva vs predictiva](../img/Anal%C3%ADtica%20descriptiva%20vs%20predictiva.webp "Analítica descriptiva vs predictiva")

# %% [markdown]
# ## **Visualización de datos**

# %% [markdown]
# La visualización de datos es una técnica fundamental en el análisis de datos que nos permite representar gráficamente la información de manera clara y concisa. La visualización nos ayuda a comprender patrones, tendencias y relaciones en los datos, lo que facilita la toma de decisiones y la comunicación de resultados.
#
# En Python, existen varias bibliotecas populares para la visualización de datos, siendo `Matplotlib` y `Seaborn` dos de las más utilizadas. A continuación, te mostraré ejemplos de visualización de datos utilizando estas bibliotecas.
#
# * **Visualización básica con Matplotlib:**
#
# Matplotlib es una biblioteca ampliamente utilizada para crear gráficos en Python. Permite generar una amplia variedad de gráficos, desde simples hasta complejos. A continuación se muestra un ejemplo básico de visualización de datos utilizando Matplotlib:

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = [1, 2, 3, 4, 5]
y = [10, 8, 6, 4, 2]

# Crear un gráfico de líneas con personalización
plt.plot(x, y, marker='o', linestyle='--', color='green', label='Datos')

# Configurar etiquetas y título
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Gráfico de Líneas Personalizado')

# Añadir leyenda
plt.legend()

# Añadir una cuadrícula
plt.grid(True, linestyle='--', alpha=0.7)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# En este ejemplo, creamos un gráfico de líneas utilizando los datos de ejemplo. Configuramos las etiquetas de los ejes `X` e `Y`, así como el título del gráfico. Luego, utilizamos `plt.show()` para mostrar el gráfico.
#
# 2. **Visualización de datos con Seaborn:**
#
# Seaborn es una biblioteca basada en Matplotlib que ofrece una interfaz más sencilla para la creación de gráficos estadísticos. Proporciona estilos y paletas de colores atractivos de forma predeterminada. Aquí tienes un ejemplo de visualización de datos utilizando Seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Datos de ejemplo
tips = sns.load_dataset('tips')

# Crear un gráfico de barras con personalización
sns.barplot(x='day', y='total_bill', data=tips, palette='Set2')  # Cambiar el conjunto de colores

# Configurar etiquetas y título
plt.xlabel('Día')
plt.ylabel('Cuenta total')
plt.title('Gráfico de Barras Personalizado')

# Añadir etiquetas en las barras
ax = plt.gca()  # Obtener el eje actual
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# En este ejemplo, utilizamos el conjunto de datos "`tips`" de Seaborn, que contiene información sobre las propinas en un restaurante. Creamos un gráfico de barras que muestra la cuenta total promedio por día de la semana. Configuramos las etiquetas de los ejes `X` e `Y`, así como el título del gráfico. Luego, utilizamos `plt.show()` para mostrar el gráfico.
#
# Estos son solo ejemplos básicos de visualización de datos en Python utilizando Matplotlib y Seaborn. Estas bibliotecas ofrecen una amplia gama de gráficos y opciones de personalización para adaptarse a tus necesidades específicas. Puedes explorar más funciones y tipos de gráficos en la documentación oficial de Matplotlib y Seaborn para crear visualizaciones más complejas y detalladas.

# %% [markdown]
# ## **La estadística y el aprendizaje de máquina**

# %% [markdown]
# La estadística y el aprendizaje de máquina son dos disciplinas interrelacionadas que se utilizan para analizar datos y hacer predicciones basadas en patrones y relaciones estadísticas.
#
# La estadística es el estudio de los datos, su análisis y la interpretación de los resultados. Proporciona métodos y técnicas para resumir y describir los datos, así como para inferir conclusiones sobre una población más amplia a partir de una muestra. Algunos conceptos estadísticos comunes incluyen medidas de tendencia central, como la media y la mediana, así como medidas de dispersión, como la desviación estándar y el rango.
#
# El aprendizaje de máquina, por otro lado, es una rama de la inteligencia artificial que se centra en el desarrollo de algoritmos y modelos que pueden aprender de los datos y hacer predicciones o tomar decisiones sin ser programados explícitamente. Utiliza técnicas estadísticas y computacionales para extraer patrones y conocimientos de los datos, y se puede aplicar a una amplia gama de problemas, como la clasificación, la regresión y el clustering.
#
# Aquí tienes un ejemplo en código Python que ilustra la aplicación de estadística y aprendizaje de máquina utilizando la biblioteca scikit-learn:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Generar datos de ejemplo
np.random.seed(0)
X = np.linspace(0, 10, 100).reshape(-1, 1)
y = 2 * X + np.random.normal(0, 1, size=(100, 1))

# Ajustar un modelo de regresión lineal
model = LinearRegression()
model.fit(X, y)

# Predecir los valores y utilizando el modelo ajustado
y_pred = model.predict(X)

# Visualizar los datos y la línea de regresión con personalización
plt.scatter(X, y, label='Datos', color='blue')  # Cambiar el color de los puntos
plt.plot(X, y_pred, color='red', linestyle='--', linewidth=2, label='Regresión lineal')  # Cambiar el color y estilo de la línea
plt.xlabel('X')
plt.ylabel('y')
plt.title('Regresión Lineal Personalizada')
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# En este ejemplo, generamos datos de ejemplo con una relación lineal y añadimos algo de ruido. Luego, utilizamos el modelo de regresión lineal de scikit-learn para ajustar una línea recta que mejor se ajuste a los datos. Finalmente, visualizamos los datos y la línea de regresión utilizando matplotlib.
#
# Este es solo un ejemplo básico de cómo se pueden combinar la estadística y el aprendizaje de máquina para realizar análisis y predicciones. La aplicación de estas disciplinas puede ser mucho más compleja y abarcar una amplia gama de problemas y técnicas. Sin embargo, este ejemplo proporciona una idea de cómo se pueden utilizar en conjunto para analizar datos y hacer predicciones basadas en patrones y relaciones estadísticas.

# %% [markdown]
# ## **Aprendizaje supervisado y no supervisado**

# %% [markdown]
# El aprendizaje supervisado y no supervisado son dos enfoques fundamentales en el campo del aprendizaje automático (machine learning) para analizar datos y extraer información significativa.
#
# 1. **Aprendizaje Supervisado:**
#
# El aprendizaje supervisado implica el uso de un conjunto de datos de entrenamiento etiquetado, donde cada muestra está asociada con una etiqueta o valor objetivo conocido. El objetivo es construir un modelo que pueda aprender a predecir las etiquetas de nuevas muestras basándose en las características de entrada. Algunos ejemplos de algoritmos de aprendizaje supervisado son la regresión lineal, el árbol de decisiones y las máquinas de vectores de soporte (SVM).
# Aquí tienes un ejemplo en código Python que ilustra el uso de un algoritmo de aprendizaje supervisado (regresión lineal):

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Generar datos de ejemplo
np.random.seed(0)
X = np.linspace(0, 10, 100).reshape(-1, 1)
y = 2 * X + np.random.normal(0, 1, size=(100, 1))

# Ajustar un modelo de regresión lineal
model = LinearRegression()
model.fit(X, y)

# Predecir los valores y utilizando el modelo ajustado
y_pred = model.predict(X)

# Personalizar el gráfico de regresión lineal
plt.figure(figsize=(8, 6))  # Cambiar el tamaño de la figura
plt.scatter(X, y, label='Datos', color='blue', marker='o')  # Cambiar el color y el marcador de los puntos
plt.plot(X, y_pred, color='red', linestyle='--', linewidth=2, label='Regresión lineal')  # Cambiar el color y estilo de la línea
plt.xlabel('X', fontsize=14)  # Cambiar el tamaño de la fuente de las etiquetas
plt.ylabel('y', fontsize=14)
plt.title('Regresión Lineal Personalizada', fontsize=16)  # Cambiar el tamaño de la fuente del título
plt.legend(fontsize=12)  # Cambiar el tamaño de la fuente de la leyenda
plt.grid(True, linestyle='--', alpha=0.7)  # Añadir una cuadrícula con estilo

# Añadir anotaciones
plt.annotate('Datos de ejemplo', xy=(3, 6), xytext=(4, 8),
             arrowprops=dict(facecolor='black', shrink=0.05), fontsize=12)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# En este ejemplo, generamos datos de ejemplo con una relación lineal y añadimos algo de ruido. Luego, utilizamos el modelo de regresión lineal de scikit-learn para ajustar una línea recta que mejor se ajuste a los datos. Finalmente, visualizamos los datos y la línea de regresión utilizando matplotlib.
#
# 2. **Aprendizaje No Supervisado:**
#
# El aprendizaje no supervisado implica el uso de un conjunto de datos sin etiquetas o valores objetivo conocidos. El objetivo principal es descubrir patrones, estructuras o relaciones ocultas en los datos. En lugar de predecir valores específicos, el aprendizaje no supervisado se centra en agrupar datos similares o encontrar representaciones latentes de los datos. Algunos ejemplos de algoritmos de aprendizaje no supervisado son el clustering (agrupamiento) y la reducción de la dimensionalidad.
# Aquí tienes un ejemplo en código Python que ilustra el uso de un algoritmo de aprendizaje no supervisado (K-means clustering):

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Generar datos de ejemplo
np.random.seed(0)
X = np.concatenate([np.random.normal(0, 1, size=(100, 2)), np.random.normal(3, 1, size=(100, 2))])

# Aplicar K-means clustering
kmeans = KMeans(n_clusters=2, n_init=10)  # Establecer n_init explícitamente
kmeans.fit(X)

# Obtener las etiquetas de los clusters
labels = kmeans.labels_

# Personalizar el gráfico de K-means clustering
plt.figure(figsize=(8, 6))  # Cambiar el tamaño de la figura
scatter = plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', edgecolor='black', s=50)  # Cambiar el color y agregar contorno a los puntos
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='x', color='red', label='Centroides', s=200)  # Cambiar el color y el tamaño de los centroides
plt.xlabel('X1', fontsize=14)  # Cambiar el tamaño de la fuente de las etiquetas
plt.ylabel('X2', fontsize=14)
plt.title('K-means Clustering Personalizado', fontsize=16)  # Cambiar el tamaño de la fuente del título
plt.legend(fontsize=12)  # Cambiar el tamaño de la fuente de la leyenda
plt.grid(True, linestyle='--', alpha=0.7)  # Añadir una cuadrícula con estilo

# Añadir anotaciones
for i, txt in enumerate(labels):
    plt.annotate(txt, (X[i, 0], X[i, 1]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='white')

# Añadir barra de color
cbar = plt.colorbar(scatter)
cbar.set_label('Cluster', rotation=270, labelpad=15)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# En este ejemplo, generamos datos de ejemplo con dos grupos distintos y utilizamos el algoritmo de clustering K-means para agrupar los datos en dos clusters. Luego, visualizamos los datos y los centroides de los clusters utilizando matplotlib.
#
# Estos son solo dos ejemplos básicos para ilustrar el aprendizaje supervisado y no supervisado en Python. Hay muchos otros algoritmos y técnicas disponibles en las bibliotecas de aprendizaje automático de Python (como scikit-learn) que se pueden utilizar para una amplia gama de problemas. La elección del enfoque adecuado (supervisado o no supervisado) dependerá de la naturaleza de los datos y del objetivo del análisis.

# %% [markdown]
# ![Aprendizaje supervisado y no supervisado](../img/Aprendizaje%20supervisado%20y%20no%20supervisado.webp "Aprendizaje supervisado y no supervisado")

# %% [markdown]
# ## **Identificación de problemas de clasificación, regresión y segmentación**

# %% [markdown]
# La identificación de problemas de clasificación, regresión y segmentación es una parte fundamental del análisis de datos y el aprendizaje automático. Estos problemas se refieren a diferentes tipos de tareas que se pueden abordar utilizando algoritmos de clasificación, regresión y segmentación. Aquí te explico cada uno de ellos con ejemplos en código Python y gráficas.
#
# 1. **Problemas de Clasificación:**
#
# Los problemas de clasificación implican asignar una etiqueta o categoría a una muestra de datos en función de sus características. El objetivo es construir un modelo que pueda aprender a clasificar nuevas muestras correctamente. Algunos ejemplos de problemas de clasificación son la detección de spam en correos electrónicos, el reconocimiento facial y la clasificación de imágenes.
#
# Aquí tienes un ejemplo en código Python que muestra el problema de clasificación utilizando el algoritmo de Support Vector Machine (SVM):

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.svm import SVC

# Generar datos de ejemplo para clasificación binaria
X, y = make_classification(n_samples=100, n_features=2, n_informative=2, n_redundant=0, random_state=0)

# Entrenar un modelo de SVM para clasificación
model = SVC(kernel='linear')
model.fit(X, y)

# Crear una malla para visualizar las regiones de decisión
h = 0.02  # tamaño del paso en la malla
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])

# Visualizar las regiones de decisión y los datos de entrenamiento
Z = Z.reshape(xx.shape)
plt.figure(figsize=(8, 6))  # Tamaño de la figura
plt.contourf(xx, yy, Z, alpha=0.8, cmap=plt.cm.Paired)  # Cambiar el mapa de colores
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap=plt.cm.Paired)  # Añadir bordes a los puntos
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Problema de Clasificación')
plt.colorbar()  # Añadir barra de color para la leyenda
plt.show()

# %% [markdown]
# En este ejemplo, generamos datos de ejemplo utilizando la función `make_classification` de scikit-learn para crear un conjunto de datos con dos clases. Luego, entrenamos un modelo de SVM lineal utilizando el algoritmo SVC. Finalmente, visualizamos las regiones de decisión y los datos de entrenamiento utilizando matplotlib.
#
# 2. **Problemas de Regresión:**
#
# Los problemas de regresión implican predecir un valor numérico o continuo basado en las características de entrada. El objetivo es construir un modelo que pueda aprender a predecir valores numéricos para nuevas muestras. Algunos ejemplos de problemas de regresión son la predicción del precio de una vivienda basada en características como el tamaño y la ubicación, la predicción de ventas en función de la publicidad y la predicción de la demanda de productos.
# Aquí tienes un ejemplo en código Python que muestra el problema de regresión utilizando el algoritmo de regresión lineal:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Generar datos de ejemplo para regresión lineal
X = np.linspace(0, 10, 100)
y = 3 * X + np.random.normal(0, 1, 100)

# Entrenar un modelo de regresión lineal
model = LinearRegression()
model.fit(X.reshape(-1, 1), y)

# Predecir los valores para nuevos datos
X_new = np.linspace(0, 10, 100)
y_pred = model.predict(X_new.reshape(-1, 1))

# Personalizar la gráfica
plt.figure(figsize=(8, 6))  # Tamaño de la figura
plt.scatter(X, y, label='Datos', alpha=0.7)  # Añadir transparencia a los puntos
plt.plot(X_new, y_pred, color='red', linewidth=2, label='Regresión lineal')  # Añadir ancho de línea y etiqueta
plt.xlabel('X')
plt.ylabel('y')
plt.title('Problema de Regresión')
plt.legend()  # Añadir leyenda
plt.grid(True)  # Mostrar cuadrícula en el fondo
plt.xlim(0, 11)  # Establecer límites de los ejes X
plt.ylim(0, 35)  # Establecer límites de los ejes y
plt.show()

# %% [markdown]
# En este ejemplo, generamos datos de ejemplo para una regresión lineal utilizando la función `linspace` de NumPy para crear una secuencia de valores en el rango [0, 10]. Luego, agregamos ruido a los datos utilizando `np.random.normal`. A continuación, entrenamos un modelo de regresión lineal utilizando el algoritmo `LinearRegression` de scikit-learn. Finalmente, visualizamos los datos y la línea de regresión utilizando matplotlib.
#
# 3. **Problemas de Segmentación:**
#
# Los problemas de segmentación implican dividir un conjunto de datos en grupos o segmentos basados en sus similitudes. El objetivo es agrupar muestras similares juntas y diferenciarlas de otras muestras. Algunos ejemplos de problemas de segmentación son la segmentación de clientes en grupos basados en su comportamiento de compra, la segmentación de imágenes en regiones de interés y la segmentación de documentos en categorías.
#
# Aquí tienes un ejemplo en código Python que muestra el problema de segmentación utilizando el algoritmo de clustering K-means:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# Generar datos de ejemplo para segmentación
X, y = make_blobs(n_samples=100, centers=3, random_state=0)

# Aplicar el algoritmo de clustering K-means
kmeans = KMeans(n_clusters=3, n_init=10)
kmeans.fit(X)

# Obtener las etiquetas de los clusters
labels = kmeans.labels_

# Personalizar la gráfica
plt.figure(figsize=(8, 6))  # Tamaño de la figura
scatter = plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', edgecolors='k', s=50, alpha=0.8)  # Personalizar puntos
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='x', color='red', label='Centroides', s=200)  # Personalizar centroides
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Problema de Segmentación')
plt.legend()
plt.colorbar(scatter)  # Añadir barra de color
plt.grid(True)  # Mostrar cuadrícula en el fondo
plt.show()

# %% [markdown]
# En este ejemplo, generamos datos de ejemplo utilizando la función `make_blobs` de scikit-learn para crear un conjunto de datos con tres grupos distintos. Luego, aplicamos el algoritmo de clustering K-means utilizando KMeans de scikit-learn. Finalmente, visualizamos los datos y los clusters utilizando matplotlib.
#
# Estos son solo ejemplos básicos para ilustrar los problemas de clasificación, regresión y segmentación en Python. Hay muchos otros algoritmos y técnicas disponibles en las bibliotecas de aprendizaje automático de Python (como scikit-learn) que se pueden utilizar para abordar una amplia gama de problemas. La elección del enfoque adecuado dependerá de la naturaleza de los datos y del objetivo del análisis.

# %% [markdown]
# | **Inicio** | **atrás 3** |
# |----------- |-------------- |
# | [🏠](../../../README.md) | [⏪](./3.VISUALIZACION_EN_PYTHON_(MATPLOTLIB).ipynb)|
