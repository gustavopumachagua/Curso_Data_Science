# %% [markdown]
# | **Inicio** | **atrás 17** | **Siguiente 19** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./17.Series_de_Pandas.ipynb)| [⏩](./19.Arreglos.ipynb)|

# %% [markdown]
# # **18. Explora y Visualiza Relaciones Estadísticas con Seaborn de Python**

# %% [markdown]
# ## **Introducción a la visualización de datos**

# %% [markdown]
# La visualización de datos es una herramienta muy importante en el análisis de datos, ya que permite mostrar de manera gráfica la información de una manera más fácil de interpretar y comprender. En el contexto de la programación con Python, existen varias librerías para la visualización de datos, como por ejemplo Matplotlib, Seaborn y Plotly.
#
# Matplotlib es una de las librerías más populares para la visualización de datos en Python, y es muy flexible y potente. Con Matplotlib, se pueden crear gráficos de líneas, barras, histogramas, gráficos de dispersión, entre otros.
#
# Seaborn es otra librería para la visualización de datos en Python, que se basa en Matplotlib. Seaborn se enfoca en gráficos estadísticos y es especialmente útil para la visualización de grandes conjuntos de datos.
#
# Plotly es una librería para la visualización de datos en Python que permite crear gráficos interactivos y dinámicos. Con Plotly, se pueden crear gráficos 3D, mapas y gráficos animados.
#
# En general, la visualización de datos es una herramienta muy importante en el análisis de datos, ya que permite obtener una mejor comprensión de la información que se está analizando. Con las librerías de visualización de datos en Python, es posible crear gráficos de alta calidad y personalizables para mostrar la información de la manera más efectiva posible.

# %% [markdown]
# ## **Tipos de gráficas en Seaborn**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un dataset de ejemplo
tips = sns.load_dataset("tips")

# Personalizar el gráfico de barras
plt.figure(figsize=(8, 6))  # Tamaño de la figura
sns.barplot(x="day", y="total_bill", data=tips, errorbar=None, palette="husl")  # Quita los intervalos de confianza y personaliza la paleta de colores
plt.title('Total Bill by Day')  # Título
plt.xlabel('Day of the Week')  # Etiqueta del eje X
plt.ylabel('Total Bill')  # Etiqueta del eje Y
plt.xticks(rotation=45)  # Rotar las etiquetas del eje X para una mejor visualización
plt.show()

# %%
# Personalizar el gráfico de líneas
plt.figure(figsize=(8, 6))
sns.lineplot(x="total_bill", y="tip", data=tips, color='green', marker='o', markersize=8, linestyle='--')
plt.title('Tip vs Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
# Personalizar el gráfico de dispersión
plt.figure(figsize=(8, 6))
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="sex", style="time", s=100)
plt.title('Tip vs Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
# Personalizar el gráfico de violín
plt.figure(figsize=(8, 6))
sns.violinplot(x="day", y="total_bill", data=tips, palette="Set2")
plt.title('Total Bill by Day')
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill')
plt.show()

# %%
import warnings

# Desactivar las advertencias de disposición automática
warnings.filterwarnings("ignore", category=UserWarning)

# Crear la figura y el gráfico
plt.figure(figsize=(8, 6))
sns.displot(tips["total_bill"], kind="kde", fill=True, color="purple")
plt.title('Distribution of Total Bill')
plt.xlabel('Total Bill')
plt.show()

# %%
import numpy as np
# Filtrar solo las columnas numéricas para el cálculo de correlación
numeric_columns = tips.select_dtypes(include=[np.number])

# Personalizar el gráfico de correlación
plt.figure(figsize=(8, 6))
sns.heatmap(numeric_columns.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## **Datos a visualizar**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Crear un dataframe de ejemplo
data = pd.DataFrame({
    "x": [1, 2, 3, 4, 5],
    "y": [2, 4, 6, 8, 10],
    "z": [1, 3, 5, 7, 9]
})

# Personalizar el gráfico de barras
sns.barplot(x="x", y="y", data=data, color='c')  # Cambiar el color de las barras
plt.title('Gráfico de Barras Personalizado')  # Título
plt.xlabel('Eje X Personalizado')  # Etiqueta del eje X
plt.ylabel('Eje Y Personalizado')  # Etiqueta del eje Y
plt.show()

# %%
# Personalizar el gráfico de líneas
sns.lineplot(x="x", y="y", data=data, color='g', linestyle='--')  # Cambiar color y estilo de línea
plt.title('Gráfico de Líneas Personalizado')
plt.xlabel('Eje X Personalizado')
plt.ylabel('Eje Y Personalizado')
plt.show()

# %%
# Personalizar el gráfico de dispersión
sns.scatterplot(x="x", y="y", data=data, color='m', s=100)  # Cambiar color y tamaño de los puntos
plt.title('Gráfico de Dispersión Personalizado')
plt.xlabel('Eje X Personalizado')
plt.ylabel('Eje Y Personalizado')
plt.show()

# %%
# Personalizar el gráfico de violín
sns.violinplot(data=data, palette="Set2")  # Cambiar la paleta de colores
plt.title('Gráfico de Violín Personalizado')
plt.xlabel('Eje X Personalizado')
plt.ylabel('Eje Y Personalizado')
plt.show()

# %%
# Personalizar el gráfico de distribución
sns.kdeplot(data["x"], color='r', fill=True)  # Cambiar color y agregar sombreado
plt.title('Gráfico de Distribución Personalizado')
plt.xlabel('Eje X Personalizado')
plt.ylabel('Eje Y Personalizado')
plt.show()

# %%
# Personalizar el mapa de calor de correlación
sns.heatmap(data.corr(), annot=True, cmap="YlGnBu")  # Cambiar la paleta de colores
plt.title('Mapa de Calor de Correlación Personalizado')
plt.show()

# %% [markdown]
# ## **Ejemplos: gráficas de líneas y dispersión**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Crear un dataframe de ejemplo
data = pd.DataFrame({
    "x": [1, 2, 3, 4, 5],
    "y": [2, 4, 6, 8, 10],
    "z": [1, 3, 5, 7, 9]
})
# Personalizar el gráfico de líneas
sns.lineplot(x="x", y="y", data=data, color='blue', marker='o', linestyle='--', markersize=8)
plt.title('Gráfico de Líneas Personalizado')
plt.xlabel('Eje X Personalizado')
plt.ylabel('Eje Y Personalizado')
plt.show()

# %%
# Personalizar el gráfico de dispersión
sns.scatterplot(x="z", y="y", data=data, hue=data['x'], palette='coolwarm', s=100, alpha=0.7)
plt.title('Gráfico de Dispersión Personalizado')
plt.xlabel('Eje X Personalizado')
plt.ylabel('Eje Y Personalizado')
plt.legend(title='Categoría X', labels=data['x'])
plt.show()

# %% [markdown]
# ## **Gráficas de dispersión**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Crear un dataframe de ejemplo
data = pd.DataFrame({
    "x": [1, 2, 3, 4, 5],
    "y": [2, 4, 6, 8, 10],
    "z": [1, 3, 5, 7, 9]
})

# Personalizar el gráfico de dispersión
sns.scatterplot(x="x", y="y", data=data, hue=data["z"], palette="viridis", size=data["z"], sizes=(50, 200), alpha=0.7)
plt.title('Gráfico de Dispersión Personalizado')
plt.xlabel('Eje X Personalizado')
plt.ylabel('Eje Y Personalizado')
plt.legend(title='Tamaño Z', labels=data['z'])
plt.show()

# %% [markdown]
# ## **Gráficas de líneas**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Crear un dataframe de ejemplo
data = pd.DataFrame({
    "x": [1, 2, 3, 4, 5],
    "y": [2, 4, 6, 8, 10]
})

# Personalizar el gráfico de líneas
sns.lineplot(x="x", y="y", data=data, marker="o", markersize=8, color="red", label="Datos de ejemplo")
plt.title('Gráfico de Líneas Personalizado')
plt.xlabel('Eje X Personalizado')
plt.ylabel('Eje Y Personalizado')
plt.legend()
plt.grid(True)  # Agregar una cuadrícula al gráfico
plt.show()

# %% [markdown]
# ## **Intervalo de confianza**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Crear un dataframe de ejemplo
data = pd.DataFrame({
    "x": [1, 2, 3, 4, 5],
    "y": [2, 4, 6, 8, 10]
})

# Calcular el intervalo de confianza
ci = sns.utils.ci(data["y"])

# Crear el gráfico de líneas
sns.lineplot(x="x", y="y", data=data, marker="o", markersize=8, color="blue", label="Datos de ejemplo")

# Rellenar el área del intervalo de confianza
plt.fill_between(data["x"], ci[0], ci[1], alpha=0.2, color="blue")

# Personalizar el título y etiquetas de los ejes
plt.title('Gráfico de Líneas con Intervalo de Confianza')
plt.xlabel('Eje X Personalizado')
plt.ylabel('Eje Y Personalizado')

# Agregar leyenda
plt.legend()

# Habilitar la cuadrícula
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## **Combinar gráficas**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Crear un dataframe de ejemplo
data = pd.DataFrame({
    "x": [1, 2, 3, 4, 5],
    "y1": [2, 4, 6, 8, 10],
    "y2": [1, 3, 5, 7, 9]
})

# Crear dos subplots
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

# Gráfico de líneas en el primer subplot
sns.lineplot(x="x", y="y1", data=data, ax=ax1, marker="o", markersize=8, color="blue", label="Línea 1")
ax1.set_title('Gráfico de Líneas')
ax1.set_xlabel('Eje X')
ax1.set_ylabel('Eje Y')
ax1.grid(True)
ax1.legend()

# Gráfico de dispersión en el segundo subplot
sns.scatterplot(x="x", y="y2", data=data, ax=ax2, color="red", label="Dispersión")
ax2.set_title('Gráfico de Dispersión')
ax2.set_xlabel('Eje X')
ax2.set_ylabel('Eje Y')
ax2.grid(True)
ax2.legend()

# Ajustar el espacio entre los subplots
plt.tight_layout()

# Mostrar los subplots
plt.show()

# %% [markdown]
# | **Inicio** | **atrás 17** | **Siguiente 19** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./17.Series_de_Pandas.ipynb)| [⏩](./19.Arreglos.ipynb)|
