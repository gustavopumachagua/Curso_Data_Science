# %% [markdown]
# | **Inicio** | **atrás 35** | **Siguiente 37** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./35.Analisis_de_Datos.ipynb)| [⏩](./37.Maldicion%20_Dimensionalidad.ipynb)|

# %% [markdown]
# # **36. Descubre cómo Visualizar Datos Categóricos con Seaborn y Python: gráficas de violín, enjambre y ➕**

# %% [markdown]
# ## **Visualización con datos categóricos**

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
frutas = ['manzanas', 'manzanas', 'plátanos', 'naranjas', 'manzanas', 'plátanos', 'peras', 'naranjas', 'naranjas']

# Calcular la frecuencia de cada tipo de fruta
frecuencias = {}
for fruta in frutas:
    if fruta in frecuencias:
        frecuencias[fruta] += 1
    else:
        frecuencias[fruta] = 1

# Visualizar los resultados en un gráfico de barras
nombres_frutas = sorted(frecuencias.keys())
frecuencias_ordenadas = [frecuencias[fruta] for fruta in nombres_frutas]

plt.bar(nombres_frutas, frecuencias_ordenadas)
plt.title('Frecuencia de Frutas')
plt.xlabel('Fruta')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ## **Tipos de gráficas categóricas**

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Datos de ejemplo
datos = {'Bebida': ['Café', 'Té', 'Refresco', 'Agua', 'Jugo'],
         'Frecuencia': [20, 15, 10, 30, 25]}

# Convertir los datos a un DataFrame de pandas
df = pd.DataFrame(datos)

# Gráfico de barras
plt.bar(df['Bebida'], df['Frecuencia'])
plt.title('Preferencias de Bebidas')
plt.xlabel('Bebida')
plt.ylabel('Frecuencia')
plt.show()

# Gráfico de pastel
plt.pie(df['Frecuencia'], labels=df['Bebida'])
plt.title('Preferencias de Bebidas')
plt.show()

# Gráfico de barras horizontales
plt.barh(df['Bebida'], df['Frecuencia'])
plt.title('Preferencias de Bebidas')
plt.xlabel('Frecuencia')
plt.ylabel('Bebida')
plt.show()

# %% [markdown]
# En este ejemplo, los datos se representan en un DataFrame de pandas con dos columnas: 'Bebida' y 'Frecuencia'. Para visualizar los datos, se utilizan tres tipos de gráficas categóricas diferentes: un gráfico de barras, un gráfico de pastel y un gráfico de barras horizontales.
#
# En el primer gráfico de barras, se traza la frecuencia de cada bebida en un eje vertical. El segundo gráfico es un gráfico de pastel que muestra la proporción de cada bebida en el total de las preferencias. Por último, el gráfico de barras horizontales muestra la frecuencia de cada bebida en un eje horizontal.
#
# Cada tipo de gráfico tiene sus ventajas y desventajas, por lo que es importante elegir el tipo adecuado para los datos que se desean visualizar.

# %% [markdown]
# ## **Gráficas de bandas (stripplot)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo de Seaborn
tips = sns.load_dataset("tips")

# Crear una gráfica de bandas con Seaborn
sns.stripplot(x="day", y="total_bill", data=tips)

# Personalizar la gráfica
plt.title("Distribución del total de la cuenta por día")
plt.xlabel("Día de la semana")
plt.ylabel("Total de la cuenta ($)")
plt.show()

# %% [markdown]
# ## **Gráficas de enjambre (swarmplot)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo de Seaborn
tips = sns.load_dataset("tips")

# Crear una gráfica de enjambre con Seaborn
sns.swarmplot(x="day", y="total_bill", data=tips)

# Personalizar la gráfica
plt.title("Distribución del total de la cuenta por día")
plt.xlabel("Día de la semana")
plt.ylabel("Total de la cuenta ($)")
plt.show()

# %% [markdown]
# ## **Diagramas de cajas y bigotes (boxplot)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo de Seaborn
tips = sns.load_dataset("tips")

# Crear un diagrama de cajas y bigotes con Seaborn
sns.boxplot(x="day", y="total_bill", data=tips)

# Personalizar la gráfica
plt.title("Distribución del total de la cuenta por día")
plt.xlabel("Día de la semana")
plt.ylabel("Total de la cuenta ($)")
plt.show()

# %% [markdown]
# ## **Gráficas de violín (violinplot)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo de Seaborn
tips = sns.load_dataset("tips")

# Crear una gráfica de violín con Seaborn
sns.violinplot(x="day", y="total_bill", data=tips)

# Personalizar la gráfica
plt.title("Distribución del total de la cuenta por día")
plt.xlabel("Día de la semana")
plt.ylabel("Total de la cuenta ($)")
plt.show()

# %% [markdown]
# ## **Gráficas de puntos (pointplot)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo de Seaborn
tips = sns.load_dataset("tips")

# Crear una gráfica de puntos con Seaborn
sns.pointplot(x="day", y="tip", data=tips)

# Personalizar la gráfica
plt.title("Propina promedio por día de la semana")
plt.xlabel("Día de la semana")
plt.ylabel("Propina promedio ($)")
plt.show()

# %% [markdown]
# ## **Gráficas de barras (barplots)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo de Seaborn
titanic = sns.load_dataset("titanic")

# Crear una gráfica de barras con Seaborn
sns.barplot(x="class", y="survived", data=titanic)

# Personalizar la gráfica
plt.title("Porcentaje de supervivencia por clase en el Titanic")
plt.xlabel("Clase")
plt.ylabel("Porcentaje de supervivencia")
plt.show()

# %% [markdown]
# ## **Gráficas de conteo (countplot)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo de Seaborn
titanic = sns.load_dataset("titanic")

# Crear una gráfica de conteo con Seaborn
sns.countplot(x="class", hue="who", data=titanic)

# Personalizar la gráfica
plt.title("Distribución de pasajeros del Titanic por clase y género")
plt.xlabel("Clase")
plt.ylabel("Número de pasajeros")
plt.show()

# %% [markdown]
# | **Inicio** | **atrás 35** | **Siguiente 37** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./35.Analisis_de_Datos.ipynb)| [⏩](./37.Maldicion%20_Dimensionalidad.ipynb)|
