# %% [markdown]
# | **Inicio** | **atrás 39** | **Siguiente 41** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./39.K-Vecinos(KNN).ipynb)| [⏩](./41.datos_categoricos_nominales.ipynb)|

# %% [markdown]
# # **40. Escalamiento, Normalización y Estandarización de Datos con Python**

# %% [markdown]
# ## **Problemática**

# %% [markdown]
# La problemática de escalamiento, normalización y estandarización de datos se refiere a la necesidad de transformar los datos antes de aplicar ciertos algoritmos de análisis de datos o aprendizaje automático.
#
# * Escalamiento: implica cambiar la escala de los datos para que estén en un rango similar, lo que ayuda a evitar que algunos atributos con valores muy grandes dominen el análisis.
#
# * Normalización: se utiliza para escalar los datos a un rango de 0 a 1. Esto es útil cuando los datos tienen diferentes unidades o escalas.
#
# * Estandarización: implica transformar los datos para que tengan una media de cero y una desviación estándar de uno. Este método es útil cuando los datos tienen diferentes medias y desviaciones estándar, lo que puede dificultar la comparación de diferentes variables.
#
# La problemática surge porque la elección del método de transformación adecuado depende de la distribución y características de los datos, y aplicar el método incorrecto puede afectar negativamente el rendimiento del modelo o análisis. Además, el proceso de transformación puede ser computacionalmente costoso y aumentar el tiempo de procesamiento.
#
# Por lo tanto, es importante comprender la naturaleza de los datos y seleccionar el método adecuado de transformación de datos para garantizar una correcta interpretación y análisis de los resultados.

# %% [markdown]
# ## **Contexto y datos**

# %% [markdown]
# La problemática de escalamiento, normalización y estandarización de datos es común en el campo del análisis de datos y el aprendizaje automático. En muchos casos, los datos utilizados en estos campos provienen de diferentes fuentes y pueden tener diferentes unidades, escalas y distribuciones. Si estos datos no se transforman adecuadamente, pueden afectar negativamente el rendimiento del modelo o análisis.

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Creamos un conjunto de datos aleatorios con diferentes escalas
data = np.array([[10, 2], [20, 4], [30, 6], [40, 8], [50, 10]])

# Escalamos los datos utilizando MinMaxScaler
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)
print("Datos escalados con MinMaxScaler:\n", scaled_data)

# Normalizamos los datos utilizando L2 norm
normalized_data = data / np.linalg.norm(data, ord=2, axis=1, keepdims=True)
print("Datos normalizados con L2 norm:\n", normalized_data)

# Estandarizamos los datos utilizando StandardScaler
standard_scaler = StandardScaler()
standardized_data = standard_scaler.fit_transform(data)
print("Datos estandarizados con StandardScaler:\n", standardized_data)
# Out:
# Datos escalados con MinMaxScaler:
#  [[0.   0.  ]
#  [0.25 0.25]
#  [0.5  0.5 ]
#  [0.75 0.75]
#  [1.   1.  ]]
# Datos normalizados con L2 norm:
#  [[0.98058068 0.19611614]
#  [0.98058068 0.19611614]
#  [0.98058068 0.19611614]
#  [0.98058068 0.19611614]
#  [0.98058068 0.19611614]]
# Datos estandarizados con StandardScaler:
#  [[-1.41421356 -1.41421356]
#  [-0.70710678 -0.70710678]
#  [ 0.          0.        ]
#  [ 0.70710678  0.70710678]
#  [ 1.41421356  1.41421356]]

# %% [markdown]
# ## **Datos graficados**

# %% [markdown]
# La problemática de escalamiento, normalización y estandarización de datos surge cuando se tienen datos que varían en magnitudes y escalas diferentes, lo que puede afectar el rendimiento de los modelos de aprendizaje automático que se entrenan con ellos.
#
# El escalamiento, la normalización y la estandarización son técnicas que se utilizan para transformar los datos de manera que se ajusten a una escala común, lo que puede mejorar el rendimiento de los modelos de aprendizaje automático.
#
# A continuación, se presentará un ejemplo de cómo aplicar estas técnicas utilizando Python y se mostrarán gráficas para ilustrar los resultados.
#
# Primero, se importarán las bibliotecas necesarias:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Luego, se generará un conjunto de datos de muestra con dos características (variables) que varían en magnitud y escala diferentes:

# %%
np.random.seed(42)

# Generar datos de muestra con dos características
X = np.random.normal(loc=10, scale=5, size=(100, 2))

# %% [markdown]
# A continuación, se mostrará un diagrama de dispersión de los datos de muestra:

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.show()

# %% [markdown]
# Como se puede observar en el diagrama de dispersión, las dos características varían en magnitud y escala diferentes, lo que puede afectar el rendimiento de los modelos de aprendizaje automático que se entrenan con estos datos.
#
# A continuación, se aplicarán las técnicas de escalamiento, normalización y estandarización para transformar los datos de muestra:

# %%
# Escalar los datos
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Normalizar los datos
from sklearn.preprocessing import Normalizer
normalizer = Normalizer()
X_normalized = normalizer.fit_transform(X)

# Estandarizar los datos
from sklearn.preprocessing import StandardScaler
standardizer = StandardScaler()
X_standardized = standardizer.fit_transform(X)

# %% [markdown]
# Una vez que se han transformado los datos de muestra, se mostrarán diagramas de dispersión para cada técnica de transformación:

# %%
# Escalamiento
plt.scatter(X_scaled[:, 0], X_scaled[:, 1])
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.show()

# Normalización
plt.scatter(X_normalized[:, 0], X_normalized[:, 1])
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.show()

# Estandarización
plt.scatter(X_standardized[:, 0], X_standardized[:, 1])
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.show()

# %% [markdown]
# ## **Distribución de los datos**

# %%
# Escalar los datos
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Normalizar los datos
from sklearn.preprocessing import Normalizer
normalizer = Normalizer()
X_normalized = normalizer.fit_transform(X)

# Estandarizar los datos
from sklearn.preprocessing import StandardScaler
standardizer = StandardScaler()
X_standardized = standardizer.fit_transform(X)

# %% [markdown]
# Luego, se mostrará la distribución de los datos para cada técnica de transformación utilizando un histograma:

# %%
# Escalamiento
plt.hist(X_scaled[:, 0], bins=20)
plt.xlabel('Característica 1')
plt.ylabel('Frecuencia')
plt.show()

plt.hist(X_scaled[:, 1], bins=20)
plt.xlabel('Característica 2')
plt.ylabel('Frecuencia')
plt.show()

# Normalización
plt.hist(X_normalized[:, 0], bins=20)
plt.xlabel('Característica 1')
plt.ylabel('Frecuencia')
plt.show()

plt.hist(X_normalized[:, 1], bins=20)
plt.xlabel('Característica 2')
plt.ylabel('Frecuencia')
plt.show()

# Estandarización
plt.hist(X_standardized[:, 0], bins=20)
plt.xlabel('Característica 1')
plt.ylabel('Frecuencia')
plt.show()

plt.hist(X_standardized[:, 1], bins=20)
plt.xlabel('Característica 2')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# Como se puede observar en los histogramas, las técnicas de escalamiento, normalización y estandarización han transformado los datos de manera que tengan una distribución más similar entre sí, lo que puede mejorar el rendimiento de los modelos de aprendizaje automático que se entrenan con estos datos. Es importante destacar que cada técnica de transformación tiene sus propias características y se deben seleccionar según el problema en particular y los requisitos del modelo a entrenar.

# %% [markdown]
# ## **Escalamiento**

# %% [markdown]
# El escalamiento es una técnica de transformación de datos que se utiliza para llevar los valores de las características de un conjunto de datos a un rango específico. Esta técnica es útil para cuando los valores de las características tienen escalas muy diferentes y se quiere asegurar que todas las características tengan un rango similar.
#
# A continuación, se muestra un ejemplo de cómo aplicar el escalamiento en Python utilizando la biblioteca scikit-learn:

# %%
# Importar la biblioteca scikit-learn
from sklearn.preprocessing import MinMaxScaler

# Crear un conjunto de datos de muestra
X = [[-1, 2], [-0.5, 6], [0, 10], [1, 18]]

# Crear un objeto scaler
scaler = MinMaxScaler()

# Escalar los datos
X_scaled = scaler.fit_transform(X)

# Imprimir los datos escalados
print(X_scaled)
# Out:
# [[0.   0.  ]
#  [0.25 0.25]
#  [0.5  0.5 ]
#  [1.   1.  ]]

# %% [markdown]
# Como se puede observar, los datos han sido escalados para que los valores de cada característica estén dentro del rango de 0 a 1. Ahora, se puede graficar estos datos escalados para observar cómo han sido transformados:

# %%
# Importar la biblioteca matplotlib
import matplotlib.pyplot as plt

# Graficar los datos escalados
plt.scatter(X_scaled[:, 0], X_scaled[:, 1])
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.show()

# %% [markdown]
# Como se puede observar, la gráfica muestra que todos los valores de las características están dentro del rango de 0 a 1, lo que indica que el escalamiento ha sido efectivo en la transformación de los datos.

# %% [markdown]
# ## **Normalización**

# %% [markdown]
# La normalización es otra técnica de transformación de datos que se utiliza para ajustar la escala de los datos, pero a diferencia del escalamiento, la normalización se utiliza para asegurar que los datos tengan una norma o magnitud igual a 1. Esta técnica es útil cuando se quiere comparar la magnitud relativa de las características.
#
# A continuación, se muestra un ejemplo de cómo aplicar la normalización en Python utilizando la biblioteca scikit-learn:

# %%
# Importar la biblioteca scikit-learn
from sklearn.preprocessing import Normalizer

# Crear un conjunto de datos de muestra
X = [[-1, 2], [-0.5, 6], [0, 10], [1, 18]]

# Crear un objeto normalizer
normalizer = Normalizer()

# Normalizar los datos
X_normalized = normalizer.fit_transform(X)

# Imprimir los datos normalizados
print(X_normalized)
# Out:
# [[-0.4472136   0.89442719]
#  [-0.08304548  0.99654576]
#  [ 0.          1.        ]
#  [ 0.05547002  0.99846035]]

# %% [markdown]
# Como se puede observar, los datos han sido normalizados para que la norma de cada fila sea igual a 1. Ahora, se puede graficar estos datos normalizados para observar cómo han sido transformados:

# %%
# Graficar los datos normalizados
plt.scatter(X_normalized[:, 0], X_normalized[:, 1])
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.show()

# %% [markdown]
# Como se puede observar, la gráfica muestra que la magnitud de los datos ha sido normalizada a una norma de 1, lo que indica que la normalización ha sido efectiva en la transformación de los datos.

# %% [markdown]
# ## **Estandarización**

# %% [markdown]
# La estandarización es otra técnica de transformación de datos que se utiliza para ajustar la escala de los datos, pero a diferencia del escalamiento y la normalización, la estandarización se utiliza para transformar los datos de manera que tengan una media de cero y una desviación estándar de uno. Esta técnica es útil cuando se quiere que los datos tengan una distribución normal y cuando se utilizan algoritmos que asumen que los datos están normalmente distribuidos.
#
# A continuación, se muestra un ejemplo de cómo aplicar la estandarización en Python utilizando la biblioteca scikit-learn:

# %%
# Importar la biblioteca scikit-learn
from sklearn.preprocessing import StandardScaler

# Crear un conjunto de datos de muestra
X = [[-1, 2], [-0.5, 6], [0, 10], [1, 18]]

# Crear un objeto scaler
scaler = StandardScaler()

# Estandarizar los datos
X_std = scaler.fit_transform(X)

# Imprimir los datos estandarizados
print(X_std)
# Out:
# [[-1.18321596 -1.18321596]
#  [-0.50709255 -0.50709255]
#  [ 0.16903085  0.16903085]
#  [ 1.52127766  1.52127766]]

# %% [markdown]
# Como se puede observar, los datos han sido estandarizados para que tengan una media de cero y una desviación estándar de uno. Ahora, se puede graficar estos datos estandarizados para observar cómo han sido transformados:

# %%
# Graficar los datos estandarizados
plt.scatter(X_std[:, 0], X_std[:, 1])
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.show()

# %% [markdown]
# Como se puede observar, la gráfica muestra que los datos han sido transformados de manera que tengan una media de cero y una desviación estándar de uno, lo que indica que la estandarización ha sido efectiva en la transformación de los datos.

# %% [markdown]
# ## **Comparación de los métodos**

# %% [markdown]
# Para comparar los métodos de escalamiento, normalización y estandarización, se puede utilizar el mismo conjunto de datos y graficar los datos transformados para observar cómo cambian en cada método.
#
# A continuación, se muestra un ejemplo de cómo aplicar los tres métodos de transformación de datos en Python utilizando la biblioteca scikit-learn y cómo graficar los datos transformados:

# %%
# Importar la biblioteca scikit-learn y matplotlib
from sklearn.preprocessing import MinMaxScaler, Normalizer, StandardScaler
import matplotlib.pyplot as plt
import numpy as np

X = np.array([[-1, 2], [-0.5, 6], [0, 10], [1, 18]])


# Crear objetos para los tres métodos de transformación de datos
scaler = MinMaxScaler()
normalizer = Normalizer()
std_scaler = StandardScaler()

# Aplicar los tres métodos de transformación de datos
X_scaled = scaler.fit_transform(X)
X_normalized = normalizer.fit_transform(X)
X_std = std_scaler.fit_transform(X)

# Graficar los datos originales y transformados
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0, 0].scatter(X[:, 0], X[:, 1])
axs[0, 0].set_title('Datos originales')
axs[0, 1].scatter(X_scaled[:, 0], X_scaled[:, 1])
axs[0, 1].set_title('Escalamiento')
axs[1, 0].scatter(X_normalized[:, 0], X_normalized[:, 1])
axs[1, 0].set_title('Normalización')
axs[1, 1].scatter(X_std[:, 0], X_std[:, 1])
axs[1, 1].set_title('Estandarización')

for ax in axs.flat:
    ax.set(xlabel='Característica 1', ylabel='Característica 2')

plt.show()

# %% [markdown]
# Como se puede observar en la gráfica, cada método de transformación de datos produce un resultado diferente. El escalamiento ajusta la escala de los datos para que estén en el rango [0, 1], la normalización ajusta la magnitud de los datos para que tengan una norma de 1 y la estandarización ajusta la media y la desviación estándar de los datos para que tengan una distribución normal con media cero y desviación estándar de uno. La elección del método de transformación de datos depende del problema específico y del tipo de algoritmo que se utilice para analizar los datos.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# Generamos un conjunto de datos de ejemplo con dos características
X = np.array([[10, 5], [20, 10], [30, 15], [40, 20]])

# Escalamos los datos utilizando MinMaxScaler
scaler_minmax = MinMaxScaler()
X_minmax = scaler_minmax.fit_transform(X)

# Escalamos los datos utilizando StandardScaler
scaler_std = StandardScaler()
X_std = scaler_std.fit_transform(X)

# Escalamos los datos utilizando RobustScaler
scaler_robust = RobustScaler()
X_robust = scaler_robust.fit_transform(X)

# Graficamos los datos originales y los escalados por cada método
fig, axs = plt.subplots(2, 2, figsize=(8, 8))
axs[0, 0].scatter(X[:, 0], X[:, 1])
axs[0, 0].set_title("Datos originales")
axs[0, 1].scatter(X_minmax[:, 0], X_minmax[:, 1])
axs[0, 1].set_title("MinMaxScaler")
axs[1, 0].scatter(X_std[:, 0], X_std[:, 1])
axs[1, 0].set_title("StandardScaler")
axs[1, 1].scatter(X_robust[:, 0], X_robust[:, 1])
axs[1, 1].set_title("RobustScaler")
plt.show()

# %% [markdown]
# Este código genera un conjunto de datos de ejemplo con dos características y luego utiliza tres métodos diferentes de escalado: MinMaxScaler, StandardScaler y RobustScaler. A continuación, se grafican los datos originales y los escalados por cada método.

# %% [markdown]
# Como puedes ver en la imagen, los datos originales (arriba a la izquierda) tienen una escala diferente en cada característica. Sin embargo, después de aplicar los diferentes métodos de escalado, los datos tienen una escala similar y se encuentran en rangos similares. En este ejemplo, los tres métodos de escalado producen resultados similares, pero en otros conjuntos de datos puede haber diferencias significativas en los resultados. Es importante probar diferentes métodos de escalado en cada conjunto de datos para encontrar el que mejor se adapte a las necesidades del problema que se está resolviendo.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Crear datos de ejemplo
np.random.seed(42)
X = np.random.normal(loc=50, scale=10, size=(100, 2))

# Escalamiento
scaler = MinMaxScaler()
X_scaled_minmax = scaler.fit_transform(X)

# Normalización
X_normalized = X / np.linalg.norm(X, axis=1, keepdims=True)

# Estandarización
scaler = StandardScaler()
X_standardized = scaler.fit_transform(X)

# Crear gráfico
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0, 0].scatter(X[:, 0], X[:, 1])
axs[0, 0].set_title('Datos originales')
axs[0, 1].scatter(X_scaled_minmax[:, 0], X_scaled_minmax[:, 1])
axs[0, 1].set_title('Escalamiento (min-max)')
axs[1, 0].scatter(X_normalized[:, 0], X_normalized[:, 1])
axs[1, 0].set_title('Normalización')
axs[1, 1].scatter(X_standardized[:, 0], X_standardized[:, 1])
axs[1, 1].set_title('Estandarización')
plt.show()

# %% [markdown]
# Este código crea un conjunto de datos de 100 puntos, cada uno con dos dimensiones, distribuidos normalmente con media 50 y desviación estándar 10. Luego, aplica los tres métodos de preprocesamiento: Escalamiento (min-max), Normalización y Estandarización, y crea un gráfico de dispersión para comparar los resultados.

# %% [markdown]
# En el gráfico, el panel superior izquierdo muestra los datos originales. El panel superior derecho muestra los datos después del Escalamiento (min-max), donde los datos se han escalado en el rango [0, 1] para cada dimensión. El panel inferior izquierdo muestra los datos después de la Normalización, donde los datos se han normalizado para que cada punto tenga una norma igual a 1. El panel inferior derecho muestra los datos después de la Estandarización, donde los datos se han transformado para tener media 0 y desviación estándar 1 para cada dimensión.
#
# Podemos observar que los tres métodos de preprocesamiento producen resultados diferentes, pero útiles para diferentes situaciones. El Escalamiento (min-max) es útil cuando queremos que todas las características tengan el mismo rango de valores, la Normalización es útil cuando queremos que todas las muestras tengan la misma escala y la Estandarización es útil cuando queremos que los datos estén centrados en torno a la media y tengan una desviación estándar conocida.

# %% [markdown]
# | **Inicio** | **atrás 39** | **Siguiente 41** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./39.K-Vecinos(KNN).ipynb)| [⏩](./41.datos_categoricos_nominales.ipynb)|
