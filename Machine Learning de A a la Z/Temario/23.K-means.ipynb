# %% [markdown]
# | **Inicio** | **atrás 22** | **Siguiente 24** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./22.Cross_validation.ipynb)| [⏩](./24.Impureza_Gini.ipynb)|

# %% [markdown]
# # **23. K-means (o K-medias) para detección de clusters**

# %% [markdown]
# ## **Introducción**

# %% [markdown]
# `K-means` (o K-medias) es un algoritmo de aprendizaje no supervisado que se utiliza para clasificar un conjunto de datos en `K` grupos diferentes. El objetivo del algoritmo es agrupar los datos de tal manera que los puntos dentro de un grupo sean similares entre sí, mientras que los puntos de diferentes grupos sean diferentes entre sí.
#
# Por ejemplo, si tuviéramos un conjunto de datos que representara las características de diferentes tipos de frutas, podríamos utilizar `K-means` para clasificar las frutas en diferentes grupos en función de sus características. Podríamos tener un grupo para las frutas cítricas, otro para las frutas de pepita, y otro para las frutas tropicales, por ejemplo.

# %% [markdown]
# ![k-medias](../imagenes%20Machine_Learning/k-medias.png "k-medias")

# %% [markdown]
# ![k-means](../imagenes%20Machine_Learning/k-means.png "k-means")

# %% [markdown]
# ## **Contexto y algoritmo**

# %% [markdown]
# `K-means` (o K-medias) es un algoritmo de agrupamiento no supervisado utilizado en el análisis de datos. Su objetivo es agrupar un conjunto de observaciones en `k` grupos, donde `k` es un número predefinido de grupos.
#
# El algoritmo funciona de la siguiente manera:
#
# * Seleccionar el número `k` de grupos que se desean crear.
# * Seleccionar `k` puntos aleatorios del conjunto de observaciones como centros iniciales de los grupos.
# * Asignar cada observación al grupo cuyo centro esté más cercano.
# * Calcular los nuevos centros de los grupos como la media de las observaciones asignadas a cada grupo.
# * Repetir los pasos `3` y `4` hasta que los centros de los grupos no cambien de manera significativa.
#
# El resultado final del algoritmo es una partición de las observaciones en k grupos, donde cada observación pertenece a un solo grupo.
#
# El algoritmo `K-means` es ampliamente utilizado en la industria y la investigación para clasificar grandes conjuntos de datos en grupos homogéneos. También es un algoritmo relativamente simple y rápido, lo que lo hace muy útil en situaciones donde se necesitan resultados rápidos. Sin embargo, es importante tener en cuenta que el resultado del algoritmo `K-means` puede depender de la selección inicial de los centros de los grupos y puede no ser el óptimo en algunos casos.

# %% [markdown]
# ## **Creación de modelo K-means**

# %% [markdown]
# Claro, te mostraré cómo crear un modelo `K-means` en Python utilizando la biblioteca `Scikit-learn` y cómo visualizar los resultados con una gráfica. En este ejemplo, utilizaremos un conjunto de datos de `iris`.

# %%
# importar las bibliotecas necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris

# cargar el conjunto de datos de iris
iris = load_iris()
X = iris.data

# crear el modelo K-means con 3 grupos
kmeans = KMeans(n_clusters=3)

# ajustar el modelo a los datos
kmeans.fit(X)

# obtener las etiquetas de los grupos
labels = kmeans.labels_

# obtener las coordenadas de los centroides
centroids = kmeans.cluster_centers_

# visualizar los resultados en una gráfica
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=300, c='r')
plt.show()
# Out:
# /home/puma/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f4c0b6a5d30>
# Traceback (most recent call last):
#   File "/home/puma/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/puma/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/puma/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
# ...

# %% [markdown]
# En este código, primero importamos las bibliotecas necesarias y cargamos el conjunto de datos de `iris`. Luego, creamos el modelo `K-means` con `3` grupos y lo ajustamos a los datos.
#
# A continuación, obtenemos las etiquetas de los grupos y las coordenadas de los centroides. Finalmente, visualizamos los resultados en una gráfica, donde cada punto representa una observación en el conjunto de datos y el color indica a qué grupo pertenece. Los centroides se muestran como estrellas rojas en la gráfica.

# %% [markdown]
# ## **Visualización de clusters**

# %% [markdown]
# La visualización de clusters es una técnica importante para entender la estructura de los grupos formados por un algoritmo de clustering, como `K-means`. Aquí te muestro algunos métodos comunes para visualizar clusters:
#
# * **Gráfico de dispersión:** se puede utilizar para visualizar dos características del conjunto de datos y colorear los puntos según su asignación de grupo. En `K-means`, los centroides también se pueden mostrar en la gráfica para visualizar su posición relativa a los puntos del conjunto de datos.
#
# * **Mapa de calor:** se puede utilizar para visualizar la densidad de puntos de un conjunto de datos y destacar las áreas de alta densidad. Los puntos se pueden colorear según su asignación de grupo.
#
# * **Gráfico de barras:** se puede utilizar para visualizar la distribución de los grupos en una característica específica del conjunto de datos. Por ejemplo, si el conjunto de datos contiene información sobre el género de los participantes, se puede crear un gráfico de barras para mostrar cuántos participantes hay en cada grupo y en cada género.
#
# * **Gráfico de líneas:** se puede utilizar para visualizar cómo cambian las características del conjunto de datos en función de la posición o el tiempo. Los grupos se pueden colorear para visualizar la asignación de grupo en diferentes puntos o tiempos.

# %%
# importar las bibliotecas necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris

# cargar el conjunto de datos de iris
iris = load_iris()
X = iris.data

# crear el modelo K-means con 3 grupos
kmeans = KMeans(n_clusters=3)

# ajustar el modelo a los datos
kmeans.fit(X)

# obtener las etiquetas de los grupos
labels = kmeans.labels_

# obtener las coordenadas de los centroides
centroids = kmeans.cluster_centers_

# visualizar los resultados en una gráfica de dispersión
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=300, c='r')
plt.xlabel('Longitud del sépalo')
plt.ylabel('Anchura del sépalo')
plt.title('Gráfico de dispersión de clusters')
plt.show()
# Out:
# /home/puma/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f4bfba64e50>
# Traceback (most recent call last):
#   File "/home/puma/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/puma/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/puma/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
# ...

# %% [markdown]
# En este ejemplo, utilizamos el conjunto de datos de `iris` y creamos un modelo `K-means` con 3 grupos. Luego, utilizamos el gráfico de dispersión para visualizar los clusters, donde cada punto representa una observación en el conjunto de datos y el color indica a qué grupo pertenece. Los centroides se muestran como estrellas rojas en la gráfica.

# %% [markdown]
# ## **Determina k con el método del codo**

# %%
# importar las bibliotecas necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris

# cargar el conjunto de datos de iris
iris = load_iris()
X = iris.data

# crear una lista vacía para almacenar las inercias
inertias = []

# crear una lista de valores de k para probar
k_values = range(1, 11)

# ajustar el modelo K-means para cada valor de k y obtener su inercia
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)

# trazar la curva del codo
plt.plot(k_values, inertias, 'bx-')
plt.xlabel('Número de clusters (k)')
plt.ylabel('Inercia')
plt.title('Método del codo')
plt.show()
# Out:
# /home/puma/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f4bfb98bc10>
# Traceback (most recent call last):
#   File "/home/puma/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/puma/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/puma/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
# ...

# %% [markdown]
# Este código ajusta el modelo `K-means` para cada valor de `k` de `1` a `10` y almacena la inercia del modelo en una lista. Luego, traza la curva del codo utilizando los valores de `k` y las inercias correspondientes. La curva del codo es una representación gráfica de la relación entre el número de clusters y la inercia. Se espera que la inercia disminuya a medida que aumenta el número de clusters. Sin embargo, a partir de un cierto punto, los beneficios de dividir los datos en más clusters disminuyen, lo que resulta en una disminución más lenta de la inercia. El "codo" en la curva representa el punto óptimo de clusters, después del cual los beneficios de agregar más clusters son menores. En el siguiente código, se puede ver un ejemplo de la gráfica resultante.

# %% [markdown]
# | **Inicio** | **atrás 22** | **Siguiente 24** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./22.Cross_validation.ipynb)| [⏩](./24.Impureza_Gini.ipynb)|
