# %% [markdown]
# | **Inicio** | **atrás 3** | **Siguiente 5** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./3_Machine_Learning.ipynb)| [⏩](./5_Machine_Learning.ipynb)|

# %% [markdown]
# # **31. KNN Imputer | Multivariate Imputation | Handling Missing**

# %% [markdown]
# La imputación de valores faltantes utilizando métodos más avanzados como el KNN Imputer y la Imputación Multivariante son estrategias más sofisticadas que pueden ser útiles cuando tienes varios atributos correlacionados. A continuación, te proporciono una explicación detallada con ejemplos en código para ambos métodos.
#
# 1. **KNN Imputer:**
#    - KNN Imputer es un método que utiliza los k vecinos más cercanos para imputar valores faltantes. Calcula la distancia entre observaciones para encontrar vecinos cercanos y luego imputa los valores faltantes basándose en los valores de los vecinos.

# %%
import pandas as pd
from sklearn.impute import KNNImputer
import numpy as np

# Crear un DataFrame de ejemplo con datos numéricos faltantes
data = pd.DataFrame({
       'A': [1, 2, np.nan, 4],
       'B': [5, np.nan, np.nan, 8],
       'C': [9, 10, 11, np.nan]})

# Imputar valores numéricos faltantes con KNN
imputer_knn = KNNImputer(n_neighbors=2)
data_knn_imputed = pd.DataFrame(imputer_knn.fit_transform(data), columns=data.columns)

print("Datos originales:")
print(data)

print("\nDatos con valores numéricos faltantes imputados con KNN:")
print(data_knn_imputed)
# Out:
# Datos originales:
#      A    B     C
# 0  1.0  5.0   9.0
# 1  2.0  NaN  10.0
# 2  NaN  NaN  11.0
# 3  4.0  8.0   NaN
#
# Datos con valores numéricos faltantes imputados con KNN:
#      A    B     C
# 0  1.0  5.0   9.0
# 1  2.0  6.5  10.0
# 2  1.5  6.5  11.0
# 3  4.0  8.0   9.5

# %% [markdown]
# 2. **Imputación Multivariante:**
#    - La imputación multivariante se basa en modelos estadísticos y utiliza la información de múltiples variables para imputar valores faltantes.

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# Crear un DataFrame de ejemplo con datos numéricos faltantes
data = pd.DataFrame({
       'A': [1, 2, np.nan, 4],
       'B': [5, np.nan, np.nan, 8],
       'C': [9, 10, 11, np.nan]})

# Imputar valores numéricos faltantes con imputación multivariante
imputer_multivariate = IterativeImputer(max_iter=10, random_state=42)
data_multivariate_imputed = pd.DataFrame(imputer_multivariate.fit_transform(data), columns=data.columns)

print("Datos originales:")
print(data)

print("\nDatos con valores numéricos faltantes imputados con imputación multivariante:")
print(data_multivariate_imputed)
# Out:
# Datos originales:
#      A    B     C
# 0  1.0  5.0   9.0
# 1  2.0  NaN  10.0
# 2  NaN  NaN  11.0
# 3  4.0  8.0   NaN
#
# Datos con valores numéricos faltantes imputados con imputación multivariante:
#           A         B          C
# 0  1.000000  5.000000   9.000000
# 1  2.000000  6.200162  10.000000
# 2  1.000031  5.601331  11.000000
# 3  4.000000  8.000000  10.002716

# %% [markdown]
# Ambos métodos son útiles en situaciones donde los datos faltantes pueden tener una estructura más compleja y pueden capturar patrones no lineales o interacciones entre variables. Es importante ajustar los parámetros, como el número de vecinos en el KNN Imputer o el número máximo de iteraciones en la imputación multivariante, según las características específicas de tus datos.

# %% [markdown]
# # **32. Imputación multivariada mediante ecuaciones encadenadas para el valor faltante | Algoritmo MICE | Computadora iterativa**

# %% [markdown]
# La imputación multivariada mediante ecuaciones encadenadas (MICE, por sus siglas en inglés) es una técnica que utiliza modelos predictivos para imputar valores faltantes en un conjunto de datos. Este método se basa en la idea de que las variables están condicionalmente relacionadas entre sí, y se pueden imputar utilizando modelos predictivos.
#
# A continuación, te proporciono una explicación detallada con ejemplos en código para la imputación MICE utilizando el paquete `fancyimpute`.
#
# **Imputación Multivariante mediante Ecuaciones Encadenadas (MICE):**
#
# 1. **Instalación del paquete:**
#    ```bash
#    pip install fancyimpute
#    ```
#
# 2. **Ejemplo en Código:**

# %%
import numpy as np
import pandas as pd
from fancyimpute import IterativeImputer

# Crear un DataFrame de ejemplo con datos numéricos faltantes
data = pd.DataFrame({
       'A': [1, 2, np.nan, 4],
       'B': [5, np.nan, np.nan, 8],
       'C': [9, 10, 11, np.nan]})

# Imputar valores numéricos faltantes con MICE
imputer_mice = IterativeImputer(max_iter=10, random_state=42)
data_mice_imputed = pd.DataFrame(imputer_mice.fit_transform(data), columns=data.columns)

print("Datos originales:")
print(data)

print("\nDatos con valores numéricos faltantes imputados con MICE:")
print(data_mice_imputed)
# Out:
# Datos originales:
#      A    B     C
# 0  1.0  5.0   9.0
# 1  2.0  NaN  10.0
# 2  NaN  NaN  11.0
# 3  4.0  8.0   NaN
#
# Datos con valores numéricos faltantes imputados con MICE:
#           A         B          C
# 0  1.000000  5.000000   9.000000
# 1  2.000000  6.200162  10.000000
# 2  1.000031  5.601331  11.000000
# 3  4.000000  8.000000  10.002716

# %% [markdown]
# Este código utiliza el algoritmo MICE para imputar valores faltantes en el conjunto de datos `data`. El `max_iter` especifica el número máximo de iteraciones, y `random_state` asegura la reproducibilidad de los resultados.
#
# La imputación MICE es útil cuando las variables están correlacionadas y puede capturar patrones más complejos que otras técnicas de imputación. Sin embargo, ten en cuenta que la elección de la estrategia de imputación dependerá de la naturaleza específica de tus datos y tus objetivos analíticos.

# %% [markdown]
# # **33. ¿Qué son los valores atípicos? Valores atípicos en el aprendizaje automático**

# %% [markdown]
# **¿Qué son los valores atípicos?**
#
# Los valores atípicos, también conocidos como outliers, son puntos de datos que difieren significativamente del resto de los datos en un conjunto. Estos valores pueden ser más grandes o más pequeños que la mayoría de los datos y pueden afectar negativamente el rendimiento de los modelos de aprendizaje automático, ya que pueden introducir ruido y sesgar los resultados.
#
# **Ejemplos en Código:**
#
# **Identificación de Valores Atípicos:**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un conjunto de datos con valores atípicos
np.random.seed(42)
data = np.concatenate([np.random.normal(0, 1, 1000), np.random.normal(8, 1, 50)])

# Visualizar el conjunto de datos
plt.figure(figsize=(10, 6))
sns.histplot(data, bins=50, kde=True)
plt.title('Distribución de Datos con Valores Atípicos')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# En este ejemplo, hemos creado un conjunto de datos con dos distribuciones normales. La segunda distribución (con media 8) representa valores atípicos.
#
# **Tratamiento de Valores Atípicos:**

# %%
from sklearn.ensemble import IsolationForest

# Identificar valores atípicos con Isolation Forest
data = data.reshape(-1, 1)  # Ajustar la forma para el modelo
iso_forest = IsolationForest(contamination=0.02, random_state=42)
outlier_preds = iso_forest.fit_predict(data)

# Filtrar los datos para excluir los valores atípicos
filtered_data = data[~(outlier_preds == -1)]

# Visualizar datos sin valores atípicos
plt.figure(figsize=(10, 6))
sns.histplot(filtered_data, bins=50, kde=True)
plt.title('Distribución de Datos sin Valores Atípicos')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# En este caso, hemos utilizado el modelo Isolation Forest para identificar valores atípicos y luego filtramos el conjunto de datos original para excluir esos valores.
#
# La identificación y manejo adecuado de valores atípicos son esenciales para garantizar que los modelos de aprendizaje automático sean robustos y generalicen bien a nuevos datos. Sin embargo, el enfoque específico puede depender del dominio y la naturaleza de los datos.

# %% [markdown]
# # **34. Detección y eliminación de valores atípicos mediante el método de puntuación Z | Manejo de valores atípicos**

# %% [markdown]
# **Detección y Eliminación de Valores Atípicos mediante el Método de Puntuación Z**
#
# El método de puntuación Z es una técnica comúnmente utilizada para identificar valores atípicos en un conjunto de datos. Consiste en calcular la puntuación Z para cada punto de datos, que mide cuántas desviaciones estándar un punto de datos está lejos de la media. Los puntos con puntuaciones Z muy altas o muy bajas se consideran valores atípicos.
#
# **Ejemplo en Código:**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un conjunto de datos con valores atípicos
np.random.seed(42)
data = np.concatenate([np.random.normal(0, 1, 1000), np.random.normal(8, 1, 50)])

# Visualizar el conjunto de datos
plt.figure(figsize=(10, 6))
sns.histplot(data, bins=50, kde=True)
plt.title('Distribución de Datos con Valores Atípicos')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# **Identificación y Eliminación de Valores Atípicos:**

# %%
from scipy import stats

# Calcular la puntuación Z para cada punto de datos
z_scores = stats.zscore(data)

# Establecer un umbral para identificar valores atípicos (por ejemplo, umbral de 3)
threshold = 3
outliers = np.where(np.abs(z_scores) > threshold)[0]

# Filtrar los datos para excluir los valores atípicos
filtered_data = data[~np.isin(np.arange(len(data)), outliers)]

# Visualizar datos sin valores atípicos
plt.figure(figsize=(10, 6))
sns.histplot(filtered_data, bins=50, kde=True)
plt.title('Distribución de Datos sin Valores Atípicos (Método de Puntuación Z)')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# En este ejemplo, hemos creado un conjunto de datos con dos distribuciones normales, una de las cuales representa valores atípicos. Luego, hemos utilizado el método de puntuación Z para identificar y eliminar los valores atípicos del conjunto de datos.
#
# Es importante ajustar el umbral según los requisitos específicos del problema y la distribución de los datos. El método de puntuación Z es una técnica simple y efectiva, pero también hay otros métodos disponibles, como el método de Tukey o el uso de modelos estadísticos más avanzados. La elección del método dependerá de la naturaleza de los datos y del problema que estés abordando.

# %% [markdown]
# # **35. Detección y eliminación de valores atípicos mediante el método IQR | Entregando valores atípicos**

# %% [markdown]
# **Detección y Eliminación de Valores Atípicos mediante el Método IQR (Rango Intercuartílico)**
#
# El método del Rango Intercuartílico (IQR) es una técnica comúnmente utilizada para identificar y eliminar valores atípicos en un conjunto de datos. El IQR es la diferencia entre el tercer cuartil (Q3) y el primer cuartil (Q1) de un conjunto de datos. Los puntos de datos que caen fuera del rango definido por Q1 - 1.5 * IQR o Q3 + 1.5 * IQR se consideran valores atípicos y pueden ser eliminados.
#
# **Ejemplo en Código:**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un conjunto de datos con valores atípicos
np.random.seed(42)
data = np.concatenate([np.random.normal(0, 1, 1000), np.random.normal(8, 1, 50)])

# Visualizar el conjunto de datos
plt.figure(figsize=(10, 6))
sns.histplot(data, bins=50, kde=True)
plt.title('Distribución de Datos con Valores Atípicos')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# **Identificación y Eliminación de Valores Atípicos mediante IQR:**

# %%
# Calcular el primer y tercer cuartil (Q1 y Q3)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)

# Calcular el IQR
iqr = q3 - q1

# Establecer los límites para identificar valores atípicos
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Identificar valores atípicos
outliers = np.where((data < lower_bound) | (data > upper_bound))[0]

# Filtrar los datos para excluir los valores atípicos
filtered_data = data[~np.isin(np.arange(len(data)), outliers)]

# Visualizar datos sin valores atípicos
plt.figure(figsize=(10, 6))
sns.histplot(filtered_data, bins=50, kde=True)
plt.title('Distribución de Datos sin Valores Atípicos (Método IQR)')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# En este ejemplo, hemos creado un conjunto de datos con dos distribuciones normales, una de las cuales representa valores atípicos. Luego, hemos utilizado el método IQR para identificar y eliminar los valores atípicos del conjunto de datos.
#
# Es importante tener en cuenta que el método IQR asume que los datos siguen una distribución aproximadamente normal. Si los datos tienen una distribución diferente, otros métodos de detección de valores atípicos pueden ser más apropiados.

# %% [markdown]
# # **36. Detección de valores atípicos mediante el método percentil | Técnica de winsorización**

# %% [markdown]
# **Detección de Valores Atípicos mediante el Método de Percentiles y Técnica de Winsorización**
#
# La técnica de Winsorización es un método para manejar valores atípicos mediante la modificación de los valores extremos en lugar de eliminarlos. Consiste en cambiar los valores atípicos por los valores más cercanos que no son atípicos, a menudo utilizando percentiles. Esta técnica ayuda a suavizar los efectos de los valores atípicos sin eliminarlos por completo.
#
# **Ejemplo en Código:**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un conjunto de datos con valores atípicos
np.random.seed(42)
data = np.concatenate([np.random.normal(0, 1, 1000), np.random.normal(8, 1, 50)])

# Visualizar el conjunto de datos
plt.figure(figsize=(10, 6))
sns.histplot(data, bins=50, kde=True)
plt.title('Distribución de Datos con Valores Atípicos')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# **Identificación y Winsorización de Valores Atípicos:**

# %%
# Calcular los percentiles 5 y 95
percentile_5 = np.percentile(data, 5)
percentile_95 = np.percentile(data, 95)

# Winsorizar los valores atípicos
winsorized_data = np.where(data < percentile_5, percentile_5, np.where(data > percentile_95, percentile_95, data))

# Visualizar datos con técnica de Winsorización
plt.figure(figsize=(10, 6))
sns.histplot(winsorized_data, bins=50, kde=True)
plt.title('Distribución de Datos con Winsorización de Valores Atípicos')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# En este ejemplo, hemos creado un conjunto de datos con dos distribuciones normales, una de las cuales representa valores atípicos. Luego, hemos utilizado la técnica de Winsorización para modificar los valores atípicos y suavizar la distribución.
#
# Es importante ajustar los percentiles de acuerdo con la naturaleza de los datos y la distribución de los valores atípicos. La técnica de Winsorización es útil cuando se desea mitigar el impacto de los valores atípicos sin eliminarlos por completo.

# %% [markdown]
# # **37. Construcción de características | División de funciones**

# %% [markdown]
# La construcción de características implica la creación de nuevas variables (características) a partir de las existentes para mejorar el rendimiento del modelo de aprendizaje automático. La división de funciones es una técnica común en la construcción de características que implica dividir una variable existente en partes más pequeñas o segmentos.
#
# **Ejemplo en Código:**
#
# Supongamos que tenemos una columna que representa la duración de una película en minutos. Podemos dividir esta variable en segmentos para crear una nueva característica que indique la categoría de duración de la película.

# %%
import pandas as pd

# Crear un DataFrame de ejemplo
data = pd.DataFrame({
    'titulo': ['Pelicula1', 'Pelicula2', 'Pelicula3', 'Pelicula4'],
    'duracion': [120, 95, 150, 110]
})

# Visualizar el DataFrame original
print("DataFrame Original:")
print(data)

# Dividir la columna 'duracion' en segmentos
bins = [0, 90, 120, 180]  # Definir los límites de los segmentos
labels = ['Corta', 'Normal', 'Larga']  # Definir etiquetas para los segmentos
data['duracion_categoria'] = pd.cut(data['duracion'], bins=bins, labels=labels, right=False)

# Visualizar el DataFrame con la nueva característica
print("\nDataFrame con Nueva Característica:")
print(data)
# Out:
# DataFrame Original:
#       titulo  duracion
# 0  Pelicula1       120
# 1  Pelicula2        95
# 2  Pelicula3       150
# 3  Pelicula4       110
#
# DataFrame con Nueva Característica:
#       titulo  duracion duracion_categoria
# 0  Pelicula1       120              Larga
# 1  Pelicula2        95             Normal
# 2  Pelicula3       150              Larga
# 3  Pelicula4       110             Normal

# %% [markdown]
# En este ejemplo, hemos creado un DataFrame con una columna de duración de películas. Luego, utilizamos la función `pd.cut()` de pandas para dividir la columna de duración en segmentos (corta, normal, larga) según los límites definidos en `bins`. La nueva característica, `duracion_categoria`, representa la categoría de duración a la que pertenece cada película.
#
# Este proceso de dividir funciones puede aplicarse a diferentes contextos y variables, adaptándolo según las necesidades específicas del conjunto de datos y del problema que se esté abordando.

# %% [markdown]
# # **38. Maldición de dimensionalidad**

# %% [markdown]
# La "maldición de la dimensionalidad" es un fenómeno en el aprendizaje automático y la estadística que se refiere a los desafíos y limitaciones asociados con el aumento de la dimensionalidad de los datos. A medida que el número de características o dimensiones de los datos aumenta, surgen varios problemas que pueden afectar negativamente el rendimiento de los modelos de aprendizaje automático.
#
# **Problemas Asociados con la Maldición de la Dimensionalidad:**
#
# 1. **Dispersión de los Datos:** A medida que la dimensionalidad aumenta, la densidad de los datos en el espacio también disminuye. Esto puede llevar a que los datos estén dispersos y a que haya menos ejemplos cercanos entre sí.
#
# 2. **Sobreajuste:** En conjuntos de datos de alta dimensionalidad, los modelos pueden volverse más propensos al sobreajuste, es decir, aprender patrones que son específicos del conjunto de entrenamiento pero no se generalizan bien a nuevos datos.
#
# 3. **Requerimientos Computacionales:** El aumento en la dimensionalidad conlleva un aumento en los requerimientos computacionales. La complejidad de los cálculos y el almacenamiento de datos puede hacer que sea más costoso trabajar con conjuntos de datos de alta dimensionalidad.
#
# **Ejemplo en Código:**
#
# A continuación, se presenta un ejemplo que ilustra la maldición de la dimensionalidad al generar un conjunto de datos en un espacio de alta dimensionalidad y calcular la distancia media entre los puntos.

# %%
import numpy as np

# Generar un conjunto de datos en un espacio de alta dimensionalidad
num_dimensiones = 100
num_ejemplos = 1000
datos_alta_dimension = np.random.random((num_ejemplos, num_dimensiones))

# Calcular la distancia media entre los puntos
distancia_media = np.mean(np.linalg.norm(datos_alta_dimension - datos_alta_dimension[0], axis=1))

print(f"Dimensionalidad: {num_dimensiones}")
print(f"Número de Ejemplos: {num_ejemplos}")
print(f"Distancia Media entre Puntos: {distancia_media}")
# Out:
# Dimensionalidad: 100
# Número de Ejemplos: 1000
# Distancia Media entre Puntos: 4.1340217756967395

# %% [markdown]
# En este ejemplo, se genera un conjunto de datos con 100 dimensiones y 1000 ejemplos. Luego, se calcula la distancia media entre los puntos en el espacio de alta dimensionalidad. Observarás que la distancia media puede ser significativamente grande, lo que refleja la dispersión de los datos en un espacio de alta dimensionalidad. Este fenómeno puede hacer que la interpretación y el rendimiento de los modelos sean más desafiantes.

# %% [markdown]
# # **39. Análisis de componentes principales (PCA) | Intuición geométrica**

# %% [markdown]
# El Análisis de Componentes Principales (PCA) es una técnica utilizada en análisis de datos y aprendizaje automático para reducir la dimensionalidad de un conjunto de datos, preservando al mismo tiempo la mayor cantidad posible de su variabilidad. La intuición detrás de PCA está relacionada con la identificación y preservación de las direcciones principales o "componentes principales" a lo largo de las cuales los datos tienen la mayor varianza.
#
# **Pasos Básicos de PCA:**
# 1. **Centrar los Datos:** Restar la media de cada característica para centrar los datos.
# 2. **Calcular la Matriz de Covarianza:** Calcular la matriz de covarianza de los datos centrados.
# 3. **Calcular Autovectores y Autovalores:** Calcular los autovectores y autovalores de la matriz de covarianza.
# 4. **Ordenar Autovectores:** Ordenar los autovectores según sus autovalores en orden descendente.
# 5. **Proyectar los Datos:** Proyectar los datos originales sobre los autovectores seleccionados para reducir la dimensionalidad.
#
# **Intuición Geométrica:**
#
# Imaginemos que tenemos un conjunto de datos en un espacio bidimensional. Los autovectores representarán las direcciones de máxima variación en los datos. El primer autovector estará en la dirección de máxima varianza, y el segundo autovector será ortogonal al primero y estará en la dirección de la segunda máxima varianza.
#
# **Ejemplo en Código:**
#
# Vamos a utilizar PCA con el conjunto de datos Iris para ilustrar el proceso. En este caso, el conjunto de datos tiene 4 dimensiones (longitud del sépalo, ancho del sépalo, longitud del pétalo y ancho del pétalo).

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

# Cargar el conjunto de datos Iris
iris = load_iris()
X = iris.data
y = iris.target

# Aplicar PCA para reducir la dimensionalidad a 2
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Visualizar los resultados
plt.figure(figsize=(8, 6))
for i in range(len(np.unique(y))):
    plt.scatter(X_pca[y == i, 0], X_pca[y == i, 1], label=f'Clase {i}')

plt.title('PCA en el Conjunto de Datos Iris')
plt.xlabel('Primer Componente Principal')
plt.ylabel('Segundo Componente Principal')
plt.legend()
plt.show()

# %% [markdown]
# En este ejemplo, aplicamos PCA al conjunto de datos Iris y reducimos la dimensionalidad a 2 componentes principales. Luego, visualizamos los datos en el espacio reducido de dos dimensiones. Los puntos en el gráfico representan las muestras del conjunto de datos, y la dirección de máxima varianza está capturada por los dos primeros componentes principales. Este es un ejemplo simplificado, pero la idea general es aplicable a conjuntos de datos de mayor dimensionalidad.

# %% [markdown]
# # **40. Análisis de componentes principales (PCA) | Formulación del problema y solución paso a paso**

# %% [markdown]
# El Análisis de Componentes Principales (PCA) es una técnica fundamental en estadísticas y aprendizaje automático para reducir la dimensionalidad de los datos mientras se mantiene la mayor cantidad posible de su variabilidad. El objetivo es encontrar una proyección de los datos en un nuevo espacio, donde las dimensiones (llamadas componentes principales) están ordenadas según la cantidad de variabilidad que capturan.
#
# **Formulación del Problema:**
# Dado un conjunto de datos $(X)$ con $(n)$ muestras y $(m)$ características, el objetivo es encontrar una transformación lineal $(W)$ que proyecta los datos originales en un nuevo espacio $(Z)$, donde $(Z)$ tiene $(m')$ componentes principales ordenadas según la varianza.
#
# **Pasos Básicos:**
#
# 1. **Centrar los Datos:**
#    - Restar la media de cada característica para centrar los datos.
#
# 2. **Calcular la Matriz de Covarianza:**
#    - Calcular la matriz de covarianza de los datos centrados.
#
# 3. **Calcular Autovectores y Autovalores:**
#    - Calcular los autovectores y autovalores de la matriz de covarianza.
#
# 4. **Ordenar Autovectores:**
#    - Ordenar los autovectores según sus autovalores en orden descendente.
#
# 5. **Seleccionar Componentes Principales:**
#    - Elegir los primeros $(m')$ autovectores como componentes principales.
#
# 6. **Proyectar los Datos:**
#    - Proyectar los datos originales en el nuevo espacio definido por los autovectores seleccionados.
#
# **Ejemplo en Código:**
#
# Vamos a utilizar el conjunto de datos Iris y aplicar PCA paso a paso.

# %%
import numpy as np
from sklearn.datasets import load_iris

# Paso 1: Cargar el conjunto de datos Iris
iris = load_iris()
X = iris.data

# Paso 2: Centrar los Datos
X_centered = X - np.mean(X, axis=0)

# Paso 3: Calcular la Matriz de Covarianza
cov_matrix = np.cov(X_centered, rowvar=False)

# Paso 4: Calcular Autovectores y Autovalores
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# Paso 5: Ordenar Autovectores
sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvectors_sorted = eigenvectors[:, sorted_indices]

# Paso 6: Seleccionar Componentes Principales (por ejemplo, los dos primeros)
num_components = 2
principal_components = eigenvectors_sorted[:, :num_components]

# Paso 7: Proyectar los Datos
X_pca = X_centered.dot(principal_components)

# Visualizar los resultados
print("Matriz de Covarianza:")
print(cov_matrix)
print("\nComponentes Principales:")
print(principal_components)
print("\nDatos Proyectados:")
print(X_pca)
# Out:
# Matriz de Covarianza:
# [[ 0.68569351 -0.042434    1.27431544  0.51627069]
#  [-0.042434    0.18997942 -0.32965638 -0.12163937]
#  [ 1.27431544 -0.32965638  3.11627785  1.2956094 ]
#  [ 0.51627069 -0.12163937  1.2956094   0.58100626]]
#
# Componentes Principales:
# [[ 0.36138659 -0.65658877]
#  [-0.08452251 -0.73016143]
#  [ 0.85667061  0.17337266]
#  [ 0.3582892   0.07548102]]
#
# Datos Proyectados:
# [[-2.68412563 -0.31939725]
#  [-2.71414169  0.17700123]
#  [-2.88899057  0.14494943]
#  [-2.74534286  0.31829898]
#  [-2.72871654 -0.32675451]
#  [-2.28085963 -0.74133045]
#  [-2.82053775  0.08946138]
#  [-2.62614497 -0.16338496]
#  [-2.88638273  0.57831175]
#  [-2.6727558   0.11377425]
#  [-2.50694709 -0.6450689 ]
#  [-2.61275523 -0.01472994]
#  [-2.78610927  0.235112  ]
#  [-3.22380374  0.51139459]
#  [-2.64475039 -1.17876464]
#  [-2.38603903 -1.33806233]
#  [-2.62352788 -0.81067951]
#  [-2.64829671 -0.31184914]
#  [-2.19982032 -0.87283904]
#  [-2.5879864  -0.51356031]
# ...

# %% [markdown]
# Este ejemplo muestra cómo llevar a cabo el Análisis de Componentes Principales paso a paso utilizando el conjunto de datos Iris. La matriz de covarianza se calcula, los autovectores se ordenan y se seleccionan los componentes principales. Luego, los datos se proyectan en el nuevo espacio definido por los autovectores seleccionados. Estos pasos ilustran el proceso fundamental de PCA. En la práctica, puedes usar bibliotecas como scikit-learn para realizar PCA de manera más eficiente.

# %% [markdown]
# | **Inicio** | **atrás 3** | **Siguiente 5** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./3_Machine_Learning.ipynb)| [⏩](./5_Machine_Learning.ipynb)|
