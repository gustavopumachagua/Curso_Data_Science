# %% [markdown]
# | **Inicio** | **Siguiente 2** |
# |----------- |---------------|
# | [🏠](../../README.md) | [⏩](2_Machine_Learning.ipynb)|

# %% [markdown]
# # **1. ¿Qué es el aprendizaje automático?**

# %% [markdown]
# El aprendizaje automático, también conocido como machine learning en inglés, es una rama de la inteligencia artificial que se enfoca en desarrollar sistemas informáticos capaces de aprender y mejorar su desempeño en tareas específicas a partir de la experiencia. En lugar de programar explícitamente un conjunto de reglas para que una computadora realice una tarea, se entrena al sistema para que pueda reconocer patrones y tomar decisiones basadas en datos.
#
# Existen varios tipos de aprendizaje automático, pero aquí te explicaré los conceptos clave y proporcionaré ejemplos:
#
# 1. **Aprendizaje supervisado:**
#
#    En el aprendizaje supervisado, se entrena un modelo utilizando un conjunto de datos etiquetados, es decir, datos en los que se conoce la respuesta correcta. El objetivo es que el modelo pueda predecir la respuesta correcta para nuevos datos no etiquetados.
#
#    Ejemplo: Clasificación de correos electrónicos como spam o no spam. Se proporciona al modelo un conjunto de correos electrónicos etiquetados como spam y no spam. El modelo aprende a identificar patrones en los correos electrónicos que ayudan a realizar la clasificación correcta y, posteriormente, puede clasificar nuevos correos electrónicos.
#
# 2. **Aprendizaje no supervisado:**
#
#    En el aprendizaje no supervisado, el modelo se entrena en datos no etiquetados y busca descubrir patrones, estructuras o relaciones en los datos sin tener una respuesta correcta predefinida.
#
#    Ejemplo: Agrupación de clientes en categorías basadas en sus patrones de compra. El modelo analiza el historial de compras de los clientes y agrupa automáticamente a los clientes en segmentos similares según sus preferencias de compra sin conocer de antemano las categorías.
#
# 3. **Aprendizaje por refuerzo:**
#
#    En el aprendizaje por refuerzo, un agente interactúa con un entorno y toma decisiones para maximizar una recompensa. El agente aprende a través de la retroalimentación que recibe del entorno.
#
#    Ejemplo: Entrenamiento de un robot para caminar. El robot realiza diferentes movimientos y recibe retroalimentación en forma de recompensas o penalizaciones según su desempeño en el equilibrio y la locomoción. Con el tiempo, el robot aprende a caminar de manera más eficiente.
#
# El aprendizaje automático se aplica en una amplia gama de campos, desde el procesamiento de lenguaje natural (como la traducción automática y el análisis de sentimientos) hasta la visión por computadora (reconocimiento de objetos en imágenes) y la toma de decisiones en finanzas, medicina y muchas otras áreas. Es una tecnología fundamental en la era de la inteligencia artificial y se utiliza para automatizar tareas, realizar predicciones y tomar decisiones basadas en datos.

# %% [markdown]
# # **2. AI vs ML vs DL**

# %% [markdown]
# Inteligencia Artificial (IA), Aprendizaje Automático (ML) y Aprendizaje Profundo (DL) son conceptos interrelacionados pero distintos en el campo de la informática y la tecnología. Aquí te proporciono una explicación detallada de cada uno, junto con ejemplos para ilustrar sus diferencias:
#
# 1. **Inteligencia Artificial (IA):**
#
#    La Inteligencia Artificial se refiere a la simulación de procesos de inteligencia humana por parte de sistemas informáticos. En otras palabras, es el campo de estudio que busca crear máquinas que puedan realizar tareas que requieren inteligencia, como razonamiento, resolución de problemas, comprensión del lenguaje natural y toma de decisiones.
#
#    Ejemplo: Un sistema de chatbot que puede mantener una conversación con los usuarios en lenguaje natural, responder preguntas y proporcionar asistencia. Estos chatbots utilizan algoritmos de procesamiento de lenguaje natural para comprender y generar respuestas.
#
# 2. **Aprendizaje Automático (ML):**
#
#    El Aprendizaje Automático es una subdisciplina de la Inteligencia Artificial que se centra en el desarrollo de algoritmos y modelos que permiten a las computadoras aprender y mejorar su rendimiento en tareas específicas a través de la experiencia y los datos, en lugar de programar reglas explícitas.
#
#    Ejemplo: Un filtro de spam de correo electrónico que aprende a clasificar los correos electrónicos como spam o no spam en función de las características de los mensajes y la retroalimentación del usuario. El filtro mejora su precisión a medida que procesa más correos electrónicos.
#
# 3. **Aprendizaje Profundo (DL):**
#
#    El Aprendizaje Profundo es una rama del Aprendizaje Automático que se enfoca en redes neuronales artificiales con múltiples capas (redes neuronales profundas). Estas redes son capaces de aprender representaciones jerárquicas y complejas de datos, lo que las hace especialmente efectivas en tareas de procesamiento de imágenes, sonido y texto.
#
#    Ejemplo: Reconocimiento de objetos en imágenes. Un modelo de Aprendizaje Profundo puede aprender a identificar objetos en una fotografía, como gatos, perros o automóviles, a través de capas de procesamiento que detectan características cada vez más abstractas, como bordes, formas y texturas.
#
# En resumen, la Inteligencia Artificial es un campo amplio que abarca la creación de sistemas inteligentes, el Aprendizaje Automático es una técnica específica que se utiliza para permitir que las máquinas aprendan a partir de datos, y el Aprendizaje Profundo es una subdisciplina del Aprendizaje Automático que se enfoca en redes neuronales profundas para resolver tareas complejas de percepción y procesamiento de datos. Los tres conceptos están relacionados y a menudo se utilizan en conjunto para abordar problemas complejos en la actualidad.

# %% [markdown]
# ![AI vs ML vs DL](../img/AI%20vs%20ML%20vs%20DL.png "AI vs ML vs DL")

# %% [markdown]
# # **3. Tipos de Aprendizajes Automático**

# %% [markdown]
# El Aprendizaje Automático (Machine Learning) se divide en varios tipos o enfoques, según la forma en que se realiza el aprendizaje y la naturaleza de los datos utilizados. Aquí te presento los tipos más comunes de Aprendizaje Automático con explicaciones detalladas y ejemplos para cada uno:
#
# 1. **Aprendizaje Supervisado:**
#
#    En el Aprendizaje Supervisado, el modelo se entrena utilizando un conjunto de datos etiquetados, donde se conoce la respuesta correcta. El objetivo es aprender a mapear entradas a salidas, de modo que el modelo pueda predecir respuestas precisas para nuevos datos no vistos.
#
#    Ejemplo: Clasificación de correo electrónico como "spam" o "no spam". El modelo se entrena con ejemplos de correos electrónicos etiquetados como spam y no spam. Una vez entrenado, puede clasificar automáticamente nuevos correos electrónicos como spam o no spam.
#
# 2. **Aprendizaje No Supervisado:**
#
#    En el Aprendizaje No Supervisado, el modelo se entrena en datos no etiquetados y busca descubrir patrones, estructuras o relaciones en los datos sin conocer la respuesta correcta de antemano.
#
#    Ejemplo: Agrupación de documentos de texto en temas similares. El modelo analiza documentos y agrupa automáticamente aquellos que comparten temas o características comunes sin que se le indique cuáles son los temas específicos.
#
# 3. **Aprendizaje por Refuerzo:**
#
#    En el Aprendizaje por Refuerzo, un agente interactúa con un entorno y toma decisiones para maximizar una recompensa a lo largo del tiempo. El agente aprende a través de la retroalimentación que recibe del entorno.
#
#    Ejemplo: Entrenamiento de un agente de inteligencia artificial para jugar ajedrez. El agente toma decisiones de movimiento basadas en las reglas del juego y recibe recompensas en función de si gana, pierde o empata partidas. A lo largo del tiempo, el agente aprende a mejorar su estrategia para maximizar las recompensas.
#
# 4. **Aprendizaje Semisupervisado:**
#
#    El Aprendizaje Semisupervisado es una combinación de aprendizaje supervisado y no supervisado. Se utiliza cuando solo se tienen etiquetas para un subconjunto de los datos, y el modelo debe aprender tanto de los datos etiquetados como de los no etiquetados.
#
#    Ejemplo: Clasificación de imágenes médicas. Si solo se tienen etiquetas para un pequeño número de imágenes, el modelo puede aprender a partir de estas y de un gran conjunto de imágenes no etiquetadas para identificar patrones relacionados con enfermedades.
#
# 5. **Aprendizaje por Transferencia:**
#
#    El Aprendizaje por Transferencia implica reutilizar un modelo pre-entrenado en una tarea específica para una tarea relacionada o similar. Esto acelera el proceso de entrenamiento y mejora el rendimiento, especialmente cuando se dispone de conjuntos de datos pequeños.
#
#    Ejemplo: Utilizar una red neuronal pre-entrenada en imágenes generales para tareas específicas, como la detección de enfermedades en imágenes médicas. El modelo pre-entrenado ya ha aprendido representaciones útiles de características visuales, que pueden aplicarse a la nueva tarea con menos datos de entrenamiento.
#
# Estos son los principales tipos de Aprendizaje Automático, y cada uno tiene aplicaciones en una amplia variedad de campos, desde la clasificación de texto y el reconocimiento de patrones hasta la toma de decisiones en tiempo real. La elección del tipo de aprendizaje depende de la naturaleza de los datos y el problema que se desea resolver.

# %% [markdown]
# ![Tipos de Aprendizajes Automático](../img/Tipos%20de%20Aprendizajes%20Automático.png "Tipos de Aprendizajes Automático")

# %% [markdown]
# # **4. Aprendizaje automático por lotes**

# %% [markdown]
# El Aprendizaje Automático por lotes, también conocido como aprendizaje por lotes (batch learning), es un enfoque en el campo del Aprendizaje Automático donde el modelo se entrena utilizando todo el conjunto de datos de entrenamiento de una sola vez. Esto significa que el modelo se ajusta a los datos completos en cada iteración del proceso de entrenamiento, en lugar de actualizar los parámetros con cada punto de datos individual.
#
# Aquí tienes una explicación más detallada del Aprendizaje Automático por lotes con un ejemplo:
#
# **Proceso de Aprendizaje Automático por lotes:**
#
# 1. **Conjunto de datos de entrenamiento:**
#
#  En el aprendizaje por lotes, se utiliza un conjunto de datos de entrenamiento que consta de pares de datos de entrada y sus correspondientes etiquetas (respuestas correctas).
#
# 2. **Iniciación del modelo:**
#
#  Se selecciona un modelo de aprendizaje automático, como una red neuronal o una regresión lineal, y se inicializan sus parámetros de manera aleatoria o mediante algún otro método. Estos parámetros se ajustarán durante el proceso de entrenamiento para hacer que el modelo sea capaz de realizar predicciones precisas.
#
# 3. **Entrenamiento:**
#
#  En el aprendizaje por lotes, se proporciona todo el conjunto de datos de entrenamiento al modelo de una sola vez. El modelo realiza predicciones para todas las muestras de entrenamiento y luego se calcula la pérdida (diferencia entre las predicciones y las etiquetas reales) para todo el conjunto de datos.
#
# 4. **Actualización de parámetros:**
#
#  El objetivo del entrenamiento es minimizar la pérdida. Para hacerlo, se utilizan técnicas de optimización, como el descenso de gradiente, para ajustar los parámetros del modelo de manera que la pérdida se reduzca. Esto implica calcular el gradiente de la pérdida con respecto a los parámetros y realizar un pequeño paso en esa dirección para minimizar la pérdida.
#
# 5. **Iteración:**
#
#  El proceso de entrenamiento se repite durante un número determinado de épocas o hasta que la pérdida converja a un valor aceptable. En cada iteración, se vuelve a calcular la pérdida y se actualizan los parámetros del modelo.
#
# **Ejemplo de Aprendizaje Automático por lotes:**
#
# Supongamos que deseas crear un modelo de aprendizaje automático para predecir los precios de las casas en función de sus características, como el tamaño, el número de habitaciones, la ubicación, etc.
#
# - Tienes un conjunto de datos de entrenamiento que contiene información sobre miles de casas, incluyendo los precios de venta reales.
# - Utilizas un modelo de regresión lineal como algoritmo de aprendizaje automático.
# - Inicias el modelo con parámetros aleatorios.
# - Alimentas todo el conjunto de datos de entrenamiento en el modelo, que calcula las predicciones de precios para todas las casas.
# - Calculas la pérdida, que mide cuán diferentes son las predicciones del modelo de los precios reales en todo el conjunto de datos.
# - Ajustas los parámetros del modelo para minimizar la pérdida, de modo que el modelo sea más preciso en sus predicciones.
# - Repites este proceso durante varias iteraciones hasta que el modelo alcance un nivel aceptable de precisión en la predicción de precios de las casas.
#
# El Aprendizaje Automático por lotes es eficiente para conjuntos de datos de tamaño moderado o pequeño, pero puede ser ineficiente si el conjunto de datos es muy grande, ya que requiere procesar todos los datos en cada iteración. En tales casos, se pueden utilizar enfoques de aprendizaje por lotes miniatura (mini-batch learning) o de aprendizaje en línea (online learning) para manejar conjuntos de datos masivos.

# %% [markdown]
# # **5. Aprendizaje en línea versus fuera de línea**

# %% [markdown]
# Aprendizaje en línea (online learning) y aprendizaje fuera de línea (offline learning) son dos enfoques de entrenamiento en el campo del Aprendizaje Automático que difieren en cómo se actualiza un modelo a medida que se disponen de nuevos datos. Aquí tienes una explicación detallada de cada uno, junto con ejemplos:
#
# 1. **Aprendizaje en línea (Online Learning):**
#
#    El aprendizaje en línea implica la actualización constante del modelo a medida que se reciben nuevos datos. En este enfoque, el modelo se entrena de manera incremental, lo que significa que se ajusta y se mejora a medida que se agregan nuevos datos al sistema. Es especialmente útil cuando se dispone de una fuente constante de datos en tiempo real y se necesita que el modelo se adapte a cambios continuos.
#
#    Ejemplo: Clasificación de correos electrónicos como spam o no spam. En lugar de entrenar el modelo una sola vez con un conjunto de datos estático, el modelo de aprendizaje en línea se ajusta continuamente a medida que llegan nuevos correos electrónicos. A medida que se etiquetan y procesan nuevos correos, el modelo mejora su capacidad para identificar spam en tiempo real.
#
# 2. **Aprendizaje fuera de línea (Offline Learning):**
#
#    El aprendizaje fuera de línea implica entrenar el modelo con un conjunto de datos estático y no actualizarlo constantemente. El modelo se entrena por completo en un conjunto de datos fijo y luego se despliega para realizar inferencias o predicciones en nuevos datos. Es adecuado cuando los datos no cambian con el tiempo o cuando la necesidad de adaptación continua no es esencial.
#
#    Ejemplo: Detección de fraudes en transacciones financieras. Se entrena un modelo de detección de fraudes utilizando un conjunto de datos histórico de transacciones. Una vez entrenado, el modelo se utiliza para evaluar las transacciones en tiempo real. Como los patrones de fraude pueden cambiar con el tiempo, se podría necesitar una actualización periódica del modelo, pero no necesariamente en tiempo real.
#
# **Diferencias clave:**
#
# - **Frecuencia de actualización:** El aprendizaje en línea se actualiza continuamente a medida que llegan nuevos datos, mientras que el aprendizaje fuera de línea se entrena por completo en un conjunto de datos estático y no se actualiza de manera continua.
#
# - **Uso de datos históricos:** El aprendizaje en línea se adapta a los cambios en los datos en tiempo real, lo que lo hace adecuado para aplicaciones en constante evolución. El aprendizaje fuera de línea se basa en datos históricos y es más adecuado cuando los datos no cambian con frecuencia.
#
# - **Ejemplos de aplicaciones:** El aprendizaje en línea se utiliza en aplicaciones como recomendaciones en tiempo real, monitoreo de redes sociales y análisis de datos de sensores en IoT. El aprendizaje fuera de línea se utiliza en aplicaciones como diagnóstico médico, traducción automática y detección de spam.
#
# La elección entre aprendizaje en línea y aprendizaje fuera de línea depende de las necesidades específicas del problema y de la disponibilidad de datos en tiempo real. A menudo, se pueden combinar ambos enfoques en sistemas híbridos para aprovechar las ventajas de cada uno.

# %% [markdown]
# # **6. Aprendizaje basado en instancias versus aprendizaje basado en modelos**

# %% [markdown]
# El aprendizaje basado en instancias y el aprendizaje basado en modelos son dos enfoques en el campo del Aprendizaje Automático para abordar problemas de clasificación y predicción. Cada enfoque se basa en diferentes métodos de representación y toma de decisiones. A continuación, te proporciono una explicación detallada de cada uno, junto con ejemplos:
#
# 1. **Aprendizaje Basado en Instancias (Instance-Based Learning):**
#
#    En el aprendizaje basado en instancias, el modelo memoriza y almacena el conjunto de datos de entrenamiento completo. En lugar de aprender un modelo generalizado, toma decisiones basándose en la similitud entre las nuevas instancias de datos y las instancias de entrenamiento almacenadas. Este enfoque es especialmente útil cuando las relaciones entre las instancias de datos son complejas o no se pueden modelar fácilmente.
#
#    Ejemplo: **K-Vecinos Más Cercanos (K-NN)**. En el algoritmo K-NN, cuando se le presenta una nueva instancia que necesita ser clasificada, el modelo busca las "K" instancias más cercanas en el conjunto de datos de entrenamiento en función de alguna medida de similitud (por ejemplo, distancia euclidiana). Luego, asigna la etiqueta de clase más común entre las K instancias cercanas a la instancia de prueba como su predicción.
#
# 2. **Aprendizaje Basado en Modelos (Model-Based Learning):**
#
#    En el aprendizaje basado en modelos, se construye un modelo general que resume las relaciones y patrones en los datos de entrenamiento. Este modelo se utiliza para realizar predicciones en nuevas instancias de datos. Los modelos pueden ser regresiones lineales, árboles de decisión, redes neuronales u otros algoritmos que se ajusten a los datos de entrenamiento y capturen relaciones subyacentes.
#
#    Ejemplo: **Regresión Lineal**. En la regresión lineal, se ajusta una línea (o un hiperplano en dimensiones superiores) a los datos de entrenamiento para modelar la relación entre las variables de entrada y la variable de salida. Una vez construido el modelo, se puede usar para predecir valores de salida para nuevas instancias de datos en función de sus características de entrada.
#
# **Diferencias clave:**
#
# - **Almacenamiento de datos:** El aprendizaje basado en instancias almacena y depende del conjunto de datos de entrenamiento completo, lo que puede ser costoso en términos de memoria. El aprendizaje basado en modelos almacena un modelo generalizado y utiliza los datos de entrenamiento para construir ese modelo.
#
# - **Generalización vs. Memorización:** El aprendizaje basado en modelos se centra en generalizar las relaciones entre los datos y es más eficiente en términos de memoria. El aprendizaje basado en instancias se basa en la memorización de ejemplos de entrenamiento individuales y puede tener un alto costo de almacenamiento.
#
# - **Robustez a ruido:** El aprendizaje basado en modelos tiende a ser más robusto al ruido en los datos, ya que se enfoca en patrones generales en lugar de datos individuales. El aprendizaje basado en instancias puede ser más sensible al ruido en los datos debido a su enfoque en ejemplos individuales.
#
# La elección entre el aprendizaje basado en instancias y el aprendizaje basado en modelos depende de la naturaleza del problema y de los recursos disponibles. A menudo, se pueden utilizar ambos enfoques de manera complementaria en sistemas de aprendizaje automático.

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# El aprendizaje basado en instancias, en particular el algoritmo de los k-vecinos más cercanos (K-NN), se caracteriza por su enfoque en la similitud entre instancias de datos para tomar decisiones.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.datasets import make_blobs
from sklearn.neighbors import KNeighborsClassifier

# Genera un conjunto de datos de dos clases
X, y = make_blobs(n_samples=100, centers=2, random_state=42)

# Crea un modelo K-NN con 3 vecinos
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X, y)

# Configuración de la gráfica
h = .02  # Tamaño de paso en la malla
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Mapa de colores personalizado para las regiones de decisión
cmap_light = ListedColormap(['#FFAAAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#0000FF'])

# Dibuja las regiones de decisión
plt.figure(figsize=(8, 6))
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# Dibuja los puntos de datos
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, marker='o', s=50)
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.title('K-NN (k=3) - Fronteras de Decisión Personalizadas')
plt.show()

# %% [markdown]
# Este código crea un conjunto de datos de ejemplo, entrena un clasificador K-NN con 3 vecinos y muestra un gráfico con los puntos de datos del conjunto de prueba, así como las fronteras de decisión generadas por el modelo K-NN. El modelo se entrena en el conjunto de entrenamiento y luego se utiliza para realizar predicciones en el conjunto de prueba. Las fronteras de decisión separan las dos clases en función de la similitud de las instancias cercanas.

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# El aprendizaje basado en modelos

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Genera datos de ejemplo
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Crea un modelo de regresión lineal
regression_model = LinearRegression()
regression_model.fit(X, y)

# Realiza predicciones con el modelo
X_new = np.array([[0], [2]])
y_pred = regression_model.predict(X_new)

# Personaliza la gráfica
plt.figure(figsize=(8, 6))  # Tamaño de la figura
plt.scatter(X, y, label='Datos de entrenamiento', color='blue', marker='o', s=30, alpha=0.7)
plt.plot(X_new, y_pred, 'r--', label='Línea de regresión', linewidth=2)

plt.xlabel('Característica')
plt.ylabel('Objetivo')
plt.legend()
plt.title('Modelo de Regresión Lineal Personalizado')
plt.grid(True)
plt.ylim(ymin=0)  # Establece el límite inferior del eje y

# Personaliza las marcas de los ejes
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.show()

# %% [markdown]
# # **7. Desafíos del aprendizaje automático**

# %% [markdown]
# El Aprendizaje Automático (Machine Learning) es una disciplina poderosa que ha impulsado una amplia gama de aplicaciones, pero también enfrenta varios desafíos significativos. Aquí te proporcionaré una explicación detallada de algunos de los desafíos más importantes del Aprendizaje Automático, junto con ejemplos:
#
# 1. **Falta de Datos de Calidad:**
#
#    - *Explicación:* El Aprendizaje Automático se basa en datos, y la calidad de los datos es esencial. La falta de datos de calidad, datos incompletos o datos sesgados puede llevar a modelos ineficaces o sesgados.
#    - *Ejemplo:* En un modelo de detección de fraudes en transacciones financieras, si los datos de entrenamiento son incompletos o sesgados hacia un tipo de fraude en particular, el modelo puede tener dificultades para detectar otros tipos de fraudes.
#
# 2. **Sobreajuste (Overfitting) y Subajuste (Underfitting):**
#
#    - *Explicación:* El sobreajuste ocurre cuando un modelo es demasiado complejo y se adapta demasiado a los datos de entrenamiento, lo que lo hace ineficaz en datos nuevos. El subajuste ocurre cuando un modelo es demasiado simple para capturar las relaciones en los datos.
#    - *Ejemplo:* En un modelo de clasificación, si se utiliza un árbol de decisión muy profundo, puede sobreajustarse a los datos de entrenamiento y no generalizar bien en datos nuevos. Por otro lado, un árbol de decisión muy superficial podría subajustarse y perder información importante.
#
# 3. **Interpretabilidad de Modelos:**
#
#    - *Explicación:* Muchos modelos de Aprendizaje Automático, como redes neuronales profundas, pueden ser difíciles de interpretar. Esto es un desafío en aplicaciones donde es importante comprender por qué un modelo toma una decisión.
#    - *Ejemplo:* En diagnóstico médico, es esencial que los médicos puedan entender y confiar en el razonamiento detrás de las predicciones del modelo para tomar decisiones clínicas.
#
# 4. **Dimensionalidad:**
#
#    - *Explicación:* Cuando se trabaja con conjuntos de datos de alta dimensionalidad (muchas características), puede ser difícil encontrar patrones y relaciones significativas. Además, puede aumentar el tiempo de entrenamiento y la complejidad del modelo.
#    - *Ejemplo:* En el procesamiento de texto, si cada palabra se convierte en una característica, el conjunto de datos puede volverse muy dimensional, lo que complica el análisis y puede requerir técnicas de reducción de dimensionalidad.
#
# 5. **Ética y Sesgo en los Datos:**
#
#    - *Explicación:* Los datos utilizados para entrenar modelos de Aprendizaje Automático a menudo pueden reflejar sesgos culturales, sociales o históricos, lo que puede llevar a modelos sesgados y decisiones discriminatorias.
#    - *Ejemplo:* Un modelo de selección de currículum vitae que se entrena con datos históricos de contratación que reflejan un sesgo de género podría discriminar inconscientemente a candidatos de ciertos géneros.
#
# 6. **Costo Computacional:**
#
#    - *Explicación:* Modelos de Aprendizaje Automático complejos, como redes neuronales profundas, pueden requerir una gran cantidad de recursos computacionales y tiempo de entrenamiento, lo que puede ser costoso.
#    - *Ejemplo:* El entrenamiento de una red neuronal profunda para tareas de procesamiento de imágenes a gran escala puede requerir hardware especializado y una infraestructura costosa.
#
# 7. **Generalización en Escenarios Cambiantes:**
#
#    - *Explicación:* Los modelos de Aprendizaje Automático pueden tener dificultades para adaptarse a datos nuevos si las condiciones cambian, lo que requiere la adaptación continua del modelo.
#    - *Ejemplo:* En el pronóstico del clima, los modelos deben ser capaces de adaptarse a patrones cambiantes en los datos climáticos a medida que evolucionan las condiciones atmosféricas.
#
# Resolver estos desafíos implica una combinación de selección cuidadosa de datos, ajuste de hiperparámetros, selección de modelos apropiados y técnicas avanzadas, como la regularización y la ingeniería de características. También es importante mantener la ética y la responsabilidad en el desarrollo de sistemas de Aprendizaje Automático para evitar consecuencias no deseadas.

# %% [markdown]
# ## **Problemas en el aprendizaje automático**

# %% [markdown]
# El Aprendizaje Automático (Machine Learning) es una disciplina poderosa, pero también está sujeta a diversos problemas que pueden surgir durante el desarrollo y la implementación de modelos. Aquí te proporcionaré una explicación detallada de algunos de los problemas comunes en el Aprendizaje Automático, junto con ejemplos:
#
# 1. **Sobreajuste (Overfitting):**
#
#    - *Explicación:* El sobreajuste ocurre cuando un modelo es demasiado complejo y se ajusta demasiado a los datos de entrenamiento. Como resultado, el modelo no generaliza bien a nuevos datos y puede tener un rendimiento deficiente en el mundo real.
#    - *Ejemplo:* En un modelo de clasificación de spam de correo electrónico, un modelo sobreajustado puede aprender patrones específicos de palabras que son únicos para el conjunto de entrenamiento, pero que no son útiles para identificar spam en correos nuevos.
#
# 2. **Subajuste (Underfitting):**
#
#    - *Explicación:* El subajuste ocurre cuando un modelo es demasiado simple para capturar las relaciones en los datos de entrenamiento. Esto también lleva a un mal rendimiento, ya que el modelo no puede representar adecuadamente la complejidad de los datos.
#    - *Ejemplo:* En un modelo de pronóstico de ventas, un modelo lineal simple puede subajustarse y no capturar las tendencias y patrones subyacentes en los datos de ventas.
#
# 3. **Falta de Datos de Entrenamiento:**
#
#    - *Explicación:* El Aprendizaje Automático requiere datos de entrenamiento significativos para construir modelos efectivos. La falta de datos de entrenamiento puede dificultar la creación de modelos precisos.
#    - *Ejemplo:* Para entrenar un modelo de detección de enfermedades raras, puede ser difícil obtener suficientes datos de pacientes afectados, lo que limita la capacidad del modelo para hacer predicciones precisas.
#
# 4. **Sesgo en los Datos:**
#
#    - *Explicación:* Los datos utilizados para entrenar modelos pueden reflejar sesgos culturales, sociales o históricos. Esto puede llevar a modelos sesgados y decisiones discriminatorias.
#    - *Ejemplo:* Un modelo de selección de currículum vitae que se entrena con datos históricos de contratación que reflejan un sesgo de género podría discriminar inconscientemente a candidatos de ciertos géneros.
#
# 5. **Dimensionalidad Alta:**
#
#    - *Explicación:* Los conjuntos de datos con muchas características (alta dimensionalidad) pueden hacer que sea difícil encontrar patrones significativos, aumentar la complejidad del modelo y requerir más recursos de cómputo.
#    - *Ejemplo:* En el procesamiento de texto, la alta dimensionalidad se produce al considerar cada palabra como una característica independiente, lo que puede aumentar la complejidad y requerir técnicas de reducción de dimensionalidad.
#
# 6. **Interpretabilidad:**
#
#    - *Explicación:* Modelos de Aprendizaje Automático, como redes neuronales profundas, pueden ser difíciles de interpretar. Esto puede ser problemático en aplicaciones donde es importante comprender el razonamiento detrás de las predicciones.
#    - *Ejemplo:* En diagnóstico médico, es esencial que los médicos puedan entender y confiar en el razonamiento detrás de las predicciones del modelo para tomar decisiones clínicas.
#
# 7. **Costo Computacional:**
#
#    - *Explicación:* Modelos de Aprendizaje Automático complejos, como redes neuronales profundas, pueden requerir una gran cantidad de recursos computacionales y tiempo de entrenamiento, lo que puede ser costoso.
#    - *Ejemplo:* El entrenamiento de una red neuronal profunda para tareas de procesamiento de imágenes a gran escala puede requerir hardware especializado y una infraestructura costosa.
#
# 8. **Ética y Responsabilidad:**
#
#    - *Explicación:* Los modelos de Aprendizaje Automático pueden tener implicaciones éticas y sociales, como la discriminación o la invasión de la privacidad, lo que plantea desafíos éticos y legales.
#    - *Ejemplo:* Un sistema de reconocimiento facial que se utiliza de manera injusta o para la vigilancia masiva puede plantear preocupaciones éticas y de privacidad.
#
# Resolver estos problemas implica una combinación de selección cuidadosa de datos, ajuste de hiperparámetros, selección de modelos apropiados y técnicas avanzadas, como la regularización y la ingeniería de características. También es importante mantener la ética y la responsabilidad en el desarrollo de sistemas de Aprendizaje Automático para evitar consecuencias no deseadas.

# %% [markdown]
# # **8. Aplicaciones de aprendizaje automático de la vida real**

# %% [markdown]
# El Aprendizaje Automático (Machine Learning) tiene una amplia gama de aplicaciones en la vida real en diversas industrias. A continuación, proporcionaré ejemplos detallados de aplicaciones de Aprendizaje Automático en situaciones reales:
#
# 1. **Reconocimiento de Voz y Asistentes Virtuales:**
#
#    - *Explicación:* Los sistemas de reconocimiento de voz utilizan modelos de Aprendizaje Automático para convertir el habla en texto. Los asistentes virtuales como Siri de Apple, Google Assistant y Amazon Alexa utilizan Aprendizaje Profundo para comprender y responder a comandos de voz.
#    - *Ejemplo:* Al hablar con un asistente virtual, como Siri, puedes pedirle que te proporcione información sobre el clima o que configure recordatorios.
#
# 2. **Clasificación de Correo No Deseado (Spam):**
#
#    - *Explicación:* Los filtros de spam en el correo electrónico utilizan modelos de Aprendizaje Automático para identificar y clasificar correos electrónicos no deseados. Estos modelos aprenden de ejemplos de correos electrónicos etiquetados como spam o no spam.
#    - *Ejemplo:* Cuando revisas tu bandeja de entrada de correo electrónico, los correos electrónicos spam se muestran en una carpeta separada o se eliminan automáticamente.
#
# 3. **Recomendaciones de Contenido:**
#
#    - *Explicación:* Plataformas de entretenimiento como Netflix y YouTube utilizan algoritmos de Aprendizaje Automático para recomendar contenido a los usuarios. Estos algoritmos analizan el historial de visualización y preferencias para hacer recomendaciones personalizadas.
#    - *Ejemplo:* Cuando ves una película en Netflix, el sistema te sugiere otras películas o programas de televisión que podrían interesarte.
#
# 4. **Diagnóstico Médico:**
#
#    - *Explicación:* La medicina utiliza el Aprendizaje Automático para ayudar en el diagnóstico de enfermedades. Los modelos analizan datos médicos, como imágenes de resonancia magnética (RM) o tomografías computarizadas (TC), para detectar anomalías o enfermedades.
#    - *Ejemplo:* Un algoritmo de Aprendizaje Automático puede analizar imágenes de mamografía para identificar signos tempranos de cáncer de mama.
#
# 5. **Vehículos Autónomos:**
#
#    - *Explicación:* Los vehículos autónomos, como coches y drones, utilizan sistemas de percepción basados en Aprendizaje Automático para reconocer señales de tráfico, peatones y obstáculos, y tomar decisiones en tiempo real.
#    - *Ejemplo:* Los automóviles autónomos de empresas como Tesla y Waymo utilizan cámaras y sensores que se basan en algoritmos de Aprendizaje Automático para navegar de manera segura.
#
# 6. **Detección de Fraudes en Transacciones Financieras:**
#
#    - *Explicación:* Los bancos y las instituciones financieras utilizan el Aprendizaje Automático para identificar transacciones fraudulentas. Los modelos analizan patrones de gastos y comportamiento del cliente para detectar actividades sospechosas.
#    - *Ejemplo:* Si realizas una compra inusualmente grande en una ubicación inusual, el sistema bancario puede enviar una alerta de fraude para verificar la autenticidad de la transacción.
#
# 7. **Procesamiento de Lenguaje Natural (NLP):**
#
#    - *Explicación:* Aplicaciones de NLP utilizan modelos de Aprendizaje Automático para entender y generar texto en lenguaje humano. Esto incluye traducción automática, chatbots y análisis de sentimiento en redes sociales.
#    - *Ejemplo:* Google Translate utiliza modelos de Aprendizaje Automático para traducir texto entre múltiples idiomas.
#
# 8. **Agricultura de Precisión:**
#
#    - *Explicación:* Los agricultores utilizan imágenes satelitales y drones con Aprendizaje Automático para monitorear y optimizar el crecimiento de cultivos, identificar plagas y reducir el uso de agua y fertilizantes.
#    - *Ejemplo:* Mediante el análisis de imágenes aéreas, se puede identificar la salud de los cultivos y tomar decisiones informadas sobre la irrigación y el tratamiento de plagas.
#
# 9. **Predicción del Tiempo y Modelos Climáticos:**
#
#    - *Explicación:* Los modelos de predicción del tiempo utilizan Aprendizaje Automático para analizar datos climáticos históricos y actuales y realizar pronósticos meteorológicos precisos.
#    - *Ejemplo:* Los servicios meteorológicos utilizan modelos de Aprendizaje Automático para proporcionar pronósticos locales y globales.
#
# 10. **Control de Calidad en Manufactura:**
#
#     - *Explicación:* Las fábricas utilizan sensores y sistemas de visión con Aprendizaje Automático para inspeccionar productos y detectar defectos en tiempo real.
#     - *Ejemplo:* En la producción de automóviles, los sistemas de visión con Aprendizaje Automático pueden detectar imperfecciones en la pintura o ensamblajes defectuosos.
#
# Estos ejemplos muestran cómo el Aprendizaje Automático se ha convertido en una herramienta fundamental en diversas áreas y ha transformado la forma en que interactuamos con la tecnología y resolvemos problemas en la vida cotidiana.

# %% [markdown]
# # **9. Ciclo de vida del desarrollo del aprendizaje automático | MLDLC en ciencia de datos**

# %% [markdown]
# El Ciclo de Vida del Desarrollo del Aprendizaje Automático (Machine Learning Development Lifecycle, MLDLC) es un enfoque estructurado para el desarrollo, implementación y mantenimiento de modelos de Aprendizaje Automático en el contexto de la Ciencia de Datos. Este ciclo de vida consta de varias etapas interconectadas que guían a los científicos de datos y a los ingenieros a lo largo del proceso. A continuación, proporcionaré una explicación detallada de las etapas del MLDLC, junto con ejemplos:
#
# 1. **Definición del Problema:**
#
#    - *Explicación:* En esta etapa, se identifica y define el problema que se pretende resolver con el Aprendizaje Automático. Se deben comprender los objetivos comerciales y recopilar los requisitos del proyecto.
#    - *Ejemplo:* Supongamos que una empresa de comercio electrónico desea reducir la tasa de abandono del carrito de compras. El problema se define como la predicción de qué usuarios abandonarán el carrito y cómo retenerlos.
#
# 2. **Adquisición de Datos:**
#
#    - *Explicación:* En esta etapa, se recopilan, limpian y preparan los datos necesarios para el entrenamiento y la evaluación de modelos. Esto puede implicar la integración de múltiples fuentes de datos y la eliminación de valores atípicos o datos faltantes.
#    - *Ejemplo:* La empresa de comercio electrónico recopila datos de registros de actividad de los usuarios, historiales de compras y datos de navegación en el sitio web.
#
# 3. **Exploración y Análisis de Datos:**
#
#    - *Explicación:* Los datos se exploran y se realiza un análisis exploratorio para comprender las relaciones entre las características y la variable objetivo. Esto ayuda a identificar patrones y seleccionar las características más relevantes.
#    - *Ejemplo:* Se pueden analizar las correlaciones entre la duración de la sesión de un usuario, la cantidad de productos en el carrito y si finalmente realizan una compra.
#
# 4. **Preparación de Datos:**
#
#    - *Explicación:* En esta etapa, los datos se preparan para el entrenamiento del modelo. Esto incluye la codificación de características, la normalización y la división de datos en conjuntos de entrenamiento y prueba.
#    - *Ejemplo:* Se codifican variables categóricas, se normalizan los valores numéricos y se dividen los datos en un 80% para entrenamiento y un 20% para pruebas.
#
# 5. **Diseño y Entrenamiento del Modelo:**
#
#    - *Explicación:* En esta etapa, se selecciona el algoritmo de Aprendizaje Automático adecuado y se entrena el modelo utilizando los datos de entrenamiento.
#    - *Ejemplo:* Se elige un algoritmo de clasificación, como Regresión Logística o un Árbol de Decisión, y se entrena el modelo para predecir la probabilidad de abandono del carrito.
#
# 6. **Evaluación del Modelo:**
#
#    - *Explicación:* El modelo se evalúa utilizando métricas de rendimiento, como precisión, sensibilidad, especificidad, F1-score, etc. Esto ayuda a determinar qué tan bien se desempeña en datos no vistos.
#    - *Ejemplo:* Se calcula la precisión del modelo en predecir correctamente si un usuario abandonará el carrito o no.
#
# 7. **Ajuste y Optimización del Modelo:**
#
#    - *Explicación:* Si el modelo no cumple con los requisitos de rendimiento, se realizan ajustes y optimizaciones. Esto puede implicar ajustar hiperparámetros, probar diferentes algoritmos o realizar ingeniería de características.
#    - *Ejemplo:* Se ajusta la profundidad de un árbol de decisión o se prueba un modelo de Bosque Aleatorio en lugar de un modelo de Regresión Logística.
#
# 8. **Implementación del Modelo:**
#
#    - *Explicación:* Una vez que el modelo cumple con los criterios de rendimiento, se implementa en un entorno de producción. Esto puede implicar la integración con sistemas en tiempo real o la creación de una aplicación web.
#    - *Ejemplo:* El modelo se implementa en el sitio web de comercio electrónico para identificar a los usuarios que pueden abandonar el carrito y tomar medidas para retenerlos.
#
# 9. **Monitorización y Mantenimiento:**
#
#    - *Explicación:* Después de la implementación, se monitorea el rendimiento del modelo en producción y se realiza un mantenimiento continuo. Esto implica la actualización del modelo a medida que cambian los datos y las condiciones.
#    - *Ejemplo:* Si las tendencias de compra de los usuarios cambian con el tiempo, el modelo se ajusta para mantener su efectividad.
#
# 10. **Documentación y Comunicación:**
#
#     - *Explicación:* Se documenta todo el proceso de desarrollo, desde la definición del problema hasta la implementación, y se comunica con partes interesadas clave.
#     - *Ejemplo:* Se crea un informe detallado que documenta los pasos seguidos, las decisiones tomadas y los resultados obtenidos.
#
# El Ciclo de Vida del Desarrollo del Aprendizaje Automático es un enfoque iterativo y continuo, ya que el mantenimiento y la mejora del modelo son esenciales para su éxito a lo largo del tiempo. Los científicos de datos y los ingenieros deben estar preparados para ajustar y optimizar los modelos a medida que se desarrollan y se implementan en situaciones de la vida real.

# %% [markdown]
# ![ciclo de vida](../img/ciclo_de_vida.png "ciclo de vida")

# %% [markdown]
# # **10. Ingeniero de datos V Analista de datos V Científico de datos V Ingeniero de ML**

# %% [markdown]
# Los roles en el campo de la Ciencia de Datos y el Aprendizaje Automático a menudo se superponen, pero cada uno tiene enfoques y responsabilidades ligeramente diferentes. Aquí te proporcionaré una explicación detallada de cuatro roles clave en este ámbito, junto con ejemplos de lo que hacen:
#
# 1. **Ingeniero de Datos:**
#
#    - *Explicación:* Los ingenieros de datos son responsables de recopilar, almacenar y procesar datos de manera eficiente y confiable. Diseñan sistemas y arquitecturas para la ingesta, transformación y almacenamiento de datos.
#    - *Ejemplo:* Un ingeniero de datos en una empresa de redes sociales desarrolla un sistema para recopilar y almacenar automáticamente los datos de millones de usuarios, lo que incluye publicaciones, fotos y relaciones entre usuarios.
#
# 2. **Analista de Datos:**
#
#    - *Explicación:* Los analistas de datos son expertos en la interpretación de datos y generación de informes. Realizan análisis exploratorios, identifican tendencias y patrones, y presentan resultados a las partes interesadas.
#    - *Ejemplo:* Un analista de datos en una empresa de comercio electrónico analiza datos de ventas para identificar los productos más vendidos, las tendencias estacionales y los patrones de compra de los clientes.
#
# 3. **Científico de Datos:**
#
#    - *Explicación:* Los científicos de datos tienen un conjunto diverso de habilidades que abarcan la recopilación y preparación de datos, análisis de datos y modelado predictivo. Se centran en la creación de modelos de Machine Learning para resolver problemas de negocio.
#    - *Ejemplo:* Un científico de datos en una compañía de seguros utiliza datos históricos para desarrollar un modelo de predicción de reclamaciones que ayuda a la empresa a identificar posibles fraudes.
#
# 4. **Ingeniero de Aprendizaje Automático (ML Engineer):**
#
#    - *Explicación:* Los ingenieros de Aprendizaje Automático se centran en la implementación y producción de modelos de Machine Learning en entornos de producción. A menudo trabajan en estrecha colaboración con los científicos de datos para llevar los modelos a la vida real.
#    - *Ejemplo:* Un ingeniero de Aprendizaje Automático en una empresa de transporte desarrolla un sistema de recomendación en tiempo real que sugiere rutas de tráfico óptimas para los conductores de entrega.
#
# Es importante destacar que estos roles no son mutuamente excluyentes y a menudo trabajan en colaboración en proyectos de Ciencia de Datos y Aprendizaje Automático. Por ejemplo, un ingeniero de datos puede recopilar y limpiar los datos, un analista de datos puede realizar análisis exploratorios, un científico de datos puede desarrollar un modelo de predicción y un ingeniero de Aprendizaje Automático puede implementar ese modelo en producción.
#
# Además, las organizaciones pueden tener diferentes nombres para estos roles, y las responsabilidades pueden variar según la empresa y la industria. Lo fundamental es que todos estos profesionales trabajan juntos para aprovechar los datos y desarrollar soluciones basadas en datos que impulsen la toma de decisiones y la innovación.

# %% [markdown]
# | **Inicio** | **Siguiente 2** |
# |----------- |---------------|
# | [🏠](../../README.md) | [⏩](2_Machine_Learning.ipynb)|
