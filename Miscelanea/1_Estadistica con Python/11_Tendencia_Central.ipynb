# %% [markdown]
# | **Inicio** | **atrás 10** | **Siguiente 12** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./10_Correlacion_de_Spearman_Pearson.ipynb)| [⏩](./12_datos_Categoricos_Ordinales.ipynb)|

# %% [markdown]
# # **11. Las 3 Medidas de Tendencia Central más Utilizadas: Promedio (o Media), Mediana y Moda con Python**

# %% [markdown]
# ## **Introducción a la medidas de tendencia central**

# %% [markdown]
# Las tres medidas de tendencia central más utilizadas son el promedio (o media), la mediana y la moda. Estas medidas nos ayudan a resumir y comprender la distribución de datos en un conjunto de observaciones. A continuación, explicaré cada una de estas medidas con ejemplos y sus respectivas gráficas en Python.
#
# 1. **Promedio (o Media):**
#
# El promedio es una medida de tendencia central que se calcula sumando todos los valores en el conjunto de datos y dividiéndolos entre el número total de observaciones. Es la suma de los valores dividida por el número de elementos en el conjunto de datos.
#
# **Ejemplo de Promedio con Python:**
#
# Supongamos que tenemos el siguiente conjunto de datos que representa las edades de un grupo de personas:

# %%
edades = [25, 30, 22, 28, 35, 27, 31, 29, 26, 24]

# %% [markdown]
# Para calcular el promedio en Python, podemos utilizar la función `mean()` de la librería NumPy:

# %%
import numpy as np

promedio = np.mean(edades)

print("Promedio:", promedio)
# Out:
# Promedio: 27.7

# %% [markdown]
# **Gráfica:**
#
# Podemos visualizar la distribución de edades con un histograma para tener una idea de cómo se agrupan los datos alrededor del promedio:

# %%
import matplotlib.pyplot as plt

plt.hist(edades, bins=5, edgecolor='black')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
plt.title('Histograma de Edades')
plt.axvline(promedio, color='red', linestyle='dashed', linewidth=2, label='Promedio')
plt.legend()
plt.show()

# %% [markdown]
# **Resultado:**
#
# La gráfica mostrará un histograma de las edades con una línea vertical roja punteada en el valor del promedio (28.7). Esta línea representa el promedio y nos indica cómo se agrupan los datos alrededor de este valor.
#
# 2. **Mediana:**
#
# La mediana es la medida de tendencia central que se encuentra en el centro de un conjunto de datos ordenados. Para calcular la mediana, es necesario ordenar los datos de manera ascendente o descendente y luego encontrar el valor que se encuentra en la posición central. Si hay un número impar de observaciones, la mediana será el valor en la posición central. Si hay un número par de observaciones, la mediana será el promedio de los dos valores centrales.
#
# **Ejemplo de Mediana con Python:**
#
# Continuando con el ejemplo anterior, vamos a calcular la mediana de las edades utilizando la función `median()` de NumPy:

# %%
mediana = np.median(edades)

print("Mediana:", mediana)
# Out:
# Mediana: 27.5

# %% [markdown]
# **Gráfica:**
#
# Podemos visualizar la mediana en el histograma anterior agregando una línea vertical verde punteada:

# %%
plt.hist(edades, bins=5, edgecolor='black')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
plt.title('Histograma de Edades')
plt.axvline(promedio, color='red', linestyle='dashed', linewidth=2, label='Promedio')
plt.axvline(mediana, color='green', linestyle='dashed', linewidth=2, label='Mediana')
plt.legend()
plt.show()

# %% [markdown]
# **Resultado:**
#
# La gráfica mostrará el histograma de las edades con dos líneas verticales punteadas: una roja para el promedio y una verde para la mediana. Esto nos permite comparar la ubicación del promedio y la mediana en la distribución de datos.
#
# 3. **Moda:**
#
# La moda es el valor que aparece con mayor frecuencia en un conjunto de datos. Es posible que un conjunto de datos tenga una moda (unimodal), dos modas (bimodal) o más modas (multimodal). También es posible que un conjunto de datos no tenga una moda, si todos los valores son diferentes y no hay repetición.
#
# **Ejemplo de Moda con Python:**
#
# Continuando con el mismo ejemplo, vamos a calcular la moda de las edades utilizando la función `mode()` de la librería SciPy:

# %%
from collections import Counter

edades = [25, 30, 22, 28, 35, 27, 31, 29, 26, 24]

# Calcular la moda
moda_counter = Counter(edades)
moda = moda_counter.most_common(1)[0][0]
frecuencia_moda = moda_counter.most_common(1)[0][1]

print("Moda:", moda)
print("Frecuencia de la Moda:", frecuencia_moda)
# Out:
# Moda: 25
# Frecuencia de la Moda: 1

# %% [markdown]
# **Gráfica:**
#
# Podemos visualizar la moda en el histograma anterior agregando una línea vertical azul punteada:

# %%
plt.hist(edades, bins=5, edgecolor='black')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
plt.title('Histograma de Edades')
plt.axvline(promedio, color='red', linestyle='dashed', linewidth=2, label='Promedio')
plt.axvline(mediana, color='green', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda, color='blue', linestyle='dashed', linewidth=2, label='Moda')
plt.legend()
plt.show()

# %% [markdown]
# **Resultado:**
#
# La gráfica mostrará el histograma de las edades con tres líneas verticales punteadas: una roja para el promedio, una verde para la mediana y una azul para la moda. Esto nos permite identificar visualmente el valor que aparece con mayor frecuencia en la distribución de datos.
#
# En resumen, el promedio, la mediana y la moda son tres medidas de tendencia central utilizadas para resumir y comprender la distribución de datos en un conjunto de observaciones. Cada una de estas medidas tiene sus propias ventajas y limitaciones, y es importante utilizarlas en función del tipo de datos y el objetivo del análisis.

# %% [markdown]
# ## **Promedio o media aritmética**

# %% [markdown]
# La media aritmética, comúnmente conocida como promedio, es una medida estadística que se utiliza para representar el valor típico o central de un conjunto de datos numéricos. Se calcula sumando todos los valores en el conjunto y luego dividiendo esa suma entre el número total de elementos en el conjunto.
#
# La fórmula para calcular el promedio de un conjunto de datos de tamaño $n$ es:
#
# $\text{Promedio} = \frac{X_1 + X_2 + \ldots + X_n}{n}$
#
# Donde $X_1$, $X_2$, $\ldots$, $X_n$ son los elementos del conjunto de datos y $n$ es el número total de elementos.
#
# Veamos un ejemplo para calcular el promedio de las siguientes notas: 80, 85, 90, 70, 95.
#
# Paso 1: Sumar todas las notas.
#
# $\text{Suma} = 80 + 85 + 90 + 70 + 95 = 420$
#
# Paso 2: Calcular el promedio.
#
# $\text{Promedio} = \frac{420}{5} = 84$
#
# Por lo tanto, el promedio de estas notas es 84.
#
# Ahora, vamos a visualizar esta información en una gráfica de barras usando Python. Utilizaremos la biblioteca `matplotlib` para graficar los datos.

# %%
import matplotlib.pyplot as plt

# Datos
notas = [80, 85, 90, 70, 95]
n = len(notas)

# Cálculo del promedio
suma = sum(notas)
promedio = suma / n

# Gráfica de barras
plt.bar(range(n), notas, tick_label=["Nota 1", "Nota 2", "Nota 3", "Nota 4", "Nota 5"])
plt.axhline(y=promedio, color='r', linestyle='dashed', label='Promedio')
plt.xlabel('Notas')
plt.ylabel('Valor')
plt.title('Notas y su Promedio')
plt.legend()
plt.show()

# %% [markdown]
# En esta gráfica, las barras representan las notas individuales, y la línea roja punteada representa el promedio (84) de las notas. La línea roja nos muestra el valor típico o central del conjunto de datos.
#
# Recuerda que el promedio es solo una medida estadística básica y puede no reflejar la distribución completa de los datos.
#
#  Por ejemplo, si tenemos un conjunto de datos {1, 2, 3, 1000}, el promedio sería (1 + 2 + 3 + 1000) / 4 = 251.5, que no representa bien la mayoría de los datos. En tales casos, otras medidas como la mediana o la desviación estándar pueden proporcionar una mejor comprensión de la distribución.

# %% [markdown]
# ## **Mediana**

# %% [markdown]
# La mediana es otra medida estadística utilizada para representar el valor central de un conjunto de datos numéricos. A diferencia del promedio, la mediana no se ve afectada por valores extremos o atípicos en los datos y, por lo tanto, proporciona una mejor representación del valor típico cuando hay valores atípicos presentes.
#
# Para calcular la mediana, primero se deben ordenar los datos en orden ascendente o descendente, y luego se selecciona el valor que se encuentra en la posición central del conjunto de datos. Si el conjunto de datos tiene un número impar de elementos, la mediana será el valor que está justo en el medio. Si el conjunto de datos tiene un número par de elementos, la mediana se calcula promediando los dos valores centrales.
#
# Veamos un ejemplo para calcular la mediana del siguiente conjunto de datos: 10, 20, 30, 40, 50.
#
# **Paso 1:** Ordenar los datos en orden ascendente: 10, 20, 30, 40, 50.
#
# **Paso 2:** Identificar el valor central, que en este caso es el tercer valor, que es 30.
#
# Por lo tanto, la mediana de este conjunto de datos es 30.
#
# Ahora, vamos a visualizar esta información en una gráfica de barras usando Python. Utilizaremos la biblioteca matplotlib para graficar los datos.

# %%
import matplotlib.pyplot as plt

# Datos
datos = [10, 20, 30, 40, 50]

# Cálculo de la mediana
n = len(datos)
datos_ordenados = sorted(datos)
mediana = datos_ordenados[n // 2] if n % 2 != 0 else (datos_ordenados[n // 2 - 1] + datos_ordenados[n // 2]) / 2

# Gráfica de barras
plt.bar(range(n), datos, tick_label=["Dato 1", "Dato 2", "Dato 3", "Dato 4", "Dato 5"])
plt.axhline(y=mediana, color='r', linestyle='dashed', label='Mediana')
plt.xlabel('Datos')
plt.ylabel('Valor')
plt.title('Datos y su Mediana')
plt.legend()
plt.show()

# %% [markdown]
# En esta gráfica, las barras representan los datos individuales, y la línea roja punteada representa la mediana (30) del conjunto de datos. La mediana nos proporciona una mejor idea del valor central de los datos, ya que no se ve afectada por los valores extremos, como el valor 10 que es más pequeño y el valor 50 que es más grande.
#
# La mediana es especialmente útil cuando tenemos datos sesgados o con valores atípicos, ya que no se ve influenciada por esos valores y ofrece una perspectiva más robusta del valor central del conjunto de datos.

# %% [markdown]
# ## **Moda**

# %% [markdown]
# La moda es otra medida estadística utilizada para representar el valor más frecuente o repetido en un conjunto de datos numéricos o categóricos. En otras palabras, la moda es el valor que aparece con mayor frecuencia en el conjunto de datos.
#
# En un conjunto de datos, puede haber uno o más valores que se repiten con mayor frecuencia. Si un conjunto de datos tiene un solo valor que aparece con mayor frecuencia, se dice que tiene una "moda unimodal". Si hay dos o más valores que tienen la misma frecuencia máxima y son más frecuentes que los demás valores, se dice que tiene una "moda bimodal" o "multimodal".
#
# Veamos un ejemplo para calcular la moda del siguiente conjunto de datos: 10, 20, 30, 40, 30, 50, 30.
#
# **Paso 1:** Identificar los valores que se repiten y contar su frecuencia:
#
# - 10 aparece 1 vez.
# - 20 aparece 1 vez.
# - 30 aparece 3 veces.
# - 40 aparece 1 vez.
# - 50 aparece 1 vez.
#
# **Paso 2:** Identificar el valor con la mayor frecuencia, que es 30. Por lo tanto, la moda de este conjunto de datos es 30.
#
# Ahora, vamos a visualizar esta información en una gráfica de barras usando Python. Utilizaremos la biblioteca `matplotlib` para graficar los datos.

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Datos
datos = [10, 20, 30, 40, 30, 50, 30]

# Cálculo de la moda
frecuencias = Counter(datos)
moda = max(frecuencias, key=frecuencias.get)

# Gráfica de barras
plt.bar(frecuencias.keys(), frecuencias.values())
plt.axhline(y=frecuencias[moda], color='r', linestyle='dashed', label='Moda')
plt.xlabel('Datos')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de Datos y su Moda')
plt.legend()
plt.show()

# %% [markdown]
# En esta gráfica, las barras representan los datos individuales, y la línea roja punteada representa la moda (30) del conjunto de datos. Podemos observar que el valor 30 es el que tiene la frecuencia más alta y, por lo tanto, es la moda del conjunto de datos.
#
# La moda es útil para identificar cuál es el valor más representativo o frecuente en un conjunto de datos. Puede ser especialmente relevante en datos categóricos, como tipos de frutas o colores, donde la moda nos dirá cuál es la opción más popular. Además, también puede ser útil en datos numéricos para identificar los valores más comunes y frecuentes en una distribución.

# %% [markdown]
# ## **Medidas de tendencia central con Python**

# %% [markdown]
# Las medidas de tendencia central son estadísticas descriptivas que nos permiten resumir y representar un conjunto de datos en un solo valor que representa su "centro". Las tres medidas de tendencia central más comunes son el promedio (o media aritmética), la mediana y la moda, que ya hemos explicado individualmente en preguntas anteriores. Ahora, vamos a proporcionar una explicación detallada de cada una junto con ejemplos y gráficas en Python para cada medida.
#
# **1. Promedio (Media Aritmética):**
#
# Ya hemos explicado el concepto y el cálculo del promedio en la primera pregunta. Repasemos rápidamente:
#
# El promedio es la suma de todos los valores en un conjunto de datos dividida por el número total de elementos.
#
# **Ejemplo:**
#
# Consideremos el siguiente conjunto de datos: 5, 10, 15, 20, 25.
#
# Paso 1: Sumar todos los valores: 5 + 10 + 15 + 20 + 25 = 75.
#
# Paso 2: Calcular el promedio: 75 / 5 = 15.

# %%
import matplotlib.pyplot as plt

# Datos
datos = [5, 10, 15, 20, 25]

# Cálculo del promedio
promedio = sum(datos) / len(datos)

# Gráfica de barras
plt.bar(range(len(datos)), datos, tick_label=["Dato 1", "Dato 2", "Dato 3", "Dato 4", "Dato 5"])
plt.axhline(y=promedio, color='r', linestyle='dashed', label='Promedio')
plt.xlabel('Datos')
plt.ylabel('Valor')
plt.title('Datos y su Promedio')
plt.legend()
plt.show()

# %% [markdown]
# **2. Mediana:**
# Ya hemos explicado el concepto y el cálculo de la mediana en la segunda pregunta. Repasemos rápidamente:
#
# La mediana es el valor central de un conjunto de datos una vez que los datos se han ordenado.
#
# **Ejemplo:**
#
# Consideremos el siguiente conjunto de datos: 10, 20, 30, 40, 50.
#
# Paso 1: Ordenar los datos en orden ascendente: 10, 20, 30, 40, 50.
#
# Paso 2: Identificar el valor central, que en este caso es el tercer valor, que es 30.

# %%
import matplotlib.pyplot as plt

# Datos
datos = [10, 20, 30, 40, 50]

# Cálculo de la mediana
n = len(datos)
datos_ordenados = sorted(datos)
mediana = datos_ordenados[n // 2] if n % 2 != 0 else (datos_ordenados[n // 2 - 1] + datos_ordenados[n // 2]) / 2

# Gráfica de barras
plt.bar(range(n), datos, tick_label=["Dato 1", "Dato 2", "Dato 3", "Dato 4", "Dato 5"])
plt.axhline(y=mediana, color='r', linestyle='dashed', label='Mediana')
plt.xlabel('Datos')
plt.ylabel('Valor')
plt.title('Datos y su Mediana')
plt.legend()
plt.show()

# %% [markdown]
# **3. Moda:**
#
# Ya hemos explicado el concepto y el cálculo de la moda en la tercera pregunta. Repasemos rápidamente:
#
# La moda es el valor más frecuente en un conjunto de datos.
#
# **Ejemplo:**
#
# Consideremos el siguiente conjunto de datos: 10, 20, 30, 40, 30, 50, 30.
#
# Paso 1: Identificar los valores que se repiten y contar su frecuencia:
#
# - 10 aparece 1 vez.
# - 20 aparece 1 vez.
# - 30 aparece 3 veces.
# - 40 aparece 1 vez.
# - 50 aparece 1 vez.
#
# Paso 2: Identificar el valor con la mayor frecuencia, que es 30.

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Datos
datos = [10, 20, 30, 40, 30, 50, 30]

# Cálculo de la moda
frecuencias = Counter(datos)
moda = max(frecuencias, key=frecuencias.get)

# Gráfica de barras
plt.bar(frecuencias.keys(), frecuencias.values())
plt.axhline(y=frecuencias[moda], color='r', linestyle='dashed', label='Moda')
plt.xlabel('Datos')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de Datos y su Moda')
plt.legend()
plt.show()

# %% [markdown]
# Estas tres medidas de tendencia central (promedio, mediana y moda) son herramientas valiosas para resumir y entender conjuntos de datos. Es importante considerar cada una de ellas según el tipo de datos que se esté analizando y la naturaleza de la distribución para obtener una visión completa de los datos.

# %% [markdown]
# ## **Distribución de datos y Medidas de tendencia central**

# %% [markdown]
# **Distribución de datos:**
#
# La distribución de datos es una descripción de cómo se encuentran distribuidos los valores en un conjunto de datos. En otras palabras, muestra cómo se agrupan o dispersan los datos alrededor de diferentes valores en el conjunto. Entender la distribución de los datos es fundamental para analizar y tomar decisiones basadas en los datos. Una distribución puede ser simétrica o asimétrica, y puede tener diferentes formas como la distribución normal, la distribución sesgada a la izquierda (negativa), la distribución sesgada a la derecha (positiva), entre otras.
#
# Algunas características importantes de una distribución incluyen la ubicación central (representada por las medidas de tendencia central), la dispersión (representada por las medidas de dispersión como la desviación estándar), y la forma general.
#
# **Medidas de tendencia central:**
#
# Las medidas de tendencia central son estadísticas descriptivas que nos permiten resumir y representar un conjunto de datos en un solo valor que representa su "centro". Las tres medidas de tendencia central más comunes son:
#
# 1. **Promedio (o media aritmética):**
#
#  Es la suma de todos los valores en un conjunto de datos dividida por el número total de elementos. Representa el valor típico de los datos y puede ser afectado por valores extremos.
#
# 2. **Mediana:**
#
#  Es el valor central de un conjunto de datos una vez que los datos se han ordenado. Es útil cuando hay valores extremos o atípicos, ya que no se ve afectada por ellos.
#
# 3. **Moda:**
#
#  Es el valor más frecuente en un conjunto de datos. Es útil para identificar el valor más representativo o frecuente en un conjunto de datos.
#
# **Ejemplo:**
#
# Consideremos el siguiente conjunto de datos de calificaciones de estudiantes en un examen:
#
# ```
# calificaciones = [70, 75, 80, 85, 90, 90, 95, 100, 100, 100]
# ```
#
# **1. Promedio:**
#
# Para calcular el promedio, sumamos todas las calificaciones y lo dividimos por el número total de calificaciones.
#
# ```
# promedio = (70 + 75 + 80 + 85 + 90 + 90 + 95 + 100 + 100 + 100) / 10
# promedio = 90
# ```
#
# **2. Mediana:**
#
# Primero, ordenamos las calificaciones de forma ascendente:
#
# ```
# calificaciones_ordenadas = [70, 75, 80, 85, 90, 90, 95, 100, 100, 100]
# ```
#
# Como hay un número par de calificaciones, la mediana será el promedio de las dos calificaciones centrales.
#
# ```
# mediana = (90 + 90) / 2
# mediana = 90
# ```
#
# **3. Moda:**
#
# La moda es el valor más frecuente, en este caso, la calificación que aparece con mayor frecuencia es 100.
#
# ```
# moda = 100
# ```
#
# **Gráficas:**
#
# Veamos cómo se ven estas medidas de tendencia central en gráficas usando Python y la biblioteca `matplotlib`.

# %%
import matplotlib.pyplot as plt

calificaciones = [70, 75, 80, 85, 90, 90, 95, 100, 100, 100]

# Cálculo del promedio
promedio = sum(calificaciones) / len(calificaciones)

# Cálculo de la mediana
n = len(calificaciones)
calificaciones_ordenadas = sorted(calificaciones)
mediana = calificaciones_ordenadas[n // 2] if n % 2 != 0 else (calificaciones_ordenadas[n // 2 - 1] + calificaciones_ordenadas[n // 2]) / 2

# Cálculo de la moda
from collections import Counter
frecuencias = Counter(calificaciones)
moda = max(frecuencias, key=frecuencias.get)

# Gráfica de barras
plt.bar(range(n), calificaciones, tick_label=[f"{i+1}" for i in range(n)])
plt.axhline(y=promedio, color='r', linestyle='dashed', label='Promedio')
plt.axhline(y=mediana, color='g', linestyle='dashed', label='Mediana')
plt.axhline(y=moda, color='b', linestyle='dashed', label='Moda')
plt.xlabel('Estudiantes')
plt.ylabel('Calificaciones')
plt.title('Calificaciones y sus Medidas de Tendencia Central')
plt.legend()
plt.show()

# %% [markdown]
# En esta gráfica, las barras representan las calificaciones de cada estudiante, y las líneas punteadas representan el promedio (en rojo), la mediana (en verde) y la moda (en azul). Podemos ver cómo estas medidas de tendencia central resumen y representan diferentes aspectos de la distribución de datos. En este caso, las tres medidas coinciden en 90, lo que indica que la mayoría de los estudiantes obtuvieron una calificación alta de 90.

# %% [markdown]
# | **Inicio** | **atrás 10** | **Siguiente 12** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./10_Correlacion_de_Spearman_Pearson.ipynb)| [⏩](./12_datos_Categoricos_Ordinales.ipynb)|
