# %% [markdown]
# | **Inicio** | **atrás 23** |
# |----------- |-------------- |
# | [🏠](../../README.md) | [⏪](./23_Exploratorio_de_Series_de_Tiempo.ipynb)|

# %% [markdown]
# # **24. Las 5 formas más Simples de Predecir el FUTURO en Series de Tiempo con Python: Media Móvil y ✚**

# %% [markdown]
# ## **Introducción**

# %% [markdown]
# Predecir el futuro en series de tiempo es un objetivo clave en el análisis de datos. Una de las formas más simples de predecir valores futuros es utilizando técnicas de promedio móvil. Aquí te explicaré dos de estas técnicas: la media móvil y la media móvil ponderada, junto con ejemplos y gráficas correspondientes utilizando Python y las bibliotecas Pandas y Matplotlib.
#
# Asegúrate de tener las bibliotecas instaladas utilizando el siguiente código:
#
# **1. Media Móvil:**
#
# La media móvil es una técnica que suaviza una serie de tiempo calculando el promedio de los valores en un intervalo de tiempo específico. Esto ayuda a eliminar el ruido y revelar tendencias subyacentes.
#
# **Ejemplo de Media Móvil:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Crear datos de ejemplo
np.random.seed(0)
dates = pd.date_range(start='2021-01-01', periods=50, freq='D')
values = np.sin(np.linspace(0, 4 * np.pi, 50)) + np.random.normal(0, 0.2, 50)

# Crear un DataFrame de Pandas
data = pd.DataFrame({'Date': dates, 'Values': values})
data.set_index('Date', inplace=True)

# Calcular la media móvil con ventana de tamaño 7
rolling_mean = data['Values'].rolling(window=7).mean()

# Graficar la serie original y la media móvil
plt.figure(figsize=(10, 6))
plt.plot(data['Values'], label='Serie Original')
plt.plot(rolling_mean, label='Media Móvil (Ventana 7)')
plt.legend()
plt.title('Media Móvil en Series de Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# En este ejemplo, hemos creado una serie de tiempo que es la suma de una función sinusoidal y ruido. Calculamos la media móvil utilizando una ventana de tamaño 7 para suavizar la serie. La gráfica muestra la serie original y la media móvil.
#
# **2. Media Móvil Ponderada:**
#
# La media móvil ponderada es similar a la media móvil, pero en lugar de asignar un peso uniforme a todos los valores en la ventana, se asignan pesos diferentes según su posición en la ventana.
#
# **Ejemplo de Media Móvil Ponderada:**

# %%
# Calcular la media móvil ponderada con ventana de tamaño 5 y pesos [0.1, 0.2, 0.3, 0.2, 0.1]
weights = [0.1, 0.2, 0.3, 0.2, 0.1]
weighted_rolling_mean = data['Values'].rolling(window=5).apply(lambda x: np.dot(x, weights), raw=True)

# Graficar la serie original y la media móvil ponderada
plt.figure(figsize=(10, 6))
plt.plot(data['Values'], label='Serie Original')
plt.plot(weighted_rolling_mean, label='Media Móvil Ponderada (Ventana 5)')
plt.legend()
plt.title('Media Móvil Ponderada en Series de Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# En este ejemplo, hemos calculado la media móvil ponderada utilizando una ventana de tamaño 5 y pesos predefinidos. La gráfica muestra la serie original y la media móvil ponderada.
#
# En resumen, las técnicas de promedio móvil, como la media móvil y la media móvil ponderada, son métodos simples pero efectivos para predecir valores futuros en series de tiempo. Estas técnicas suavizan los datos y pueden ayudar a identificar tendencias subyacentes al eliminar el ruido.

# %% [markdown]
# ## **Métodos de Pronóstico Simples**

# %% [markdown]
# Los métodos de pronóstico simples son enfoques básicos utilizados para hacer predicciones en series de tiempo. Estos métodos no tienen en cuenta patrones complicados ni consideran relaciones complejas entre las observaciones pasadas y futuras. A continuación, te explicaré tres de los métodos de pronóstico más simples: Naïve, Media y Aleatorio, junto con ejemplos y gráficas correspondientes utilizando Python y las bibliotecas Pandas y Matplotlib.
#
# **1. Método Naïve (Inocente):**
#
# El método Naïve es uno de los métodos más simples de pronóstico. Consiste en asumir que el próximo valor será igual al valor más reciente en la serie de tiempo.
#
# **Ejemplo de Método Naïve:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Crear datos de ejemplo
np.random.seed(0)
dates = pd.date_range(start='2021-01-01', periods=50, freq='D')
values = np.sin(np.linspace(0, 4 * np.pi, 50)) + np.random.normal(0, 0.2, 50)

# Crear un DataFrame de Pandas
data = pd.DataFrame({'Date': dates, 'Values': values})
data.set_index('Date', inplace=True)

# Calcular el pronóstico Naïve
naive_forecast = data['Values'].shift(1)

# Graficar la serie original y el pronóstico Naïve
plt.figure(figsize=(10, 6))
plt.plot(data['Values'], label='Serie Original')
plt.plot(naive_forecast, label='Pronóstico Naïve')
plt.legend()
plt.title('Pronóstico Naïve en Series de Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# En este ejemplo, hemos creado una serie de tiempo con una función sinusoidal y ruido. El pronóstico Naïve simplemente es el valor más reciente de la serie de tiempo, desplazado hacia adelante. La gráfica muestra la serie original y el pronóstico Naïve.
#
# **2. Método de la Media:**
#
# El método de la Media pronostica los valores futuros utilizando el promedio de los valores pasados en la serie de tiempo.
#
# **Ejemplo de Método de la Media:**

# %%
# Calcular el pronóstico de la Media
mean_forecast = data['Values'].rolling(window=5).mean()

# Graficar la serie original y el pronóstico de la Media
plt.figure(figsize=(10, 6))
plt.plot(data['Values'], label='Serie Original')
plt.plot(mean_forecast, label='Pronóstico de la Media (Ventana 5)')
plt.legend()
plt.title('Pronóstico de la Media en Series de Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# En este ejemplo, hemos calculado el pronóstico de la Media utilizando el promedio móvil con una ventana de tamaño 5. La gráfica muestra la serie original y el pronóstico de la Media.
#
# **3. Método Aleatorio:**
#
# El método Aleatorio pronostica valores futuros seleccionando aleatoriamente valores anteriores de la serie de tiempo.
#
# **Ejemplo de Método Aleatorio:**

# %%
# Calcular el pronóstico Aleatorio
random_forecast = np.random.choice(data['Values'], size=len(data))

# Graficar la serie original y el pronóstico Aleatorio
plt.figure(figsize=(10, 6))
plt.plot(data['Values'], label='Serie Original')
plt.plot(data.index, random_forecast, label='Pronóstico Aleatorio')
plt.legend()
plt.title('Pronóstico Aleatorio en Series de Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# En este ejemplo, hemos calculado el pronóstico Aleatorio seleccionando valores anteriores de la serie de tiempo de manera aleatoria. La gráfica muestra la serie original y el pronóstico Aleatorio.
#
# En resumen, los métodos de pronóstico simples, como Naïve, Media y Aleatorio, son enfoques básicos para predecir valores futuros en series de tiempo. Estos métodos no tienen en cuenta patrones complejos y se utilizan generalmente como puntos de referencia para comparar con métodos más avanzados. Las gráficas ilustran cómo se comparan los pronósticos con la serie original.

# %% [markdown]
# ## **Método Ingenuo**

# %% [markdown]
# El método ingenuo, también conocido como "Naïve" o "Inocente", es uno de los métodos de pronóstico más simples y directos en el análisis de series de tiempo. Consiste en asumir que el próximo valor en la serie de tiempo será igual al valor más reciente observado. Aunque este enfoque puede parecer demasiado simplista, es útil como punto de referencia inicial y para evaluar la eficacia de otros métodos más complejos.
#
# A continuación, te proporcionaré una explicación detallada, un ejemplo y las respectivas gráficas para ilustrar el método ingenuo utilizando Python y las bibliotecas Pandas y Matplotlib.
#
#
# **Ejemplo de Método Ingenuo:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Crear datos de ejemplo
np.random.seed(0)
dates = pd.date_range(start='2021-01-01', periods=50, freq='D')
values = np.sin(np.linspace(0, 4 * np.pi, 50)) + np.random.normal(0, 0.2, 50)

# Crear un DataFrame de Pandas
data = pd.DataFrame({'Date': dates, 'Values': values})
data.set_index('Date', inplace=True)

# Calcular el pronóstico ingenuo (Naïve)
naive_forecast = data['Values'].shift(1)

# Graficar la serie original y el pronóstico ingenuo (Naïve)
plt.figure(figsize=(10, 6))
plt.plot(data['Values'], label='Serie Original')
plt.plot(naive_forecast, label='Pronóstico Ingenuo (Naïve)')
plt.legend()
plt.title('Pronóstico Ingenuo en Series de Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# En este ejemplo, hemos creado una serie de tiempo que es la suma de una función sinusoidal y ruido. El pronóstico ingenuo simplemente toma el valor más reciente de la serie de tiempo y lo desplaza hacia adelante. La gráfica muestra la serie original y el pronóstico ingenuo.
#
# **Interpretación:**
#
# - La línea azul representa la serie de tiempo original.
# - La línea naranja representa el pronóstico ingenuo, donde cada valor es el mismo que el valor en el tiempo anterior.
#
# Aunque el método ingenuo es muy básico y no considera patrones o tendencias en los datos, puede ser útil como un punto de partida para comprender la naturaleza de los datos y para evaluar la eficacia de otros métodos de pronóstico más complejos. En ocasiones, métodos más sofisticados no superan al método ingenuo si los datos no presentan patrones claros.

# %% [markdown]
# ## **Método de la Media**

# %% [markdown]
# El método de la media es uno de los métodos de pronóstico más simples en el análisis de series de tiempo. Consiste en calcular el promedio de los valores pasados en la serie y utilizar ese promedio como pronóstico para los valores futuros. Aunque este método no considera patrones complejos ni tendencias en los datos, puede ser útil para suavizar ruido y obtener una idea general de la dirección en la que se mueven los datos.
#
# A continuación, te proporcionaré una explicación detallada, un ejemplo y las respectivas gráficas para ilustrar el método de la media utilizando Python y las bibliotecas Pandas y Matplotlib.
#
# **Ejemplo de Método de la Media:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Crear datos de ejemplo
np.random.seed(0)
dates = pd.date_range(start='2021-01-01', periods=50, freq='D')
values = np.sin(np.linspace(0, 4 * np.pi, 50)) + np.random.normal(0, 0.2, 50)

# Crear un DataFrame de Pandas
data = pd.DataFrame({'Date': dates, 'Values': values})
data.set_index('Date', inplace=True)

# Calcular el pronóstico de la media con ventana de tamaño 5
mean_forecast = data['Values'].rolling(window=5).mean()

# Graficar la serie original y el pronóstico de la media
plt.figure(figsize=(10, 6))
plt.plot(data['Values'], label='Serie Original')
plt.plot(mean_forecast, label='Pronóstico de la Media (Ventana 5)')
plt.legend()
plt.title('Pronóstico de la Media en Series de Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# En este ejemplo, hemos creado una serie de tiempo que es la suma de una función sinusoidal y ruido. El pronóstico de la media calcula el promedio móvil utilizando una ventana de tamaño 5 para suavizar la serie. La gráfica muestra la serie original y el pronóstico de la media.
#
# **Interpretación:**
#
# - La línea azul representa la serie de tiempo original.
# - La línea naranja representa el pronóstico de la media, donde cada valor es el promedio de los valores en una ventana móvil de tamaño 5.
#
# Aunque el método de la media es simple y no considera patrones complejos, puede ser útil para identificar tendencias generales en los datos al eliminar el ruido. Sin embargo, este método puede ser sensible a cambios abruptos en los datos debido a la naturaleza de suavización de la media móvil.

# %% [markdown]
# ## **Método de la Media Móvil Simple**

# %% [markdown]
# El Método de la Media Móvil Simple es una técnica básica de pronóstico en el análisis de series de tiempo que consiste en calcular el promedio de un conjunto de observaciones pasadas en un intervalo de tiempo definido. Este método se utiliza para suavizar la serie de tiempo y reducir el ruido, lo que puede ayudar a identificar patrones o tendencias subyacentes.
#
# A continuación, te proporcionaré una explicación detallada, un ejemplo y las respectivas gráficas para ilustrar el Método de la Media Móvil Simple utilizando Python y las bibliotecas Pandas y Matplotlib.
#
# **Ejemplo de Método de la Media Móvil Simple:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Crear datos de ejemplo
np.random.seed(0)
dates = pd.date_range(start='2021-01-01', periods=50, freq='D')
values = np.sin(np.linspace(0, 4 * np.pi, 50)) + np.random.normal(0, 0.2, 50)

# Crear un DataFrame de Pandas
data = pd.DataFrame({'Date': dates, 'Values': values})
data.set_index('Date', inplace=True)

# Calcular la media móvil simple con ventana de tamaño 5
rolling_mean = data['Values'].rolling(window=5).mean()

# Graficar la serie original y la media móvil simple
plt.figure(figsize=(10, 6))
plt.plot(data['Values'], label='Serie Original')
plt.plot(rolling_mean, label='Media Móvil Simple (Ventana 5)')
plt.legend()
plt.title('Media Móvil Simple en Series de Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# En este ejemplo, hemos creado una serie de tiempo que es la suma de una función sinusoidal y ruido. Calculamos la media móvil simple utilizando una ventana de tamaño 5 para suavizar la serie. La gráfica muestra la serie original y la media móvil simple.
#
# **Interpretación:**
#
# - La línea azul representa la serie de tiempo original.
# - La línea naranja representa la media móvil simple, donde cada valor es el promedio de los valores en una ventana de tamaño 5.
#
# La media móvil simple suaviza los datos al eliminar el ruido y destacar patrones más claros en la serie de tiempo. Es importante elegir el tamaño adecuado de la ventana según la frecuencia y la naturaleza de los datos. Este método puede ser útil para identificar tendencias generales en los datos y obtener una visión más clara de su comportamiento a lo largo del tiempo.

# %% [markdown]
# ## **Método de la Deriva**

# %% [markdown]
# El Método de la Deriva, también conocido como método de tendencia lineal, es un enfoque simple de pronóstico en el análisis de series de tiempo que se basa en la extrapolación de una tendencia lineal en los datos pasados para predecir valores futuros. Este método asume que la serie de tiempo sigue una trayectoria lineal y utiliza la ecuación de una línea para hacer pronósticos.
#
# A continuación, te proporcionaré una explicación detallada, un ejemplo y las respectivas gráficas para ilustrar el Método de la Deriva utilizando Python y las bibliotecas Pandas y Matplotlib.
#
# **Ejemplo de Método de la Deriva:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Crear datos de ejemplo
np.random.seed(0)
dates = pd.date_range(start='2021-01-01', periods=50, freq='D')
trend = 0.1 * np.arange(50)
values = trend + np.random.normal(0, 0.2, 50)

# Crear un DataFrame de Pandas
data = pd.DataFrame({'Date': dates, 'Values': values})
data.set_index('Date', inplace=True)

# Calcular la tendencia lineal utilizando regresión
coefficients = np.polyfit(np.arange(len(data)), data['Values'], 1)
trend_line = np.polyval(coefficients, np.arange(len(data)))

# Graficar la serie original y la tendencia lineal
plt.figure(figsize=(10, 6))
plt.plot(data['Values'], label='Serie Original')
plt.plot(trend_line, label='Tendencia Lineal')
plt.legend()
plt.title('Método de la Deriva en Series de Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# En este ejemplo, hemos creado una serie de tiempo que sigue una tendencia lineal (la variable "trend") junto con ruido aleatorio. Utilizamos regresión lineal para calcular la ecuación de la línea de tendencia. La gráfica muestra la serie original y la tendencia lineal.
#
# **Interpretación:**
#
# - La línea azul representa la serie de tiempo original con tendencia y ruido.
# - La línea naranja representa la tendencia lineal extrapolada utilizando el método de la deriva.
#
# El método de la deriva es útil cuando existe una tendencia lineal clara en los datos y se desea proyectar esa tendencia en el futuro. Sin embargo, es importante tener en cuenta que este método no captura patrones más complejos y no es adecuado para series de tiempo con fluctuaciones irregulares o no lineales. En situaciones donde la tendencia es más compleja, es posible que sea necesario utilizar métodos más avanzados.

# %% [markdown]
# ## **Método Ingenuo Estacional**

# %% [markdown]
# El Método Ingenuo Estacional, también conocido como método de descomposición aditiva estacional, es una técnica simple de pronóstico en el análisis de series de tiempo que tiene en cuenta las estacionalidades en los datos. Este método asume que el próximo valor en la serie de tiempo será igual al valor observado en el mismo período en el ciclo estacional anterior. Es especialmente útil cuando los datos tienen patrones estacionales consistentes.
#
# A continuación, te proporcionaré una explicación detallada, un ejemplo y las respectivas gráficas para ilustrar el Método Ingenuo Estacional utilizando Python y las bibliotecas Pandas y Matplotlib.
#
#
# **Ejemplo de Método Ingenuo Estacional:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Crear datos de ejemplo con estacionalidad
np.random.seed(0)
dates = pd.date_range(start='2021-01-01', periods=100, freq='D')
seasonality = np.sin(np.linspace(0, 4 * np.pi, 100))
values = 3 * seasonality + np.random.normal(0, 0.5, 100)

# Crear un DataFrame de Pandas
data = pd.DataFrame({'Date': dates, 'Values': values})
data.set_index('Date', inplace=True)

# Calcular el pronóstico ingenuo estacional
seasonal_forecast = data['Values'].shift(1)

# Graficar la serie original y el pronóstico ingenuo estacional
plt.figure(figsize=(10, 6))
plt.plot(data['Values'], label='Serie Original')
plt.plot(seasonal_forecast, label='Pronóstico Ingenuo Estacional')
plt.legend()
plt.title('Método Ingenuo Estacional en Series de Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# En este ejemplo, hemos creado una serie de tiempo que incluye estacionalidad sinusoidal y ruido. El pronóstico ingenuo estacional asume que el próximo valor será igual al valor en el mismo período en el ciclo estacional anterior. La gráfica muestra la serie original y el pronóstico ingenuo estacional.
#
# **Interpretación:**
#
# - La línea azul representa la serie de tiempo original con estacionalidad y ruido.
# - La línea naranja representa el pronóstico ingenuo estacional, donde cada valor es el mismo que el valor en el mismo período del ciclo estacional anterior.
#
# El método ingenuo estacional es especialmente útil cuando los datos tienen patrones estacionales consistentes, como en este ejemplo. Sin embargo, este método no captura patrones de tendencia o cambios en el ciclo estacional a lo largo del tiempo. Para datos más complejos, es posible que necesites utilizar métodos más avanzados que consideren tendencias y estacionalidades cambiantes.

# %% [markdown]
# ## **Pronósticos simples con Python**

# %% [markdown]
# Los pronósticos simples son enfoques básicos para predecir valores futuros en series de tiempo. Estos métodos no tienen en cuenta patrones complejos ni relaciones avanzadas entre las observaciones pasadas y futuras. Aquí te explicaré tres de los pronósticos simples más comunes: Naïve, Media Móvil y Método de la Deriva, junto con ejemplos y gráficas correspondientes utilizando Python y las bibliotecas Pandas y Matplotlib.
#
# **1. Pronóstico Naïve (Inocente):**
#
# El pronóstico Naïve asume que el próximo valor en la serie de tiempo será igual al valor más reciente observado. Es un método simple pero útil como punto de referencia inicial y para evaluar otros métodos.
#
# **Ejemplo de Pronóstico Naïve:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Crear datos de ejemplo
np.random.seed(0)
dates = pd.date_range(start='2021-01-01', periods=50, freq='D')
values = np.sin(np.linspace(0, 4 * np.pi, 50)) + np.random.normal(0, 0.2, 50)

# Crear un DataFrame de Pandas
data = pd.DataFrame({'Date': dates, 'Values': values})
data.set_index('Date', inplace=True)

# Calcular el pronóstico Naïve
naive_forecast = data['Values'].shift(1)

# Graficar la serie original y el pronóstico Naïve
plt.figure(figsize=(10, 6))
plt.plot(data['Values'], label='Serie Original')
plt.plot(naive_forecast, label='Pronóstico Naïve')
plt.legend()
plt.title('Pronóstico Naïve en Series de Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# **2. Pronóstico de la Media Móvil:**
#
# El pronóstico de la Media Móvil calcula el promedio de los valores pasados en un intervalo de tiempo definido y lo utiliza como pronóstico para valores futuros.
#
# **Ejemplo de Pronóstico de la Media Móvil:**

# %%
# Calcular el pronóstico de la Media Móvil con ventana de tamaño 5
rolling_mean_forecast = data['Values'].rolling(window=5).mean()

# Graficar la serie original y el pronóstico de la Media Móvil
plt.figure(figsize=(10, 6))
plt.plot(data['Values'], label='Serie Original')
plt.plot(rolling_mean_forecast, label='Pronóstico de la Media Móvil (Ventana 5)')
plt.legend()
plt.title('Pronóstico de la Media Móvil en Series de Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# **3. Pronóstico de la Deriva (Tendencia Lineal):**
#
# El pronóstico de la Deriva asume una tendencia lineal en los datos y proyecta esta tendencia hacia el futuro.
#
# **Ejemplo de Pronóstico de la Deriva:**

# %%
# Calcular la tendencia lineal utilizando regresión
coefficients = np.polyfit(np.arange(len(data)), data['Values'], 1)
trend_line_forecast = np.polyval(coefficients, np.arange(len(data)))

# Graficar la serie original y el pronóstico de la Deriva
plt.figure(figsize=(10, 6))
plt.plot(data['Values'], label='Serie Original')
plt.plot(trend_line_forecast, label='Pronóstico de la Deriva (Tendencia Lineal)')
plt.legend()
plt.title('Pronóstico de la Deriva en Series de Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# En resumen, los pronósticos simples son métodos básicos para predecir valores futuros en series de tiempo. Aunque estos métodos no capturan patrones complejos, son útiles como puntos de partida para comprender la serie y evaluar otros métodos más avanzados. Las gráficas muestran cómo los pronósticos simples se comparan con la serie de tiempo original.

# %% [markdown]
# | **Inicio** | **atrás 23** |
# |----------- |-------------- |
# | [🏠](../../README.md) | [⏪](./23_Exploratorio_de_Series_de_Tiempo.ipynb)|
