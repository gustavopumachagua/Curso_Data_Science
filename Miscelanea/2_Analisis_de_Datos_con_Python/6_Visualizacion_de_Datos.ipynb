# %% [markdown]
# | **Inicio** | **atrás 5** | **Siguiente 7** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./5_Filtra_Datos_en_DataFrames.ipynb)| [⏩](./7_Manejo_de_Datos_Faltantes.ipynb)|

# %% [markdown]
# # **6. Visualización de Datos usando Matplotlib de Python - Curso introductorio a la creación de gráficas**

# %% [markdown]
# ## **Introducción a la Visualización de Datos**

# %% [markdown]
# ¡Por supuesto! La visualización de datos es una parte esencial del análisis de datos, ya que te permite comprender patrones, tendencias y relaciones en los datos de manera más intuitiva. En Python, una biblioteca comúnmente utilizada para la visualización de datos es Matplotlib. A continuación, te proporcionaré una explicación detallada junto con ejemplos y gráficos correspondientes.
#
# **Paso 1: Importar Matplotlib y Datos de Ejemplo**
#
# Comencemos importando la biblioteca Matplotlib y creando datos de ejemplo que utilizaremos para crear visualizaciones.

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo']
ventas = [1000, 1200, 800, 1500, 1100]

# %% [markdown]
# **Paso 2: Gráfico de Línea**
#
# Un gráfico de línea es útil para visualizar tendencias a lo largo del tiempo o de una variable a otra. Vamos a crear un gráfico de línea para visualizar las ventas mensuales.

# %%
plt.plot(meses, ventas, marker='o')
plt.xlabel('Mes')
plt.ylabel('Ventas')
plt.title('Ventas Mensuales')
plt.grid(True)
plt.show()

# %% [markdown]
# **Paso 3: Gráfico de Barras**
#
# Los gráficos de barras son ideales para comparar diferentes categorías o valores. Vamos a crear un gráfico de barras para comparar las ventas de diferentes meses.

# %%
plt.bar(meses, ventas)
plt.xlabel('Mes')
plt.ylabel('Ventas')
plt.title('Ventas Mensuales')
plt.show()

# %% [markdown]
# **Paso 4: Gráfico de Pastel**
#
# Un gráfico de pastel es útil para mostrar la proporción de diferentes categorías en un conjunto de datos. Vamos a crear un gráfico de pastel para visualizar la proporción de ventas en diferentes meses.

# %%
plt.pie(ventas, labels=meses, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Distribución de Ventas Mensuales')
plt.show()

# %% [markdown]
# **Paso 5: Gráfico de Dispersión**
#
# Los gráficos de dispersión se utilizan para mostrar la relación entre dos variables. Crearemos un gráfico de dispersión para visualizar la relación entre los meses y las ventas.

# %%
plt.scatter(meses, ventas, color='blue')
plt.xlabel('Mes')
plt.ylabel('Ventas')
plt.title('Relación entre Meses y Ventas')
plt.show()

# %% [markdown]
# Estos son solo ejemplos básicos de cómo utilizar Matplotlib para crear diferentes tipos de gráficos y visualizar datos. Puedes explorar más tipos de gráficos, personalizar colores, estilos y agregar más detalles según tus necesidades. La visualización de datos te permite comunicar información de manera efectiva y descubrir insights importantes en tus conjuntos de datos.

# %% [markdown]
# ## **Anatomía de la Figura de Matplotlib**

# %% [markdown]
# ¡Por supuesto! La anatomía de una figura en Matplotlib se refiere a las diferentes partes que componen un gráfico creado utilizando esta biblioteca. Aquí te proporcionaré una explicación detallada de las principales componentes de una figura de Matplotlib, acompañada de un ejemplo para ilustrar cada parte.
#
# **Anatomía de la Figura de Matplotlib:**
#
# 1. **Figura (`figure`):** La figura es el lienzo en el que se crean los gráficos. Puede contener uno o varios gráficos. Se puede acceder a la figura utilizando el método `plt.figure()`.
#
# 2. **Ejes (`axes`):** Los ejes son los espacios dentro de la figura donde se dibujan los gráficos. Puedes pensar en ellos como los "subgráficos" individuales. Se pueden crear con `fig.add_subplot()` o `plt.subplots()`.
#
# 3. **Título (`title`):** El título proporciona una descripción general del gráfico y se coloca en la parte superior del gráfico.
#
# 4. **Etiquetas de Ejes (`xlabel` y `ylabel`):** Las etiquetas de ejes describen las dimensiones del gráfico, como las etiquetas para el eje x (horizontal) y el eje y (vertical).
#
# 5. **Leyenda (`legend`):** La leyenda muestra las etiquetas para los diferentes elementos en el gráfico. Se puede crear utilizando el parámetro `label` en las funciones de trazado y luego activarla con `plt.legend()`.
#
# 6. **Gráficos (`plot`):** Los gráficos son los datos visualizados en la figura. Pueden ser líneas, barras, puntos, entre otros.
#
# 7. **Cuadrícula (`grid`):** La cuadrícula añade líneas de referencia en el gráfico para facilitar la lectura de los datos.
#
# 8. **Texto (`text`):** Se pueden agregar anotaciones de texto en diferentes ubicaciones del gráfico utilizando la función `plt.text()`.
#
# 9. **Tamaño de la Figura (`figsize`):** El tamaño de la figura se define mediante el parámetro `figsize` al crear la figura. Especifica el ancho y alto en pulgadas.
#
# **Ejemplo:**
#
# Aquí tienes un ejemplo que ilustra la anatomía de una figura de Matplotlib utilizando un gráfico de línea:

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo']
ventas = [1000, 1200, 800, 1500, 1100]

# Crear una figura y ejes
fig, ax = plt.subplots()

# Trazar el gráfico de línea
ax.plot(meses, ventas, marker='o')

# Etiquetas y título
ax.set_xlabel('Mes')
ax.set_ylabel('Ventas')
ax.set_title('Ventas Mensuales')

# Leyenda
ax.legend(['Ventas'])

# Mostrar cuadrícula
ax.grid(True)

# Mostrar la figura
plt.show()

# %% [markdown]
# Este ejemplo demuestra cómo cada una de las partes mencionadas se integra en un gráfico de línea creado con Matplotlib. Recuerda que puedes personalizar aún más tu figura ajustando colores, estilos y otros detalles según tus necesidades específicas.

# %% [markdown]
# ## **Creación de Figuras Simples**

# %% [markdown]
# ¡Por supuesto! Aquí te mostraré cómo crear algunas figuras simples utilizando la biblioteca Matplotlib en Python. Comenzaremos con ejemplos de gráficos de línea, gráficos de barras y gráficos de dispersión.
#
# **Gráfico de Línea:**

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = [1, 2, 3, 4, 5]
y = [10, 25, 15, 30, 20]

# Crear una figura y ejes
plt.figure()
plt.plot(x, y, marker='o')

# Etiquetas y título
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Gráfico de Línea')

# Mostrar la figura
plt.show()

# %% [markdown]
# **Gráfico de Barras:**

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
categorias = ['A', 'B', 'C', 'D']
valores = [20, 35, 25, 40]

# Crear una figura y ejes
plt.figure()
plt.bar(categorias, valores)

# Etiquetas y título
plt.xlabel('Categorías')
plt.ylabel('Valores')
plt.title('Gráfico de Barras')

# Mostrar la figura
plt.show()

# %% [markdown]
# **Gráfico de Dispersión:**

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = [1, 2, 3, 4, 5]
y = [10, 25, 15, 30, 20]

# Crear una figura y ejes
plt.figure()
plt.scatter(x, y, color='blue')

# Etiquetas y título
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Gráfico de Dispersión')

# Mostrar la figura
plt.show()

# %% [markdown]
# Estos ejemplos ilustran cómo crear figuras simples utilizando Matplotlib. Puedes personalizar estos gráficos con colores, estilos de línea, etiquetas, títulos y otras opciones según tus preferencias y necesidades. La biblioteca Matplotlib ofrece una gran flexibilidad para crear una variedad de visualizaciones personalizadas.

# %% [markdown]
# ## **Generación de Datos Aleatorios y Contexto de Ejercicios**

# %% [markdown]
# ¡Por supuesto! A menudo es útil generar datos aleatorios para realizar pruebas, practicar o crear ejemplos de visualización. Aquí te mostraré cómo generar datos aleatorios y te proporcionaré un contexto para algunos ejemplos de ejercicios de visualización.
#
# **Generación de Datos Aleatorios:**
#
# Python ofrece la biblioteca `random` para generar datos aleatorios. A continuación, te muestro cómo generar una lista de números enteros aleatorios y una lista de números de punto flotante aleatorios:

# %%
import random

# Generar 5 números enteros aleatorios entre 1 y 100
numeros_enteros = [random.randint(1, 100) for _ in range(5)]
print("Números enteros aleatorios:", numeros_enteros)

# Generar 5 números de punto flotante aleatorios entre 0 y 1
numeros_flotantes = [random.random() for _ in range(5)]
print("Números de punto flotante aleatorios:", numeros_flotantes)
# Out:
# Números enteros aleatorios: [47, 97, 59, 77, 56]
# Números de punto flotante aleatorios: [0.29586085665111095, 0.7536283274042758, 0.11543597790178184, 0.5210217084248072, 0.8993447431932335]

# %% [markdown]
# **Contexto de Ejercicios de Visualización:**
#
# Supongamos que eres un analista de ventas y estás interesado en visualizar el rendimiento de productos en diferentes regiones. Aquí tienes algunos ejercicios de visualización con un contexto relacionado:
#
# **Ejercicio 1: Gráfico de Barras para Ventas de Productos**
#
# Genera datos aleatorios para las ventas mensuales de tres productos (A, B, C) en un trimestre. Crea un gráfico de barras para visualizar las ventas de estos productos.
#
# **Ejercicio 2: Gráfico de Línea para Ventas Regionales**
#
# Genera datos aleatorios para las ventas mensuales en tres regiones (Norte, Sur, Este) durante un semestre. Crea un gráfico de línea para comparar las ventas en estas regiones a lo largo del tiempo.
#
# **Ejercicio 3: Gráfico de Dispersión para Precio y Cantidad Vendida**
#
# Genera datos aleatorios para el precio y la cantidad vendida de un producto en diferentes transacciones. Crea un gráfico de dispersión para visualizar la relación entre el precio y la cantidad vendida.
#
# **Ejercicio 4: Histograma para Distribución de Ingresos**
#
# Genera datos aleatorios para los ingresos mensuales de empleados en una empresa. Crea un histograma para visualizar la distribución de ingresos entre los empleados.
#
# **Ejercicio 5: Gráfico de Pastel para Composición de Gastos**
#
# Genera datos aleatorios para los gastos mensuales en diferentes categorías (Alimentación, Vivienda, Transporte, Entretenimiento). Crea un gráfico de pastel para visualizar la composición de los gastos.
#
# Estos ejercicios te permitirán aplicar conceptos de generación de datos aleatorios y visualización para abordar situaciones del mundo real. Recuerda que los datos aleatorios son útiles para practicar y experimentar, pero en situaciones reales, los datos reales brindarán resultados más significativos.

# %% [markdown]
# ## **Personalización de Figuras**

# %% [markdown]
# ¡Por supuesto! La personalización de figuras en Matplotlib te permite ajustar colores, estilos, títulos, etiquetas y muchos otros aspectos para crear visualizaciones atractivas y efectivas. A continuación, te mostraré cómo personalizar diferentes aspectos de una figura utilizando ejemplos.
#
# **Personalización de Colores y Estilos:**

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = [1, 2, 3, 4, 5]
y1 = [10, 25, 15, 30, 20]
y2 = [5, 18, 12, 22, 8]

# Crear una figura y ejes
fig, ax = plt.subplots()

# Trazar los gráficos de línea con colores y estilos diferentes
ax.plot(x, y1, color='blue', linestyle='-', marker='o', label='Serie 1')
ax.plot(x, y2, color='green', linestyle='--', marker='x', label='Serie 2')

# Etiquetas y título
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Gráfico Personalizado')

# Leyenda
ax.legend()

# Mostrar la figura
plt.show()

# %% [markdown]
# **Personalización de Títulos y Etiquetas:**

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
categorias = ['A', 'B', 'C', 'D']
valores = [20, 35, 25, 40]

# Crear una figura y ejes
plt.figure()
plt.bar(categorias, valores)

# Etiquetas y título
plt.xlabel('Categorías')
plt.ylabel('Valores')
plt.title('Gráfico de Barras Personalizado')

# Mostrar la figura
plt.show()

# %% [markdown]
# **Personalización de Ejes y Cuadrícula:**

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = [1, 2, 3, 4, 5]
y = [10, 25, 15, 30, 20]

# Crear una figura y ejes
plt.figure()
plt.scatter(x, y, color='red')

# Etiquetas y título
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Gráfico de Dispersión Personalizado')

# Personalización de ejes y cuadrícula
plt.xticks([1, 2, 3, 4, 5])
plt.yticks([0, 10, 20, 30, 40])
plt.grid(True, linestyle='--', alpha=0.7)

# Mostrar la figura
plt.show()

# %% [markdown]
# Estos ejemplos te muestran cómo personalizar diferentes aspectos de las figuras en Matplotlib, incluyendo colores, estilos, títulos, etiquetas, ejes y cuadrícula. Puedes explorar aún más opciones de personalización en la documentación de Matplotlib para adaptar tus visualizaciones a tus necesidades y preferencias específicas.

# %% [markdown]
# ## **Gráficas de Barras Verticales**

# %% [markdown]
# Las gráficas de barras verticales son un tipo de visualización que se utiliza para representar datos en forma de barras rectangulares dispuestas verticalmente. Cada barra representa una categoría o valor, y la altura de la barra está relacionada con la magnitud del valor que representa. Estas gráficas son útiles para comparar datos entre diferentes categorías y destacar diferencias y patrones. A continuación, te proporcionaré una explicación detallada junto con un ejemplo y su respectiva gráfica de barras verticales.
#
# **Ejemplo: Ventas Mensuales de Productos**
#
# Supongamos que tienes datos sobre las ventas mensuales de tres productos (A, B, C) en un año. Quieres visualizar estas ventas utilizando una gráfica de barras verticales.
#
# **Paso 1: Importar Matplotlib y Crear Datos de Ejemplo**
#
# Comenzamos importando la biblioteca Matplotlib y creando los datos de ejemplo para las ventas mensuales de tres productos.

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo']
ventas_producto_a = [100, 120, 80, 150, 110]
ventas_producto_b = [80, 110, 90, 130, 100]
ventas_producto_c = [120, 100, 110, 90, 130]

# %% [markdown]
# **Paso 2: Crear la Gráfica de Barras Verticales**
#
# Ahora utilizamos Matplotlib para crear la gráfica de barras verticales que visualizará las ventas mensuales de los tres productos.

# %%
# Crear una figura y ejes
plt.figure()

# Crear las barras verticales
plt.bar(meses, ventas_producto_a, label='Producto A')
plt.bar(meses, ventas_producto_b, label='Producto B')
plt.bar(meses, ventas_producto_c, label='Producto C')

# Etiquetas y título
plt.xlabel('Meses')
plt.ylabel('Ventas')
plt.title('Ventas Mensuales de Productos')
plt.legend()

# Mostrar la figura
plt.show()

# %% [markdown]
# **Resultado:**
#
# La gráfica de barras verticales resultante tendrá tres conjuntos de barras correspondientes a los productos A, B y C. Cada barra mostrará las ventas mensuales para el producto correspondiente en cada mes.
#
# Recuerda que esta es una representación simple de una gráfica de barras verticales. Puedes personalizarla aún más ajustando colores, estilos, títulos y otros detalles según tus preferencias y necesidades específicas. Las gráficas de barras verticales son especialmente útiles cuando deseas comparar magnitudes en diferentes categorías.

# %% [markdown]
# ## **Gráficas de Barras Horizontales**

# %% [markdown]
# Las gráficas de barras horizontales son un tipo de visualización que se utiliza para representar datos en forma de barras rectangulares dispuestas horizontalmente. Cada barra representa una categoría o valor, y la longitud de la barra está relacionada con la magnitud del valor que representa. Estas gráficas son excelentes para comparar datos entre diferentes categorías y destacar diferencias y patrones, especialmente cuando se desea enfocar en una comparación de magnitudes. A continuación, te proporcionaré una explicación detallada junto con un ejemplo y su respectiva gráfica de barras horizontales.
#
# **Ejemplo: Población de Países**
#
# Supongamos que tienes datos sobre la población de cinco países en millones. Quieres visualizar estas poblaciones utilizando una gráfica de barras horizontales.
#
# **Paso 1: Importar Matplotlib y Crear Datos de Ejemplo**
#
# Comenzamos importando la biblioteca Matplotlib y creando los datos de ejemplo para la población de cinco países.

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
paises = ['China', 'India', 'Estados Unidos', 'Indonesia', 'Pakistán']
poblacion = [1439323776, 1380004385, 331002651, 273523615, 220892340]

# %% [markdown]
# **Paso 2: Crear la Gráfica de Barras Horizontales**
#
# Ahora utilizamos Matplotlib para crear la gráfica de barras horizontales que visualizará la población de los cinco países.

# %%
# Crear una figura y ejes
plt.figure()

# Crear las barras horizontales
plt.barh(paises, poblacion, color='blue')

# Etiquetas y título
plt.xlabel('Población (Millones)')
plt.ylabel('Países')
plt.title('Población de Países')

# Mostrar la figura
plt.show()

# %% [markdown]
# **Resultado:**
#
# La gráfica de barras horizontales resultante tendrá cinco barras horizontales, cada una correspondiente a un país y su respectiva población en millones. La longitud de cada barra representará la población del país.
#
# Recuerda que esta es una representación simple de una gráfica de barras horizontales. Puedes personalizarla aún más ajustando colores, estilos, títulos y otros detalles según tus preferencias y necesidades específicas. Las gráficas de barras horizontales son especialmente útiles cuando deseas comparar magnitudes entre diferentes categorías, y resultan particularmente efectivas cuando tienes etiquetas de texto largas, como nombres de países.

# %% [markdown]
# ## **Gráficas de Barras Apiladas**

# %% [markdown]
# Las gráficas de barras apiladas son una forma de visualización que se utiliza para representar datos en forma de barras rectangulares apiladas unas sobre otras. Cada barra representa una categoría o valor, y las barras se apilan para mostrar la contribución individual de cada subvalor a la categoría total. Estas gráficas son útiles para comparar la relación entre los subvalores dentro de cada categoría y ver cómo cambia esta relación entre diferentes categorías. A continuación, te proporcionaré una explicación detallada junto con un ejemplo y su respectiva gráfica de barras apiladas.
#
# **Ejemplo: Ingresos de Departamentos**
#
# Supongamos que tienes datos sobre los ingresos mensuales de tres departamentos (Ventas, Marketing, Finanzas) en diferentes trimestres. Quieres visualizar estos ingresos utilizando una gráfica de barras apiladas.
#
# **Paso 1: Importar Matplotlib y Crear Datos de Ejemplo**
#
# Comenzamos importando la biblioteca Matplotlib y creando los datos de ejemplo para los ingresos de los tres departamentos en diferentes trimestres.

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
trimestres = ['Q1', 'Q2', 'Q3', 'Q4']
ingresos_ventas = [200, 250, 220, 270]
ingresos_marketing = [150, 180, 160, 190]
ingresos_finanzas = [120, 130, 110, 140]

# %% [markdown]
# **Paso 2: Crear la Gráfica de Barras Apiladas**
#
# Ahora utilizamos Matplotlib para crear la gráfica de barras apiladas que visualizará los ingresos de los tres departamentos en diferentes trimestres.

# %%
# Crear una figura y ejes
plt.figure()

# Crear las barras apiladas
plt.bar(trimestres, ingresos_ventas, label='Ventas')
plt.bar(trimestres, ingresos_marketing, bottom=ingresos_ventas, label='Marketing')
plt.bar(trimestres, ingresos_finanzas, bottom=[i+j for i,j in zip(ingresos_ventas, ingresos_marketing)], label='Finanzas')

# Etiquetas y título
plt.xlabel('Trimestres')
plt.ylabel('Ingresos')
plt.title('Ingresos de Departamentos por Trimestre')
plt.legend()

# Mostrar la figura
plt.show()

# %% [markdown]
# **Resultado:**
#
# La gráfica de barras apiladas resultante mostrará cuatro barras apiladas correspondientes a cada trimestre. Cada barra estará compuesta por segmentos que representan los ingresos de los tres departamentos. La altura total de la barra representará el ingreso total en ese trimestre.
#
# Recuerda que esta es una representación simple de una gráfica de barras apiladas. Puedes personalizarla aún más ajustando colores, estilos, títulos y otros detalles según tus preferencias y necesidades específicas. Las gráficas de barras apiladas son útiles para mostrar cómo contribuyen diferentes subvalores a una categoría total.

# %% [markdown]
# ## **Gráficas de Dispersión**

# %% [markdown]
# Las gráficas de dispersión son una forma de visualización que se utiliza para mostrar la relación entre dos variables. Cada punto en la gráfica representa un par de valores correspondientes a las dos variables. Estas gráficas son ideales para identificar patrones, tendencias, correlaciones y valores atípicos en los datos. A continuación, te proporcionaré una explicación detallada junto con un ejemplo y su respectiva gráfica de dispersión.
#
# **Ejemplo: Relación entre Horas de Estudio y Calificación de Examen**
#
# Supongamos que tienes datos sobre las horas de estudio y las calificaciones obtenidas por varios estudiantes en un examen. Quieres visualizar la relación entre estas dos variables utilizando una gráfica de dispersión.
#
# **Paso 1: Importar Matplotlib y Crear Datos de Ejemplo**
#
# Comenzamos importando la biblioteca Matplotlib y creando los datos de ejemplo para las horas de estudio y las calificaciones de los estudiantes.

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
horas_estudio = [2, 3, 1.5, 4, 5, 3.5, 6, 2.5, 4.5]
calificaciones = [70, 85, 60, 95, 100, 80, 110, 75, 90]

# %% [markdown]
# **Paso 2: Crear la Gráfica de Dispersión**
#
# Ahora utilizamos Matplotlib para crear la gráfica de dispersión que visualizará la relación entre las horas de estudio y las calificaciones de los estudiantes.

# %%
# Crear una figura y ejes
plt.figure()

# Crear la gráfica de dispersión
plt.scatter(horas_estudio, calificaciones, color='blue', marker='o')

# Etiquetas y título
plt.xlabel('Horas de Estudio')
plt.ylabel('Calificación')
plt.title('Relación entre Horas de Estudio y Calificación de Examen')

# Mostrar la figura
plt.show()

# %% [markdown]
# **Resultado:**
#
# La gráfica de dispersión resultante mostrará puntos dispersos en el plano, donde cada punto representa un estudiante. El eje x representará las horas de estudio y el eje y representará las calificaciones del examen.
#
# Recuerda que esta es una representación simple de una gráfica de dispersión. Puedes personalizarla aún más ajustando colores, estilos, títulos y otros detalles según tus preferencias y necesidades específicas. Las gráficas de dispersión son útiles para visualizar la relación entre dos variables y ayudan a identificar patrones y tendencias en los datos.

# %% [markdown]
# ## **Gráficas de Pie**

# %% [markdown]
# Las gráficas de pastel, también conocidas como gráficas circulares, son una forma de visualización que se utiliza para mostrar la proporción de diferentes partes con respecto a un todo. Estas gráficas representan cada parte como una porción de un círculo, donde el tamaño del sector es proporcional al valor que representa. Son ideales para mostrar la composición relativa de categorías en un conjunto de datos. A continuación, te proporcionaré una explicación detallada junto con un ejemplo y su respectiva gráfica de pastel.
#
# **Ejemplo: Composición de Gastos Mensuales**
#
# Supongamos que tienes datos sobre los gastos mensuales en diferentes categorías (Alimentación, Vivienda, Transporte, Entretenimiento). Quieres visualizar la composición de gastos utilizando una gráfica de pastel.
#
# **Paso 1: Importar Matplotlib y Crear Datos de Ejemplo**
#
# Comenzamos importando la biblioteca Matplotlib y creando los datos de ejemplo para los gastos mensuales en diferentes categorías.

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
categorias = ['Alimentación', 'Vivienda', 'Transporte', 'Entretenimiento']
gastos = [600, 1000, 400, 300]

# %% [markdown]
# **Paso 2: Crear la Gráfica de Pastel**
#
# Ahora utilizamos Matplotlib para crear la gráfica de pastel que visualizará la composición de gastos en diferentes categorías.

# %%
# Crear una figura y ejes
plt.figure()

# Crear la gráfica de pastel
plt.pie(gastos, labels=categorias, autopct='%1.1f%%', startangle=140)

# Propiedades adicionales
plt.axis('equal')  # Para que el círculo de la gráfica se vea circular
plt.title('Composición de Gastos Mensuales')

# Mostrar la figura
plt.show()

# %% [markdown]
# **Resultado:**
#
# La gráfica de pastel resultante mostrará sectores circulares, donde cada sector representa una categoría de gastos. El tamaño de cada sector es proporcional al gasto en esa categoría.
#
# Recuerda que esta es una representación simple de una gráfica de pastel. Puedes personalizarla aún más ajustando colores, porcentaje de formato, títulos y otros detalles según tus preferencias y necesidades específicas. Las gráficas de pastel son útiles para mostrar la distribución proporcional de partes dentro de un todo.

# %% [markdown]
# ## **Combinar Gráficas**

# %% [markdown]
# La combinación de gráficas se refiere a la práctica de superponer o mostrar múltiples tipos de gráficas en una misma figura para comparar y visualizar datos desde diferentes perspectivas. Puedes combinar gráficas para presentar información más completa y hacer que tus visualizaciones sean más efectivas. Aquí tienes una explicación detallada junto con un ejemplo y sus respectivas gráficas de combinación.
#
# **Ejemplo: Combinación de Gráfica de Línea y Gráfica de Barras**
#
# Supongamos que tienes datos sobre los ingresos y los gastos mensuales de un negocio durante un año. Quieres visualizar tanto los ingresos como los gastos en la misma figura para comparar su tendencia a lo largo del tiempo.
#
# **Paso 1: Importar Matplotlib y Crear Datos de Ejemplo**
#
# Comenzamos importando la biblioteca Matplotlib y creando los datos de ejemplo para los ingresos y los gastos mensuales.

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']
ingresos = [5000, 5500, 6000, 6200, 7000, 7500, 8000, 7800, 8500, 9000, 9500, 10000]
gastos = [4000, 4200, 4500, 4800, 5000, 5500, 6000, 5800, 6200, 6500, 7000, 7500]

# %% [markdown]
# **Paso 2: Crear la Combinación de Gráficas**
#
# Ahora utilizamos Matplotlib para crear una figura con una gráfica de línea para los ingresos y una gráfica de barras para los gastos.

# %%
# Crear una figura y ejes
fig, ax1 = plt.subplots()

# Trazar la gráfica de línea para los ingresos
ax1.plot(meses, ingresos, color='blue', marker='o', label='Ingresos')
ax1.set_xlabel('Meses')
ax1.set_ylabel('Ingresos', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.legend(loc='upper left')

# Crear un segundo eje y para la gráfica de barras de gastos
ax2 = ax1.twinx()
ax2.bar(meses, gastos, color='red', alpha=0.3, label='Gastos')
ax2.set_ylabel('Gastos', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.legend(loc='upper right')

# Título
plt.title('Combinación de Gráfica de Línea e Gráfica de Barras')

# Mostrar la figura
plt.show()

# %% [markdown]
# **Resultado:**
#
# La figura resultante mostrará una gráfica de línea para los ingresos (con eje y izquierdo) y una gráfica de barras para los gastos (con eje y derecho). Las dos gráficas están superpuestas en el mismo espacio y permiten comparar fácilmente las tendencias de ingresos y gastos a lo largo del tiempo.
#
# Recuerda que esta es una representación simple de cómo combinar gráficas. Puedes ajustar colores, estilos, etiquetas y otros detalles para personalizar la visualización según tus preferencias y necesidades específicas. La combinación de gráficas es una técnica poderosa para presentar información completa en una sola figura.

# %% [markdown]
# | **Inicio** | **atrás 5** | **Siguiente 7** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./5_Filtra_Datos_en_DataFrames.ipynb)| [⏩](./7_Manejo_de_Datos_Faltantes.ipynb)|
