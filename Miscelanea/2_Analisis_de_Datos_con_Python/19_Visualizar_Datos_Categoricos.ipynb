# %% [markdown]
# | **Inicio** | **atrás 18** | **Siguiente 20** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./18_Explora_y_Visualiza_Relaciones_Estadisticas.ipynb)| [⏩](./20_%20Entropia_en_Machine_Learning.ipynb)|

# %% [markdown]
# # **19. Descubre cómo Visualizar Datos Categóricos con Seaborn y Python: gráficas de violín, enjambre y ➕**

# %% [markdown]
# ## **Visualización con datos categóricos**

# %% [markdown]
# La visualización de datos categóricos es fundamental para comprender las relaciones y patrones en conjuntos de datos que contienen variables categóricas, como etiquetas, categorías o grupos. Seaborn ofrece varias funciones y tipos de gráficos específicos para visualizar datos categóricos. Aquí tienes ejemplos de cómo visualizar datos categóricos utilizando Seaborn:
#
# **Ejemplo de Visualización de Datos Categóricos:**
#
# Supongamos que tienes datos de ventas por categoría de productos y deseas comparar las ventas promedio por categoría utilizando un gráfico de barras.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Crear datos simulados
data = {
    "categoria": ["Electrónica", "Ropa", "Hogar", "Electrónica", "Ropa", "Hogar"],
    "ventas": [1500, 1800, 2200, 2500, 2300, 2800]
}
df = pd.DataFrame(data)

# Crear un gráfico de barras de ventas por categoría
plt.figure(figsize=(8, 6))
sns.barplot(x="categoria", y="ventas", data=df)
plt.title("Gráfico de Barras: Ventas por Categoría")
plt.xlabel("Categoría")
plt.ylabel("Ventas")
plt.show()

# %% [markdown]
# En este ejemplo, utilizamos `sns.barplot()` para crear un gráfico de barras que muestra las ventas promedio por categoría. Las categorías se encuentran en el eje x y las ventas en el eje y. Puedes personalizar la apariencia del gráfico utilizando funciones como `plt.title()`, `plt.xlabel()`, `plt.ylabel()` y otros.
#
# Además de los gráficos de barras, Seaborn también ofrece otros tipos de gráficos categóricos, como gráficos de cuenta, gráficos de cajas, gráficos de violín, gráficos de puntos y más. Estos gráficos te permiten visualizar y comparar datos categóricos de manera efectiva, lo que puede ser útil para identificar tendencias, patrones o relaciones en tus datos.

# %% [markdown]
# ## **Tipos de gráficas categóricas**

# %% [markdown]
# Seaborn ofrece una variedad de tipos de gráficos categóricos para visualizar y comparar datos categóricos. Aquí hay algunos de los tipos de gráficos categóricos más comunes que puedes crear utilizando Seaborn:
#
# 1. **Gráfico de Barras (`sns.barplot`):** Muestra la media y el intervalo de confianza de una variable categórica en el eje x y una variable numérica en el eje y. Es útil para comparar categorías y sus valores numéricos asociados.
#
# 2. **Gráfico de Cuenta (`sns.countplot`):** Muestra la frecuencia de ocurrencia de cada categoría en el eje x. Es especialmente útil para visualizar la distribución de categorías en una variable categórica.
#
# 3. **Gráfico de Cajas (`sns.boxplot`):** Muestra la distribución y la dispersión de datos numéricos por categoría. Puede ayudar a identificar tendencias y valores atípicos en diferentes categorías.
#
# 4. **Gráfico de Violín (`sns.violinplot`):** Combina un diagrama de cajas con un gráfico de densidad en cada categoría. Proporciona información sobre la distribución de datos en cada categoría.
#
# 5. **Gráfico de Puntos (`sns.pointplot`):** Muestra los valores medios y el intervalo de confianza de una variable numérica en el eje y para diferentes categorías en el eje x. Es útil para comparar categorías y sus valores medios.
#
# 6. **Gráfico de Barra Apilada (`sns.barplot` con parámetro `hue`):** Permite comparar subcategorías dentro de categorías utilizando colores para representar diferentes subcategorías.
#
# 7. **Gráfico de Torta (`plt.pie`):** Muestra la proporción de cada categoría en un círculo, ideal para visualizar porcentajes o proporciones.
#
# 8. **Gráfico de Mapa de Calor (`sns.heatmap`):** Muestra la relación entre dos variables categóricas al resaltar las frecuencias o valores en una matriz.
#
# Estos son solo algunos ejemplos de tipos de gráficos categóricos disponibles en Seaborn. Puedes experimentar con diferentes tipos de gráficos y personalizar su apariencia para presentar tus datos de manera efectiva y visualizar las relaciones entre categorías en tus conjuntos de datos.

# %% [markdown]
# ## **Datos a visualizar**

# %% [markdown]
# Para mostrar ejemplos de visualización de datos categóricos, necesitamos datos específicos que podamos utilizar. Aquí hay un conjunto de datos de ejemplo que podemos usar para ilustrar los diferentes tipos de gráficos categóricos en Seaborn:
#
# Supongamos que tenemos datos de ventas de diferentes productos en tres ciudades diferentes durante varios meses. Los datos podrían verse así:

# %%
import pandas as pd

data = {
    "producto": ["A", "B", "C", "A", "B", "C", "A", "B", "C"],
    "ciudad": ["Ciudad A", "Ciudad B", "Ciudad A", "Ciudad B", "Ciudad A", "Ciudad B", "Ciudad A", "Ciudad B", "Ciudad A"],
    "mes": ["Enero", "Enero", "Febrero", "Febrero", "Marzo", "Marzo", "Abril", "Abril", "Mayo"],
    "ventas": [150, 200, 180, 220, 250, 300, 190, 210, 240]
}

df = pd.DataFrame(data)

# %% [markdown]
# Con este conjunto de datos, podemos mostrar ejemplos de diferentes tipos de gráficos categóricos utilizando Seaborn.
#
# **Ejemplos de Gráficos Categóricos:**
#
# 1. Gráfico de Barras:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.barplot(x="producto", y="ventas", data=df)
plt.title("Gráfico de Barras: Ventas por Producto")
plt.xlabel("Producto")
plt.ylabel("Ventas")
plt.show()

# %% [markdown]
# 2. Gráfico de Cuenta:

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x="ciudad", data=df)
plt.title("Gráfico de Cuenta: Distribución de Ciudades")
plt.xlabel("Ciudad")
plt.ylabel("Cantidad")
plt.show()

# %% [markdown]
# 3. Gráfico de Cajas:

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x="ciudad", y="ventas", data=df)
plt.title("Gráfico de Cajas: Ventas por Ciudad")
plt.xlabel("Ciudad")
plt.ylabel("Ventas")
plt.show()

# %% [markdown]
# 4. Gráfico de Violín:

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x="mes", y="ventas", data=df)
plt.title("Gráfico de Violín: Distribución de Ventas por Mes")
plt.xlabel("Mes")
plt.ylabel("Ventas")
plt.show()

# %% [markdown]
# Estos son solo algunos ejemplos de cómo puedes visualizar datos categóricos utilizando Seaborn. Puedes explorar diferentes tipos de gráficos y personalizar su apariencia para adaptarse a tus necesidades y presentar tus datos de manera efectiva.

# %% [markdown]
# ## **Gráficas de bandas (stripplot)**

# %% [markdown]
# El gráfico de bandas, también conocido como "strip plot", es otro tipo de gráfico categórico que se utiliza para visualizar la distribución de datos en una variable categórica. En este tipo de gráfico, se representan puntos individuales a lo largo de un eje categórico, lo que permite ver la dispersión de los datos y la densidad en diferentes categorías. Seaborn ofrece la función `sns.stripplot()` para crear gráficos de bandas.
#
# Aquí tienes un ejemplo de cómo crear y visualizar un gráfico de bandas utilizando Seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo
data = {
    "producto": ["A", "B", "C", "A", "B", "C", "A", "B", "C"],
    "ventas": [150, 200, 180, 220, 250, 300, 190, 210, 240]
}

df = pd.DataFrame(data)

# Crear un gráfico de bandas
plt.figure(figsize=(8, 6))
sns.stripplot(x="producto", y="ventas", data=df, jitter=True, color="blue", size=8)
plt.title("Gráfico de Bandas: Ventas por Producto")
plt.xlabel("Producto")
plt.ylabel("Ventas")
plt.show()

# %% [markdown]
# En este ejemplo, estamos creando un gráfico de bandas que muestra las ventas de diferentes productos. Usamos el eje x para representar los productos y el eje y para representar las ventas. El parámetro `jitter=True` agrega un pequeño desplazamiento aleatorio a los puntos para evitar que se superpongan cuando hay datos superpuestos. También estamos personalizando el color y el tamaño de los puntos.
#
# Este tipo de gráfico es útil para identificar la densidad de datos en diferentes categorías y para observar la distribución de los valores en cada categoría. Puedes experimentar con diferentes parámetros para ajustar la apariencia del gráfico según tus necesidades.

# %% [markdown]
# ## **Gráficas de enjambre (swarmplot)**

# %% [markdown]
# El gráfico de enjambre, también conocido como "swarm plot", es otro tipo de gráfico categórico que se utiliza para visualizar la distribución de datos en una variable categórica. Similar al gráfico de bandas, el gráfico de enjambre muestra puntos individuales a lo largo de un eje categórico, pero en este caso, los puntos no se superponen, lo que permite una mejor visualización de la distribución de datos. Seaborn ofrece la función `sns.swarmplot()` para crear gráficos de enjambre.
#
# Aquí tienes un ejemplo de cómo crear y visualizar un gráfico de enjambre utilizando Seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo
data = {
    "producto": ["A", "B", "C", "A", "B", "C", "A", "B", "C"],
    "ventas": [150, 200, 180, 220, 250, 300, 190, 210, 240]
}

df = pd.DataFrame(data)

# Crear un gráfico de enjambre
plt.figure(figsize=(8, 6))
sns.swarmplot(x="producto", y="ventas", data=df, color="purple", size=8)
plt.title("Gráfico de Enjambre: Ventas por Producto")
plt.xlabel("Producto")
plt.ylabel("Ventas")
plt.show()

# %% [markdown]
# En este ejemplo, estamos creando un gráfico de enjambre que muestra las ventas de diferentes productos. Utilizamos el eje x para representar los productos y el eje y para representar las ventas. Los puntos no se superponen en el gráfico de enjambre, lo que permite observar la distribución de datos de manera más clara.
#
# Al igual que con otros tipos de gráficos categóricos, puedes ajustar parámetros como el color, el tamaño de los puntos y más para personalizar la apariencia del gráfico según tus preferencias. El gráfico de enjambre es especialmente útil cuando tienes una cantidad moderada de datos categóricos y deseas ver la distribución de manera más detallada que en un gráfico de barras o bandas.

# %% [markdown]
# ## **Diagramas de cajas y bigotes (boxplot)**

# %% [markdown]
# El diagrama de cajas y bigotes, también conocido como "boxplot", es una representación gráfica que muestra la distribución de datos en un conjunto de categorías. Este gráfico es especialmente útil para identificar la dispersión y las tendencias centrales de los datos, así como para detectar valores atípicos o extremos. Seaborn ofrece la función `sns.boxplot()` para crear diagramas de cajas y bigotes.
#
# Aquí tienes un ejemplo de cómo crear y visualizar un diagrama de cajas y bigotes utilizando Seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo
data = {
    "producto": ["A", "B", "C", "A", "B", "C", "A", "B", "C"],
    "ventas": [150, 200, 180, 220, 250, 300, 190, 210, 240]
}

df = pd.DataFrame(data)

# Crear un diagrama de cajas y bigotes
plt.figure(figsize=(8, 6))
sns.boxplot(x="producto", y="ventas", data=df, palette="Set3")
plt.title("Diagrama de Cajas y Bigotes: Ventas por Producto")
plt.xlabel("Producto")
plt.ylabel("Ventas")
plt.show()

# %% [markdown]
# En este ejemplo, estamos creando un diagrama de cajas y bigotes que muestra las ventas de diferentes productos. Utilizamos el eje x para representar los productos y el eje y para representar las ventas. El diagrama de cajas y bigotes muestra la mediana, el rango intercuartil (IQR), los valores mínimos y máximos, así como los posibles valores atípicos.
#
# Puedes personalizar la apariencia del diagrama ajustando parámetros como el color, el estilo de las líneas, el ancho de las cajas y más. Este tipo de gráfico es útil para resumir la distribución de datos en diferentes categorías y para identificar posibles valores atípicos que puedan afectar el análisis.

# %% [markdown]
# ## **Gráficas boxen (boxenplot)**

# %% [markdown]
# El gráfico Boxen, también conocido como "boxenplot", es una variante más informativa y detallada del diagrama de cajas y bigotes (boxplot). Se utiliza para visualizar la distribución de datos en función de diferentes categorías y proporciona una visión más detallada de la forma y la dispersión de los datos. El gráfico Boxen es especialmente útil cuando se trabaja con conjuntos de datos grandes y se desea observar las diferencias en la distribución de forma más precisa.
#
# Para crear un gráfico Boxen en Seaborn, puedes utilizar la función `sns.boxenplot()`. A continuación, te muestro un ejemplo de cómo crear y visualizar un gráfico Boxen:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo
data = {
    "producto": ["A", "B", "C", "A", "B", "C", "A", "B", "C"],
    "ventas": [150, 200, 180, 220, 250, 300, 190, 210, 240]
}

df = pd.DataFrame(data)

# Crear un gráfico Boxen
plt.figure(figsize=(8, 6))
sns.boxenplot(x="producto", y="ventas", data=df, palette="Set2")
plt.title("Gráfico Boxen: Ventas por Producto")
plt.xlabel("Producto")
plt.ylabel("Ventas")
plt.show()

# %% [markdown]
# En este ejemplo, estamos creando un gráfico Boxen que muestra las ventas de diferentes productos. Al igual que con otros gráficos categóricos, utilizamos el eje x para representar los productos y el eje y para representar las ventas. El gráfico Boxen muestra cuartiles y percentiles más detallados que el diagrama de cajas y bigotes estándar, lo que permite una visión más precisa de la distribución de datos.
#
# Puedes personalizar la apariencia del gráfico Boxen ajustando parámetros como el color, el estilo de las líneas y más. Este tipo de gráfico es particularmente útil cuando se necesita una representación detallada de la distribución de datos en diferentes categorías y para identificar posibles valores atípicos y tendencias.

# %% [markdown]
# ## **Gráficas de violín (violinplot)**

# %% [markdown]
# El gráfico de violín, también conocido como "violinplot", es una visualización que combina un diagrama de cajas y bigotes con una representación de la distribución de datos en forma de un "violín". Esta representación combina la información de la mediana, los cuartiles y la dispersión de los datos, permitiendo observar tanto la tendencia central como la forma de la distribución en cada categoría.
#
# Para crear un gráfico de violín en Seaborn, puedes utilizar la función `sns.violinplot()`. Aquí tienes un ejemplo de cómo crear y visualizar un gráfico de violín:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo
data = {
    "producto": ["A", "B", "C", "A", "B", "C", "A", "B", "C"],
    "ventas": [150, 200, 180, 220, 250, 300, 190, 210, 240]
}

df = pd.DataFrame(data)

# Crear un gráfico de violín
plt.figure(figsize=(8, 6))
sns.violinplot(x="producto", y="ventas", data=df, palette="pastel")
plt.title("Gráfico de Violín: Distribución de Ventas por Producto")
plt.xlabel("Producto")
plt.ylabel("Ventas")
plt.show()

# %% [markdown]
# En este ejemplo, estamos creando un gráfico de violín que muestra la distribución de ventas de diferentes productos. El eje x representa los productos y el eje y representa las ventas. Cada "violín" muestra la distribución de datos en función de la categoría, con su forma indicando la densidad y la dispersión de los valores.
#
# Puedes personalizar la apariencia del gráfico de violín ajustando parámetros como el color, el estilo de las líneas y más. Este tipo de gráfico es útil para visualizar tanto la forma como la dispersión de los datos en diferentes categorías, lo que puede ayudar a identificar patrones y tendencias en los datos.

# %% [markdown]
# ## **Gráficas de puntos (pointplot)**

# %% [markdown]
# El gráfico de puntos, también conocido como "pointplot", es una visualización que muestra la relación entre dos variables categóricas o una variable categórica y una variable numérica. En este tipo de gráfico, se representa la tendencia central (generalmente la media) de la variable numérica en función de las categorías de la variable categórica.
#
# Para crear un gráfico de puntos en Seaborn, puedes utilizar la función `sns.pointplot()`. A continuación, te muestro un ejemplo de cómo crear y visualizar un gráfico de puntos:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo
data = {
    "mes": ["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio"],
    "ventas": [150, 200, 180, 220, 250, 300]
}

df = pd.DataFrame(data)

# Crear un gráfico de puntos
plt.figure(figsize=(8, 6))
sns.pointplot(x="mes", y="ventas", data=df, color="blue")
plt.title("Gráfico de Puntos: Ventas Mensuales")
plt.xlabel("Mes")
plt.ylabel("Ventas")
plt.show()

# %% [markdown]
# En este ejemplo, estamos creando un gráfico de puntos que muestra las ventas mensuales en función de los meses. El eje x representa los meses y el eje y representa las ventas. Los puntos en el gráfico representan la tendencia central (media) de las ventas para cada mes.
#
# Puedes personalizar la apariencia del gráfico de puntos ajustando parámetros como el color, el estilo de las líneas y más. Este tipo de gráfico es útil para mostrar comparaciones de tendencias centrales entre diferentes categorías categóricas y puede ser especialmente útil cuando se trata de analizar datos con múltiples grupos y valores medios.

# %% [markdown]
# ## **Gráficas de barras (barplots)**

# %% [markdown]
# Las gráficas de barras, también conocidas como "barplots", son una forma efectiva de representar datos categóricos y comparar las cantidades entre diferentes categorías. En un gráfico de barras, cada categoría se representa en el eje x, mientras que la altura de la barra en el eje y indica la cantidad o valor asociado a esa categoría.
#
# Para crear un gráfico de barras en Seaborn, puedes utilizar la función `sns.barplot()`. A continuación, te muestro un ejemplo de cómo crear y visualizar un gráfico de barras:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo
data = {
    "producto": ["A", "B", "C"],
    "ventas": [150, 200, 180]
}

df = pd.DataFrame(data)

# Crear un gráfico de barras
plt.figure(figsize=(8, 6))
sns.barplot(x="producto", y="ventas", data=df, palette="pastel")
plt.title("Gráfico de Barras: Ventas por Producto")
plt.xlabel("Producto")
plt.ylabel("Ventas")
plt.show()

# %% [markdown]
# En este ejemplo, estamos creando un gráfico de barras que muestra las ventas por producto. Cada producto se representa en el eje x, mientras que la altura de la barra indica la cantidad de ventas en el eje y.
#
# Puedes personalizar la apariencia del gráfico de barras ajustando parámetros como el color, el estilo de las barras y más. Además, los gráficos de barras también son útiles para visualizar relaciones entre variables categóricas y numéricas, como por ejemplo, comparar la cantidad promedio de ventas para diferentes categorías.

# %% [markdown]
# ## **Gráficas de conteo (countplot)**

# %% [markdown]
# Las gráficas de conteo, también conocidas como "countplot", son una forma simple y efectiva de visualizar la distribución de una variable categórica mostrando el recuento de observaciones en cada categoría. Cada barra en el gráfico representa el número de veces que una categoría específica aparece en el conjunto de datos.
#
# Para crear un gráfico de conteo en Seaborn, puedes utilizar la función `sns.countplot()`. Aquí tienes un ejemplo de cómo crear y visualizar un gráfico de conteo:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo
data = {
    "producto": ["A", "B", "C", "A", "B", "C", "A", "B", "C"],
    "ventas": [150, 200, 180, 220, 250, 300, 190, 210, 240]
}

df = pd.DataFrame(data)

# Crear un gráfico de conteo
plt.figure(figsize=(8, 6))
sns.countplot(x="producto", data=df, palette="pastel")
plt.title("Gráfico de Conteo: Distribución de Productos")
plt.xlabel("Producto")
plt.ylabel("Cantidad")
plt.show()

# %% [markdown]
# En este ejemplo, estamos creando un gráfico de conteo que muestra la distribución de productos en función de su frecuencia en el conjunto de datos. El eje x representa los productos y el eje y representa la cantidad de veces que aparece cada producto.
#
# Puedes personalizar la apariencia del gráfico de conteo ajustando parámetros como el color y el estilo de las barras. Este tipo de gráfico es especialmente útil para visualizar rápidamente la distribución de datos en variables categóricas y puede ayudar a identificar categorías dominantes y tendencias en los datos.

# %% [markdown]
# | **Inicio** | **atrás 18** | **Siguiente 20** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./18_Explora_y_Visualiza_Relaciones_Estadisticas.ipynb)| [⏩](./20_%20Entropia_en_Machine_Learning.ipynb)|
