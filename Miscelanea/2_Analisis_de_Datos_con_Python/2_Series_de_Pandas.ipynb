# %% [markdown]
# | **Inicio** | **atrás 1** | **Siguiente 3** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./1_Jupyter_Notebook.ipynb)| [⏩](./3_DataFrames_de_Pandas.ipynb)|

# %% [markdown]
# # **2. Series de Pandas: El Componente Principal de los DataFrames para Analizar Datos con Python**

# %% [markdown]
# ## **Introducción a las Series**

# %% [markdown]
# **Series de Pandas: El Componente Principal de los DataFrames para Analizar Datos con Python**
#
# Las Series son una de las estructuras de datos fundamentales en la librería de Python llamada Pandas, diseñada para el análisis y manipulación de datos. Las Series son un componente principal de los DataFrames, que son estructuras de datos tabulares más complejas y utilizadas en el análisis de datos. Una Serie es una estructura unidimensional que puede contener datos homogéneos, es decir, del mismo tipo, como números, cadenas, fechas, etc. Veamos una explicación detallada con ejemplos y gráficos:
#
# **Creación de una Serie:**
#
# Para crear una Serie en Pandas, puedes usar el constructor `pd.Series()`. Aquí tienes un ejemplo sencillo:

# %%
import pandas as pd

data = [10, 20, 30, 40, 50]
serie = pd.Series(data)
print(serie)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# **Acceso a Datos en una Serie:**
#
# Puedes acceder a los datos en una Serie utilizando índices numéricos o etiquetas (si se proporcionan). Por defecto, una Serie tiene índices numéricos generados automáticamente desde 0. Aquí tienes ejemplos:

# %%
print(serie[2])  # Acceso por índice
print(serie[1:4])  # Acceso por rango de índices
# Out:
# 30
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# **Operaciones con Series:**
#
# Las Series en Pandas también permiten realizar operaciones vectorizadas, como sumas y multiplicaciones, similar a los arrays de NumPy. Aquí tienes un ejemplo:

# %%
serie_double = serie * 2
print(serie_double)
# Out:
# 0     20
# 1     40
# 2     60
# 3     80
# 4    100
# dtype: int64

# %% [markdown]
# **Visualización de una Serie:**
#
# Pandas ofrece integración con librerías de visualización como `matplotlib`. Aquí tienes cómo visualizar una Serie en un gráfico:

# %%
import matplotlib.pyplot as plt

serie.plot(kind='line', marker='o')
plt.title('Ejemplo de Visualización de una Serie')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.grid(True)
plt.show()

# %% [markdown]
# Este código generará un gráfico de línea con los valores de la Serie en el eje $y$ y los índices en el eje $x$.
#
# **Indexación Personalizada:**
#
# Puedes personalizar los índices de una Serie para que sean etiquetas significativas en lugar de números. Por ejemplo:

# %%
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo']
serie_con_indices = pd.Series(data, index=meses)
print(serie_con_indices)
# Out:
# Enero      10
# Febrero    20
# Marzo      30
# Abril      40
# Mayo       50
# dtype: int64

# %% [markdown]
# **Resumen:**
#
# En resumen, las Series son estructuras unidimensionales en Pandas que contienen datos homogéneos. Son el componente principal de los DataFrames y se utilizan ampliamente en el análisis y manipulación de datos. Las Series ofrecen funcionalidades para acceder a los datos, realizar operaciones vectorizadas y visualizar datos, lo que las convierte en una herramienta esencial en el análisis de datos con Python.

# %% [markdown]
# ## **Creación y manipulación de Series**

# %% [markdown]
# **Creación y Manipulación de Series en Pandas**
#
# Las Series son una estructura fundamental en Pandas para trabajar con datos unidimensionales. Aquí te proporcionaré una explicación detallada de cómo crear y manipular Series, acompañada de ejemplos y visualizaciones.
#
# **Creación de Series:**
#
# Puedes crear una Serie en Pandas utilizando el constructor `pd.Series()`. Puedes pasar una lista, un array NumPy u otras estructuras de datos para crear una Serie. Veamos un ejemplo con una lista de temperaturas:

# %%
import pandas as pd

temperaturas = [22.5, 23.7, 25.1, 21.8, 20.5]
serie_temperaturas = pd.Series(temperaturas)
print(serie_temperaturas)
# Out:
# 0    22.5
# 1    23.7
# 2    25.1
# 3    21.8
# 4    20.5
# dtype: float64

# %% [markdown]
# **Acceso y Manipulación de Series:**
#
# Puedes acceder a elementos individuales de una Serie utilizando índices numéricos:

# %%
print(serie_temperaturas[2])  # Acceso al tercer elemento (índice 2)
# Out:
# 25.1

# %% [markdown]
# También puedes utilizar operaciones vectorizadas y filtrado:

# %%
serie_doble = serie_temperaturas * 2
temperaturas_mayor_22 = serie_temperaturas[serie_temperaturas > 22]

# %% [markdown]
# **Visualización de Series:**
#
# Pandas se integra bien con librerías de visualización como `matplotlib`. Aquí tienes cómo visualizar una Serie con un gráfico de líneas:

# %%
import matplotlib.pyplot as plt

serie_temperaturas.plot(kind='line', marker='o')
plt.title('Variación de Temperaturas')
plt.xlabel('Días')
plt.ylabel('Temperatura (°C)')
plt.grid(True)
plt.show()

# %% [markdown]
# Esta visualización mostrará una gráfica de líneas con las temperaturas en el eje $y$ y los días en el eje $x$.
#
# **Indexación Personalizada:**
#
# Puedes asignar etiquetas personalizadas a los índices de una Serie:

# %%
dias = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes']
serie_temperaturas_con_indices = pd.Series(temperaturas, index=dias)
print(serie_temperaturas_con_indices)
# Out:
# Lunes        22.5
# Martes       23.7
# Miércoles    25.1
# Jueves       21.8
# Viernes      20.5
# dtype: float64

# %% [markdown]
# **Creación de Series desde un Diccionario:**
#
# También puedes crear Series directamente desde un diccionario. Las claves se convierten en índices y los valores en los datos de la Serie:

# %%
datos_dict = {'Ene': 15, 'Feb': 18, 'Mar': 20, 'Abr': 16, 'May': 14}
serie_dict = pd.Series(datos_dict)
print(serie_dict)
# Out:
# Ene    15
# Feb    18
# Mar    20
# Abr    16
# May    14
# dtype: int64

# %% [markdown]
# En resumen, las Series en Pandas son una estructura esencial para trabajar con datos unidimensionales. Puedes crearlas a partir de diferentes tipos de datos y manipularlas para realizar operaciones y análisis. La integración con librerías de visualización como `matplotlib` facilita la visualización de los datos en gráficos significativos.

# %% [markdown]
# ## **Atributos de las Series y acceso a sus valores**

# %% [markdown]
# Las Series en Pandas tienen varios atributos que proporcionan información sobre la Serie y permiten acceder a sus valores. Aquí están algunos de los atributos más comunes y cómo acceder a los valores de una Serie:
#
# **Atributos de las Series:**
#
# 1. **values:** Devuelve los valores de la Serie como un array NumPy.
# 2. **index:** Devuelve los índices de la Serie.
# 3. **dtype:** Devuelve el tipo de datos de los elementos de la Serie.
# 4. **size:** Devuelve el número de elementos en la Serie.
# 5. **shape:** Devuelve la forma (dimensiones) de la Serie.
#
# **Acceso a los Valores de una Serie:**
#
# Puedes acceder a los valores de una Serie de diferentes maneras:
#
# 1. **Por Índice Numérico:** Utiliza índices numéricos para acceder a elementos individuales.

# %%
import pandas as pd

data = [10, 20, 30, 40, 50]
serie = pd.Series(data)
valor = serie[2]  # Acceso al tercer elemento (índice 2)
print(valor)
# Out:
# 30

# %% [markdown]
# 2. **Por Índice Personalizado:** Si la Serie tiene índices personalizados, puedes utilizar las etiquetas.

# %%
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo']
serie_con_indices = pd.Series(data, index=meses)
valor_marzo = serie_con_indices['Marzo']
print(valor_marzo)
# Out:
# 30

# %% [markdown]
# 3. **Por Rango de Índices:** Utiliza el operador de rebanado para acceder a un rango de elementos.

# %%
valores_rango = serie[1:4]  # Acceso a los elementos del índice 1 al 3
print(valores_rango)
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# 4. **Por Condición:** Utiliza una condición booleana para filtrar elementos.

# %%
valores_mayores_a_30 = serie[serie > 30]  # Valores mayores a 30
print(valores_mayores_a_30)
# Out:
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# 5. **A través de Métodos:** Utiliza métodos como `head()` y `tail()` para acceder a los primeros o últimos valores.

# %%
primer_valor = serie.head(1)  # Primer valor
print(primer_valor)
ultimos_valores = serie.tail(3)  # Últimos 3 valores
print(ultimos_valores)
# Out:
# 0    10
# dtype: int64
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# **Acceso a los Atributos:**
#
# Puedes acceder a los atributos de una Serie utilizando el nombre del atributo seguido de paréntesis.

# %%
atributos = {
    'values': serie.values,
    'index': serie.index,
    'dtype': serie.dtype,
    'size': serie.size,
    'shape': serie.shape
}

for attr, value in atributos.items():
    print(f'{attr}: {value}')
# Out:
# values: [10 20 30 40 50]
# index: RangeIndex(start=0, stop=5, step=1)
# dtype: int64
# size: 5
# shape: (5,)

# %% [markdown]
# En resumen, los atributos de las Series proporcionan información sobre la estructura y los valores de la Serie. Puedes acceder a los valores utilizando índices numéricos, índices personalizados, condiciones booleanas y métodos específicos. Estos atributos y técnicas de acceso son fundamentales para trabajar con datos en Pandas.

# %% [markdown]
# ## **Métodos básicos comunes**

# %% [markdown]
# Los métodos básicos en las Series de Pandas son funciones incorporadas que te permiten realizar diversas operaciones en los datos. Estos métodos son esenciales para el análisis y la manipulación de datos. A continuación, te proporciono una explicación detallada de algunos métodos comunes, junto con ejemplos y posibles gráficos.
#
# **Métodos Básicos Comunes en las Series de Pandas:**
#
# 1. **`head()` y `tail()`:**
#
# Devuelven los primeros o últimos n elementos de la Serie.

# %%
import pandas as pd

data = [10, 20, 30, 40, 50]
serie = pd.Series(data)
primeros_3 = serie.head(3)  # Primeros 3 elementos
ultimos_2 = serie.tail(2)   # Últimos 2 elementos

# %% [markdown]
# 2. **`describe()`:**
#
#  Proporciona estadísticas resumidas sobre la Serie, como la media, mediana, desviación estándar, etc.

# %%
descripcion = serie.describe()
print(descripcion)
# Out:
# count     5.000000
# mean     30.000000
# std      15.811388
# min      10.000000
# 25%      20.000000
# 50%      30.000000
# 75%      40.000000
# max      50.000000
# dtype: float64

# %% [markdown]
# 3. **`sum()`, `mean()`, `median()`:**
#
#  Calculan la suma, el promedio y la mediana de los valores de la Serie, respectivamente.

# %%
suma = serie.sum()
promedio = serie.mean()
mediana = serie.median()

# %% [markdown]
# 4. **`max()` y `min()`:**
#
#  Devuelven el valor máximo y mínimo de la Serie.

# %%
maximo = serie.max()
minimo = serie.min()

# %% [markdown]
# 5. **`unique()` y `value_counts()`:**
#
#  `unique()` devuelve los valores únicos en la Serie, y `value_counts()` cuenta la frecuencia de cada valor único.

# %%
valores_unicos = serie.unique()
conteo_valores = serie.value_counts()

# %% [markdown]
# 6. **`sort_values()`:**
#
#  Ordena los valores de la Serie en orden ascendente o descendente.

# %%
serie_ordenada = serie.sort_values(ascending=False)  # Orden descendente

# %% [markdown]
# **Ejemplo con Gráficos:**
#
# Vamos a considerar el método `value_counts()` para visualizar la frecuencia de los valores en una Serie:

# %%
import matplotlib.pyplot as plt

# Crear una Serie de datos de ejemplo
etiquetas = ['Manzana', 'Banana', 'Manzana', 'Naranja', 'Banana', 'Uva']
serie_frutas = pd.Series(etiquetas)

# Obtener el conteo de cada fruta
conteo_frutas = serie_frutas.value_counts()

# Crear un gráfico de barras para mostrar la frecuencia
plt.bar(conteo_frutas.index, conteo_frutas.values)
plt.title('Frecuencia de Frutas')
plt.xlabel('Fruta')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Este código generará un gráfico de barras que muestra la frecuencia de cada fruta en la Serie.
#
# Estos métodos y sus aplicaciones te permitirán realizar diversas operaciones básicas y obtener información útil de tus Series de datos en Pandas.

# %% [markdown]
# ## **Operaciones vectoriales aritméticas**

# %% [markdown]
# **Operaciones Vectoriales Aritméticas en las Series de Pandas**
#
# Las operaciones vectoriales aritméticas son una característica poderosa de las Series de Pandas. Permiten realizar cálculos entre Series de manera eficiente y concisa, aplicando operaciones elemento a elemento. Esta funcionalidad es esencial para el análisis y la manipulación de datos en Pandas. A continuación, te proporcionaré una explicación detallada junto con ejemplos y posibles gráficos.
#
# **Operaciones Vectoriales Aritméticas:**
#
# Las operaciones aritméticas se aplican automáticamente a cada elemento de la Serie. Las operaciones básicas incluyen la suma, resta, multiplicación y división. Aquí está cómo funcionan:

# %%
import pandas as pd

serie1 = pd.Series([10, 20, 30, 40])
serie2 = pd.Series([5, 10, 15, 20])

suma = serie1 + serie2
resta = serie1 - serie2
multiplicacion = serie1 * serie2
division = serie1 / serie2

# %% [markdown]
# **Operaciones con Funciones NumPy:**
#
# Puedes aplicar funciones NumPy directamente a una Serie, lo que es especialmente útil para cálculos más complejos:

# %%
import numpy as np

serie = pd.Series([1, 2, 3, 4, 5])
raices_cuadradas = np.sqrt(serie)
logaritmos = np.log(serie)

# %% [markdown]
# **Ejemplo con Gráficos:**
#
# Vamos a considerar la adición y la multiplicación de Series para crear gráficos que muestren el efecto de estas operaciones:

# %%
import matplotlib.pyplot as plt

# Crear dos Series de ejemplo
serie1 = pd.Series([1, 2, 3, 4, 5])
serie2 = pd.Series([5, 4, 3, 2, 1])

# Suma de Series
suma = serie1 + serie2

# Multiplicación de Series
multiplicacion = serie1 * serie2

# Crear gráficos para visualizar los resultados
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(serie1, label='Serie 1')
plt.plot(serie2, label='Serie 2')
plt.plot(suma, label='Suma')
plt.title('Suma de Series')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(serie1, label='Serie 1')
plt.plot(serie2, label='Serie 2')
plt.plot(multiplicacion, label='Multiplicación')
plt.title('Multiplicación de Series')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Este código generará dos gráficos: uno que muestra la suma de las Series y otro que muestra la multiplicación de las Series. Los gráficos ayudan a visualizar cómo las operaciones aritméticas afectan a las Series.
#
# Las operaciones vectoriales aritméticas en Pandas simplifican el cálculo y la manipulación de datos en Series, permitiéndote realizar operaciones complejas de manera eficiente.

# %% [markdown]
# ## **Funciones de estadística y de agregación básicas**

# %% [markdown]
# Las funciones de estadística y de agregación son esenciales para comprender y resumir los datos en las Series de Pandas. Estas funciones permiten calcular estadísticas descriptivas y realizar agregaciones en los datos. A continuación, te proporcionaré una explicación detallada junto con ejemplos y posibles gráficos.
#
# **Funciones de Estadística y Agregación Básicas:**
#
# 1. **`mean()`:**
#
#  Calcula la media de los valores en la Serie.

# %%
import pandas as pd

serie = pd.Series([10, 20, 30, 40, 50])
media = serie.mean()

# %% [markdown]
# 2. **`median()`:**
#
#  Calcula la mediana de los valores en la Serie.

# %%
mediana = serie.median()

# %% [markdown]
# 3. **`sum()`:**
#
#  Calcula la suma total de los valores en la Serie.

# %%
suma = serie.sum()

# %% [markdown]
# 4. **`min()` y `max()`:**
#
#  Calculan el valor mínimo y máximo de la Serie.

# %%
minimo = serie.min()
maximo = serie.max()

# %% [markdown]
# 5. **`std()`:**
#
#  Calcula la desviación estándar de los valores en la Serie.

# %%
desviacion_estandar = serie.std()

# %% [markdown]
# 6. **`count()`:**
#
#  Cuenta el número de valores no nulos en la Serie.

# %%
conteo = serie.count()

# %% [markdown]
# **Ejemplo con Gráficos:**
#
# Vamos a considerar algunas de estas funciones de estadística y agregación y representar los resultados en gráficos:

# %%
import matplotlib.pyplot as plt

# Crear una Serie de ejemplo
valores = [12, 18, 15, 20, 25, 30, 22, 28, 24, 19]
serie_valores = pd.Series(valores)

# Calcular estadísticas
media = serie_valores.mean()
mediana = serie_valores.median()
minimo = serie_valores.min()
maximo = serie_valores.max()

# Visualizar datos y estadísticas en un gráfico
plt.hist(serie_valores, bins=10, edgecolor='black')
plt.axvline(media, color='red', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana, color='green', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(minimo, color='blue', linestyle='dashed', linewidth=2, label='Mínimo')
plt.axvline(maximo, color='orange', linestyle='dashed', linewidth=2, label='Máximo')
plt.legend()
plt.title('Distribución de Valores y Estadísticas')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# Este código generará un histograma que muestra la distribución de valores en la Serie junto con líneas verticales que indican la media, la mediana, el mínimo y el máximo.
#
# Las funciones de estadística y de agregación en Pandas te permiten obtener información clave sobre los datos en tus Series. Al visualizar estas estadísticas en gráficos, puedes tener una comprensión más completa de la distribución y las tendencias en los datos.

# %% [markdown]
# | **Inicio** | **atrás 1** | **Siguiente 3** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./1_Jupyter_Notebook.ipynb)| [⏩](./3_DataFrames_de_Pandas.ipynb)|
