# %% [markdown]
# | **Inicio** | **atrás 4** | **Siguiente 6** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./4_%20datos_de_Excel_CSV.ipynb)| [⏩](./6_Visualizacion_de_Datos.ipynb)|

# %% [markdown]
# # **5. Filtra Datos en DataFrames de Pandas para un mejor Análisis de Datos con Python**

# %% [markdown]
# ## **Introducción a los Filtros en Pandas**

# %% [markdown]
# ¡Por supuesto! Trabajar con Pandas en Python es una excelente manera de filtrar y analizar datos. Aquí tienes una explicación detallada sobre cómo filtrar datos en DataFrames de Pandas para un mejor análisis, acompañada de ejemplos y visualizaciones gráficas.
#
# **Paso 1: Importar Pandas y cargar los datos**
#
# Primero, necesitamos importar la biblioteca Pandas y cargar los datos en un DataFrame. Supongamos que tenemos un conjunto de datos de ventas mensuales:

# %%
import pandas as pd

# Crear un DataFrame de ejemplo
data = {
    'Mes': ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo'],
    'Ventas': [1000, 1200, 800, 1500, 1100]
}

df = pd.DataFrame(data)

# %% [markdown]
# **Paso 2: Filtrar datos según condiciones**
#
# Ahora, vamos a aprender cómo filtrar los datos en función de ciertas condiciones. Supongamos que queremos analizar los meses en los que las ventas fueron superiores a 1000:

# %%
ventas_altas = df[df['Ventas'] > 1000]

# %% [markdown]
# **Paso 3: Visualizar los datos filtrados**
#
# Una vez que hemos filtrado los datos, podemos visualizarlos para un análisis más claro. Aquí vamos a usar la biblioteca Matplotlib para crear gráficos simples:

# %%
import matplotlib.pyplot as plt

# Crear un gráfico de barras para las ventas altas
plt.bar(ventas_altas['Mes'], ventas_altas['Ventas'])
plt.xlabel('Mes')
plt.ylabel('Ventas')
plt.title('Ventas Mensuales Superiores a 1000')
plt.show()

# %% [markdown]
# **Paso 4: Filtrar usando múltiples condiciones**
#
# Pandas también permite filtrar utilizando múltiples condiciones. Supongamos que queremos analizar los meses en los que las ventas fueron superiores a 1000 y también inferiores a 1500:

# %%
ventas_interesantes = df[(df['Ventas'] > 1000) & (df['Ventas'] < 1500)]

# %% [markdown]
# **Paso 5: Visualizar datos filtrados con múltiples condiciones**
#
# Vamos a visualizar estos datos filtrados nuevamente utilizando un gráfico de barras:

# %%
plt.bar(ventas_interesantes['Mes'], ventas_interesantes['Ventas'])
plt.xlabel('Mes')
plt.ylabel('Ventas')
plt.title('Ventas Mensuales entre 1000 y 1500')
plt.show()

# %% [markdown]
# Recuerda que estos son ejemplos básicos para ilustrar cómo filtrar y visualizar datos con Pandas y Matplotlib. En situaciones reales, tus conjuntos de datos y análisis pueden ser mucho más complejos, pero estos pasos te proporcionan una base sólida para comenzar a trabajar con tus propios datos.

# %% [markdown]
# ## **Explicación del Contexto de los Ejercicios**

# %% [markdown]
# **Contexto de los Ejercicios y Datos de Ejemplo**
#
# Supongamos que eres un analista de datos en una empresa que vende productos y tienes un conjunto de datos que registra las ventas mensuales de ciertos productos durante los primeros cinco meses del año. El objetivo es filtrar y analizar estos datos para obtener una comprensión más profunda de las ventas.
#
# En este escenario:
#
# - Los datos consisten en dos columnas: "Mes" y "Ventas".
# - La columna "Mes" registra el mes correspondiente (Enero, Febrero, Marzo, Abril, Mayo).
# - La columna "Ventas" registra la cantidad de ventas para ese mes en particular.
#
# **Ejercicio 1: Filtrar Ventas Altas**
#
# El primer ejercicio trata sobre filtrar los datos para analizar los meses en los que las ventas fueron superiores a $1000. Esto podría ser importante para identificar los meses en los que las ventas fueron particularmente fuertes.
#
# **Ejercicio 2: Filtrar Ventas Interesantes**
#
# En el segundo ejercicio, se te pide que filtres los datos para identificar los meses en los que las ventas estuvieron en el rango de $1000 a $1500. Esto podría ser útil para identificar los meses en los que las ventas estuvieron en un rango específico, posiblemente considerado como "ventas promedio".
#
# **Visualización de Datos**
#
# En ambos ejercicios, después de filtrar los datos, se generan gráficos de barras para visualizar las ventas de los meses seleccionados. Los gráficos de barras son una forma efectiva de visualizar datos categóricos como los meses y sus respectivas ventas. Cada barra en el gráfico representa un mes, y la altura de la barra indica el valor de las ventas para ese mes.
#
# Estas visualizaciones te permitirán identificar rápidamente tendencias en las ventas y analizar cómo varían según las condiciones que has establecido en tus filtros.
#
# Recuerda que estos ejemplos son simplificados para fines ilustrativos, pero en situaciones reales, podrías trabajar con conjuntos de datos más grandes y realizar análisis más complejos para tomar decisiones informadas sobre el rendimiento de tus productos y estrategias de ventas.

# %% [markdown]
# ## **Cómo Filtrar Información en DataFrames**

# %% [markdown]
# **Paso 1: Importar Pandas y cargar los datos**
#
# Primero, importamos la biblioteca Pandas y creamos un DataFrame con datos de ejemplo:

# %%
import pandas as pd

# Crear un DataFrame con datos de ejemplo
data = {
    'Producto': ['A', 'B', 'C', 'A', 'B', 'C'],
    'Ventas': [1000, 1200, 800, 1500, 1100, 900]
}

df = pd.DataFrame(data)

# %% [markdown]
# **Paso 2: Filtrar datos utilizando condiciones**
#
# Pandas nos permite filtrar datos utilizando condiciones lógicas. Supongamos que queremos filtrar los productos con ventas superiores a 1000:

# %%
ventas_altas = df[df['Ventas'] > 1000]

# %% [markdown]
# **Paso 3: Visualizar datos filtrados**
#
# Ahora, vamos a visualizar los datos filtrados mediante un gráfico de barras. Utilizaremos la biblioteca Matplotlib para crear la visualización:

# %%
import matplotlib.pyplot as plt

# Crear un gráfico de barras para productos con ventas altas
plt.bar(ventas_altas['Producto'], ventas_altas['Ventas'])
plt.xlabel('Producto')
plt.ylabel('Ventas')
plt.title('Productos con Ventas Altas')
plt.show()

# %% [markdown]
# **Paso 4: Filtrar utilizando múltiples condiciones**
#
# Pandas también nos permite combinar múltiples condiciones para realizar filtrados más complejos. Supongamos que queremos filtrar los productos con ventas superiores a 1000 y que pertenecen a la categoría 'A':

# %%
productos_interesantes = df[(df['Ventas'] > 1000) & (df['Producto'] == 'A')]

# %% [markdown]
# **Paso 5: Visualizar datos filtrados con múltiples condiciones**
#
# Vamos a visualizar nuevamente estos datos filtrados utilizando un gráfico de barras:

# %%
plt.bar(productos_interesantes['Producto'], productos_interesantes['Ventas'])
plt.xlabel('Producto')
plt.ylabel('Ventas')
plt.title('Productos Interesantes (Ventas > 1000 y Producto A)')
plt.show()

# %% [markdown]
# **Contexto de los Ejemplos**
#
# En estos ejemplos, estamos trabajando con un DataFrame que contiene información sobre productos y sus ventas. Cada fila representa una venta de un producto específico. Los pasos que hemos seguido ilustran cómo filtrar los datos para analizar productos con ciertas condiciones de ventas y cómo visualizar esta información utilizando gráficos de barras.
#
# Es importante recordar que los ejemplos anteriores son simples y se utilizan para ilustrar los conceptos de filtrado y visualización. En situaciones reales, podrías tener conjuntos de datos más grandes y aplicar filtros más complejos para obtener información significativa sobre tus datos.

# %% [markdown]
# ## **Ejercicios Básicos de Filtrado**

# %% [markdown]
# **Ejercicio 1: Filtrar datos por una columna numérica**
#
# Supongamos que tienes un DataFrame con información sobre estudiantes y sus calificaciones en un curso. Quieres filtrar los estudiantes que han obtenido una calificación superior a 90.

# %%
import pandas as pd

data = {
    'Estudiante': ['Ana', 'Juan', 'María', 'Carlos'],
    'Calificacion': [85, 92, 88, 95]
}

df = pd.DataFrame(data)

# Filtrar estudiantes con calificación superior a 90
calif_altas = df[df['Calificacion'] > 90]
print(calif_altas)
# Out:
#   Estudiante  Calificacion
# 1       Juan            92
# 3     Carlos            95

# %% [markdown]
# **Ejercicio 2: Filtrar datos por una columna categórica**
#
# Ahora, imagina que tienes un DataFrame con información sobre empleados y sus departamentos. Quieres filtrar los empleados que trabajan en el departamento de "Ventas".

# %%
data = {
    'Empleado': ['Elena', 'Pedro', 'Laura', 'Miguel'],
    'Departamento': ['Ventas', 'Finanzas', 'Ventas', 'Recursos Humanos']
}

df = pd.DataFrame(data)

# Filtrar empleados del departamento de "Ventas"
ventas_empleados = df[df['Departamento'] == 'Ventas']
print(ventas_empleados)
# Out:
#   Empleado Departamento
# 0    Elena       Ventas
# 2    Laura       Ventas

# %% [markdown]
# **Ejercicio 3: Filtrar datos usando múltiples condiciones**
#
# Supongamos que tienes un DataFrame con información sobre productos y sus precios. Quieres filtrar los productos que tienen un precio superior a 50 y pertenecen a la categoría "Electrónicos".

# %%
data = {
    'Producto': ['Laptop', 'TV', 'Smartphone', 'Tablet'],
    'Precio': [800, 600, 1000, 40],
    'Categoria': ['Electrónicos', 'Electrónicos', 'Electrónicos', 'Electrónicos']
}

df = pd.DataFrame(data)

# Filtrar productos con precio superior a 50 y categoría "Electrónicos"
productos_interesantes = df[(df['Precio'] > 50) & (df['Categoria'] == 'Electrónicos')]
print(productos_interesantes)
# Out:
#      Producto  Precio     Categoria
# 0      Laptop     800  Electrónicos
# 1          TV     600  Electrónicos
# 2  Smartphone    1000  Electrónicos

# %% [markdown]
# **Ejercicio 4: Filtrar datos por un rango de fechas**
#
# Imagina que tienes un DataFrame con información sobre transacciones financieras y sus fechas. Quieres filtrar las transacciones que ocurrieron en el segundo trimestre del año.

# %%
data = {
    'Fecha': ['2023-04-15', '2023-05-20', '2023-06-10', '2023-07-05'],
    'Monto': [150, 200, 300, 50]
}

df = pd.DataFrame(data)
df['Fecha'] = pd.to_datetime(df['Fecha'])

# Filtrar transacciones del segundo trimestre
segundo_trimestre = df[(df['Fecha'].dt.month >= 4) & (df['Fecha'].dt.month <= 6)]
print(segundo_trimestre)
# Out:
#        Fecha  Monto
# 0 2023-04-15    150
# 1 2023-05-20    200
# 2 2023-06-10    300

# %% [markdown]
# Estos ejercicios básicos te ayudarán a comprender cómo aplicar diferentes tipos de filtros en DataFrames de Pandas. A medida que ganes experiencia, podrás realizar filtrados más complejos y adaptarlos a situaciones de análisis de datos del mundo real.

# %% [markdown]
# ## **Cargar archivo con datos de 229 países**

# %% [markdown]
# ¡Por supuesto! Para cargar un archivo con datos de 229 países en un DataFrame de Pandas, necesitarás tener el archivo en un formato compatible, como CSV (Comma-Separated Values) o Excel. Aquí te proporcionaré ejemplos para ambos formatos.
#
# **Cargar datos desde un archivo CSV:**
#
# Supongamos que tienes un archivo CSV llamado "paises.csv" que contiene datos de los 229 países. Asegúrate de que el archivo esté en el mismo directorio que tu script de Python o proporciona la ruta correcta al archivo.

# %%
import pandas as pd

# Cargar datos desde un archivo CSV
df = pd.read_csv('paises.csv')

# Mostrar las primeras filas del DataFrame
print(df.head())

# %% [markdown]
# **Cargar datos desde un archivo Excel:**
#
# Supongamos que tienes un archivo Excel llamado "paises.xlsx" que contiene datos de los 229 países. Asegúrate de que el archivo esté en el mismo directorio que tu script de Python o proporciona la ruta correcta al archivo.

# %%
import pandas as pd

# Cargar datos desde un archivo Excel
df = pd.read_excel('paises.xlsx')

# Mostrar las primeras filas del DataFrame
print(df.head())

# %% [markdown]
# Asegúrate de que el archivo CSV o Excel contenga los datos organizados en columnas, donde cada columna represente una característica o propiedad de los países (por ejemplo, nombre del país, población, área, idioma, etc.).
#
# Si tienes el archivo en otro formato o la estructura de los datos es diferente, tendrás que adaptar el código para que se ajuste a tus necesidades.
#
# Una vez que hayas cargado los datos en un DataFrame, podrás realizar análisis, filtrados, visualizaciones y otras operaciones en función de las características de los países que se encuentren en los datos.

# %% [markdown]
# ## **Ejercicios Avanzados con Condiciones Booleanas**

# %% [markdown]
# ¡Por supuesto! Aquí tienes algunos ejercicios avanzados que involucran el uso de condiciones booleanas para filtrar y analizar datos en DataFrames de Pandas.
#
# **Ejercicio 1: Filtrar países con población y área grandes**
#
# Supongamos que tienes un DataFrame llamado `paises_df` con información sobre diferentes países, incluyendo su nombre, población y área en kilómetros cuadrados. Quieres filtrar los países que tienen una población superior a 100 millones y un área mayor a 500,000 kilómetros cuadrados.

# %%
import pandas as pd

# Crear un DataFrame con datos ficticios sobre países
data = {
    'Pais': ['Estados Unidos', 'China', 'India', 'Brasil', 'Rusia'],
    'Continente': ['América', 'Asia', 'Asia', 'América', 'Europa'],
    'Poblacion': [331002651, 1444216107, 1380004385, 212559417, 145934462],
    'Area': [9525067, 9596960, 3287263, 8515767, 17098242],
    'Idioma': ['Inglés', 'Chino', 'Hindi', 'Portugués', 'Ruso']
}

paises_df = pd.DataFrame(data)
print(paises_df)

# Supongamos que paises_df ya está cargado con los datos de los países

# Filtrar países con población > 100 millones y área > 500,000 km^2
paises_grandes = paises_df[(paises_df['Poblacion'] > 100_000_000) & (paises_df['Area'] > 500_000)]
print(paises_grandes)
# Out:
#              Pais Continente   Poblacion      Area     Idioma
# 0  Estados Unidos    América   331002651   9525067     Inglés
# 1           China       Asia  1444216107   9596960      Chino
# 2           India       Asia  1380004385   3287263      Hindi
# 3          Brasil    América   212559417   8515767  Portugués
# 4           Rusia     Europa   145934462  17098242       Ruso
#              Pais Continente   Poblacion      Area     Idioma
# 0  Estados Unidos    América   331002651   9525067     Inglés
# 1           China       Asia  1444216107   9596960      Chino
# 2           India       Asia  1380004385   3287263      Hindi
# 3          Brasil    América   212559417   8515767  Portugués
# 4           Rusia     Europa   145934462  17098242       Ruso

# %% [markdown]
# **Ejercicio 2: Clasificar países por densidad de población**
#
# Deseas calcular y clasificar los países en el DataFrame según su densidad de población (población dividida por área) en orden descendente.

# %%
# Calcular densidad de población y clasificar los países
paises_df['Densidad_Poblacion'] = paises_df['Poblacion'] / paises_df['Area']
paises_ordenados = paises_df.sort_values(by='Densidad_Poblacion', ascending=False)
print(paises_ordenados)
# Out:
#              Pais Continente   Poblacion      Area     Idioma  \
# 2           India       Asia  1380004385   3287263      Hindi
# 1           China       Asia  1444216107   9596960      Chino
# 0  Estados Unidos    América   331002651   9525067     Inglés
# 3          Brasil    América   212559417   8515767  Portugués
# 4           Rusia     Europa   145934462  17098242       Ruso
#
#    Densidad_Poblacion
# 2          419.803461
# 1          150.486832
# 0           34.750690
# 3           24.960690
# 4            8.535057

# %% [markdown]
# **Ejercicio 3: Filtrar países con idiomas específicos**
#
# Supongamos que tienes una lista de idiomas populares y quieres filtrar los países que tienen uno de esos idiomas como idioma oficial.

# %%
idiomas_populares = ['Inglés', 'Español', 'Francés']

# Filtrar países con idiomas populares como idioma oficial
paises_con_idiomas_populares = paises_df[paises_df['Idioma'].isin(idiomas_populares)]
print(paises_con_idiomas_populares)
# Out:
#              Pais Continente  Poblacion     Area  Idioma  Densidad_Poblacion
# 0  Estados Unidos    América  331002651  9525067  Inglés            34.75069

# %% [markdown]
# **Ejercicio 4: Filtrar países por continente y características**
#
# Si tienes un DataFrame con información detallada sobre los países, puedes realizar filtrados más específicos. Supongamos que deseas filtrar los países en el continente "Asia" con población entre 50 y 100 millones y área entre 200,000 y 500,000 kilómetros cuadrados.

# %%
# Filtrar países en Asia con población y área específicas
asia_filtros = (paises_df['Continente'] == 'Asia') & \
               (paises_df['Poblacion'].between(50_000_000, 100_000_000)) & \
               (paises_df['Area'].between(200_000, 500_000))

paises_asia_filtrados = paises_df[asia_filtros]
print(paises_asia_filtrados)
# Out:
# Empty DataFrame
# Columns: [Pais, Continente, Poblacion, Area, Idioma, Densidad_Poblacion]
# Index: []

# %% [markdown]
# Recuerda que estos ejercicios son ejemplos simplificados para ilustrar el uso de condiciones booleanas en el filtrado y análisis de datos en DataFrames de Pandas. En situaciones reales, los conjuntos de datos y los análisis pueden ser más complejos, pero estos ejercicios te brindan una base sólida para abordar desafíos más avanzados.

# %% [markdown]
# | **Inicio** | **atrás 4** | **Siguiente 6** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./4_%20datos_de_Excel_CSV.ipynb)| [⏩](./6_Visualizacion_de_Datos.ipynb)|
