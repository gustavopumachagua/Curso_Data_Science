# %% [markdown]
# | **Inicio** | **atrás 14** | **Siguiente 16** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./14_GINI.ipynb)| [⏩](./16_Datos_de_Entrenamiento.ipynb)|

# %% [markdown]
# # **15. Conoce la Maldición de la Dimensionalidad que afecta a Machine Learning y a la Ciencia de Datos**

# %% [markdown]
# ## **Introducción**

# %% [markdown]
# La Maldición de la Dimensionalidad es un fenómeno que afecta a diversos campos, incluyendo el aprendizaje automático (Machine Learning) y la ciencia de datos. Se refiere a los desafíos y dificultades que surgen cuando se trabaja con conjuntos de datos en espacios de alta dimensionalidad, es decir, cuando los datos tienen un gran número de características o dimensiones.
#
# Cuando el número de características en un conjunto de datos aumenta, se presentan varios problemas y desafíos asociados a la Maldición de la Dimensionalidad:
#
# ### 1. Dispersión de los Datos:
# En espacios de alta dimensionalidad, los datos tienden a dispersarse en lugar de agruparse. Esto significa que las observaciones individuales pueden estar muy separadas entre sí. Como resultado, encontrar patrones y relaciones significativas entre los datos se vuelve más difícil.
#
# ### 2. Densidad de Datos:
# Conforme aumenta la dimensionalidad, la cantidad de datos requeridos para mantener una densidad adecuada de muestras en el espacio aumenta exponencialmente. Esto puede ser problemático, ya que en la práctica puede ser difícil recopilar una cantidad suficiente de datos para abordar esta creciente demanda.
#
# ### 3. Espacio Vacío:
# En espacios de alta dimensionalidad, la mayoría del espacio puede quedar vacío. Esto significa que hay muchas regiones en el espacio que no contienen ninguna muestra. Esto puede llevar a problemas como el sobreajuste, ya que el modelo podría encontrar patrones en regiones vacías que no son representativos de los datos reales.
#
# ### 4. Costo Computacional:
# Los algoritmos que funcionan bien en dimensiones bajas pueden volverse ineficientes en dimensiones altas debido al aumento en la complejidad computacional. Esto puede llevar a un aumento en los tiempos de entrenamiento y predicción.
#
# ### 5. Muestra Insuficiente:
# A medida que aumenta la dimensionalidad, la cantidad de muestras existentes puede volverse insuficiente para representar adecuadamente las relaciones entre las características. Esto puede llevar a resultados poco confiables y modelos ineficaces.
#
# ### Ejemplo:
# Supongamos que estamos trabajando con un conjunto de datos de imágenes en escala de grises. Cada píxel en la imagen se considera una característica, lo que significa que una imagen de 100x100 píxeles se traducirá en un vector de 10,000 dimensiones. Visualizar o analizar directamente datos en un espacio de tal dimensionalidad es prácticamente imposible y puede llevar a una pérdida significativa de información.
#
# ### Gráfica:
# Vamos a generar un conjunto de datos aleatorio en diferentes dimensiones y luego graficaremos cómo cambia la densidad de las muestras a medida que aumenta la dimensionalidad:

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
num_samples = 100
num_dimensions = [1, 2, 10, 100]

plt.figure(figsize=(12, 8))

for dim in num_dimensions:
    data = np.random.rand(num_samples, dim)
    plt.subplot(2, 2, num_dimensions.index(dim) + 1)
    
    if dim == 1:
        plt.hist(data, bins=20, color='b', alpha=0.7)
    else:
        plt.scatter(data[:, 0], data[:, 1], c='b', marker='o', s=30)
    
    plt.title(f"{dim} Dimensiones")

plt.tight_layout()
plt.show()

# %% [markdown]
# Este código generará una gráfica con subplots que ilustran cómo cambia la densidad de las muestras a medida que aumenta la dimensionalidad.
#
# En resumen, la Maldición de la Dimensionalidad es un desafío fundamental en el análisis de datos en espacios de alta dimensionalidad. Los científicos de datos y los profesionales de Machine Learning deben ser conscientes de sus efectos y considerar técnicas como la reducción de dimensionalidad y la selección de características para mitigar sus impactos negativos.

# %% [markdown]
# ## **Graficar datos en 1D, 2D y 3D**

# %% [markdown]
# Claro, a continuación te proporcionaré una explicación detallada junto con ejemplos y sus respectivas gráficas para visualizar datos en 1D, 2D y 3D.
#
# **Visualización de Datos en 1D:**
#
# Cuando se trata de visualizar datos en una dimensión (1D), generalmente utilizamos histogramas para representar la distribución de los datos. Un histograma divide el rango de valores en "bins" y muestra cuántos datos caen en cada bin.
#
# **Ejemplo:**
#
# Supongamos que tenemos un conjunto de datos unidimensional que representa las edades de un grupo de personas. Queremos visualizar cómo están distribuidas estas edades.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos aleatorios de edades
np.random.seed(0)
ages = np.random.randint(18, 65, size=100)

# Crear un histograma
plt.hist(ages, bins=10, color='blue', alpha=0.7)
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Distribución de Edades')
plt.show()

# %% [markdown]
# En este ejemplo, el eje x representa las edades y el eje y muestra la frecuencia de personas en cada rango de edades.
#
# **Visualización de Datos en 2D:**
#
# Cuando tenemos datos en dos dimensiones (2D), la forma más común de visualización es mediante un gráfico de dispersión. Cada punto en el gráfico representa una instancia de datos con sus valores en dos características.
#
# **Ejemplo:**
#
# Supongamos que tenemos un conjunto de datos que contiene las calificaciones de dos exámenes para un grupo de estudiantes. Queremos visualizar cómo se relacionan las calificaciones en estos dos exámenes.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos aleatorios de calificaciones
np.random.seed(0)
exam1_scores = np.random.randint(0, 100, size=50)
exam2_scores = np.random.randint(0, 100, size=50)

# Crear un gráfico de dispersión
plt.scatter(exam1_scores, exam2_scores, color='green', marker='o')
plt.xlabel('Calificación Examen 1')
plt.ylabel('Calificación Examen 2')
plt.title('Relación entre Calificaciones en Examen 1 y Examen 2')
plt.show()

# %% [markdown]
# En este ejemplo, cada punto en el gráfico representa una calificación en el Examen 1 en el eje x y una calificación en el Examen 2 en el eje y.
#
# **Visualización de Datos en 3D:**
#
# La visualización de datos en tres dimensiones (3D) se realiza utilizando gráficos 3D. Puedes usar la librería `mpl_toolkits.mplot3d` de Matplotlib para crear estos gráficos.
#
# **Ejemplo:**
#
# Supongamos que tenemos datos en tres dimensiones que representan las calificaciones en tres exámenes diferentes para un grupo de estudiantes. Queremos visualizar cómo se distribuyen las calificaciones en estos tres exámenes.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generar datos aleatorios de calificaciones en tres exámenes
np.random.seed(0)
exam1_scores = np.random.randint(0, 100, size=50)
exam2_scores = np.random.randint(0, 100, size=50)
exam3_scores = np.random.randint(0, 100, size=50)

# Crear un gráfico 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(exam1_scores, exam2_scores, exam3_scores, c='purple', marker='o')
ax.set_xlabel('Calificación Examen 1')
ax.set_ylabel('Calificación Examen 2')
ax.set_zlabel('Calificación Examen 3')
ax.set_title('Distribución de Calificaciones en 3 Exámenes')
plt.show()

# %% [markdown]
# En este ejemplo, cada punto en el gráfico 3D representa una calificación en el Examen 1 en el eje x, una calificación en el Examen 2 en el eje y y una calificación en el Examen 3 en el eje z.
#
# Estos ejemplos ilustran cómo visualizar datos en diferentes dimensiones utilizando diferentes tipos de gráficos. La elección del tipo de visualización depende del número de dimensiones y la información que deseas comunicar.

# %% [markdown]
# ## **Espacio de configuraciones**

# %% [markdown]
# El "espacio de configuraciones" se refiere al conjunto de todas las posibles combinaciones o configuraciones de parámetros que un modelo puede tener. En el contexto de machine learning y optimización de hiperparámetros, el espacio de configuraciones se refiere a todas las combinaciones posibles de valores que pueden tomar los hiperparámetros de un modelo.
#
# Cuando entrenamos modelos de machine learning, generalmente tenemos varios hiperparámetros que pueden ser ajustados para optimizar el rendimiento del modelo. Estos hiperparámetros pueden incluir la tasa de aprendizaje, el número de árboles en un bosque aleatorio, el número de vecinos en el algoritmo k-NN, etc. El proceso de búsqueda de los mejores hiperparámetros implica explorar diferentes combinaciones de valores para estos hiperparámetros y seleccionar aquellos que produzcan el mejor rendimiento en términos de métricas de evaluación, como la precisión, el F1-score o el error cuadrático medio.
#
# El espacio de configuraciones puede ser vasto y complejo, especialmente cuando se tienen múltiples hiperparámetros con diferentes rangos de valores. La búsqueda manual a través de todo el espacio de configuraciones no es práctica ni eficiente. Aquí es donde entran en juego las técnicas de búsqueda en rejilla y búsqueda aleatoria, que permiten automatizar el proceso de búsqueda y selección de los mejores hiperparámetros.
#
# En resumen, el espacio de configuraciones se refiere a todas las posibles combinaciones de valores que los hiperparámetros de un modelo pueden tener. La tarea de encontrar la mejor combinación de hiperparámetros se aborda a través de técnicas de optimización y búsqueda, como la búsqueda en rejilla y la búsqueda aleatoria, para encontrar los valores que maximizan el rendimiento del modelo en los datos de validación o prueba.

# %% [markdown]
# | **Inicio** | **atrás 14** | **Siguiente 16** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./14_GINI.ipynb)| [⏩](./16_Datos_de_Entrenamiento.ipynb)|
