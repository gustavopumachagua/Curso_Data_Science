# %% [markdown]
# | **Inicio** | **atrás 21** |
# |----------- |-------------- |
# | [🏠](../../README.md) | [⏪](./21_Funciones_Matematicas_para_Ciencia_de_Datos.ipynb)|

# %% [markdown]
# # **22. Análisis Exploratorio de Datos**

# %% [markdown]
# ## **Tema 1: Introducción al análisis exploratorio de datos**

# %% [markdown]
# ### **¿Qué es y para qué sirve el análisis exploratorio de datos?**

# %% [markdown]
# **Que aprenderás en esta lectura?**
#
# * Entenderás que es y para qué sirve un Aanálisis Exploratorio de Datos (Exploratory Data Analysis o E.D.A).
# * Conocerás los distintos tipos de análisis de datos que existen.
# Identificaras distintos tipos de variables y análisis que puedes realizar con ellas.
# * Serás capaz de explorar conjuntos de datos de `n` variables.
# * Identificarás las ventajas y desventajas de distintas visualizaciones de datos.
#
#
# **Conocimientos requeridos:**
#
# Para que puedas ir efectuando y entendiendo los trabajos al par de la lectura, se asume que posees conocimientos previos en.
#
# * Python y algún notebook de tu preferencia.
# * Principios de visualización de datos.
# * Pandas y NumPy.
# * Matplotlib y Seaborn.
# * Estadística.

# %% [markdown]
# ### **Que es el Análisis Exploratorio de Datos (E.D.A)**

# %% [markdown]
# En pocas palabras, un Análisis exploratorio de datos es el proceso determinado por el científico John W. Turkey para su tratamiento estadístico de muestras recogidas durante la investigación.
#
# **Los procesos básicos para un E.D.A**
#
# 1. **Transformar los datos:**
#
#  Nos sirve para saber qué hacer frente a valores nulos, faltantes o datos atípicos. Además de establecer si hay necesidad de reducir la dimensionalidad de datos.
#
# 2. **Visualizar:**
#
#  Utilizar alguna herramienta para hacer una representación gráfica de los datos, por ejemplo, R, Jupyter, notebook, Google Colab, etc.
#
# 3. **Analizar e Interpretar:**
#
#  Analizar e interpretar los datos a través de diferentes visualizaciones.
#
# 4. **Documentar:**
#
#  Documentar todas las gráficas y estadísticas generadas.
#
# Los puntos será trabajar en el proceso de conocer en detalle nuestros datos y otorgarles un sentido, poder determinaremos la forma correcta de como tratarlos, indagar en ellos para obtener las respuestas que necesitemos y transformar los datos en información útil.

# %% [markdown]
# ### **¿Cómo hacer un análisis exploratorio de datos?**

# %% [markdown]
# **¿Por qué deberías realizar un Análisis Exploratorio de Datos?**
#
# **Organizar y entender las variables**
#
# Lograremos identificar los distintos tipos de variables, las categorías a las que pertenecen y por consiguiente el tipo de análisis que podemos realizar con ellas.
#
# **Establecer relaciones entre variables**
#
# Lograr establecer relaciones entre las variables, por ejemplo, ver como una variable se modifica si la grafico junto a otra,
#
# **Encontrar patrones ocultos en los datos**
#
# Encontrarás patrones que de no haber hecho las visualizaciones y la exploración de los datos no hubieran sido visibles a simple vista.
#
# Este será el punto donde buscaremos encontrar los data insights
#
# **Ayudarte a escoger el modelo correcto para la necesidad correcta**
#
# Al empezar con un conjunto de datos podemos pensar que elegiremos algún modelo que prediga $X$ cosa, pero no obstante sin antes identificar que variables sirven, cuáles no sirven, como se encuentran relacionadas, cuáles son las variables que mejor se ajustan a algún tipo de modelo u otro, lo más probable es que al construir el modelo tengamos un resultado deficiente.
#
# El hacer el EDA nos ayudará a encontrar el modelo correcto para la necesidad correcta.
#
# **Ayuda a la toma de decisiones basadas en datos**
#
# La toma de decisiones basadas en los datos será uso de hechos, métricas y datos para guiar decisiones estratégicas que se alineen con las metas, objetivos y las iniciativas de nuestra organización.

# %% [markdown]
# ### **¿ Cuáles son los pasos para realizar un análisis exploratorio de datos?**

# %% [markdown]
# En cada paso para nuestro EDA, deberemos tener en cuenta una serie de preguntas para lograr avanzar en el análisis.
#
# **PASO 1: Hacer preguntas**
#
# Una vez visualizados los datos, debemos empezar a preguntarnos sobre ellos.
#
# * ¿Que te gustaría encontrar?
# * ¿Que quisieras saber de los datos?
# * ¿Cuál es la razón para actuar el análisis?
#
#
# Una vez tengamos nuestras preguntas, podremos generar una, guia para nuestro proceso de exploración de datos
#
# **PASO 2: Determinar el tamaño de los datos**
#
# * ¿Cuantas observaciones existen?
# * ¿Cuantas variables hay?
# * ¿Necesito todas las observaciones?
# * ¿Necesito todas las variables?
#
# **PASO 3: Categorizar las variables**
#
# * ¿Cuantas variables categóricas existen?
# * ¿Cuantas variables continuas existen?
# * ¿Como puedo explorar cada variable dependiendo de su categoría?
#
# **PASO 4: Limpieza y validación de datos**
#
# * ¿tengo valores faltantes?
# * ¿Cuál es la proporción de datos faltantes
# * ¿Como puedo tratar los datos faltantes?
# * ¿Cuál es la distribución de los datos?
# * ¿Tengo valores atípicos?
#
# **PASO 5: Establecer relaciones**
#
# * ¿Existen algún tipo de relación entre mi variable $X$ y $Y >$?
# * ¿Qué pasa si ahora considero a la variable $Z$ en el análisis?
# * ¿Qué significa que las observaciones se agrupen?
# * ¿Qué significa el patrón que se observa?
#
# Este proceso es cíclico. A pesar de que pueda parecer infinito, este proceso en algún momento debe salir del ciclo y continuar para obtener algún tipo de valor

# %% [markdown]
# ![Procesos](../img/proceso1.png "procesos")
# ![procesos](../img/proceso.png "procesos")

# %% [markdown]
# ### **Tipos de análisis de datos**

# %% [markdown]
# Sin importar el tamaño del conjunto de datos que tengamos, podemos dividir el conjunto de datos en 4 partes evocando a una pregunta esencial por cada etapa
#
# **Analítica Descriptiva**
#
# Es el análisis más básico. Permite dar una vista general de las propiedades, dimensiones y comportamiento de un fenómeno desde la mera descripción de los datos.
#
# **Analítica Diagnostica**
#
# Es aplicar unos criterios diferenciales a los datos descriptivos para identificar una situación problemática. Permite establecer relaciones entre variables y crear hipótesis sobre las posibles causas de su comportamiento actual.
#
# **Analítica Predictiva**
#
# Utiliza datos para explicar un posible comportamiento de las variables de interés si se siguen las tendencias actuales o si estas cambian. Permite determinar si la situación problemática identificada puede representar mayor o menor riesgo en el futuro.
#
# **Analítica Prescriptiva**
#
# Emplea datos para apoyar la toma de decisiones, con base en eventos del pasado. Propone soluciones basadas en evidencia. Igualmente, la etapa prescriptiva también puede hacer iniciar el ciclo de nuevo, ya que monitorear la solución también da pie a procesos nuevos de descripción y diagnóstico de ese monitoreo, volviendo a iniciar el ciclo una vez más.

# %% [markdown]
# ![Analisis](../img/analisis.png "Analisis")

# %% [markdown]
# **Ejemplo**
#
# 1. **Analítica Descriptiva (Que sucedió?)**
#
# Fuiste a dormir por la noche como cualquier otra, sintiéndote bien, pero al despertar te das cuenta de que te sientes fatigado, con dolor muscular, flema y fiebre. Al preguntarte que está sucediendo hiciste una descripción de los síntomas que te hacen sentir mal.
# Al tratar de averiguar porque te sientes mal recuerdas que estuviste junto a un compañero de trabajo que se sentía enfermo hace dos días, por lo que decides ir al médico para poder recibir un diagnóstico
#
# 2. **Analítica Diagnostica (Porque sucedió?)**
#
# Cuando llegas al hospital, el doctor hará un breve interrogatorio para tener una descripción general de lo que te está ocurriendo, pidiéndote que le repitas los síntomas que tienes en ese momento para luego darte un diagnóstico y concluir de que tienes un resfriado común tas la descripción de tus síntomas.
#
# 3. **Analítica Predictiva (Que podría pasar si?)**
#
# Antes de irte del hospital, una enfermera te detiene y te menciona que quiere hacerte unos análisis, ya que puede ocurrir el caso de lo que sería una enfermedad común para la normalidad de las personas, a ti te trate completamente diferente, por lo cual la enfermera realiza los análisis necesarios para saber si puede ocurrir una situación inesperada ante esta enfermedad por cierta condición, tras los análisis se concluye que estás bien y pasas a la siguiente etapa
#
# Analítica Prescriptiva (Que debería hacerse?)
# La enfermera al llegar a la conclusión de que te encuentras bien, te da el alta y previamente te prescribe los medicamentos y tipo de descanso que tendrás que realizar.

# %% [markdown]
# ### **Tipos de datos y análisis de variables**

# %% [markdown]
# **Tipos de variables**
#
# Las variables categóricas pueden clasificarse en:
#
# **Variables categóricas**
#
# * **Variable nominal**
#
# Es aquella variable cualitativa cuya categoría no sigue ningún orden, se agrupa sin ninguna jerarquía entre sí.
#
# **Ejemplos:**
#
# * Lateralidad (zurdo, diestro)
# * Estado civil (soltero, casado, divorciado, unión libre)
# * Grupo sanguíneo (Grupo A-Grupo B-Grupo AB-Grupo 0)
#
# * **Variable ordinal**
#
# Son aquellas variables categóricas con orden secuencial o progresión natural esperable o jerarquía.
#
# **Ejemplos:**
#
# * Medalla deportiva (oro, plata, bronce)
# * Nivel de clase educativa (último año, primer año, etc.)
#
# **Variables numéricas**
#
# * **Variables continuas**
#
# Son aquellas características que se miden dentro de un rango continuo infinito de valores numéricos y se registran con números reales. Pueden presentar cualquier valor dentro de cierto intervalo.
#
# **Ejemplos:**
#
# * Estatura (1,76543 m)
# * Peso (55,6625 kg)
# * Tamaño de lesión de leishmaniasis (6,0458 mm)
#
# * **Variables discretas**
#
# También llamadas discontinuas, están asociadas a conteos o enumeraciones, razón por la cual solo pueden registrarse con números enteros (0,1,2,3, etc.)
#
# **Ejemplos:**
#
# * Número de hijos en una familia (0, 1, 2, 3, etc.)
# * Número de familias residentes en una manzana (20, 25, 45)
# * Número de insectos atrapados en una red (0, 1, 2, 5, 10)

# %% [markdown]
# ### **Tipos de análisis**

# %% [markdown]
# **Análisis Univariado**
#
# El Análisis Univariado busca analizar cada variable por separado, entender sus características y como se definen por sí misma.
#
# **Análisis Bivariado**
#
# El Análisis Bi variado busca analizar la relación de cada par de variables. Permite buscar relaciones intrínsecas entre los datos
#
# **Análisis Multivariado**
#
# El Análisis Multivariado busca analizar el efecto simultáneo de múltiples variables. Analiza la variable como un conjunto
#
# En el comienzo de la EDA, el análisis univariado te va a dar información mucho más valiosa que comenzar con todas las variables al mismo tiempo. Te ayuda a analizar la contribución individual de una variable sobre las demás para luego incrementar la cantidad de variables y analizar los efectos en conjunto.

# %% [markdown]
# ### **Herramientas de software para el análisis exploratorio de datos**

# %% [markdown]
# Existen una gran variedad de herramientas que podemos usar, esto será un proceso en el que tendrás que ver por tu cuenta cuál es tu herramienta preferida, ya que al fin de cuentas lo que importara son los resultados que entregues.
#
# Acá tienes un listado de herramientas de las que puedes probar:
#
# * Jupyter
# * R Studio
# * Visual Studio COde
# * Google Colab
# * Deepnote
# * Amazon EMR
# * Amazon SageMaker
# * Azure Machine Learning
# * Google Cloud Plataform
# * Apache Spark

# %% [markdown]
# ### **Importar librerías**

# %%
import empiricaldist
import janitor
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import palmerpenguins
import scipy.stats
import seaborn as sns
import sklearn.metrics
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats as ss

# %% [markdown]
# ### **Establecer apariencia general de los gráficos**

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11,9.4)

penguin_color = {
    'Adelie':'#ff6602ff',
    'Gentoo':'#0f7175ff',
    'Chinstrap':'#c65dc9ff',
    'Torgersen': '#955FC8', 
    'Biscoe': '#94e2c3', 
    'Dream': '#345469',
}

# %% [markdown]
# ### **Cargar los datos**

# %% [markdown]
# **Utilizando el paquete palmerpenguins**
#
# **Datos Crudos**

# %%
raw_penguins_df = palmerpenguins.load_penguins_raw()
raw_penguins_df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
#
# ...

# %% [markdown]
# **Datos Previamente procesados**

# %%
preprocess_penguins_df = palmerpenguins.load_penguins()
preprocess_penguins_df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %% [markdown]
# ### **Utilizando Pandas**

# %% [markdown]
# * **Datos crudos**

# %%
raw_penguins_df = pd.read_csv('../data/datos_crudo.csv') # Raw Data

# %%
raw_penguins_df.head(3)
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# ...

# %% [markdown]
# * **Datos preprocesador**

# %%
preprocess_penguins_df = pd.read_csv('../data/datos_procesado.csv') # preprocessed Data

# %%
preprocess_penguins_df.head(3)
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# ...

# %% [markdown]
# ### **Utilizando los conjuntos de datos de seaborn**

# %%
preprocess_penguins_df = sns.load_dataset('penguins')
preprocess_penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# ¡Ahora tenemos los datos crudos, es hora de hacernos las preguntas! Algunas preguntas interesantes pueden ser:
#
# * ¿Cuál es la vida promedio de un pingüino?
# * ¿Viven más las hembras o los machos?
# * ¿La altura es un rasgo distintivo del sexo?
# * ¿Cuál es la proporción altura/ancho de los picos?
# * ¿Correlación peso/sexo?
# * ¿Correlación especie pico?

# %% [markdown]
# ### **Recolección de datos, limpieza y validación**

# %% [markdown]
# Anteriormente, vimos que teníamos 2 conjuntos de datos, uno crudo y otro ya pre procesado, también constábamos con una validación de que esos números y dates estaban bien.

# %% [markdown]
# **¿Qué es la recolección de datos?**

# %% [markdown]
# Es la forma de recolección de información que permite obtener conocimiento de primera mano e ideas originales sobre el problema de investigación.

# %% [markdown]
# **Tipos de recolección de datos**

# %% [markdown]
# **Primaria**
#
# Datos Recolectados de primera mano a través de encuestas, entrevistas, experimentos y otros. Puedes decidir que recolectas y que quiere medir. Tienes total control de los datos.
#
# **Secundaria**
#
# Datos previamente recolectados por una fuente primaria externa al usuario primario. Son datos abiertos que puedes utilizar. No tienes control sobre lo que se mide o sobre el objetivo del estudio
#
# Por ejemplo, datos de departamentos de gobierno o empresas similares a la del usuario primario.
#
# **Terciaria**
#
# Datos que se adquieren de fuentes completamente externas al usuario primario. Son datos accesibles a todo el mundo por lo que pierde su valor y tienden a ser datos genéricos
#
# Por ejemplo, a través de proveedores de datos.

# %% [markdown]
# **¿Qué es la validación de datos?**
#
# Es el proceso de asegurar la consistencia y precisión dentro de un conjunto de datos. Si los datos no son precisos desde el comienzo, los resultados no serán precisos.
#
# **¿Qué se debe validar para asegurar consistencia?**
#
# * **Modelos de datos:**
#
# Si un tercero recolecto los datos, verifica que preguntas quería responder con los datos. Si eres quien recolecta los datos, hazte muchas preguntas y considera si esos datos son suficientes para responderlas.
#
# * **Seguimiento de formato estándar de archivos:**
#
# Verifica que la extensión de los archivos que estás manejando correspondan con el formato interno que tienen. Asegúrate que los números se expresen en el formato que estás trabajando.
#
# Un ejemplo puede ser los distintos formatos de fechas.
#
# * **Tipos de datos:**
#
# Verifica que los datos son del tipo que se indica en el dataset.
#
# Un ejemplo es que te estés leyendo una variable que debería tener datos booleanos y te encuentres un 0.5 en alguna de sus casillas, lo más probable es que algo haya ocurrido en el proceso de recolección de datos.
#
# * **Rango de variables:**
#
# Comprueba que las variables estén dentro del rango establecido en la recolección de datos. En caso de encontrar variables fuera del rango, pregúntate: como llegaron esos datos aquí, ¿tienen algún significado alterno? ¿Debo preservarlos o eliminarlos?
#
# Un ejemplo puede ser que tienes los datos de unos exámenes que sus notas van desde el 1 al 10, pero te encuentras a un alumno que se sacó un 12 y en otro caso uno que se sacó un -7, en este caso se salieron del rango establecido.
#
# * **Unicidad:**
#
# Revisa que tan únicos son los datos. Detecta si existe duplicidad en los datos y corrige.
#
# Un ejemplo es que encuentres 2 identificadores únicos por pingüino, lo cual no estaría bien de misma forma que una persona tenga dos documentos de identidad nacional con distintos números para el mismo país.
#
# * **Consistencia de expresiones:**
#
# Se refiere a como la persona que recolecta los datos define sus variables. Formato de fecha, de hora, variables escritas de la misma forma en toda la tabla. No son datos erróneos, solo es cuestión de darle el formato adecuado.
#
# * **Valores nulos:**
#
# Pueden estar explícitos o implícitos en el dataset. Son datos faltantes. ¿Por qué está vacío?, puedo rellenarlo con otro dato? ¿Está vacío por un proceso aleatorio o tiene un sentido?

# %% [markdown]
# ### **Ejercicio de validación de datos**

# %% [markdown]
# **¿Qué tipo de datos son las variables del conjunto de datos?**

# %%
preprocess_penguins_df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %% [markdown]
# **¿Cuantas variables de cada tipo de dato tenemos en el conjunto de datos?**

# %%
(
    preprocess_penguins_df
    .dtypes
    .value_counts()
)
# Out:
# float64    4
# object     3
# Name: count, dtype: int64

# %% [markdown]
# **¿Cuantas observaciones y variables tenemos en el conjunto de datos?**

# %%
preprocess_penguins_df.shape
# Out:
# (344, 7)

# %% [markdown]
# **¿Existen valores nulos explícitos en el conjunto de datos?**

# %%
preprocess_penguins_df.isnull().any()
# Out:
# species              False
# island               False
# bill_length_mm        True
# bill_depth_mm         True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %% [markdown]
# **¿De tener observaciones con valores nulos? ¿Cuántas tenemos por cada variable?**

# %%
(
    preprocess_penguins_df
    .isnull()
    .sum()
)
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %% [markdown]
# **¿Cuantos valores nulos tenemos en el total en el conjunto de datos?**

# %%
(
    preprocess_penguins_df
    .isnull()
    .sum()
    .sum()
)
# Out:
# 19

# %% [markdown]
# **¿Cuál es la proporción de valores nulos pro cada variable?**

# %%
(
    preprocess_penguins_df
    .isnull()
    .melt()
    .pipe(
        lambda df: (
            sns.displot(
                data=df,
                y='variable',
                hue='value',
                multiple='fill',
                aspect=3
            )
        )
    )
)
# Out:
# /home/puma/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **¿Cómo podemos visualizar los valores nulos en todo el conjunto de datos?**

# %%
(
    preprocess_penguins_df
    .isnull()
    .transpose()
    .pipe(
        lambda df: (
            sns.heatmap(
                data=df,
            )
        )

    )
)
# Out:
# <Axes: >

# %% [markdown]
# En este caso podemos eliminar los valores nulos, ya que no representan para este práctico una gran cantidad de datos por lo que puede no afectarnos, en otro tipo de análisis será importante evaluar si eliminar o no eliminar, ya que puede afectarnos.

# %% [markdown]
# **¿Cuantas observaciones perdemos si eliminamos los datos faltantes?**

# %% [markdown]
# Veremos a comparación de antes que tendremos menos filas, por lo que guardaremos el nuevo dataset que ya se eliminaron sus datos nulos

# %%
(
    preprocess_penguins_df.shape,
    preprocess_penguins_df.dropna().shape
)
# Out:
# ((344, 7), (333, 7))

# %%
penguins_df = (
    preprocess_penguins_df
    .dropna()
)

penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# ## **Tema 2: Análisis univariado**

# %% [markdown]
# ### **Explorando una variable categórica: conteos y proporciones**

# %% [markdown]
# **Tabulación**
#
# Contabiliza la frecuencia de aparición de cada valor único de una variable.
#
# En el caso de nuestras especies tenemos 3 especies únicas, los Adelie, Gentoo y Chinstrap, de esta.
#
# **Proporciones**
#
# Relación de correspondencia entre las partes y el todo.
#
# Como ya mencionamos, tenemos 333 pingüinos de los datos ya procesados, donde se dividen en 3 especies, los Adelie que son 146, Gentoo 119 y los Chinstrap 68, lo cual corresponden a una proporción de $\frac{146}{33}$, $\frac{119}{333}$, $\frac{68}{333}$
#
# Ahora pasemos a la práctica

# %% [markdown]
# ### **Preludio: ¿Que estadísticos describen el conjunto de datos?**

# %% [markdown]
# **Todas las variables**

# %%
penguins_df.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      333     333      333.000000     333.000000         333.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       146     163             NaN            NaN                NaN
# mean       NaN     NaN       43.992793      17.164865         200.966967
# std        NaN     NaN        5.468668       1.969235          14.015765
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.500000      15.600000         190.000000
# 50%        NaN     NaN       44.500000      17.300000         197.000000
# 75%        NaN     NaN       48.600000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex
# count    333.000000   333
# unique          NaN     2
# ...

# %% [markdown]
# **Solo las numéricas**

# %%
penguins_df.describe(include=np.number)
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# **Solo categorías: Tipos de datos object**

# %%
penguins_df.describe(include=object)
# Out:
#        species  island   sex
# count      333     333   333
# unique       3       3     2
# top     Adelie  Biscoe  Male
# freq       146     163   168

# %% [markdown]
# **Solo categorías: Configurar tipo de dato category**

# %%
(
    penguins_df
    .astype(
        {
        'species': 'category',
        'island': 'category',
        'sex': 'category'
        }
    )
    .dtypes
)
# Out:
# species              category
# island               category
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                  category
# dtype: object

# %%
penguins_df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %% [markdown]
# ### **Visualizar los conteos**

# %% [markdown]
# **Pandas**

# %%
(
    penguins_df
    .species
    .value_counts()
    .plot(
        kind='bar'
    )
)
# Out:
# <Axes: xlabel='species'>

# %% [markdown]
# **Seaborn**

# %%
sns.catplot(
    data=penguins_df,
    x='species',
    kind='count',
    palette=penguin_color,
    )
# Out:
# /home/puma/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
(
    penguins_df
    .value_counts('species',sort=True)
    .reset_index(name='count')
    .pipe(
        lambda df: (
            sns.barplot( 
                data=df,
                x='species',
                y='count',
                palette=penguin_color,
                alpha=0.5
            )
        )
    )
)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# **Como visualizar las proporciones**

# %%
(
    penguins_df
    .add_column('x','')
    .pipe(
        lambda df: (
            sns.displot(
                data=df,
                x='x',
                hue='species',
                multiple='fill',
                palette=penguin_color,
                stat='percent',
                alpha=0.5
            )
        )
    )
)
# Out:
# /home/puma/anaconda3/lib/python3.9/site-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `pd.DataFrame.assign` instead.
#   return method(self._obj, *args, **kwargs)
# /home/puma/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### **Estadística descriptiva aplicada: medidas de tendencia central**

# %% [markdown]
# **Medidas de tendencia central**

# %% [markdown]
# * Media aritmética (promedio)
#
# * Media ponderada
#
# * Media geométrica
#
# * Media armónica
#
# * Mediana (dato central)
#
# * Moda (dato que más se repite)

# %% [markdown]
# **Media o promedio**

# %%
penguins_df.bill_depth_mm.mean()
# Out:
# 17.164864864864864

# %% [markdown]
# **Mediana**

# %%
penguins_df.median(numeric_only=True)
# Out:
# bill_length_mm         44.5
# bill_depth_mm          17.3
# flipper_length_mm     197.0
# body_mass_g          4050.0
# dtype: float64

# %% [markdown]
# **Moda**

# %%
penguins_df.mode()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Biscoe            41.1           17.0              190.0
#
#    body_mass_g   sex
# 0       3800.0  Male

# %%
penguins_df.describe(include=object)
# Out:
#        species  island   sex
# count      333     333   333
# unique       3       3     2
# top     Adelie  Biscoe  Male
# freq       146     163   168

# %% [markdown]
# ### **Estadística descriptiva aplicada: medidas de dispersión**

# %% [markdown]
# **Medidas de dispersión**

# %% [markdown]
# * **Rango**
#
# La diferencia entre el valor máximo y el valor mínimo de los datos.
#
# * **Rango intercuartílico**
#
# Comprenden ± 25% de los datos respecto a la mediana.
#
# * **Desviación estándar**
#
# Ofrece la dispersión media de una variable.

# %% [markdown]
# ![cuartil](../img/cuartil.png "cuartil")

# %% [markdown]
# **Asimetría estadística**

# %% [markdown]
# ![Asimetria](../img/asimetria.png "Asimetria")

# %% [markdown]
# * Asimetría positiva, distribución con mayor dispersión a la derecha de la media.
#
# * Asimetría negativa, distribución con mayor dispersión a la izquierda de la media.

# %% [markdown]
# **Rango**

# %%
max=penguins_df.max(numeric_only=True)
min=penguins_df.min(numeric_only=True)

'RANGE',np.subtract(max,min)
# Out:
# ('RANGE',
#  bill_length_mm         27.5
#  bill_depth_mm           8.4
#  flipper_length_mm      59.0
#  body_mass_g          3600.0
#  dtype: float64)

# %% [markdown]
# **Curtosis**

# %% [markdown]
# * Meoscurtica el índice vale 0
# * Leptocurtica el índice es mayor que 0
# * Platocurtica el índice es menor que 0

# %% [markdown]
# ![Curtosis](../img/curtosis.png "Curtosis")

# %% [markdown]
# Una curtosis mayor a 0 indica que la mayoría de los datos están muy concentrados alrededor de la media, lo cual indica que hay poca variabilidad en los datos, es decir, el rango es pequeño
#
# Una curtosis negativa indica lo contrario, los datos están alejados de la media, lo cual indica mucha variabilidad en los datos, su rango es amplio.

# %% [markdown]
# ### **Ejercicio de obtención de medidas de dispersión**

# %% [markdown]
# **Medidas de dispersión**

# %% [markdown]
# **¿Cuál es el valor máximo de las variables?**

# %%
penguins_df.max(numeric_only=True)
# Out:
# bill_length_mm         59.6
# bill_depth_mm          21.5
# flipper_length_mm     231.0
# body_mass_g          6300.0
# dtype: float64

# %% [markdown]
# **¿Cuál es el valor mínimo de las variables?**

# %%
penguins_df.min(numeric_only=True)
# Out:
# bill_length_mm         32.1
# bill_depth_mm          13.1
# flipper_length_mm     172.0
# body_mass_g          2700.0
# dtype: float64

# %% [markdown]
# **¿Cuál es el rango de las variables?**

# %%
np.subtract(penguins_df.max(numeric_only=True), penguins_df.min(numeric_only=True))
# Out:
# bill_length_mm         27.5
# bill_depth_mm           8.4
# flipper_length_mm      59.0
# body_mass_g          3600.0
# dtype: float64

# %% [markdown]
# **¿Cuál es la desviación estándar de las variables?**

# %%
penguins_df.std(numeric_only=True)
# Out:
# bill_length_mm         5.468668
# bill_depth_mm          1.969235
# flipper_length_mm     14.015765
# body_mass_g          805.215802
# dtype: float64

# %% [markdown]
# ![Distribucion Normal](../img/distribucion_normal.png "Distribucion Normal")

# %%
print(f'''
mean + std
{penguins_df.mean(numeric_only=True) + penguins_df.std(numeric_only=True)}

mean - std
{penguins_df.mean(numeric_only=True) - penguins_df.std(numeric_only=True)}
''')
# Out:
# mean + std
# bill_length_mm         49.461461
# bill_depth_mm          19.134100
# flipper_length_mm     214.982732
# body_mass_g          5012.272859
# dtype: float64
#
# mean - std
# bill_length_mm         38.524124
# bill_depth_mm          15.195629
# flipper_length_mm     186.951202
# body_mass_g          3401.841255
# dtype: float64

# %% [markdown]
# **¿Cuál es el rango intercuartílico de las variables?**

# %%
import pandas as pd
from io import StringIO

# Ruta al archivo CSV (ajusta la ruta y nombre de archivo según sea necesario)
archivo_csv = '../data/datos_procesado.csv'

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(archivo_csv)

# Seleccionar columnas numéricas relevantes
columnas_numericas = ['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)']

# Calcular el IQR para cada columna numérica
iqr_values = df[columnas_numericas].quantile(0.75) - df[columnas_numericas].quantile(0.25)

# Mostrar el IQR para cada columna
print("Rango intercuartílico (IQR) para cada variable:")
print(iqr_values)
# Out:
# Rango intercuartílico (IQR) para cada variable:
# Culmen Length (mm)        9.275000
# Culmen Depth (mm)         3.100000
# Flipper Length (mm)      23.000000
# Body Mass (g)          1200.000000
# Delta 15 N (o/oo)         0.872232
# Delta 13 C (o/oo)         1.258255
# dtype: float64

# %% [markdown]
# **¿Cómo puedo visualizar la distribución de una variable?**

# %% [markdown]
# **Histograma**

# %%
plt.figure(figsize=(8,4))
sns.histplot(
    data=penguins_df,
    x='flipper_length_mm',
)
plt.axvline(
    x=penguins_df.flipper_length_mm.mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)

# %% [markdown]
# En este caso, la distribución pareciera bimodal, pero se debe a que las 3 especies tienen distribuciones distintas, sin embargo, cada especie pareciera tener una distribución normal.

# %%
species = penguins_df.species.unique()

adelie_df = penguins_df.query("species == 'Adelie'")
gentoo_df = penguins_df.query("species == 'Gentoo'")
chinstrap_df = penguins_df.query("species == 'Chinstrap'")

specie = [adelie_df,gentoo_df,chinstrap_df]

# %%
plt.figure(figsize=(8,4))
sns.histplot(
    data=penguins_df,
    x='flipper_length_mm',
    hue='species',
    bins=20
)

for i in specie:
    plt.axvline(
        x=i.flipper_length_mm.mean(),
        color='red',
        linestyle='dashed',
        linewidth=2
    )

# %% [markdown]
# **Diagrama de caja / boxplot**

# %%
plt.figure(figsize=(8,4))
sns.boxplot (
    data=penguins_df,
    x='flipper_length_mm',
    y='species'
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='species'>

# %% [markdown]
# Determinación el tamaño de binwidth del histograma mediante la regla de Freedman-Diaconis
#
# $2\frac{IQR(x)}{\sqrt{n}}$

# %%
def freedman_diaconis_bindwith(x: pd.Series) -> float:
    """Find optimal bindwith using Freedman-Diaconis rule."""

    IQR = x.quantile(.075) - x.quantile(0.25)
    N = x.size

    return np.abs(2 * IQR / N * 1/3)
freedman_diaconis_bindwith(penguins_df.bill_length_mm)
# Out:
# 0.006646646646646648

# %%
sns.histplot(
    data=penguins_df,
    x='flipper_length_mm',
    hue='species',
    multiple='layer',
    # binwidth=freedman_diaconis_bindwith(penguins_df.bill_length_mm)
)

for i in specie:
    plt.axvline(
        x=i.flipper_length_mm.mean(),
        color='red',
        linestyle='dashed',
        linewidth=2
    )

# %% [markdown]
# **Estadística descriptiva aplicada: distribuciones**

# %% [markdown]
# Nos enfocaremos en las probabilidades de encontrar un determinado valor.

# %% [markdown]
# **¿Como visualizar una distribución?**

# %% [markdown]
# Ya conociendo los histogramas, que básicamente definimos que tomara nuestra variable, realizar intervalos y contar las frecuencias de ocurrencias de estos valores dentro de nuestros intervalos. Pero ahora nos surge la siguiente preguntas:
#
# * ¿Cuál es la probabilidad de encontrar un número?
# * ¿Cuál es la probabilidad de encontrar un número igual o menor a otro número?
# * ¿Cuál es la probabilidad de encontrar un número entre el intervalo $A$ y $B$?
# Estas preguntas evocan a las funciones de probabilidad:
#
# * Función de Probabilidad de masas (PMF, Probability Mass Function)
# * Función de Distribución Acumulada (CDF, Cumulative Distribution Function)
# * Función de Probabilidad de Densidad (PDF, Probability Density Function)

# %% [markdown]
# **Función de Probabilidad de masas (PMFs)**

# %% [markdown]
# Nos indica la probabilidad de que una variable aleatoria discreta tome un valor determinado.
#
# **Ejemplo:** Cuál es la probabilidad de que en un salón haya personas de 23 años.

# %% [markdown]
# **Función de Distribución Acumulada (CDFs)**

# %% [markdown]
# Devuelve la probabilidad de que una variable sea menor o igual a un valor determinado.
#
# **Ejemplo:** Cuál es la probabilidad de que en un salón haya personas de 23 o menos años.

# %% [markdown]
# **Función de Probabilidad de Densidad (PDFs)**

# %% [markdown]
# Determina la probabilidad de que una variable continua tome un valor determinado entre un intervalo de valores.
#
# **Ejemplo:** Cuál es la probabilidad de que en un salón haya una persona de 1.845 metros

# %% [markdown]
# ### **Distribuciones con Python: PMFs, CDFs y PDFs**

# %% [markdown]
# **PMF: Función de Probabilidad de masas**

# %% [markdown]
# **Utilizando Seaborn**
#
# Nos suplimos del parámetro `stat` y lo configuramos con su opción 'probability', el cual permitirá comparar de manera sencilla la probabilidad de que obtengamos un valor determinado

# %%
fig,ax = plt.subplots(ncols=4,nrows=1,figsize=(20,5))

for i in range(len(specie) + 1):
    sns.histplot(
        ax = ax[i],
        data=penguins_df if i == 0 else specie[i-1],
        x='flipper_length_mm',
        binwidth=1,
        stat='probability',
        hue='species',
        palette=penguin_color
    );

# %% [markdown]
# **Utilizando empiricaldist**

# %% [markdown]
# Con la función PMF.from_seq de dist, nos suplimos de su parámetro normalize donde si le damos el valor booleano de True nos arrojará las probabilidades de que ocurra cada valor y si lo ponemos en False nos arrojará las veces que se repite.

# %%
(
    empiricaldist.Pmf.from_seq(
    penguins_df.flipper_length_mm,
    normalize=True # cambia a su probabilidad o a frecuencia
    )
    .sort_values(ascending=False) # remueve para que no se ordenen 
    .head() # remueve para ver los resultados completos
)
# Out:
# flipper_length_mm
# 190.0    0.063063
# 195.0    0.051051
# 187.0    0.048048
# 193.0    0.042042
# 210.0    0.042042
# Name: , dtype: float64

# %%
# Guardamos el objeto empiricaldist en una variable
pmf_flipper_length_mm = empiricaldist.Pmf.from_seq(
    penguins_df.flipper_length_mm,
    normalize=True
)

# %%
# usamos el metodo .bar para graficar el PMF como lo hicimos en seaborn 
pmf_flipper_length_mm.bar()

# %%
# Usamos nuestro objeto para preguntar las probabilidades de encontrar un pinguino con una longitud de ala X
print(f'''
    180 = {(pmf_flipper_length_mm(180)*100).round(4)} %
    190 = {(pmf_flipper_length_mm(190)*100).round(4)} %
    200 = {(pmf_flipper_length_mm(200)*100).round(4)} %
    210 = {(pmf_flipper_length_mm(210)*100).round(4)} %
    230 = {(pmf_flipper_length_mm(230)*100).round(4)} %
    ''')
# Out:
#     180 = 1.2012 %
#     190 = 6.3063 %
#     200 = 1.2012 %
#     210 = 4.2042 %
#     230 = 2.1021 %

# %% [markdown]
# ### **ECDF: Función empírica de probabilidad acumulada**

# %% [markdown]
# **Utilizando Seaborn**
#
# `seaborn.ecdfplot`
#
# Realizamos el gráfico ECDF para saber cuál es la probabilidad de obtener un valor igual o menor a partir de cierto valor.

# %%
fig,ax = plt.subplots(ncols=4,nrows=1,figsize=(20,5))

for i in range(len(specie) + 1):
    sns.ecdfplot(
        ax = ax[i],
        data=penguins_df if i == 0 else specie[i-1],
        x='flipper_length_mm',
        # stat='probability',
        hue= None if i == 0 else 'species',
        palette=penguin_color
    );
# Out:
# /tmp/ipykernel_489/2950573714.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.ecdfplot(

# %% [markdown]
# Para realizarnos una pregunta en este caso observemos el resultado de la especie Adelie.
#
# Si miramos en las $X$ el valor 200, podemos preguntarnos sobre cuál es la probabilidad de que un pingüino en general (grafico 1) tenga un ala igual o menos a 200 mm de largo.
#
# Al observar el gráfico concluimos que sería aproximadamente a ojo del más o menos 58%, lo cual es la desventaja de usar Seaborn que solo nos permite hacer una estimación visual de la pregunta que buscamos responder

# %% [markdown]
# **Utilizando empiricaldist**
#
# A mismo modo que en el ejercicio anterior podemos guardar nuestro objeto de `empericaldist.cdf` en una variable para empezar a trabajar sobre nuestras preguntas

# %%
# Guardamos nuestro objeto CDF en una variable con los datos
cdf_flipper_length_mm = empiricaldist.Cdf.from_seq(
    penguins_df.flipper_length_mm,
    normalize=True
)

# %%
# Graficamos nuestro CDF con la funcion plot
cdf_flipper_length_mm.plot()

q = 200 # quantity
p = cdf_flipper_length_mm.forward(q) # probability
print('la probabilidad de tener una ala de:' ,q, 'mm es de:',p*100,'%')
# Out:
# la probabilidad de tener una ala de: 200 mm es de: 56.75675675675676 %

# %% [markdown]
# Como vimos podemos graficar y obtener respuestas precisas con la librería empiricaldist y agregando algo de código podemos conseguir algunas presentaciones más visuales

# %%
# Graficamos con empiricaldist
cdf_flipper_length_mm.plot() # Graficamos

q = 200 # quantity
p = cdf_flipper_length_mm.forward(q) # probability

plt.vlines( # Linea eje Y
    x=q,
    ymin=0,
    ymax=p,
    linestyles='dashed',color='black',linewidth=2
)
plt.hlines( # Linea eje X
    y=p,
    xmin=pmf_flipper_length_mm.qs[0], # cuantiles
    xmax=q,
    linestyles='dashed',color='black',linewidth=2
)

plt.plot(q,p,'ro') # Punto de interseccion rojo

# %% [markdown]
# De esta manera podemos añadir líneas guías que nos ayuden a visualizar estos valores, en este caso realizamos unas líneas guías para saber en donde encontrar el valor de 200 y su probabilidad, de esta forma podemos empezar a explorar distintas variables sin vernos afectados por valores extremos

# %%
# Grafica CDF con sus respectivos cuantiles
cdf_flipper_length_mm.step()

p_1 = 0.25 # specifi probability
p_2 = 0.75

ps = (0.25, 0.75) # IQR
qs = cdf_flipper_length_mm.inverse(ps) # {0.25 = 190} y {0.75 = 213}

plt.vlines(
    x=qs,
    ymin=0,
    ymax=ps,
    linestyles='--',color='black',
)

plt.hlines(
    y=ps,
    xmin=cdf_flipper_length_mm.qs[0],
    xmax=qs,
    linestyles='--',color='black',
)

plt.plot(qs,ps,'ro') # puntos de interseccion

# %% [markdown]
# La función de distribución acumulada está relacionado con el manejo de los cuartiles, ya que si marcamos la probabilidad de encontrar el 25% y 75% de nuestros datos, ya nos encontraríamos delimitando nuestro rango intercuartílico, que es lo que realizamos en la gráfica.

# %% [markdown]
# **Comparando distribuciones**

# %%
fig,ax = plt.subplots(1,4,figsize=(20,8))

p_1 = 0.25 # specifi probability
p_2 = 0.75
ps = (p_1, p_2) # IQR

for i in range(len(species)+1):
    sns.ecdfplot(
    ax = ax[i],
    data=penguins_df if i == 0 else specie[i-1],
    x='flipper_length_mm',
    hue='species',
    palette=penguin_color
    )

    qs = empiricaldist.Cdf.from_seq(penguins_df.flipper_length_mm if i ==0 else specie[i-1].flipper_length_mm,normalize=True).inverse(ps)

    if i == 0:
        pass
    else:
        ax[i].vlines(
            x=qs,
            ymin=0,
            ymax=ps,
            linestyles='--',color='black',
        )
        ax[i].hlines(
            y=ps,
            xmin=empiricaldist.Cdf.from_seq(specie[i-1].flipper_length_mm,normalize=True).qs[0],
            xmax=qs,
            linestyles='--',color='black',
        )
        ax[i].plot(qs,ps,'ro') # puntos de interseccion

# %% [markdown]
# **PDF: Funciones de Densidad de Probabilidad**

# %% [markdown]
# Nos ayudan a estimar la probabilidad para valores que no contiene el dataset, formando una distribución continua. También son útiles para ver la forma de la distribución a detalle y hacer comparaciones con la distribución teórica.
#
# **Utilizando Seaborn**

# %%
# Grafica de la Densidad de probabilidad.
sns.kdeplot(
    data=penguins_df,
    x='flipper_length_mm',
    bw_method=0.1,
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
# Obtenemos los estadisticos de la variable

stats = penguins_df.body_mass_g.describe()
stats
# Out:
# count     333.000000
# mean     4207.057057
# std       805.215802
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4775.000000
# max      6300.000000
# Name: body_mass_g, dtype: float64

# %%
# generamos los valores aleatorios a partir de los estadisticos de los datos para tener la distribucion teorica utilizando el ECDFs

xs = np.linspace(stats['min'],stats['max']) # array de valores aleatorios
ys = scipy.stats.norm(stats['mean'], stats['std']).cdf(xs) #valores de probabilidad para cada valor

# grafica de la distribucion de datos aleatorios
plt.plot(xs,ys, color='black',linestyle='--')

# %% [markdown]
# De esta forma logramos graficar nuestra función de distribución acumulada teórica, pero sabemos que nuestros datos reales probablemente no sigan una distribución normal, pero para no andar con base en suposiciones debemos comparar nuestra distribución teórica de datos simulados con nuestra distribución empírica de datos reales.

# %%
xs = np.linspace(stats['min'],stats['max'])
ys = scipy.stats.norm(stats['mean'], stats['std']).cdf(xs)

plt.plot(xs,ys, color='black',linestyle='--')

# grafica de la distribucion de los datos reales
empiricaldist.Cdf.from_seq(
    penguins_df.body_mass_g,
    normalize=True
).plot()
# Out:
# <Axes: xlabel='body_mass_g'>

# %% [markdown]
# Ahora tenemos nuestra función de cuanto pesa un pingüino comparado de como seria si aleatoriamente nuestros datos tuvieran un comportamiento de distribución normal.
#
# Como podemos ver, hay zonas del gráfico en que la distribución teórica se parece a los datos reales de los pingüinos, pero en otras que no, por ejemplo nuestra distribución normal teórica se encuentra por debajo de los datos reales, siendo que la línea azul está por encima de la línea negra y en otras ocurre lo opuesto
#
# De este modo vemos que los datos no se comportan de una manera normal, ya que es un caso de uso para las funciones acumuladas de probabilidad, pero a mismo modo también estamos interesados en las funciones de densidad de probabilidad.

# %% [markdown]
# **Comparando la distribución de los datos con la teórica utilizando PDFs**

# %%
# generar valores aleatorios a partir de los estadisticos de los datos usando PDF

xs = np.linspace(stats['min'],stats['max'])  # array de valores aleatorios
ys = scipy.stats.norm(stats['mean'], stats['std']).pdf(xs) # valores de probabilidad para cada valor

plt.plot(xs,ys, color='black',linestyle='--') # grafica de la distribucion de datos aleatorios

# Grafico PDF con valores reales
sns.kdeplot(
    data = penguins_df,
    x='body_mass_g',
)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# Ahora tenemos otra forma donde podemos interpretar nuestros datos, teniendo nuestra distribución teórica siendo representada por las líneas negras y los datos recolectados por las líneas azules.
#
# Podemos diferenciar como nuestra distribución se encuentra positivamente sesgada a la izquierda, dándonos la idea de que nuestros datos no siguen una distribución normal.
#
# Esto es importante, ya que en el mundo de los datos muchos de los estadísticos, pruebas, o análisis asumirán muchas cosas y donde una esas cosas es que tus datos seguirán una distribución normal, tanto los datos como los residuos al ajustar un modelo.

# %% [markdown]
# **Bonus: Ley de los Grandes Números y Teorema del Límite Central**

# %% [markdown]
# **¿Qué es la Ley de los Grandes Números?**
#
# La probabilidad experimental tiende a la probabilidad teórica a medida que aumenta el número de repeticiones del experimento.
#
# Es muy útil cuando no se conoce la probabilidad teórica de un evento y tenemos la capacidad de aumentar la muestra. Mediante este teorema, al incrementar la muestra, la probabilidad experimental al final se convertirá en la probabilidad teórica.
#
# **Ejemplo:**
#
# Imaginemos que tenemos un dado de 6 caras que se encuentra en perfecto equilibrio, o sea, que la probabilidad de que caiga cada cara es exactamente 1/6.
#
# Si tiramos el dado 10 veces, el dado cayó más veces de alguna cara que sus otras caras, pero si el experimento lo repetimos a un número lo suficiente grande para que las probabilidades se emparejen, tendremos una distribución casi exacta de 1/6 por cara
#
# **Teorema del límite central**
#
# La media de las muestras tiende aproximadamente a una distribución normal
#
# La suma de $n$ variables aleatorias independientes con medias y varianzas finitas converge en distribución a una variable aleatoria normal

# %% [markdown]
# ### **Ley de los Grandes Números en Python**

# %% [markdown]
# Tomamos como ejemplo el lanzamiento de un dado de 6 caras con todas sus probabilidades iguales

# %%
# Creamos un dado de 6 caras con la libreria empiricaldist
dice = empiricaldist.Pmf.from_seq([1,2,3,4,5,6]) 
dice.bar()

# %% [markdown]
# Valores de probabilidad para cada cara del dado en diferentes tamaños de muestras

# %%
# Arrojamos el dado 100, 1000 y 10000 para el experimento
for sample_size in (100, 1000, 10000):
    sample_size = int(sample_size)
    values = dice.sample(sample_size)

    sample_pmf = empiricaldist.Pmf.from_seq(values)

    plt.figure(figsize=(5,5))
    sample_pmf.bar()

    plt.axhline(y=1/6, color='r',linestyle='--')
    plt.title(f'sample size: {sample_size}')

# %% [markdown]
# **Teorema del Límite Central en Python**

# %% [markdown]
# Analizamos una variable binaria

# %%
# Distribucion binomial del sexo de los pinguinos
plt.figure(figsize=(5,5))
(penguins_df.sex.value_counts(normalize=True),
penguins_df.sex.value_counts(normalize=True).plot(kind='bar'))
# Out:
# (sex
#  Male      0.504505
#  Female    0.495495
#  Name: proportion, dtype: float64,
#  <Axes: xlabel='sex'>)

# %% [markdown]
# La variable sex sigue una distribución binomial. Como es categórica, debemos convertirla en una variable numérica

# %%
sex_numeric = penguins_df.sex.replace(['male','female'], [1,0])

# %% [markdown]
# Fijamos el número de muestras a tomar y el tamaño de cada muestra, luego calculamos la media de los machos de cada muestra y a todas ellas le sacamos la media observando así que se aproxima a la proporción de machos dada por los datos

# %%
import pandas as pd
import numpy as np

# Supongamos que sex_numeric es una lista con "Male" y "Female"
sex_numeric = ["Male", "Female"] * 20  # Ejemplo de datos

number_sample = 1000  # Cantidad de muestras a tomar
sample_size = 35  # Tamaño de la muestra

sample_proportions = []  # Lista para almacenar las proporciones de "Male" en cada muestra

for i in range(number_sample):
    # Tomar una muestra aleatoria de 'sex_numeric'
    sex_numeric_sample = np.random.choice(sex_numeric, sample_size)
    # Calcular la proporción de "Male" en la muestra
    male_proportion = np.mean(sex_numeric_sample == "Male")
    # Agregar la proporción al lista
    sample_proportions.append(male_proportion)

# Calcular la media de las proporciones
male_population_mean = np.mean(sample_proportions)
print(f'Estimated percentage of male penguins in population is: {male_population_mean * 100:.2f}%')
# Out:
# Estimated percentage of male penguins in population is: 49.71%

# %% [markdown]
# La distribución binomial se convierte en este caso en una distribución Normal, como se evidencia en la gráfica que sigue

# %%
import seaborn as sns
import scipy.stats
import matplotlib.pyplot as plt

# Calcula la proporción de 'Male' en cada muestra
sample_proportions = sample_df.apply(lambda col: (col == 'Male').mean())

# Convierte las proporciones en un DataFrame
sample_means_binomial = pd.DataFrame(sample_proportions, columns=['sample_mean'])

# Distribución Teórica
stats = sample_means_binomial.describe()
xs = np.linspace(stats.loc['min'], stats.loc['max'], 100)
ys = scipy.stats.norm(stats.loc['mean'], stats.loc['std']).pdf(xs)
plt.plot(xs, ys, color='black', linestyle='--', label='Distribución Teórica')

# Distribución Empírica
sns.kdeplot(data=sample_means_binomial['sample_mean'], label='Distribución Empírica')

# Promedio
plt.axvline(x=sample_proportions.mean(), color='red', linestyle='--', label='Promedio de Proporciones')

plt.xlabel('Proporción de Male')
plt.ylabel('Densidad')
plt.legend()
plt.show()

# %% [markdown]
# Otra manera de verlo es ir incrementando la cantidad de muestras y observar el efecto en la proporción de machos, vemos como

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular el recuento de 'Male' en la población
male_count_population = sum(1 for gender in sex_numeric if gender == 'Male')

# Calcular el recuento de 'Male' en cada muestra
male_count_per_sample = sample_df.apply(lambda col: (col == 'Male').sum())

# Crear un DataFrame con el tamaño de la muestra y el recuento de 'Male'
sample_size_experiment = pd.DataFrame({
    'sample_size': range(1, number_sample + 1),
    'male_count': male_count_per_sample
})

# Gráfico del recuento de 'Male' en función del tamaño de la muestra
plt.figure(figsize=(8, 5))
sns.scatterplot(data=sample_size_experiment, x='sample_size', y='male_count')
plt.xlabel('Tamaño de la Muestra')
plt.ylabel('Recuento de Male')
plt.title('Recuento de Male en función del tamaño de la muestra')
plt.axhline(y=male_count_population, color='red', linestyle='dashed', label='Recuento de Male en la población')
plt.legend()
plt.show()

# %% [markdown]
# Conforme vayamos incrementando el tamaño de la muestra (Nuestro eje $X$) se va acercando a nuestra línea roja que representa la media estimada (Nuestro eje $Y$), por lo que pasamos de una distribución binomial a tener una distribución normal de las medias que representan la proporción de nuestros pingüinos de la población.

# %% [markdown]
# ## **Tema 3: Análisis bivariado**

# %% [markdown]
# Anteriormente, todos los análisis los realizamos en una sola variable, por ejemplo vimos el comportamiento de la variable `flipper_length`, también como se compara la distribución teórica con la empírica para la variable `body_mass` y por último la proporción del sexo de los pingüinos.
#
# Ahora aprenderemos a establecer las relaciones entre dos variables.

# %% [markdown]
# **Estableciendo relaciones: gráficos de puntos**
#
# La relación entre $X$ e $Y$ variables puede analizarse mediante un gráfico de puntos o scatterplot. Nos da una idea de la tendencia o agrupamiento de los datos y ver como una variable afecta a la otra.
#
# Algunas sugerencias para construir un scatterplot son:
#
# **Gráfica de puntos con Python:**
#
# Cuando hay muchos puntos en la gráfica no se perciben de forma correcta. Puedes mejorar la visualización modificando la transparencia de los puntos con el parámetro alpha. Un alpha de 1/30 implica que se necesitan 30 datos para que el punto sea totalmente del color negro.
#
# **Scatterplot**

# %%
sns.scatterplot(
    data=penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    alpha=1/2,
    s=100
);

# %% [markdown]
# Utilizar histogramas de dos dimensiones. Cuenta los valores que quedan dentro de un intervalo de la variable $X$ y un intervalo de la variable ‘$Y$’ y muestra la frecuencia usando una barra de colores.

# %%
sns.displot(
    data=penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    rug=True, # Analizar cada wea como asdaslkd
);
# Out:
# /home/puma/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# En vez de hacer un histograma 2D, también podemos hacer una estimación de las densidades de nuestros pingüinos, así podemos ver como nuestros datos se acumulan en 2 focos principales y en 1 con menor densidad en la zona de arriba

# %%
sns.displot(
    data=penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    rug=True, # Analizar cada wea como asdaslkd
    kind='kde'
);
# Out:
# /home/puma/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Otra cosa que podemos hacer es combinar múltiples gráficos para que nos facilite entender la distribución de las variables

# %%
sns.jointplot(
    data=penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    kind='kde',
);

# %% [markdown]
# Cambio de color de los puntos. Ayuda a visualizar las zonas donde se concentra la mayor cantidad de datos

# %%
sns.jointplot(
    data=penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    kind='kde',
    hue='species'
);

# %% [markdown]
# **Estableciendo relaciones: gráficos de violín, caja y enjambre**

# %% [markdown]
# Abran ocasiones donde los datos no sean tan representativos con los tipos de gráficos de dispersión, por ejemplo si graficáramos la edad, tendríamos zonas faltas de datos, que podrían ir del 1 a 7 años y de repente saltar a los 15 hasta los 35 años, entonces este caso fue representado tal que:
#
# **¿Que pasa si tengo una variable discreta?**

# %% [markdown]
# ![Variable Discreta](../img/variables_discreta.png "Variable Discreta")

# %% [markdown]
# Ante una variable discreta donde al hacer un gráfico de puntos se nos formarían estos patrones de línea donde nos encontraríamos con zonas faltas de información.
#
# Por lo tanto, podemos progresar con este tipo de gráficas y darles una interpretación más útil, es dándole un ruido aleatorio que nos ayude a separar los puntos y visualizarlos de una mejor manera

# %% [markdown]
# ![ruido](../img/ruido.png "ruido")

# %% [markdown]
# De esta forma podemos ver mejor la distribución de los datos, ya que todos pertenecen a una misma observación, pero al agregar el ruido podemos identificar más fácil en que parte se están acumulando los datos.
#
# Otra idea que puedes realizar es un diagrama de cajas o `boxplot`, donde estarías graficando tu variable discreta en el eje de $X$ y tu variable numérica de distribución en el eje $Y$.

# %% [markdown]
# **Gráficos de violín y boxplot con Python:**

# %% [markdown]
# Exploremos las relaciones entre variables categóricas y numéricas con un `scatterplot`:

# %%
sns.scatterplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm'
)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# Por cada especie tenemos una línea dada su variable numérica, por observar el gráfico podemos concluir que los Gentoo tienen alas más grandes que las otras dos especies, mientras los Chinstrap y los Adelie se encuentran por debajo, ya comparando los Chinstrap con los Adelie podemos ver que su distribución está un poquito más por encima que los Adelie.
#
# Visualizar los puntos es una herramienta muy útil para tener idea de que sucede en nuestros datos.
#
# Pero otra cosa que nos puede ayudar a visualizar mejor es darle color a los puntos separándolos por especies:

# %%
sns.scatterplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color
)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# Otra forma de visualizar es dándole un ruido aleatorio a los puntos, ya que nos ayudara a identificar si la cantidad de puntos que se superponen es mayor o menor por especie:

# %%
sns.stripplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color,
);

# %% [markdown]
# Con este nuevo gráfico podemos tener una mejor visualización de en donde se nos están concentrando los puntos, por ejemplo los Adelie en el eje de las $Y$ de los 190 tenemos una concentración de datos.

# %% [markdown]
# **Boxplot**

# %% [markdown]
# Otra cosa que podemos realizar es un boxplot para poder visualizar las propiedades estadísticas de nuestro conjunto de datos para cada una de nuestras variables categóricas, que en este caso sería las especies:
#
# Un diagrama de caja (o diagrama de caja y bigotes) muestra la distribución de datos cuantitativos de una manera que facilita las comparaciones entre variables o entre niveles de una variable categórica. El cuadro muestra los cuartiles del conjunto de datos, mientras que los bigotes se extienden para mostrar el resto de la distribución, excepto los puntos que se determinan como "valores atípicos" (outliners) mediante un método que es una función del rango intercuartílico.

# %%
sns.boxplot(
    data=penguins_df,
    x='flipper_length_mm',
    y='species',
    palette=penguin_color
);

# %% [markdown]
# De esta forma vemos los estadísticos generales de nuestros pingüinos y podemos detectar un `Outliner` para los Adelie.
#
# Un problema que tenemos con los `Boxplots` es que no nos deja ver como se encontraban distribuidos nuestros datos, así que para poder mejorar nuestra visualización añadiremos un `stripplot` al gráfico del `boxplot`.

# %%
# Guardamos el boxplot en una variable
ax = sns.boxplot(
    data=penguins_df,
    x='flipper_length_mm',
    y='species',
    palette=penguin_color,
);

ax = sns.stripplot(
    data=penguins_df,
    x='flipper_length_mm',
    y='species',
    color='.3'
);

# %% [markdown]
# De esta forma logramos ver nuestro boxplot y a misma vez como se distribuyen nuestros puntos, teniendo una idea de cuantos puntos están cayendo en cierta zona.
#
# **Violinplot**
#
# Un diagrama de violín juega un papel similar al de un diagrama de caja y bigotes. Muestra la distribución de datos cuantitativos a través de varios niveles de una (o más) variables categóricas, de modo que esas distribuciones puedan compararse. A diferencia de un diagrama de caja, en el que todos los componentes del diagrama corresponden a puntos de datos reales, el diagrama de violín presenta una estimación de la densidad del núcleo de la distribución subyacente.

# %%
ax = sns.violinplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    palette=penguin_color,
);

# ax = sns.stripplot(
#     data=penguins_df,
#     x='flipper_length_mm',
#     y='species',
#     color='.3'
# );

# %% [markdown]
# A misma manera que el boxplot podemos agregar un `stripplot` para el `violinplot`.

# %%
sns.violinplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    color='.8'
)
sns.stripplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    palette=penguin_color
)
# Out:
# /tmp/ipykernel_489/2473959723.py:7: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# Teniendo la idea de como se encuentran nuestros datos distribuidos y a su vez la densidad, podemos comenzar a generar conclusiones como:
#
# Si tomamos a nuestros pingüinos Adelie, tendrían una distribución normal, pero si los mezclamos con los otros dos ya no tendrían una distribución normal.
#
# **Swarmplot**
#
# Esta función es similar a la del stripplot, pero los puntos se ajustan (solo a lo largo del eje categórico) para que no se superpongan. Esto brinda una mejor representación de la distribución de valores, pero no se adapta bien a un gran número de observaciones. Este estilo de trama a veces se llama "enjambre de abejas".

# %%
sns.swarmplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    palette=penguin_color
)
# Out:
# /tmp/ipykernel_489/3962694466.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# **Estableciendo relaciones: matrices de correlación**

# %% [markdown]
# Ya vimos como establecer reacciones entre variables numéricas, pero llega el momento en que necesitamos saber si existe alguna correlación entre nuestras variables
#
# **Correlación:**
#
# Expresa hasta que unto dos variables están relacionadas entre sí. Es decir, si cambian conjuntamente.
#
# Un ejemplo puede ser tratar la longitud del ala de un pingüino con su masa corporal:

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(
    data=penguins_df,
    x='flipper_length_mm',
    y='body_mass_g',
    color='.0',
    s=20
);

# %% [markdown]
# Podemos apreciar que hay una relación directa sobre mientras más grande es el ala del pingüino, más pesa el mismo y cuando más chica es el ala del pingüino, menos pesa el mismo.
#
# Por lo tanto, podemos concluir que estas variables se encuentran relacionadas, pero la pregunta es:
#
# **¿Que tan relacionadas están?**
#
# Para cuantificar este que tan relacionadas están nos guiamos del coeficiente de correlación

# %% [markdown]
# **Coeficiente de correlación**
#
# Cuantifica la intensidad de la relación lineal entre dos variables en un análisis de correlación.

# %% [markdown]
# ![Coeficiente de correlación](../img/Coeficiente%20de%20correlación.png "Coeficiente de correlación")

# %% [markdown]
# **Correlación no implica causalidad**
#
# **Causalidad:** Cuando algo (la causa) genera otra cosa (efecto)
#
# Un ejemplo puede ser cuando en verano, cuando los días están soleados y esto causa que:
#
# * La gente es más propensa a comer helado
# * La gente es más propensa a sufrir quemaduras
#
# Que la gente coma más helado no es causa de las quemaduras

# %% [markdown]
# ![correlacion](../img/correlacion.png "correlacion")

# %% [markdown]
# Este ejemplo es funcional para la explicación, ya que no siempre podremos estimar si una variable es causante de otra variable y para determinarlo deberíamos realizar experimentos para entender si esta relación entre distintas variables es más que una correlación y también implica causalidad.

# %% [markdown]
# **Matrices de Correlación con Python:**

# %% [markdown]
# **¿Existe una correlación lineal entre alguna de nuestras variables?**

# %%
# Selecciona solo las columnas numéricas del DataFrame
numeric_columns = penguins_df.select_dtypes(include=[np.number])

# Calcula la correlación entre estas columnas
correlation_matrix = numeric_columns.corr()

# Muestra la matriz de correlación
print(correlation_matrix)
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
#
#                    body_mass_g
# bill_length_mm        0.589451
# bill_depth_mm        -0.472016
# flipper_length_mm     0.872979
# body_mass_g           1.000000

# %% [markdown]
# **¿Como puedo visualizar los coeficientes de correlación?**

# %% [markdown]
# **Heatmap**

# %%
# Selecciona solo las columnas numéricas del DataFrame
numeric_columns = penguins_df.select_dtypes(include=[np.number])

# Calcula la correlación entre estas columnas
correlation_matrix = numeric_columns.corr()

# Grafica el mapa de calor de correlación
plt.figure(figsize=(10, 8))
sns.heatmap(
    data=correlation_matrix,
    cmap=sns.diverging_palette(20, 238, as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidth=.5,
    annot=True
)
plt.show()

# %% [markdown]
# En caso de existir alguna correlación de tipo lineal, a primera vista, podemos ver que predomina la correlación positiva entre las variables.
#
# * Si vemos la variable del año podemos ver que tiene valores cercanos al 0, por lo que asumimos que esta variable no se encuentra correlacionada linealmente con las otras variables.
#
# * Si vemos la intersección de las variables `flipper_length_mm` con `body_mass_g`, podemos ver que su coeficiente de correlación es de 0.87 lo cual nos indica que existe una alta correlación positiva/
#
# De esta manera podemos ir generando información sobre qué variables y cuáles no existe una correlación, si esta es positiva o negativa.
#
# **Clustermap**
#
# Otra opción es graficar con un Clustermap, el cual nos retorna un gráfico parecido al heatmap, pero con los valores ordenados, teniendo una esquina donde se nos concentran nuestras correlaciones positivas.

# %%
# Selecciona solo las columnas numéricas del DataFrame
numeric_columns = penguins_df.select_dtypes(include=[np.number])

# Calcula la correlación entre estas columnas
correlation_matrix = numeric_columns.corr()

# Genera el clustermap de correlación
plt.figure(figsize=(10, 8))
sns.clustermap(
    data=correlation_matrix,
    cmap=sns.diverging_palette(20, 238, as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidth=.5,
    annot=True
)
plt.show()

# %% [markdown]
# **¿Como podría representar una variable categórica como numérica discreta?**

# %% [markdown]
# **1. Codificación de Etiquetas (Label Encoding):**

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Crear un DataFrame de ejemplo
data = {'Categoría': ['A', 'B', 'A', 'C', 'B', 'C']}
df = pd.DataFrame(data)

# Crear una instancia de LabelEncoder
label_encoder = LabelEncoder()

# Aplicar la codificación de etiquetas a la columna categórica
df['Categoría_encoded'] = label_encoder.fit_transform(df['Categoría'])

# Mostrar el DataFrame resultante
print("DataFrame con Codificación de Etiquetas:")
print(df)
# Out:
# DataFrame con Codificación de Etiquetas:
#   Categoría  Categoría_encoded
# 0         A                  0
# 1         B                  1
# 2         A                  0
# 3         C                  2
# 4         B                  1
# 5         C                  2

# %% [markdown]
# **Ejemplo 2: Codificación One-Hot**

# %%
# Utilizando pandas para la codificación one-hot
df_one_hot = pd.get_dummies(df, columns=['Categoría'], prefix=['Categoría'])

# Mostrar el DataFrame resultante
print("\nDataFrame con Codificación One-Hot:")
print(df_one_hot)
# Out:
# DataFrame con Codificación One-Hot:
#    Categoría_encoded  Categoría_A  Categoría_B  Categoría_C
# 0                  0         True        False        False
# 1                  1        False         True        False
# 2                  0         True        False        False
# 3                  2        False        False         True
# 4                  1        False         True        False
# 5                  2        False        False         True

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Supongamos que tienes un DataFrame 'df' con una columna 'Categoría_encoded'
# Aquí creamos un DataFrame de ejemplo con categorías codificadas
data = {'Categoría_encoded': [0, 1, 0, 2, 1, 2]}
df = pd.DataFrame(data)

# Supongamos algunos valores de correlación para demostración
# Estos valores deben estar en el rango [-1, 1]
correlation_values = np.array([[1.0, 0.3], [0.3, 1.0]])

# Crear la matriz de correlación
correlation_matrix = pd.DataFrame(correlation_values, columns=['Categoría_encoded', 'Otra Categoría'])

# Crear el clustermap solo si la matriz de correlación es válida
if not correlation_matrix.empty:
    sns.clustermap(correlation_matrix, cmap='coolwarm', linewidths=0.5, annot=True)

    # Mostrar el gráfico
    plt.show()
else:
    print("La matriz de correlación está vacía. Asegúrate de que tus datos sean válidos.")

# %% [markdown]
# **Limitantes de los coeficientes de correlación lineal**

# %% [markdown]
# Solo nos ayuda a determinar la posible existencia de una correlación lineal; sin embargo, su ausencia no significa que no exista otro tipo de correlación.
#
# Para demostrarlo de una manera gráfica, pasaremos a generar un conjunto de datos aleatorios.

# %%
from sklearn.metrics import r2_score


plt.figure(figsize=(5,5))

x = np.linspace(-100,120,100)
y = x**2
y += np.random.normal(0,1000,x.size)

plt.scatter(x=x,y=y)
plt.show()

np.corrcoef(x,y)
# Out:
# array([[1.        , 0.31932677],
#        [0.31932677, 1.        ]])

# %% [markdown]
# Para este caso podemos ver la correlación cuadrática de nuestros datos.
#
# En el caso de que aplicáramos un Coeficiente de Pearson (`np.corrcoef`) veríamos que la correlación entre variables seria de 0.07, lo cual indicaría una correlación lineal inexistente.
# Pero con este resultado no podemos afirmar que no existe una correlación entre nuestros datos, ya que en el gráfico podemos ver una correlación cuadrática.
#
# Ahora veamos lo que cuando los datos tienen un comportamiento cúbico:

# %%
plt.figure(figsize=(5,5))

x = np.linspace(-100,100,100)
y = x**3
y += np.random.normal(0,1000,x.size)

plt.scatter(x,y)
plt.show()

np.corrcoef(x,y)
# Out:
# array([[1.        , 0.91672905],
#        [0.91672905, 1.        ]])

# %% [markdown]
# Cuando la distribución tiene un comportamiento cúbico, el coeficiente detecta la correlación simulando que es una línea recta donde se compensa los valores, por lo que hace una lectura errónea del panorama.
#
# Recordando nuestra matriz de correlación, veíamos que la correlación entre el largo y ancho del pico era cercana al $0$, por lo tanto, podíamos concluir que nuestras variables no se encontraban relacionadas

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(
    data=penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
)
plt.show()
penguins_df.bill_depth_mm.corr(penguins_df.bill_length_mm)
# Out:
# -0.22862563591302906

# %% [markdown]
# A primera vista las variables aparentan tener una correlación nula, pero es porque se están calculando las tres especies de pingüinos como si fueran una misma, Si lo separamos por especie podremos visualizar mejor su correlación:

# %%
sns.scatterplot(
    data=penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    hue='species',
    palette=penguin_color,
)
plt.show()
penguins_df.groupby('species').bill_depth_mm.corr(penguins_df.bill_length_mm)
# Out:
# species
# Adelie       0.385813
# Chinstrap    0.653536
# Gentoo       0.654023
# Name: bill_depth_mm, dtype: float64

# %% [markdown]
# De esta forma podemos observar mejor la correlación que existe entre el largo y ancho del pico de los pingüinos separados por cada especie
#
# Hay que tener cuidado con casos como estos, porque no analizar bien nuestra matriz de correlación puede generar este tipo de limitantes, donde no vemos el panorama de los datos

# %% [markdown]
# **El coeficiente de correlación no nos habla del impacto de la relación**

# %% [markdown]
# Con impacto nos referimos al hecho de que podemos tener un coeficiente de correlación que es más alto que otro, pero esto no necesariamente nos indica que este coeficiente sea mejor para predecir que otro coeficiente con menor valor.
#
# **Ejemplo:**

# %%
np.random.seed(42)
x_1= np.linspace(0,100,100)
y_1= 0.1 * x_1 + 3 + np.random.uniform(-2,2, size=x_1.size)

sns.scatterplot(
    x=x_1,
    y=y_1
)

x_2= np.linspace(0,100,100)
y_2= 0.5 * x_2 + 1 + np.random.uniform(0,60, size=x_2.size)

sns.scatterplot(
    x=x_2,
    y=y_2
)

plt.legend(labels=['1','2'])

print(np.corrcoef(x_1,y_1))
print(np.corrcoef(x_2,y_2))
# Out:
# [[1.         0.92761617]
#  [0.92761617 1.        ]]
# [[1.         0.67476343]
#  [0.67476343 1.        ]]

# %% [markdown]
# Como vemos, tenemos dos series, los azules ($x_1$) y los naranjas ($x_2$), y vemos que el coeficiente de correlación de $x_1$ es de 0.92 lo cual nos indica una correlación casi perfecta, pero en nuestra $x_2$ vemos que su coeficiente de correlación es menor 0.67.
#
# En este caso, si solo hubiéramos visto el coeficiente de correlación de $x_1$ por ser más alto, nos hubiéramos perdido de la serie $x_2$, que tiene un mayor impacto (la pendiente o inclinación de $Y$)
#
# Imagina el caso en que la $X$ es algo que represente algún esfuerzo y la $Y$ es lo que te represente el dinero generado por el esfuerzo.
#
# Efectivamente, en la serie 1 tenemos una correlación alta, que se encuentra bien definida su trayectoria, pero a cambio su impacto es bajo, por lo tanto, crece poco en referencia a la serie 2.
#
# Pero analizando a la serie 2, vemos que la correlación es menos marcada que la serie 1, pero el impacto que genera este en el eje Y es mucho mayor que el de la serie 1, representando una cantidad mayor de dinero.
#
# Este tipo de ejemplo es muy útil para entender por qué visualizar el impacto de la relación, ya que:
#
# Un coeficiente de correlación por sí mismo, no nos mostrara del impacto que ocurre entre las variables

# %% [markdown]
# **Estableciendo relaciones: análisis de regresión simple**

# %% [markdown]
# Hemos aprendido sobre las matrices de correlación y coeficientes de correlación lineal como el de Pearson, pero llegado cierto momento nos encontramos con las limitantes de los mismos, como tal un coeficiente de correlación líneas no nos indican el impacto de la relación entre las variables, por lo tanto:

# %% [markdown]
# **¿Como calcular la fuerza del efecto?**

# %% [markdown]
# Mediante un análisis de regresión simple, podemos medir la fuerza del efecto en los datos mediante el ajuste de una línea recta, mediante la cual podremos calcular nuestro slope que nos indicara la inclinación nuestra pendiente.
#
# Es mucho más efectivo para interpretar el comportamiento de los datos.

# %%
sns.lmplot(
    data=penguins_df,
    x='bill_depth_mm',
    y='bill_length_mm',
    hue='species',
    palette=penguin_color,
    aspect=1.5
)
# Out:
# /home/puma/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Limitaciones del análisis de regresión simple**

# %% [markdown]
# A misma manera que vimos con las matrices de correlaciones, la regresión simple posee ventajas y desventajas, entenderlas nos ayudaran a saber cuando usarlas en el momento correcto.
#
# **Limitaciones:**
#
# * La regresión lineal simple de $A − B$ no es lo mismo que la de $B − A$
# * Si dos variables crecen o decrecen siguiendo las mismas pautas, no implica necesariamente que una cause la otra
# * Solo puede manejar relaciones lineales.
#
# Pongamos en práctica estas limitantes con Python

# %% [markdown]
# **La regresión lineal simple no es simétrica**

# %%
# Definimos nuestras variables de interes
x = penguins_df.bill_length_mm
y = penguins_df.bill_depth_mm

# %%
# Ajustemos un modelo de regresion lineal para cada variable

# X contra Y
res_x_y = scipy.stats.linregress(x=x,y=y)

# Y contra X
res_y_x = scipy.stats.linregress(x=y, y=x)

# %%
print(f'''
{res_x_y}

{res_y_x}''')
# Out:
# LinregressResult(slope=-0.08232675339862275, intercept=20.786648668433823, rvalue=-0.22862563591302903, pvalue=2.5282897209443286e-05, stderr=0.01926834673577886, intercept_stderr=0.8541730787409801)
#
# LinregressResult(slope=-0.6349051704195022, intercept=54.89085424504754, rvalue=-0.22862563591302903, pvalue=2.5282897209443286e-05, stderr=0.14859778216623312, intercept_stderr=2.567341513538256)

# %% [markdown]
# Visualización de la Asimetría de la Regresión Lineal

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
sns.scatterplot(
    ax=ax[0],
    x=y,
    y=x
)

fx_2 = np.array([y.min(),y.max()])
fy_2 = res_y_x.intercept + res_y_x.slope * fx_2

ax[0].plot(fx_2,fy_2)
sns.scatterplot(
    ax=ax[1],
    x=x,
    y=y,
)

fx_1 = np.array([x.min(), x.max()])
fy_1 = res_x_y.intercept + res_x_y.slope * fx_1

ax[1].plot(fx_1, fy_1)

# %% [markdown]
# A pesar de que los gráficos parecen similares, no lo son, ya que uno es el transpuesto del otro y esto cambia la forma que interpretamos la pendiente o `Slope` entre las variables.

# %%
# Grafico de ambos slopes
sns.scatterplot(
    x=x,
    y=y
)

plt.plot(fx_1, fy_1)
plt.plot(fy_2, fx_2)
plt.legend({f'x:{x.name}',f'x:{y.name}'})

# %% [markdown]
# **La regresión no nos dice nada sobre la causalidad, pero existen herramientas para separar las relaciones entre múltiples variables**

# %% [markdown]
# Ahora que sabemos que una limitante de las regresiones lineales simples, veremos el concepto en Python con la librería statsmodels para separar sus relaciones
#
# * statsmodels.formula.api.ols
# * Fitting models using R-style formulas

# %%
(
    smf.ols(
         formula='bill_length_mm ~ bill_depth_mm',
        data=penguins_df
    )
    .fit()
    .params
)
# Out:
# Intercept        54.890854
# bill_depth_mm    -0.634905
# dtype: float64

# %%
(
    smf.ols(
        formula='bill_depth_mm ~ bill_length_mm',
        data=penguins_df
    )
    .fit()
    .params
)
# Out:
# Intercept         20.786649
# bill_length_mm    -0.082327
# dtype: float64

# %% [markdown]
# De esta forma logramos ver él intercepto o el punto de corte del eje $Y$ y como por cada unidad que se mueva en el eje $X$ se modificaria el `slope`.
#
# En el ejemplo vemos que cuando tenemos a `bill_length_mm` en el eje $X$ y a `bill_depth_mm` en el eje $Y$, el punto de corte del eje $Y$ se daria en el punto 54.89 y el `slope` o pendiente seria de -0.634.
#
# Y cuando transponemos las variables el punto de corte se da en el punto 20.78 y el slope o pendiente es de -0.082
#
# En la fórmula podríamos agregar distintas variables para explicar el fenómeno de nuestro interés, pero esto involucraría trabajar con más de dos variables, que es lo que veremos con el análisis de regresión múltiple

# %% [markdown]
# **Análisis de regresión múltiple**

# %% [markdown]
# Ya vimos las ventajas, desventajas de usar una regresión lineal simple, pero ya ha llegado el momento de que implementemos más de dos variables a la vez, ya sea porque:
#
# * Buscamos encontrar la relación entre dos o más variables
# * Creemos que la interacción de múltiple variables pueden afectar a nuestra variable objetivo
#
# Para poder explorar y determinar estos intereses, un ejemplo es el análisis de regresión múltiple.
#
# Anteriormente, vimos que una de las limitaciones del análisis de regresión simple era que es un modelo para regresiones lineales, donde no podíamos incorporar comportamientos no lineales.
# Pero con el análisis de regresión múltiple si podemos analizar distintos comportamientos.
#
# Otra de las limitaciones que vimos de la regresión simple era que no necesariamente nos indicaba la relación entre la causa y efecto de las variables.
# Pero el análisis de regresión múltiple al dejarnos incorporar distintas variables nos permitirá explicar si la relación entre nuestras variables realmente está afectando o no el comportamiento de nuestra variable objetivo

# %% [markdown]
# **Análisis de regresión múltiple en Python:**

# %% [markdown]
# Para realizar este ejercicio, imaginaremos un escenario hipotético, donde somos científicos y nos encontrábamos en la Antártida haciendo mediciones sobre los pingüinos, donde mediamos la longitud y grosor de sus alas, sus picos, si son machos o hembras y su peso. Pero resulta que te olvidaste tu balanza donde pesabas a los pingüinos, entonces tomaste todas las otras medidas, pero te falto registrar cuanto pesaba cada pingüino, por lo tanto, se te planteo este problema:
#
# Olvidaste tu báscula para pesar a los pingüinos.¿Cuál sería la mejor forma de capturar ese dato?
#
# ¿Te preguntaste si existía alguna manera de poder asociar las medidas que tenías y lograr inferir cuanto pesaba cada pingüino?
#
# Por lo tanto, para resolver este problema usaremos los modelos de regresión múltiple

# %% [markdown]
# **Creando modelos**

# %%
import pandas as pd
import numpy as np

# Supongamos que tienes un DataFrame llamado penguins_df con varias columnas, incluyendo algunas no numéricas
# Vamos a crear un DataFrame de ejemplo para demostración

# Crear un DataFrame de ejemplo
data = {
    'height': [172, 165, 180, 168, 175],
    'weight': [70, 62, 78, 65, 72],
    'species': ['Adelie', 'Gentoo', 'Chinstrap', 'Adelie', 'Gentoo']
}

penguins_df = pd.DataFrame(data)

# Asegúrate de que solo estamos considerando columnas numéricas
numeric_penguins_df = penguins_df[['height', 'weight']]

# Calcula la matriz de correlación
correlation_matrix = numeric_penguins_df.corr()

# Muestra la matriz de correlación
print("Matriz de correlación:")
print(correlation_matrix)
# Out:
# Matriz de correlación:
#           height    weight
# height  1.000000  0.997625
# weight  0.997625  1.000000

# %% [markdown]
# | **Inicio** | **atrás 21** |
# |----------- |-------------- |
# | [🏠](../../README.md) | [⏪](./21_Funciones_Matematicas_para_Ciencia_de_Datos.ipynb)|
