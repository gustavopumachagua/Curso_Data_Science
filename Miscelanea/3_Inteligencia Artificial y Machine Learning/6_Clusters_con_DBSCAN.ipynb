# %% [markdown]
# | **Inicio** | **atrás 5** | **Siguiente 7** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./5_Random_Forest.ipynb)| [⏩](./7_Modelos_de_Machine_Learning.ipynb)|

# %% [markdown]
# # **6. Identifica Clusters con DBSCAN: Algoritmo paso a paso e implementación con Python**

# %% [markdown]
# ## **Introducción**

# %% [markdown]
# Clustering significa agrupar un conjunto de puntos de datos en grupos o "clusters" basados en ciertas similitudes. DBSCAN (Density-Based Spatial Clustering of Applications with Noise) es un algoritmo de clustering que se basa en la densidad de los puntos en el espacio para identificar clusters de formas arbitrarias. A continuación, te proporcionaré una explicación paso a paso del algoritmo DBSCAN junto con un ejemplo de implementación en Python y sus respectivas gráficas.
#
# **Pasos del Algoritmo DBSCAN:**
#
# 1. **Parámetros**: DBSCAN requiere dos parámetros principales: el radio de vecindad (ε o "eps") y el número mínimo de puntos dentro de un radio ε para considerar un punto central ("min_samples").
#
# 2. **Definir Vecindad**: Para cada punto del conjunto de datos, se determinan los puntos que están dentro del radio ε alrededor de él. Si el número de puntos en la vecindad es mayor o igual a "min_samples", el punto se considera un punto central.
#
# 3. **Expandir Clusters**: Se expanden los clusters a partir de los puntos centrales. Esto significa que si un punto central puede alcanzar otro punto (dentro de su vecindad) o este último es también un punto central, se agrupan en el mismo cluster.
#
# 4. **Etiquetar Puntos**: Los puntos que no están en un cluster se etiquetan como ruido ("noise"). Estos puntos no cumplen con los requisitos para formar parte de un cluster.
#
# **Ejemplo con Gráficas:**
#
# Supongamos que tenemos un conjunto de puntos bidimensionales y queremos aplicar DBSCAN para identificar clusters. Utilizaremos la librería `scikit-learn` para implementar el algoritmo y `matplotlib` para visualizar los resultados.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons

# Generar datos de ejemplo (dos lunas)
X, _ = make_moons(n_samples=200, noise=0.05, random_state=42)

# Crear el modelo DBSCAN
dbscan = DBSCAN(eps=0.3, min_samples=5)
labels = dbscan.fit_predict(X)

# Visualizar los clusters y el ruido
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.title('DBSCAN: Identificación de Clusters y Ruido')
plt.show()

# %% [markdown]
# **Interpretación de la Visualización:**
#
# En este ejemplo, hemos generado datos en forma de dos lunas y aplicado DBSCAN para identificar los clusters. Los puntos se han coloreado de acuerdo con su asignación a clusters. Los puntos que no están en ningún cluster se consideran ruido y se han asignado con la etiqueta -1.
#
# **Ajuste de Parámetros:**
#
# La elección adecuada de los parámetros ε y "min_samples" es crucial en DBSCAN. Si ε es demasiado pequeño, es posible que muchos puntos no estén asignados a ningún cluster. Si ε es demasiado grande, todos los puntos podrían terminar en un mismo cluster. Experimenta con diferentes valores para encontrar el equilibrio correcto.
#
# **Limitaciones de DBSCAN:**
#
# DBSCAN es efectivo para identificar clusters con formas arbitrarias y es resistente al ruido. Sin embargo, puede tener dificultades en identificar clusters de diferentes densidades y puede ser sensible a la elección de parámetros.
#
# En resumen, DBSCAN es un algoritmo de clustering que se basa en la densidad de puntos para identificar clusters. La implementación en Python utilizando `scikit-learn` es relativamente sencilla y puede proporcionar una forma eficaz de identificar clusters en tus datos.

# %% [markdown]
# ## **Algoritmo paso a paso**

# %% [markdown]
# ¡Por supuesto! Aquí te proporciono el algoritmo DBSCAN (Density-Based Spatial Clustering of Applications with Noise) paso a paso para una comprensión más detallada. A medida que sigas los pasos, ten en cuenta que este algoritmo identifica clusters basados en la densidad de los puntos en el espacio y puede asignar puntos como ruido si no cumplen con ciertos criterios.
#
# **Pasos del Algoritmo DBSCAN:**
#
# 1. **Parámetros Iniciales**: Define los parámetros del algoritmo: ε (eps), el radio de vecindad, y "min_samples", el número mínimo de puntos para considerar un cluster.
#
# 2. **Definir Vecindad**: Para cada punto ($P$) en el conjunto de datos, encuentra todos los puntos que están dentro del radio ε (distancia euclidiana) alrededor de ($P$). Si la cantidad de puntos en esta vecindad es mayor o igual a "min_samples", ($P$) se considera un punto central.
#
# 3. **Expandir Cluster**: Para cada punto central, encuentra todos los puntos que están dentro del radio ε alrededor de él. Si estos puntos también son puntos centrales, se agrupan en el mismo cluster. Repite este proceso hasta que no se puedan agregar más puntos al cluster.
#
# 4. **Asignar a Cluster o Ruido**: Todos los puntos que no están en clusters se consideran ruido. Los puntos que están en la vecindad de un punto central pero no son puntos centrales se asignan al cluster del punto central.
#
# 5. **Resultados Finales**: Al finalizar el proceso, tendrás los clusters identificados y los puntos que se consideran ruido.
#
# **Ejemplo Paso a Paso:**
#
# Supongamos que tenemos los siguientes puntos en un conjunto de datos bidimensional y queremos aplicar DBSCAN:
#
# Puntos: A, B, C, D, E, F, G, H, I, J
#
# - Parámetros iniciales: ε = 2, min_samples = 3
#
# **Paso 1: Definir Vecindad**
#
# - Punto A: Vecindad = [B, C]
# - Punto B: Vecindad = [A, C, D, E]
# - Punto C: Vecindad = [A, B, D, E]
# - ...
#
# **Paso 2: Expandir Clusters**
#
# - Punto B es un punto central porque su vecindad tiene más de 3 puntos. Asignar cluster 1 y expandir.
#
# **Paso 3: Expandir Cluster**
#
# - Punto D y E están dentro del radio ε alrededor de B y son puntos centrales. Agregar a cluster 1.
#
# **Paso 4: Asignar a Cluster o Ruido**
#
# - Puntos A, C y F están dentro del radio ε alrededor de B pero no son puntos centrales. Asignar a cluster 1.
#
# **Paso 5: Resultados Finales**
#
# - Cluster 1: [A, B, C, D, E, F]
#
# En este ejemplo, hemos formado un cluster basado en densidad con los puntos A, B, C, D, E y F. Los puntos G, H, I y J no se agruparon y se consideran ruido.
#
# **Nota**: La implementación real puede involucrar optimizaciones y detalles adicionales para manejar casos especiales y mejorar la eficiencia.
#
# Recuerda que DBSCAN es muy útil para identificar clusters en datos con formas arbitrarias y es resistente al ruido, pero la elección de los parámetros es crítica para obtener resultados precisos.

# %% [markdown]
# ## **DBSCAN con Scikit-learn**

# %% [markdown]
# Claro, estaré encantado de explicarte cómo utilizar DBSCAN (Density-Based Spatial Clustering of Applications with Noise) con la librería Scikit-learn en Python. Vamos a seguir los pasos necesarios para aplicar DBSCAN a un conjunto de datos y visualizar los resultados. Utilizaremos el conjunto de datos "blobs" proporcionado por Scikit-learn para este ejemplo.
#
# **Paso 1: Importar Librerías y Generar Datos de Ejemplo**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# Generar datos de ejemplo
X, _ = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# %% [markdown]
# **Paso 2: Preprocesamiento de Datos**
#
# Es importante escalar los datos antes de aplicar DBSCAN para asegurarnos de que todas las características tengan la misma importancia.

# %%
# Escalar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# **Paso 3: Crear y Entrenar el Modelo DBSCAN**

# %%
# Crear el modelo DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)

# Entrenar el modelo y predecir las asignaciones de clusters
labels = dbscan.fit_predict(X_scaled)

# %% [markdown]
# **Paso 4: Visualizar los Resultados**

# %%
# Crear una matriz de colores para los clusters
colors = np.array(['#377eb8', '#ff7f00', '#4daf4a', '#f781bf', '#a65628', '#984ea3', '#999999'])

# Visualizar los clusters y los puntos ruido
plt.scatter(X[:, 0], X[:, 1], c=colors[labels])
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.title('DBSCAN Clustering')
plt.show()

# %% [markdown]
# **Interpretación de la Visualización:**
#
# En el gráfico resultante, cada punto se colorea según el cluster al que fue asignado por DBSCAN. Los puntos que quedan sin color son considerados como ruido. Puedes observar que DBSCAN ha identificado los clusters de manera efectiva y también ha identificado algunos puntos como ruido, ya que no cumplen con los criterios de densidad.
#
# **Ajuste de Parámetros:**
#
# En el ejemplo, hemos usado `eps=0.5` como el radio de vecindad y `min_samples=5` como el número mínimo de puntos para considerar un cluster. Es importante experimentar con diferentes valores de estos parámetros para obtener los mejores resultados según los datos y la naturaleza de los clusters.
#
# **Conclusión:**
#
# DBSCAN es una herramienta útil para identificar clusters basados en densidad en conjuntos de datos. Scikit-learn facilita la implementación de este algoritmo y la visualización de los resultados, lo que te permite comprender mejor la estructura de tus datos y la presencia de clusters y ruido.

# %% [markdown]
# | **Inicio** | **atrás 5** | **Siguiente 7** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./5_Random_Forest.ipynb)| [⏩](./7_Modelos_de_Machine_Learning.ipynb)|
