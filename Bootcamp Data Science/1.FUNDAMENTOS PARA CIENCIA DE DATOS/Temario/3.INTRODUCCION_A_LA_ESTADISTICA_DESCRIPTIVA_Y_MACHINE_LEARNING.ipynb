# %% [markdown]
# | **Inicio** | **atrás 2** |
# |----------- |-------------- |
# | [🏠](../../../README.md) | [⏪](./2.INTRODUCCION_AL_ALGEBRA_LINEAL.ipynb)|

# %% [markdown]
# # **3. INTRODUCCIÓN A LA ESTADÍSTICA DESCRIPTIVA Y MACHINE LEARNING**

# %% [markdown]
# La introducción a la estadística descriptiva y el aprendizaje automático (machine learning) es un tema amplio, pero puedo darte una explicación general y mostrarte un ejemplo básico en Python para ilustrar algunos conceptos clave.
#
# * **Estadística descriptiva:**
#
# La estadística descriptiva es una rama de la estadística que se centra en la recopilación, organización, resumen y presentación de datos. Su objetivo principal es describir y resumir las características importantes de un conjunto de datos sin hacer inferencias o conclusiones más allá de los datos observados.
#
# **Ejemplo en Python:**
#
# Supongamos que tenemos una lista de alturas de personas y queremos calcular algunas medidas descriptivas básicas:

# %%
import numpy as np

# Datos de ejemplo
alturas = [165, 170, 155, 180, 160, 175, 150, 185, 168, 172]

# Calcular medidas descriptivas
media = np.mean(alturas)
mediana = np.median(alturas)
desviacion_estandar = np.std(alturas)

print("Media:", media)
print("Mediana:", mediana)
print("Desviación estándar:", desviacion_estandar)
# Out:
# Media: 168.0
# Mediana: 169.0
# Desviación estándar: 10.334408546211051

# %% [markdown]
# En este ejemplo, calculamos la media (promedio), la mediana y la desviación estándar de las alturas de las personas. Estas medidas descriptivas nos brindan información sobre el valor típico, la dispersión y la variabilidad de los datos.
#
# * **Aprendizaje automático (Machine Learning):**
#
# El aprendizaje automático es un subcampo de la inteligencia artificial que se enfoca en desarrollar algoritmos y modelos que permiten a las máquinas aprender y tomar decisiones basadas en datos sin ser programadas explícitamente. El objetivo principal es construir modelos predictivos o descriptivos a partir de datos de entrenamiento.
#
# **Ejemplo en Python:**
#
# Consideremos un problema de clasificación en el que queremos construir un modelo para predecir si una flor es de tipo `Iris-setosa` o `Iris-versicolor` en función de sus longitudes y anchos de pétalos. Utilizaremos el conjunto de datos `Iris`, ampliamente utilizado en el aprendizaje automático.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression

# Cargar el conjunto de datos Iris
iris = load_iris()
X = iris.data[:, 2:]  # Longitud y ancho de los pétalos
y = iris.target

# Entrenar un modelo de regresión logística
model = LogisticRegression()
model.fit(X, y)

# Graficar los puntos de datos y las regiones de decisión del modelo
x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02), np.arange(y_min, y_max, 0.02))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Personalizar la gráfica
plt.figure(figsize=(10, 8))

# Graficar las regiones de decisión
plt.contourf(xx, yy, Z, alpha=0.8, cmap='viridis')

# Graficar los puntos de datos
scatter = plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap='viridis', s=100)

# Agregar leyenda
legend_labels = ['Setosa', 'Versicolor', 'Virginica']
plt.legend(handles=scatter.legend_elements()[0], labels=legend_labels, title='Clases')

# Ajustar etiquetas y título
plt.xlabel('Longitud del pétalo')
plt.ylabel('Ancho del pétalo')
plt.title('Clasificación de flores Iris')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# En este ejemplo, utilizamos el algoritmo de regresión logística para construir un modelo de clasificación que puede predecir la especie de una flor `Iris` en función de sus características de pétalos. Graficamos los puntos de datos y las regiones de decisión del modelo para visualizar cómo se realiza la clasificación.
#
# Esto es solo una introducción básica a la estadística descriptiva y el aprendizaje automático. Ambos campos tienen muchos conceptos y técnicas más avanzados que se pueden explorar, pero espero que este ejemplo te brinde una idea inicial de cómo se pueden aplicar en Python.

# %% [markdown]
# ## **La estadística descriptiva**

# %% [markdown]
# La estadística descriptiva es una rama de la estadística que se encarga de recopilar, organizar, resumir y presentar datos de forma numérica o gráfica. Su objetivo principal es describir las características principales de un conjunto de datos, sin realizar inferencias o conclusiones más allá de los datos observados. A través de la estadística descriptiva, se busca resumir y visualizar la información contenida en los datos, proporcionando una comprensión más clara y concisa de los mismos.
#
# A continuación, te mostraré un ejemplo en código Python para ilustrar algunos conceptos de la estadística descriptiva, así como su representación gráfica.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de ejemplo: edades de una muestra de personas
edades = [22, 25, 31, 35, 40, 42, 45, 50, 55, 60]

# Cálculo de medidas descriptivas básicas
media = np.mean(edades)
mediana = np.median(edades)
desviacion_estandar = np.std(edades)

# Creación de un histograma de frecuencias
plt.hist(edades, bins=5, edgecolor='black')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Histograma de Edades')

# Agregar líneas para mostrar la media y la mediana
plt.axvline(media, color='red', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana, color='green', linestyle='dashed', linewidth=2, label='Mediana')

# Mostrar la leyenda
plt.legend()

# Mostrar la gráfica
plt.show()

# Impresión de las medidas descriptivas
print("Media:", media)
print("Mediana:", mediana)
print("Desviación estándar:", desviacion_estandar)
# Out:
# Media: 40.5
# Mediana: 41.0
# Desviación estándar: 11.859595271340417

# %% [markdown]
# En este ejemplo, tenemos una lista de edades de una muestra de personas. Aplicaremos algunas medidas descriptivas básicas y crearemos un histograma de frecuencias para visualizar la distribución de las edades.
#
# El histograma muestra cómo se distribuyen las edades en diferentes rangos. Los valores de las edades se agrupan en "`bins`" o intervalos y se muestra la frecuencia de observaciones en cada `bin`. Esto nos da una idea de la forma de la distribución y nos permite identificar patrones o características importantes de los datos.
#
# Además, calculamos la media (promedio), la mediana y la desviación estándar de las edades. Estas medidas descriptivas nos proporcionan información sobre el valor central, la dispersión y la variabilidad de los datos.
#
# En resumen, la estadística descriptiva nos ayuda a resumir y comprender los datos mediante medidas numéricas y gráficas. Esto nos permite obtener una visión general de los datos y extraer información importante sin hacer inferencias o generalizaciones más allá de los datos observados.

# %% [markdown]
# ## **Gráficos estadísticos**

# %% [markdown]
# Los gráficos estadísticos son herramientas visuales que nos permiten representar los datos de manera clara y comprensible. Estas representaciones gráficas ayudan a visualizar la distribución, la relación o la variación de los datos, lo que facilita la interpretación y el análisis de la información estadística. A continuación, te mostraré algunos ejemplos de gráficos estadísticos comunes junto con su implementación en código Python.
#
# * **Histograma:**
#
# El histograma es un gráfico de barras que muestra la frecuencia de los valores en diferentes intervalos o `bins`. Es útil para visualizar la distribución de una variable continua.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos de ejemplo
datos = np.random.normal(0, 1, 1000)

# Crear histograma con personalización
plt.hist(datos, bins=20, edgecolor='black', color='skyblue', alpha=0.7)  # Añadir transparencia y cambiar color
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.title('Histograma')

# Agregar línea vertical para la media
media = np.mean(datos)
plt.axvline(media, color='red', linestyle='dashed', linewidth=2, label='Media')

# Agregar leyenda
plt.legend()

# Añadir cuadrícula
plt.grid(True, linestyle='--', alpha=0.5)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# * **Diagrama de dispersión:**
#
# El diagrama de dispersión muestra la relación entre dos variables numéricas. Cada punto en el gráfico representa una observación y su ubicación en el plano cartesiano está determinada por los valores de ambas variables.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos de ejemplo
x = np.random.normal(0, 1, 100)
y = 2 * x + np.random.normal(0, 1, 100)

# Crear diagrama de dispersión con personalización
plt.scatter(x, y, color='skyblue', marker='o', label='Datos')  # Cambiar color y marcador
plt.xlabel('Variable X')
plt.ylabel('Variable Y')
plt.title('Diagrama de Dispersión')

# Agregar línea de regresión
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
plt.plot(x, polynomial(x), color='red', linestyle='--', label='Línea de Regresión')

# Agregar leyenda
plt.legend()

# Añadir cuadrícula
plt.grid(True, linestyle='--', alpha=0.5)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# * **Gráfico de barras:**
#
# El gráfico de barras muestra la comparación de diferentes categorías o grupos mediante barras rectangulares. Es útil para representar datos categóricos o variables discretas.

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
categorias = ['A', 'B', 'C', 'D']
valores = [20, 35, 30, 15]

# Crear gráfico de barras con personalización
plt.bar(categorias, valores, color='skyblue', edgecolor='black')  # Cambiar color de las barras y del borde
plt.xlabel('Categorías', fontsize=12)  # Cambiar tamaño de la fuente en el eje x
plt.ylabel('Valores', fontsize=12)  # Cambiar tamaño de la fuente en el eje y
plt.title('Gráfico de Barras', fontsize=14)  # Cambiar tamaño de la fuente del título
plt.xticks(fontsize=10)  # Cambiar tamaño de la fuente en el eje x
plt.yticks(fontsize=10)  # Cambiar tamaño de la fuente en el eje y

# Agregar etiquetas en las barras
for i, valor in enumerate(valores):
    plt.text(i, valor + 0.5, str(valor), ha='center', va='bottom', fontsize=10)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# * **Gráfico de pastel:**
#
# El gráfico de pastel o de torta muestra la proporción de cada categoría en relación con el total. Es útil para representar datos porcentuales o proporcionales.

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
categorias = ['A', 'B', 'C', 'D']
valores = [30, 20, 25, 15]

# Colores personalizados para cada categoría
colores = ['lightblue', 'lightcoral', 'lightgreen', 'lightsalmon']

# Explode para resaltar una porción (opcional)
explode = (0, 0.1, 0, 0)

# Crear gráfico de pastel con personalización
plt.pie(valores, labels=categorias, autopct='%1.1f%%', colors=colores, explode=explode, startangle=90)
plt.title('Gráfico de Pastel', fontsize=14)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# Estos son solo algunos ejemplos de gráficos estadísticos. Existen muchos otros tipos de gráficos, como diagramas de caja, gráficos de línea, gráficos de área, entre otros, que se utilizan en diferentes situaciones para representar datos de manera efectiva. La elección del gráfico adecuado depende del tipo de datos y el objetivo de la visualización.

# %% [markdown]
# ## **Gráficos de dispersión y burbujas**

# %% [markdown]
# Los gráficos de dispersión y burbujas son tipos de gráficos que se utilizan para visualizar la relación entre dos o tres variables numéricas. Estos gráficos son útiles para identificar patrones, tendencias o correlaciones entre las variables. A continuación, te mostraré ejemplos de implementación en código Python y sus gráficas correspondientes.
#
# * **Gráfico de Dispersión:**
#
# Un gráfico de dispersión muestra la relación entre dos variables numéricas. Cada punto en el gráfico representa una observación y su ubicación en el plano cartesiano está determinada por los valores de ambas variables. Este gráfico nos permite identificar la distribución de los datos y detectar posibles patrones o relaciones.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos de ejemplo
x = np.random.normal(0, 1, 100)
y = 2 * x + np.random.normal(0, 1, 100)

# Personalizar el gráfico de dispersión
plt.scatter(x, y, color='blue', marker='o', edgecolors='black', alpha=0.7, label='Datos')

# Agregar líneas de referencia
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

# Etiquetas y título
plt.xlabel('Variable X', fontsize=12)
plt.ylabel('Variable Y', fontsize=12)
plt.title('Gráfico de Dispersión Personalizado', fontsize=14)

# Añadir leyenda
plt.legend()

# Ajustar diseño
plt.grid(True)
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# En el ejemplo anterior, se generan datos aleatorios para las variables `x` e `y`. Luego, se crea un gráfico de dispersión utilizando la función `scatter` de `Matplotlib`. Cada punto en el gráfico representa una observación con sus valores correspondientes en el eje `x` e `y`.
#
# * **Gráfico de Burbujas:**
#
# Un gráfico de burbujas es similar a un gráfico de dispersión, pero agrega una tercera dimensión al tamaño de los puntos. Esto se logra asignando un tamaño proporcional a los valores de una tercera variable. El tamaño de las burbujas puede representar una medida adicional o una variable adicional en el conjunto de datos.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos de ejemplo
x = np.random.normal(0, 1, 100)
y = np.random.normal(0, 1, 100)
sizes = np.random.randint(10, 100, 100)  # Tamaño de las burbujas
colors = np.random.rand(100)  # Colores aleatorios

# Personalizar el gráfico de burbujas
plt.scatter(x, y, s=sizes, c=colors, alpha=0.7, edgecolors='black', cmap='viridis')

# Barra de color
cbar = plt.colorbar()
cbar.set_label('Color')

# Etiquetas y título
plt.xlabel('Variable X', fontsize=12)
plt.ylabel('Variable Y', fontsize=12)
plt.title('Gráfico de Burbujas Personalizado', fontsize=14)

# Ajustar diseño
plt.grid(True)
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# En este ejemplo, se generan datos aleatorios para las variables `x` e `y`, así como tamaños aleatorios para las burbujas en la variable sizes. Luego, se crea un gráfico de burbujas utilizando la función `scatter`, donde el parámetro `s` se establece como `sizes` para asignar el tamaño de las burbujas.
#
# El gráfico de burbujas permite visualizar tres variables de manera simultánea: dos variables en los ejes `x` e `y`, y una tercera variable representada por el tamaño de las burbujas.
#
# Estos son solo ejemplos básicos de gráficos de dispersión y burbujas. Es posible personalizar aún más estos gráficos ajustando los colores, etiquetas, leyendas y otros elementos visuales según tus necesidades y preferencias.

# %% [markdown]
# ## **Gráficos de barras, barras apiladas y agrupadas**

# %% [markdown]
# Los gráficos de barras, barras apiladas y barras agrupadas son tipos de gráficos que se utilizan para representar datos categóricos o discretos en forma de barras rectangulares. Estos gráficos son útiles para comparar diferentes categorías y observar las diferencias o similitudes entre ellas. A continuación, te mostraré ejemplos de implementación en código Python y sus gráficas correspondientes.
#
# * **Gráfico de Barras:**
#
# Un gráfico de barras muestra la frecuencia o el valor de una variable en diferentes categorías. Cada categoría se representa por una barra individual cuya altura representa la frecuencia o valor correspondiente. Este tipo de gráfico es ideal para comparar categorías y visualizar la magnitud de las diferencias entre ellas.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de ejemplo
categorias = ['A', 'B', 'C', 'D']
valores = [25, 40, 30, 15]

# Crear gráfico de barras con personalizaciones
plt.bar(categorias, valores, color=['blue', 'green', 'red', 'purple'], edgecolor='black', linewidth=2)

# Etiquetas y título
plt.xlabel('Categorías', fontsize=12)
plt.ylabel('Valores', fontsize=12)
plt.title('Gráfico de Barras Personalizado', fontsize=14)

# Ajustar diseño
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# En el ejemplo anterior, se definen las categorías y los valores correspondientes en las variables categorias y valores. Luego, se crea un gráfico de barras utilizando la función `bar` de `Matplotlib`. Cada barra representa una categoría y su altura indica el valor asociado.
#
# * **Gráfico de Barras Apiladas:**
#
# Un gráfico de barras apiladas muestra múltiples variables o subcategorías dentro de cada categoría. Las barras se apilan una encima de la otra, y la altura total de cada barra representa la suma de los valores de las subcategorías. Este tipo de gráfico es útil para comparar la composición o la contribución de diferentes subcategorías dentro de cada categoría.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de ejemplo
categorias = ['A', 'B', 'C', 'D']
valores1 = [25, 40, 30, 15]
valores2 = [15, 30, 20, 25]

# Crear gráfico de barras apiladas con personalizaciones
plt.bar(categorias, valores1, label='Grupo 1', color='blue', edgecolor='black', linewidth=1)
plt.bar(categorias, valores2, bottom=valores1, label='Grupo 2', color='orange', edgecolor='black', linewidth=1)

# Etiquetas y título
plt.xlabel('Categorías', fontsize=12)
plt.ylabel('Valores', fontsize=12)
plt.title('Gráfico de Barras Apiladas Personalizado', fontsize=14)

# Ajustar diseño
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# En este ejemplo, se tienen dos grupos de valores representados por las variables `valores1` y `valores2`. Mediante el uso de la función `bar`, se crean barras apiladas para cada categoría. El parámetro `bottom` se utiliza para indicar el valor base de cada barra apilada.
#
# * **Gráfico de Barras Agrupadas:**
#
# Un gráfico de barras agrupadas muestra múltiples variables o subcategorías dentro de cada categoría, pero en lugar de apilar las barras, se agrupan una al lado de la otra. Esto permite una comparación directa entre las subcategorías de diferentes categorías.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de ejemplo
categorias = ['A', 'B', 'C', 'D']
valores1 = [25, 40, 30, 15]
valores2 = [15, 30, 20, 25]

# Configuración de posición de las barras
pos = np.arange(len(categorias))
ancho = 0.35

# Crear gráfico de barras agrupadas con personalizaciones
plt.bar(pos, valores1, ancho, label='Grupo 1', color='blue', edgecolor='black', linewidth=1)
plt.bar(pos + ancho, valores2, ancho, label='Grupo 2', color='orange', edgecolor='black', linewidth=1)

# Etiquetas y título
plt.xlabel('Categorías', fontsize=12)
plt.ylabel('Valores', fontsize=12)
plt.title('Gráfico de Barras Agrupadas Personalizado', fontsize=14)

# Ajustar diseño
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.xticks(pos + ancho / 2, categorias, fontsize=10)
plt.yticks(fontsize=10)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# En este ejemplo, se tienen dos grupos de valores representados por las variables `valores1` y `valores2`. El arreglo pos se utiliza para establecer la posición de cada grupo de barras agrupadas. Mediante el uso de la función `bar` y ajustando la posición de las barras, se crean barras agrupadas para cada categoría.
#
# Estos son solo ejemplos básicos de gráficos de barras, barras apiladas y barras agrupadas. Es posible personalizar aún más estos gráficos ajustando los colores, etiquetas, leyendas y otros elementos visuales según tus necesidades y preferencias.

# %% [markdown]
# ## **Gráficos de líneas, columnas, combinados**

# %% [markdown]
# Los gráficos de líneas, columnas y combinados son tipos de gráficos utilizados para visualizar datos en forma de líneas o columnas. Cada tipo de gráfico tiene sus propias características y se utiliza en diferentes situaciones. A continuación, te proporcionaré una explicación detallada y ejemplos de implementación en código Python para cada uno de ellos, junto con las respectivas gráficas.
#
# * **Gráfico de Líneas:**
#
# Un gráfico de líneas muestra la relación y tendencia de un conjunto de datos a lo largo de un eje. Es útil para representar datos continuos y resaltar patrones, cambios o tendencias en los datos a lo largo del tiempo o de otra variable continua.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de ejemplo
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Crear gráfico de líneas con personalizaciones
plt.plot(x, y, color='blue', linestyle='-', linewidth=2, marker='o', markersize=6, label='y = sin(x)')

# Etiquetas y título
plt.xlabel('Eje x', fontsize=12)
plt.ylabel('Eje y', fontsize=12)
plt.title('Gráfico de Líneas Personalizado', fontsize=14)

# Ajustar diseño
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# En este ejemplo, se genera una serie de datos `x` utilizando la función `linspace` para crear una secuencia de valores desde 0 hasta 10. Luego, se calcula la función `seno` de cada valor de `x` y se guarda en la variable `y`. Mediante la función `plot`, se traza el gráfico de líneas, donde los valores de `x` representan el eje horizontal y los valores de `y` representan el eje vertical.
#
# * **Gráfico de Columnas:**
#
# Un gráfico de columnas muestra la comparación de datos discretos o categóricos utilizando columnas verticales. Cada columna representa una categoría y su altura indica la magnitud de la variable asociada. Este tipo de gráfico es útil para comparar diferentes categorías y resaltar las diferencias entre ellas.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de ejemplo
categorias = ['A', 'B', 'C', 'D']
valores = [25, 40, 30, 15]

# Crear gráfico de columnas con personalizaciones
plt.bar(categorias, valores, color='green', edgecolor='black', linewidth=2, alpha=0.7)

# Etiquetas y título
plt.xlabel('Categorías', fontsize=12)
plt.ylabel('Valores', fontsize=12)
plt.title('Gráfico de Columnas Personalizado', fontsize=14)

# Ajustar diseño
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# En este ejemplo, se definen las categorías y los valores correspondientes en las variables categorias y valores. Luego, se crea un gráfico de columnas utilizando la función `bar`, donde cada columna representa una categoría y su altura indica el valor asociado.
#
# * **Gráfico Combinado:**
#
# Un gráfico combinado permite mostrar múltiples series de datos utilizando diferentes tipos de gráficos en el mismo gráfico. Esto es útil cuando se desea comparar diferentes variables o tendencias en un solo gráfico.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de ejemplo
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Crear gráfico combinado
fig, ax1 = plt.subplots()

# Gráfico de líneas en el primer eje y
ax1.plot(x, y1, 'b-', label='Seno')
ax1.set_xlabel('Eje x')
ax1.set_ylabel('Seno', color='b')
ax1.tick_params('y', colors='b')
ax1.set_title('Gráfico Combinado')

# Segundo eje y
ax2 = ax1.twinx()

# Gráfico de columnas en el segundo eje y
ax2.bar(x, y2, alpha=0.3, label='Coseno', color='g')
ax2.set_ylabel('Coseno', color='g')
ax2.tick_params('y', colors='g')

# Leyenda
fig.legend(loc='upper right')

plt.show()

# %% [markdown]
# En este ejemplo, se generan dos series de datos `y1` y `y2` utilizando funciones trigonométricas. Se crea un gráfico combinado utilizando `subplots` para generar dos ejes y superponer los gráficos. En el eje principal (`ax1`), se traza el gráfico de líneas para `y1`, mientras que en el segundo eje `y` (`ax2`), se traza un gráfico de columnas para `y2`. Cada eje `y` tiene su propia escala y etiquetas correspondientes.
#
# Estos ejemplos proporcionan una idea de cómo crear gráficos de líneas, columnas y combinados utilizando Python y la biblioteca `Matplotlib`. Puedes personalizar aún más estos gráficos según tus necesidades, como ajustar colores, estilos, leyendas, etiquetas de ejes, entre otros.

# %% [markdown]
# ## **La estadística y el Machine Learning**

# %% [markdown]
# La estadística y el aprendizaje automático (Machine Learning) son dos disciplinas interrelacionadas que se utilizan para analizar y comprender los datos. Ambas tienen como objetivo extraer información útil y tomar decisiones basadas en patrones y relaciones presentes en los datos. A continuación, te proporcionaré una explicación detallada de cada una, junto con ejemplos de implementación en código Python y algunas visualizaciones comunes.
#
# * **Estadística:**
#
# La estadística es una rama de las matemáticas que se centra en recopilar, analizar e interpretar datos para obtener información significativa. Se utiliza para describir y resumir los datos, así como para inferir conclusiones sobre una población más amplia a partir de una muestra de datos.
#
# **Ejemplo en código Python:**
#
# Supongamos que tenemos una lista de alturas de personas y queremos calcular la media y la desviación estándar.

# %%
import numpy as np

# Datos de ejemplo (alturas en centímetros)
alturas = [165, 170, 155, 180, 160, 175, 150, 185, 165, 170]

# Cálculo de la media y desviación estándar
media = np.mean(alturas)
desviacion_estandar = np.std(alturas)

print("Media:", media)
print("Desviación estándar:", desviacion_estandar)
# Out:
# Media: 167.5
# Desviación estándar: 10.307764064044152

# %% [markdown]
# En este ejemplo, utilizamos la biblioteca `NumPy` para calcular la media y la desviación estándar de la lista de alturas. La media representa el valor promedio de las alturas, mientras que la desviación estándar indica qué tan dispersos están los datos con respecto a la media.
#
# * **Gráficas asociadas:**
#
# Algunas gráficas comunes utilizadas en estadística incluyen el histograma y el diagrama de caja (`boxplot`).

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo (asegúrate de tener la variable 'alturas' definida)
alturas = np.random.normal(170, 10, 100)

# Gráfico de histograma
plt.hist(alturas, bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Alturas')
plt.ylabel('Frecuencia')
plt.title('Histograma de Alturas')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# Gráfico de diagrama de caja
plt.boxplot(alturas, vert=False, patch_artist=True, boxprops=dict(facecolor='lightgreen'))
plt.xlabel('Alturas')
plt.title('Diagrama de Caja de Alturas')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# En el primer gráfico, se muestra un histograma que representa la distribución de las alturas. Los datos se agrupan en intervalos (`bins`) y se muestra la frecuencia con la que aparecen en cada intervalo.
#
# En el segundo gráfico, se presenta un diagrama de caja que proporciona información sobre la mediana, el rango intercuartil (`IQR`) y los valores atípicos de las alturas.
#
# * **Machine Learning:**
#
# El aprendizaje automático (Machine Learning) es una rama de la inteligencia artificial que se enfoca en el desarrollo de algoritmos y modelos que permiten a las computadoras aprender automáticamente a partir de los datos y tomar decisiones o hacer predicciones sin ser programadas explícitamente. Se basa en la construcción de modelos estadísticos y utiliza técnicas para identificar patrones y relaciones en los datos.
#
# **Ejemplo en código Python:**
#
# Supongamos que tenemos un conjunto de datos con información sobre el tamaño de las casas (en metros cuadrados) y sus precios de venta. Queremos construir un modelo de regresión lineal para predecir el precio de una casa en función de su tamaño.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Datos de ejemplo (tamaño de las casas y precios)
tamanios = np.array([80, 100, 120, 150, 200, 250, 300]).reshape(-1, 1)
precios = np.array([150000, 200000, 250000, 300000, 400000, 500000, 600000])

# Construcción del modelo de regresión lineal
modelo = LinearRegression()
modelo.fit(tamanios, precios)

# Predicción del precio de una casa de tamaño 180 metros cuadrados
tamanio_nuevo = np.array([[180]])
precio_predicho = modelo.predict(tamanio_nuevo)

print("Precio predicho:", precio_predicho)
# Out:
# Precio predicho: [360085.53100499]

# %% [markdown]
# En este ejemplo, utilizamos la biblioteca `scikit-learn` para construir un modelo de regresión lineal. El modelo se ajusta a los datos de tamaño de las casas y precios para aprender la relación entre ambas variables. Luego, podemos usar el modelo entrenado para hacer predicciones, como predecir el precio de una casa con un tamaño de 180 metros cuadrados.
#
# * **Gráficas asociadas:**
#
# En el caso de la regresión lineal, una gráfica comúnmente utilizada es el gráfico de dispersión con la línea de regresión.

# %%
import matplotlib.pyplot as plt

# Supongamos que 'tamanios' y 'precios' están definidos

# Crear el gráfico de dispersión
plt.scatter(tamanios, precios, label='Datos reales', color='blue')

# Añadir la línea de regresión
plt.plot(tamanios, modelo.predict(tamanios), color='red', label='Línea de Regresión')

# Personalizar el gráfico
plt.xlabel('Tamaño (metros cuadrados)')
plt.ylabel('Precio')
plt.title('Regresión Lineal')
plt.legend()  # Mostrar la leyenda
plt.grid(True, linestyle='--', alpha=0.7)  # Añadir cuadrícula punteada
plt.show()

# %% [markdown]
# En esta gráfica, se muestran los puntos de datos representados por el tamaño de las casas y los precios en un gráfico de dispersión. Además, se traza la línea de regresión que representa la relación aprendida por el modelo de regresión lineal.
#
# Estos ejemplos ilustran cómo se aplican la estadística y el aprendizaje automático utilizando Python y las bibliotecas `NumPy`, `scikit-learn` y `Matplotlib`. Tanto la estadística como el aprendizaje automático son herramientas poderosas para analizar y comprender los datos, y pueden aplicarse en una amplia gama de problemas y situaciones.

# %% [markdown]
# ## **Paradigmas de Aprendizaje en Machine Learning**

# %% [markdown]
# Los paradigmas de aprendizaje en Machine Learning se refieren a las diferentes aproximaciones o enfoques utilizados para resolver problemas de aprendizaje automático. Cada paradigma tiene sus propias características, suposiciones y técnicas asociadas. A continuación, te proporcionaré una explicación detallada de algunos de los paradigmas de aprendizaje más comunes, junto con ejemplos de implementación en código Python y visualizaciones asociadas.
#
# * **Aprendizaje Supervisado:**
#
# En el aprendizaje supervisado, se utiliza un conjunto de datos etiquetados (datos de entrenamiento) que consisten en pares de entradas y salidas esperadas. El objetivo es aprender una función que pueda mapear nuevas entradas a las salidas correctas. Los algoritmos de aprendizaje supervisado se dividen en clasificación (cuando la salida es categórica) y regresión (cuando la salida es continua).
#
# **Ejemplo en código Python:**
#
# Supongamos que tenemos un conjunto de datos que representa el tamaño de las flores y su correspondiente especie (rosa, tulipán o lirio). Queremos construir un modelo de clasificación utilizando el algoritmo de `Support Vector Machine` (`SVM`) para predecir la especie de una flor desconocida basada en su tamaño.

# %%
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo (tamaño de las flores y especie)
tamanios = np.array([[3, 5], [4, 6], [2, 4], [6, 8], [5, 7], [4.5, 5.5]])
especies = np.array(['rosa', 'rosa', 'tulipán', 'lirio', 'lirio', 'tulipán'])

# Construcción del modelo de clasificación SVM
modelo = SVC()
modelo.fit(tamanios, especies)

# Predicción de la especie para una flor de tamaño (4, 5)
flor_nueva = np.array([[4, 5]])
especie_predicha = modelo.predict(flor_nueva)

print("Especie predicha:", especie_predicha)
# Out:
# Especie predicha: ['rosa']

# %% [markdown]
# En este ejemplo, utilizamos la biblioteca `scikit-learn` para construir un modelo de clasificación `SVM`. El modelo se ajusta a los datos de tamaño de las flores y especies para aprender la relación entre ambas variables. Luego, podemos usar el modelo entrenado para hacer predicciones, como predecir la especie de una flor con un tamaño específico.
#
# * **Gráfica asociada:**
#
# Una visualización común en clasificación supervisada es el gráfico de dispersión con diferentes colores para cada clase.

# %%
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo (tamaño de las flores y especie)
tamanios = np.array([[3, 5], [4, 6], [2, 4], [6, 8], [5, 7], [4.5, 5.5]])
especies = np.array(['rosa', 'rosa', 'tulipán', 'lirio', 'lirio', 'tulipán'])

# Mapeo de etiquetas de especie a valores numéricos
especies_numeros = np.unique(especies, return_inverse=True)[1]

# Construcción del modelo de clasificación SVM
modelo = SVC()
modelo.fit(tamanios, especies_numeros)

# Predicción de la especie para una flor de tamaño (4, 5)
flor_nueva = np.array([[4, 5]])
especie_predicha_numero = modelo.predict(flor_nueva)

especie_predicha = np.unique(especies)[especie_predicha_numero]

print("Especie predicha:", especie_predicha)

# Colores y marcadores para cada especie
colores = ['red', 'blue', 'green']
marcadores = ['o', 's', '^']

# Gráfico de dispersión con colores según la especie
plt.figure(figsize=(8, 6))
for i, especie in enumerate(np.unique(especies_numeros)):
    indices = especies_numeros == especie
    plt.scatter(tamanios[indices, 0], tamanios[indices, 1], c=colores[i], marker=marcadores[i], label=f'Especie {i}')

# Marcar la flor nueva
plt.scatter(flor_nueva[:, 0], flor_nueva[:, 1], c='black', marker='*', s=200, label='Flor Nueva')

plt.xlabel('Tamaño (característica 1)')
plt.ylabel('Tamaño (característica 2)')
plt.title('Clasificación de Flores')
plt.legend()
plt.show()
# Out:
# Especie predicha: ['rosa']

# %% [markdown]
# En esta gráfica, los puntos de datos representan el tamaño de las flores en un gráfico de dispersión. Los puntos se colorean de acuerdo a la especie correspondiente, lo que permite visualizar la separación de las clases y cómo se distribuyen los datos.
#
# * **Aprendizaje No Supervisado:**
#
# En el aprendizaje no supervisado, no se utilizan etiquetas en los datos de entrenamiento. El objetivo principal es descubrir patrones, estructuras o agrupamientos inherentes en los datos. Los algoritmos de aprendizaje no supervisado se dividen en `clustering` (agrupamiento) y reducción de la dimensionalidad.
#
# **Ejemplo en código Python:**
#
# Supongamos que tenemos un conjunto de datos que representa las características de diferentes flores, pero no tenemos información sobre sus especies. Queremos utilizar el algoritmo de clustering K-means para agrupar las flores en diferentes categorías basadas en sus características.

# %%
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

# Datos de ejemplo (características de flores)
X = np.array([[3, 5], [4, 6], [2, 4], [6, 8], [5, 7], [4.5, 5.5]])

# Entrenamiento del modelo de clustering K-means
kmeans = KMeans(n_clusters=2, random_state=42, n_init=10)
kmeans.fit(X)

# Predicción del grupo al que pertenece cada muestra
y_pred = kmeans.predict(X)

# Colores y marcadores distintivos para cada grupo
colores = ['blue', 'green']
marcadores = ['o', 's']

# Gráfica de los datos y los grupos encontrados
plt.figure(figsize=(8, 6))
for i, grupo in enumerate(np.unique(y_pred)):
    indices = y_pred == grupo
    plt.scatter(X[indices, 0], X[indices, 1], c=colores[i], marker=marcadores[i], label=f'Grupo {i}')

# Centroides marcados en rojo con 'x'
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='x', s=200, label='Centroides')

# Etiquetas para los puntos y centroides
for i, txt in enumerate(np.arange(1, len(X) + 1)):
    plt.annotate(txt, (X[i, 0], X[i, 1]), textcoords="offset points", xytext=(0, 5), ha='center')

for i, txt in enumerate(np.arange(1, len(kmeans.cluster_centers_) + 1)):
    plt.annotate(f'Centroide {txt}', (kmeans.cluster_centers_[i, 0], kmeans.cluster_centers_[i, 1]),
                 textcoords="offset points", xytext=(0, 5), ha='center')

plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.title('Clustering con K-means')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# En la gráfica resultante, los puntos se colorean según el grupo al que pertenecen, determinado por el algoritmo K-means. También se muestran los centroides de cada grupo como cruces rojas.
#
# * **Aprendizaje por refuerzo:**
#
# En el aprendizaje por refuerzo, un agente aprende a tomar decisiones en un entorno para maximizar una recompensa acumulativa. El agente interactúa con el entorno a través de acciones y recibe retroalimentación en forma de recompensas o castigos según sus acciones. El objetivo es aprender una política óptima que guíe al agente para tomar las mejores acciones en cada estado. Un ejemplo popular de aprendizaje por refuerzo es el algoritmo Q-learning.
# Aquí tienes un ejemplo simplificado de Q-learning en Python:

# %%
import numpy as np

# Configuración del entorno y recompensas
num_estados = 4
num_acciones = 2
recompensas = np.array([[0, -1], [-1, 1], [-1, 1], [-1, 0]])

# Matriz Q inicial
Q = np.zeros((num_estados, num_acciones))

# Hiperparámetros
factor_aprendizaje = 0.1
factor_descuento = 0.9
num_episodios = 100

# Algoritmo de Q-learning
for _ in range(num_episodios):
    estado_actual = 0
    while estado_actual != num_estados - 1:
        accion = np.argmax(Q[estado_actual])
        siguiente_estado = np.random.choice(range(num_estados))
        recompensa = recompensas[estado_actual, accion]
        Q[estado_actual, accion] += factor_aprendizaje * (recompensa + factor_descuento * np.max(Q[siguiente_estado]) - Q[estado_actual, accion])
        estado_actual = siguiente_estado

print("Matriz Q aprendida:")
print(Q)
# Out:
# Matriz Q aprendida:
# [[ 1.25651052  0.        ]
#  [-0.1         2.27965136]
#  [-0.0828271   1.95567482]
#  [ 0.          0.        ]]

# %% [markdown]
# En este ejemplo, se utiliza una matriz Q para almacenar los valores de utilidad (Q-values) para cada par estado-acción. El agente utiliza la matriz Q para seleccionar la mejor acción en cada estado y actualizar los valores de Q a medida que interactúa con el entorno. Después del entrenamiento, se imprime la matriz Q aprendida.
#
# Ten en cuenta que estos ejemplos son solo ilustrativos y pueden simplificar algunos aspectos del problema real. Además, las gráficas mostradas son solo ejemplos básicos y podrían ser más complejas en situaciones reales.

# %% [markdown]
# ## **Aprendizaje supervisado y no supervisado**

# %% [markdown]
# El aprendizaje supervisado y no supervisado son dos paradigmas fundamentales en el campo del aprendizaje automático (machine learning). A continuación, te proporcionaré una explicación detallada de cada uno, junto con ejemplos de código en Python y visualizaciones gráficas.
#
# * **Aprendizaje Supervisado:**
#
# El aprendizaje supervisado implica entrenar un modelo utilizando ejemplos de entrada y salida conocidos para que pueda realizar predicciones o clasificar nuevos ejemplos. En este paradigma, se proporciona un conjunto de datos de entrenamiento etiquetado, donde cada ejemplo tiene características de entrada y una etiqueta o valor de salida correspondiente.
#
# **Ejemplo en código Python:**
#
# Supongamos que tenemos un conjunto de datos de flores con características como longitud y ancho de pétalos, así como su especie (etiqueta). Podemos utilizar un algoritmo de aprendizaje supervisado, como la regresión logística, para predecir la especie de una flor desconocida en función de sus características.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Datos de entrenamiento
X_train = np.array([[5.1, 3.5], [4.9, 3.0], [6.7, 3.1], [6.0, 3.0]])
y_train = np.array([0, 0, 1, 1])  # 0: Setosa, 1: Versicolor

# Crear y entrenar el modelo
model = LogisticRegression()
model.fit(X_train, y_train)

# Datos de prueba
X_test = np.array([[5.5, 2.5], [6.3, 2.9]])

# Realizar predicciones
y_pred = model.predict(X_test)

# Graficar los datos de entrenamiento
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, marker='o', label='Entrenamiento')

# Graficar los datos de prueba y las predicciones
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_pred, marker='x', s=100, label='Predicciones')

plt.xlabel('Longitud del pétalo')
plt.ylabel('Ancho del pétalo')
plt.title('Predicciones de especies de flores')
plt.legend()
plt.show()

# %% [markdown]
# En este ejemplo, utilizamos la regresión logística como algoritmo de aprendizaje supervisado para clasificar las flores en dos especies diferentes (Setosa y Versicolor). Entrenamos el modelo utilizando los datos de entrenamiento etiquetados y luego realizamos predicciones en nuevos datos de prueba. La gráfica muestra los puntos de datos de entrenamiento con diferentes colores según su especie, así como las predicciones en los nuevos datos representadas por '`x`'.
#
# * **Aprendizaje No Supervisado:**
#
# El aprendizaje no supervisado implica descubrir patrones y estructuras ocultas en un conjunto de datos sin la necesidad de etiquetas o valores de salida conocidos. En este paradigma, el modelo aprende de forma autónoma a partir de los datos y encuentra agrupaciones, relaciones o características significativas.
#
# **Ejemplo en código Python:**
#
# Supongamos que tenemos un conjunto de datos de clientes con características demográficas y de comportamiento de compra. Podemos utilizar un algoritmo de aprendizaje no supervisado, como el clustering (agrupamiento), para agrupar a los clientes en segmentos similares basados en sus características.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Datos de entrada
X = np.array([[1, 2], [1.5, 1.8], [5, 8], [8, 8], [1, 0.6], [9, 11]])

# Crear y entrenar el modelo de clustering
model = KMeans(n_clusters=2, n_init=10)  # Puedes ajustar el valor de n_init aquí
model.fit(X)

# Obtener las etiquetas de los clusters y los centroides
labels = model.labels_
centroids = model.cluster_centers_

# Definir colores y marcadores
colors = ['r', 'g']
markers = ['o', 's']

# Graficar los datos y los centroides
for i in range(len(X)):
    plt.scatter(X[i, 0], X[i, 1], color=colors[labels[i]], marker=markers[labels[i]])

plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', color='b', s=100, label='Centroides')
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.title('Clustering de clientes')

# Agregar leyenda
plt.legend()

plt.show()

# %% [markdown]
# En este ejemplo, utilizamos el algoritmo de `clustering K-means` como un ejemplo de aprendizaje no supervisado. Agrupamos a los clientes en dos segmentos (2 clusters) en función de sus características demográficas y de comportamiento de compra. La gráfica muestra los puntos de datos de entrada coloreados según su cluster asignado, y los centroides de los clusters se representan con '`x`'.
#
# Espero que estos ejemplos te hayan proporcionado una comprensión clara de los conceptos de aprendizaje supervisado y no supervisado, así como su implementación en Python y visualización gráfica.

# %% [markdown]
# ## **Identificando el tipo de problema a resolver**

# %% [markdown]
# Para identificar el tipo de problema a resolver en Machine Learning, es importante comprender la naturaleza de los datos y los objetivos que se quieren lograr. A continuación, te proporcionaré una explicación detallada de los diferentes tipos de problemas en Machine Learning, junto con ejemplos de código en Python y visualizaciones gráficas.
#
# * **Problemas de clasificación:**
#
# En los problemas de clasificación, el objetivo es asignar una etiqueta o categoría a una instancia de datos basada en sus características. Es decir, se busca predecir a qué clase pertenece cada ejemplo. Algunos ejemplos de problemas de clasificación incluyen la detección de spam en correos electrónicos, la clasificación de imágenes en diferentes categorías o la predicción de la probabilidad de enfermedad basada en síntomas.
#
# **Ejemplo en código Python:**
#
# Supongamos que tenemos un conjunto de datos que contiene información sobre frutas, como su peso y textura, y queremos clasificar si una fruta es una manzana o una naranja. Podemos utilizar un algoritmo de clasificación, como el clasificador de vecinos más cercanos (K-Nearest Neighbors), para resolver este problema.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

# Datos de entrenamiento
X_train = np.array([[100, 2], [120, 3], [130, 1], [140, 3], [150, 2], [160, 2]])
y_train = np.array(['naranja', 'naranja', 'manzana', 'manzana', 'manzana', 'naranja'])

# Asignar colores numéricos a las clases
color_map = {'naranja': 0, 'manzana': 1}
colors = [color_map[label] for label in y_train]

# Crear y entrenar el clasificador
classifier = KNeighborsClassifier(n_neighbors=3)
classifier.fit(X_train, y_train)

# Datos de prueba
X_test = np.array([[110, 2]])

# Realizar la clasificación
y_pred = classifier.predict(X_test)

# Graficar los datos y la clasificación
plt.scatter(X_train[:, 0], X_train[:, 1], c=colors, cmap='viridis', label='Datos de entrenamiento', edgecolors='k')
plt.scatter(X_test[:, 0], X_test[:, 1], c=color_map[y_pred[0]], marker='x', s=200, label='Fruta clasificada')
plt.xlabel('Peso')
plt.ylabel('Textura')
plt.title('Clasificación de frutas')

# Agregar leyenda
plt.legend()

# Mostrar barra de color
plt.colorbar(label='Clases')

plt.show()

# %% [markdown]
# En este ejemplo, utilizamos el clasificador de vecinos más cercanos para clasificar las frutas en manzanas y naranjas según su peso y textura. Entrenamos el clasificador con los datos de entrenamiento etiquetados y realizamos la clasificación en nuevos datos de prueba. La gráfica muestra los datos de entrenamiento coloreados según su clase, y la nueva fruta a clasificar se representa con '`x`'.
#
# * **Problemas de regresión:**
#
# En los problemas de regresión, el objetivo es predecir un valor numérico continuo en función de las características de entrada. En otras palabras, se busca encontrar una relación funcional entre las variables de entrada y salida. Algunos ejemplos de problemas de regresión incluyen la predicción de los precios de las viviendas según sus características, la estimación de la demanda de productos en función de factores externos o la predicción del rendimiento de un estudiante en función de sus horas de estudio.
#
# **Ejemplo en código Python:**
#
# Supongamos que tenemos un conjunto de datos que contiene información sobre el tamaño de las casas (en metros cuadrados) y sus precios de venta, y queremos predecir el precio de una casa nueva basada en su tamaño. Podemos utilizar un algoritmo de regresión, como la regresión lineal, para resolver este problema.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Datos de entrenamiento
X_train = np.array([[80], [100], [120], [150], [180]])
y_train = np.array([150000, 200000, 230000, 280000, 320000])

# Crear y entrenar el modelo de regresión lineal
regression = LinearRegression()
regression.fit(X_train, y_train)

# Datos de prueba
X_test = np.array([[110]])

# Realizar la predicción
y_pred = regression.predict(X_test)

# Graficar los datos y la predicción
plt.scatter(X_train, y_train, label='Datos de entrenamiento')
plt.plot(X_test, y_pred, color='red', linestyle='--', label='Predicción')
plt.xlabel('Tamaño')
plt.ylabel('Precio')
plt.title('Predicción de precios de casas')

# Agregar leyenda
plt.legend()

# Mostrar la grilla
plt.grid(True)

plt.show()

# %% [markdown]
# En este ejemplo, utilizamos la regresión lineal para predecir los precios de las casas según su tamaño. Entrenamos el modelo con los datos de entrenamiento y realizamos la predicción en un nuevo dato de prueba. La gráfica muestra los datos de entrenamiento y la línea de regresión que representa la predicción de los precios de las casas.
#
# * **Problemas de agrupamiento (clustering):**
#
# En los problemas de agrupamiento, el objetivo es agrupar instancias de datos similares en clusters o grupos, sin tener etiquetas previas. El algoritmo de agrupamiento busca encontrar patrones y estructuras ocultas en los datos. Algunos ejemplos de problemas de agrupamiento incluyen la segmentación de clientes en grupos de comportamiento similar, la clasificación de noticias en categorías temáticas o la identificación de grupos de genes con perfiles de expresión similares.
#
# **Ejemplo en código Python:**
#
# Supongamos que tenemos un conjunto de datos que contiene información sobre las características de diferentes flores, como su longitud y ancho de pétalos, y queremos agrupar las flores en diferentes tipos según su similitud. Podemos utilizar un algoritmo de clustering, como K-means, para resolver este problema.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Datos de entrada
X = np.array([[1, 2], [1.5, 1.8], [5, 8], [8, 8], [1, 0.6], [9, 11]])

# Crear y entrenar el modelo de clustering
model = KMeans(n_clusters=2, n_init=10)  # Establecer explícitamente n_init
model.fit(X)

# Obtener las etiquetas de los clusters y los centroides
labels = model.labels_
centroids = model.cluster_centers_

# Mapear etiquetas a colores
colors = np.array(['r', 'g'])[labels]

# Graficar los datos y los centroides
plt.scatter(X[:, 0], X[:, 1], color=colors)
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', color='b', s=100, label='Centroides')

plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.title('Clustering de flores')

# Agregar leyenda
plt.legend()

plt.show()

# %% [markdown]
# En este ejemplo, utilizamos el algoritmo de clustering K-means para agrupar las flores en dos segmentos basados en las características de longitud y ancho de pétalos. La gráfica muestra los datos de entrada coloreados según su cluster asignado, y los centroides de los clusters se representan con una '`x`'.
#
# Estos son solo algunos ejemplos de los diferentes tipos de problemas en Machine Learning. Es importante tener en cuenta que hay otros tipos de problemas, como detección de anomalías, recomendación, procesamiento de lenguaje natural, entre otros, cada uno con sus propias técnicas y enfoques específicos.

# %% [markdown]
# | **Inicio** | **atrás 2** |
# |----------- |-------------- |
# | [🏠](../../../README.md) | [⏪](./2.INTRODUCCION_AL_ALGEBRA_LINEAL.ipynb)|
